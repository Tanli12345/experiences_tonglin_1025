# %%
# MMoE_online_estimate_nrmse.py
import os
import time
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_absolute_error
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Dense, Concatenate, Multiply, Lambda,
                                     Dropout, BatchNormalization, GlobalAveragePooling1D,
                                     Reshape, Conv1D, MaxPooling1D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import BinaryCrossentropy, SparseCategoricalCrossentropy, MeanSquaredError
from tensorflow.keras.metrics import BinaryAccuracy, SparseCategoricalAccuracy
import matplotlib.font_manager as fm

# ---------- 中文字体 ----------
def set_chinese_font():
    try:
        font_paths = ['/usr/share/fonts/truetype/wqy/wqy-microhei.ttc',
                      'C:/Windows/Fonts/simhei.ttf',
                      '/System/Library/Fonts/PingFang.ttc']
        for font_path in font_paths:
            if os.path.exists(font_path):
                fm.fontManager.addfont(font_path)
                plt.rcParams['font.family'] = fm.FontProperties(fname=font_path).get_name()
                plt.rcParams['axes.unicode_minus'] = False
                print(f"✅ 成功设置中文字体: {plt.rcParams['font.family']}")
                return True
        plt.rcParams['font.family'] = ['SimHei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("⚠️ 未找到指定字体，使用默认兼容字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False
set_chinese_font()

# ---------- 加载数据集 ----------
def load_dataset(npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"):
    data = np.load(npz_path, allow_pickle=True)
    signals = data["signals"]
    labels = data["labels"].astype(np.int32)
    jnr_values = data["jnr_values"].astype(np.float32)
    fs = float(data["fs"])
    L = int(data["L"])
    noise_power_db = float(data["noise_power_db"])
    type2label = data["type_to_label"].item()

    interference_type_names = {
        "satellite_signal": "Satellite_Signal",
        "single_tone": "Single_Tone",
        "comb_spectra": "Comb_Spectra",
        "sweeping": "Sweeping-LFM",
        "pulse": "Pulse",
        "frequency_hopping": "Frequency_Hopping",
        "noise_fm": "Noise_FM",
        "noise_am": "Noise_AM",
        "random_combination": "Random_Combination"
    }
    label2name = {i: interference_type_names[k] for k, i in type2label.items()}
    return {
        "signals": signals,
        "labels": labels,
        "jnr_values": jnr_values,
        "fs": fs,
        "L": L,
        "noise_power_db": noise_power_db,
        "type2label": type2label,
        "label2name": label2name
    }

# ---------- 在线估算标签 ----------
def estimate_start_end(signal, fs, threshold_factor=2.0):
    power = signal ** 2
    avg_pow = np.mean(power)
    thresh = threshold_factor * avg_pow
    above = power > thresh
    diff = np.diff(above.astype(int))
    starts = np.where(diff == 1)[0]
    ends = np.where(diff == -1)[0]
    if len(starts) == 0 or len(ends) == 0:
        return 0.0, 0.0
    return float(starts[0] / fs * 1e3), float(ends[-1] / fs * 1e3)

def estimate_jnr(signal, noise_power_db):
    total_power = 10 * np.log10(np.mean(signal ** 2) + 1e-12)
    return float(total_power - noise_power_db)

# ---------- 数据预处理 ----------
def preprocess_data(dataset, aug_ratio=0.1):
    signals = dataset["signals"]
    labels = dataset["labels"]
    jnr_values = dataset["jnr_values"]
    L = dataset["L"]
    noise_power_db = dataset["noise_power_db"]

    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() for s in signals])

    no_key = "satellite_signal"
    det_labels = (labels != dataset["type2label"][no_key]).astype(np.float32)

    # 在线估算回归标签
    param_labels = []
    for sig in signals:
        st, et = estimate_start_end(sig, dataset["fs"])
        jnr = estimate_jnr(sig, noise_power_db)
        param_labels.append([st, et, jnr])
    param_labels = np.array(param_labels, dtype=np.float32)

    # 丢弃含 NaN/Inf 的样本
    mask = ~(
        np.any(np.isnan(signals), axis=1) |
        np.any(np.isinf(signals), axis=1) |
        np.isnan(det_labels) | np.isinf(det_labels) |
        np.isnan(labels) | np.isinf(labels) |
        np.any(np.isnan(param_labels), axis=1) | np.any(np.isinf(param_labels), axis=1)
    )
    print(f"🧹 丢弃 {np.sum(~mask)} / {len(mask)} 条含 NaN/Inf 的样本")
    signals, det_labels, labels, param_labels, jnr_values = \
        signals[mask], det_labels[mask], labels[mask], param_labels[mask], jnr_values[mask]

    X_train, X_tmp, y_det_train, y_det_tmp, y_type_train, y_type_tmp, y_param_train, y_param_tmp, jnr_train, jnr_tmp = train_test_split(
        signals, det_labels, labels, param_labels, jnr_values,
        test_size=0.3, random_state=42, stratify=labels
    )
    X_val, X_test, y_det_val, y_det_test, y_type_val, y_type_test, y_param_val, y_param_test, jnr_val, jnr_test = train_test_split(
        X_tmp, y_det_tmp, y_type_tmp, y_param_tmp, jnr_tmp,
        test_size=2/3, random_state=42, stratify=y_type_tmp
    )

    return {
        "X_train": X_train, "X_val": X_val, "X_test": X_test,
        "y_det_train": y_det_train, "y_det_val": y_det_val, "y_det_test": y_det_test,
        "y_type_train": y_type_train, "y_type_val": y_type_val, "y_type_test": y_type_test,
        "y_param_train": y_param_train, "y_param_val": y_param_val, "y_param_test": y_param_test,
        "jnr_values_train": jnr_train, "jnr_values_val": jnr_val, "jnr_values_test": jnr_test,
        "type2label": dataset["type2label"], "label2name": dataset["label2name"],
        "L": L, "fs": dataset["fs"], "noise_power_db": noise_power_db
    }

# ---------- MMoE 模型 ----------
def build_mmoe_model(input_shape, num_classes, num_experts=4, expert_dim=64, gate_dim=32):
    inputs = Input(shape=input_shape)
    x = Reshape((input_shape[0], 1))(inputs)
    
    # 共享主干
    x = Conv1D(64, 7, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    x = Conv1D(128, 5, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    x = Conv1D(256, 3, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    shared_features = GlobalAveragePooling1D()(x)

    # 专家网络
    experts = []
    for i in range(num_experts):
        expert = Dense(expert_dim, activation='relu', name=f'expert_{i}')(shared_features)
        expert = Dense(expert_dim, activation='relu', name=f'expert_{i}_2')(expert)
        experts.append(expert)
    experts_stack = tf.stack(experts, axis=1)

    # 门控网络
    def build_gate(input_tensor, num_experts, name):
        gate = Dense(gate_dim, activation='relu')(input_tensor)
        gate = Dense(num_experts, activation='softmax', name=name)(gate)
        return gate

    gate_det = build_gate(shared_features, num_experts, name='gate_detection')
    gate_cls = build_gate(shared_features, num_experts, name='gate_classification')
    gate_reg = build_gate(shared_features, num_experts, name='gate_regression')

    def gate_apply(gate, experts_stack):
        return tf.reduce_sum(tf.expand_dims(gate, axis=-1) * experts_stack, axis=1)

    det_feat = gate_apply(gate_det, experts_stack)
    cls_feat = gate_apply(gate_cls, experts_stack)
    reg_feat = gate_apply(gate_reg, experts_stack)

    # 任务输出
    det_out = Dense(1, activation='sigmoid', name='detection_output')(det_feat)
    cls_out = Dense(num_classes, activation='softmax', name='classification_output')(cls_feat)
    reg_feat = Dense(3, activation='linear')(reg_feat)
    reg_out = Lambda(lambda z: tf.clip_by_value(z, -1e3, 1e3), name='regression_output')(reg_feat)

    model = Model(inputs, [det_out, cls_out, reg_out])
    model.compile(
        optimizer=Adam(1e-3),
        loss={
            'detection_output': BinaryCrossentropy(),
            'classification_output': SparseCategoricalCrossentropy(),
            'regression_output': MeanSquaredError()
        },
        loss_weights={
            'detection_output': 0.8,
            'classification_output': 2.0,
            'regression_output': 0.3
        },
        metrics={
            'detection_output': BinaryAccuracy(),
            'classification_output': SparseCategoricalAccuracy(),
            'regression_output': 'mae'
        }
    )
    return model

# ---------- 单任务基准 ----------
def build_single_task_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Reshape((input_shape[0], 1))(inputs)
    x = Conv1D(64, 7, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    x = Conv1D(128, 5, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    x = Conv1D(256, 3, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    shared_features = GlobalAveragePooling1D()(x)

    det_out = Dense(1, activation='sigmoid', name='detection_output')(shared_features)
    cls_out = Dense(num_classes, activation='softmax', name='classification_output')(shared_features)
    reg_feat = Dense(3, activation='linear')(shared_features)
    reg_out = Lambda(lambda z: tf.clip_by_value(z, -1e3, 1e3), name='regression_output')(reg_feat)

    model = Model(inputs, [det_out, cls_out, reg_out])
    model.compile(
        optimizer=Adam(1e-3),
        loss={
            'detection_output': BinaryCrossentropy(),
            'classification_output': SparseCategoricalCrossentropy(),
            'regression_output': MeanSquaredError()
        },
        metrics={
            'detection_output': BinaryAccuracy(),
            'classification_output': SparseCategoricalAccuracy(),
            'regression_output': 'mae'
        }
    )
    return model

# ---------- 数据增强 ----------
@tf.function
def aug_fn(x):
    x = tf.cast(x, tf.float32)
    if tf.random.uniform([]) > 0.2:
        snr = tf.random.uniform([], 5., 25.)
        noise = tf.random.normal(tf.shape(x), dtype=tf.float32) * tf.math.reduce_std(x) * tf.cast(10.0 ** (-snr / 20.0), tf.float32)
        x = x + noise
    if tf.random.uniform([]) > 0.3:
        shift = tf.random.uniform([], -100, 100, dtype=tf.int32)
        x = tf.roll(x, shift=shift, axis=0)
    if tf.random.uniform([]) > 0.3:
        scale = tf.random.uniform([], 0.7, 1.3)
        x = x * scale
    if tf.random.uniform([]) > 0.7:
        freq_shift = tf.random.uniform([], -0.1, 0.1)
        n = tf.cast(tf.shape(x)[0], tf.float32)
        x = x * tf.cos(2 * np.pi * freq_shift * tf.range(n, dtype=tf.float32))
    return x

# ---------- NRMSE ----------
def nrmse(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2, axis=0))
    y_range = np.max(y_true, axis=0) - np.min(y_true, axis=0)
    return rmse / (y_range + 1e-8)

# ---------- 评估 + 打印 + NRMSE ----------
def evaluate_and_print(models, data, batch=128, model_name="MMoE"):
    os.makedirs("reports", exist_ok=True)
    ds_test = tf.data.Dataset.from_tensor_slices((
        data['X_test'],
        {
            'detection_output': data['y_det_test'],
            'classification_output': data['y_type_test'],
            'regression_output': data['y_param_test']
        }
    )).batch(batch).prefetch(tf.data.AUTOTUNE)

    y_det_true, y_type_true, y_param_true = [], [], []
    y_det_pred, y_type_pred, y_param_pred = [], [], []

    for x, y in ds_test:
        y_det_true.append(y['detection_output'].numpy())
        y_type_true.append(y['classification_output'].numpy())
        y_param_true.append(y['regression_output'].numpy())

        preds = [m(x, training=False) for m in models]
        det_avg = np.mean([p[0].numpy() for p in preds], axis=0)
        cls_avg = np.mean([p[1].numpy() for p in preds], axis=0)
        reg_avg = np.mean([p[2].numpy() for p in preds], axis=0)

        y_det_pred.append(det_avg)
        y_type_pred.append(cls_avg)
        y_param_pred.append(reg_avg)

    y_det_true = np.concatenate(y_det_true, axis=0)
    y_type_true = np.concatenate(y_type_true, axis=0)
    y_param_true = np.concatenate(y_param_true, axis=0)
    y_det_pred = np.concatenate(y_det_pred, axis=0)
    y_type_pred = np.concatenate(y_type_pred, axis=0)
    y_param_pred = np.concatenate(y_param_pred, axis=0)

    # 前 5 条
    print("\n" + "="*80)
    print(f"📥 {model_name} 输入信号（前 5 条）")
    print("="*80)
    for i in range(5):
        print(f"样本 {i}: {y_param_true[i]} ...")

    print("\n" + "="*80)
    print(f"📤 {model_name} 真实 vs 预测（前 5 条）")
    print("="*80)
    for i in range(5):
        print(f"样本 {i}:")
        print(f"  det_true: {y_det_true[i]:.4f}  |  det_pred: {y_det_pred[i,0]:.4f}")
        print(f"  cls_true: {y_type_true[i]}     |  cls_pred: {np.argmax(y_type_pred[i])}")
        print(f"  reg_true: {y_param_true[i]}  |  reg_pred: {y_param_pred[i]}")

    # NRMSE
    reg_nrmse = nrmse(y_param_true, y_param_pred)
    print("\n" + "="*80)
    print(f"📈 {model_name} NRMSE 报告")
    print("="*80)
    print("参数维度: [start_time, end_time, jnr_db]")
    for i, name in enumerate(["start_time", "end_time", "jnr_db"]):
        print(f"{name}: {reg_nrmse[i]:.4f}")
    print(f"平均 NRMSE: {np.mean(reg_nrmse):.4f}")

    # 保存
    with open(f"reports/{model_name}_nrmse_report.txt", "w", encoding="utf-8") as f:
        f.write("参数维度: [start_time, end_time, jnr_db]\n")
        for i, name in enumerate(["start_time", "end_time", "jnr_db"]):
            f.write(f"{name}: {reg_nrmse[i]:.4f}\n")
        f.write(f"平均 NRMSE: {np.mean(reg_nrmse):.4f}\n")
    print(f"✅ {model_name} NRMSE 报告已写入 reports/{model_name}_nrmse_report.txt")
    return reg_nrmse

# ---------- 训练单个模型 ----------
def train_single_model(data, model_idx, model_builder, epochs=120, batch=128):
    input_shape, num_classes = (data["L"],), len(data["type2label"])
    model = model_builder(input_shape, num_classes)

    unique_labels = np.unique(data['y_type_train'])
    cls_weights = compute_class_weight('balanced', classes=unique_labels, y=data['y_type_train'])
    cls_weight_dict = {lab: float(w) for lab, w in zip(unique_labels, cls_weights)}
    sample_weights = np.array([cls_weight_dict[lab] for lab in data['y_type_train']])

    def filter_nan(*args):
        x, y = args[0], args[1]
        ok = (tf.reduce_all(tf.math.is_finite(x)) &
              tf.math.is_finite(y['detection_output']) &
              tf.reduce_all(tf.math.is_finite(y['regression_output'])))
        if len(args) == 3:
            ok &= tf.math.is_finite(args[2])
        return ok

    ds_train = tf.data.Dataset.from_tensor_slices((
        data['X_train'],
        {
            'detection_output': data['y_det_train'],
            'classification_output': data['y_type_train'],
            'regression_output': data['y_param_train']
        },
        sample_weights
    ))
    ds_train = ds_train.filter(filter_nan)
    ds_train = ds_train.map(lambda x, y, w: (aug_fn(x), y, w), num_parallel_calls=tf.data.AUTOTUNE)
    ds_train = ds_train.shuffle(10000).batch(batch).prefetch(tf.data.AUTOTUNE)

    ds_val = tf.data.Dataset.from_tensor_slices((
        data['X_val'],
        {
            'detection_output': data['y_det_val'],
            'classification_output': data['y_type_val'],
            'regression_output': data['y_param_val']
        }
    ))
    ds_val = ds_val.filter(filter_nan)
    ds_val = ds_val.batch(batch).prefetch(tf.data.AUTOTUNE)

    os.makedirs("models", exist_ok=True)
    ckpt = f"models/{model_builder.__name__}_{model_idx}.keras"
    callbacks = [
        EarlyStopping(monitor='val_classification_output_sparse_categorical_accuracy', patience=20,
                      restore_best_weights=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_classification_output_sparse_categorical_accuracy', factor=0.5,
                          patience=10, min_lr=1e-5, mode='max', verbose=1),
        ModelCheckpoint(ckpt, save_best_only=True, save_weights_only=False,
                        monitor='val_classification_output_sparse_categorical_accuracy', mode='max', verbose=1)
    ]

    print(f"\n🔥 训练第 {model_idx + 1} 个模型（{model_builder.__name__}）...")
    start_time = time.time()
    history = model.fit(ds_train, validation_data=ds_val, epochs=epochs, callbacks=callbacks, verbose=1)
    end_time = time.time()
    training_time = end_time - start_time
    print(f"✅ 模型 {model_idx + 1} 训练完成，耗时 {training_time:.2f} 秒")
    return model, training_time

# ---------- 主函数 ----------
def main():
    for d in ["models", "visualizations", "reports"]:
        os.makedirs(d, exist_ok=True)

    print("="*80)
    print("🚀 开始训练 MMoE 多任务模型（在线估算标签 + NRMSE）")
    print("="*80)

    dataset = load_dataset()
    data = preprocess_data(dataset, aug_ratio=0.1)

    input_shape, num_classes = (data["L"],), len(data["type2label"])
    n_models = 3
    epochs = 120
    batch_size = 128

    # MMoE
    print("\n" + "="*50)
    print("🔹 训练 MMoE 多任务模型")
    print("="*50)
    mmoe_models, mmoe_times = [], []
    for i in range(n_models):
        model, t = train_single_model(data, i, build_mmoe_model, epochs=epochs, batch=batch_size)
        mmoe_models.append(model)
        mmoe_times.append(t)
        nrmse_mmoe = evaluate_and_print([model], data, batch=batch_size, model_name="MMoE")

    # Single-Task
    print("\n" + "="*50)
    print("🔹 训练 单任务 基准模型")
    print("="*50)
    single_models, single_times = [], []
    for i in range(n_models):
        model, t = train_single_model(data, i, build_single_task_model, epochs=epochs, batch=batch_size)
        single_models.append(model)
        single_times.append(t)
        nrmse_single = evaluate_and_print([model], data, batch=batch_size, model_name="SingleTask")

    # 保存结果
    results = {
        "mmoe": {"times": mmoe_times, "nrmse": nrmse_mmoe.tolist()},
        "single": {"times": single_times, "nrmse": nrmse_single.tolist()},
        "config": {
            "input_shape": input_shape,
            "num_classes": num_classes,
            "n_models": n_models,
            "epochs": epochs,
            "batch_size": batch_size
        }
    }
    with open("reports/training_results_nrmse.json", "w") as f:
        json.dump(results, f, indent=4)

    print("\n" + "="*50)
    print("📈 训练时间统计")
    print("="*50)
    print("MMoE 模型:")
    for i, t in enumerate(mmoe_times):
        print(f"  模型 {i+1}: {t:.2f} 秒")
    print("\n单任务 模型:")
    for i, t in enumerate(single_times):
        print(f"  模型 {i+1}: {t:.2f} 秒")

if __name__ == "__main__":
    main()
# Out:
# 2025-10-20 10:32:37.412880: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-20 10:32:37.451800: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-20 10:32:37.977705: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# ================================================================================
# 🚀 开始训练 MMoE 多任务模型（在线估算标签 + NRMSE）
# ================================================================================
# 🧹 丢弃 0 / 81000 条含 NaN/Inf 的样本
#
# ==================================================
# 🔹 训练 MMoE 多任务模型
# ==================================================
# 2025-10-20 10:33:00.319984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46590 MB memory:  -> device: 0, name: NVIDIA vGPU-48GB, pci bus id: 0000:c8:00.0, compute capability: 8.9
# 🔥 训练第 1 个模型（build_mmoe_model）...
# Epoch 1/120
# 2025-10-20 10:33:01.952387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [56700]
# 	 [[{{node Placeholder/_2}}]]
# 2025-10-20 10:33:01.952639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [56700]
# 	 [[{{node Placeholder/_2}}]]
# 2025-10-20 10:33:04.993106: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-10-20 10:33:05.194948: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-10-20 10:33:05.234886: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7fddb403d330 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-20 10:33:05.234902: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA vGPU-48GB, Compute Capability 8.9
# 2025-10-20 10:33:05.238772: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-20 10:33:05.346666: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#     443/Unknown - 14s 17ms/step - loss: 3.0735 - detection_output_loss: 0.2226 - classification_output_loss: 1.2791 - regression_output_loss: 1.1239 - detection_output_binary_accuracy: 0.8874 - classification_output_sparse_categorical_accuracy: 0.5068 - regression_output_mae: 0.4117
# 2025-10-20 10:33:15.768557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype int32 and shape [8100]
# 	 [[{{node Placeholder/_1}}]]
# Epoch 1: val_classification_output_sparse_categorical_accuracy improved from -inf to 0.43815, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 15s 20ms/step - loss: 3.0735 - detection_output_loss: 0.2226 - classification_output_loss: 1.2791 - regression_output_loss: 1.1239 - detection_output_binary_accuracy: 0.8874 - classification_output_sparse_categorical_accuracy: 0.5068 - regression_output_mae: 0.4117 - val_loss: 3.2715 - val_detection_output_loss: 0.2887 - val_classification_output_loss: 1.4836 - val_regression_output_loss: 0.2443 - val_detection_output_binary_accuracy: 0.8889 - val_classification_output_sparse_categorical_accuracy: 0.4381 - val_regression_output_mae: 0.3166 - lr: 0.0010
# Epoch 2/120
# 442/443 [============================>.] - ETA: 0s - loss: 2.1338 - detection_output_loss: 0.1726 - classification_output_loss: 0.9829 - regression_output_loss: 0.0997 - detection_output_binary_accuracy: 0.9065 - classification_output_sparse_categorical_accuracy: 0.6110 - regression_output_mae: 0.1854
# Epoch 2: val_classification_output_sparse_categorical_accuracy improved from 0.43815 to 0.62333, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 2.1325 - detection_output_loss: 0.1725 - classification_output_loss: 0.9823 - regression_output_loss: 0.0997 - detection_output_binary_accuracy: 0.9067 - classification_output_sparse_categorical_accuracy: 0.6111 - regression_output_mae: 0.1854 - val_loss: 1.8988 - val_detection_output_loss: 0.1756 - val_classification_output_loss: 0.8674 - val_regression_output_loss: 0.0787 - val_detection_output_binary_accuracy: 0.8972 - val_classification_output_sparse_categorical_accuracy: 0.6233 - val_regression_output_mae: 0.1813 - lr: 0.0010
# Epoch 3/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.9617 - detection_output_loss: 0.1606 - classification_output_loss: 0.9086 - regression_output_loss: 0.0533 - detection_output_binary_accuracy: 0.9149 - classification_output_sparse_categorical_accuracy: 0.6360 - regression_output_mae: 0.1417
# Epoch 3: val_classification_output_sparse_categorical_accuracy improved from 0.62333 to 0.68519, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 1.9618 - detection_output_loss: 0.1607 - classification_output_loss: 0.9086 - regression_output_loss: 0.0533 - detection_output_binary_accuracy: 0.9148 - classification_output_sparse_categorical_accuracy: 0.6361 - regression_output_mae: 0.1416 - val_loss: 1.6173 - val_detection_output_loss: 0.1298 - val_classification_output_loss: 0.7478 - val_regression_output_loss: 0.0591 - val_detection_output_binary_accuracy: 0.9411 - val_classification_output_sparse_categorical_accuracy: 0.6852 - val_regression_output_mae: 0.1457 - lr: 0.0010
# Epoch 4/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.8461 - detection_output_loss: 0.1538 - classification_output_loss: 0.8563 - regression_output_loss: 0.0350 - detection_output_binary_accuracy: 0.9168 - classification_output_sparse_categorical_accuracy: 0.6566 - regression_output_mae: 0.1159
# Epoch 4: val_classification_output_sparse_categorical_accuracy improved from 0.68519 to 0.68827, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 17ms/step - loss: 1.8453 - detection_output_loss: 0.1538 - classification_output_loss: 0.8559 - regression_output_loss: 0.0350 - detection_output_binary_accuracy: 0.9167 - classification_output_sparse_categorical_accuracy: 0.6567 - regression_output_mae: 0.1159 - val_loss: 1.6704 - val_detection_output_loss: 0.1400 - val_classification_output_loss: 0.7743 - val_regression_output_loss: 0.0324 - val_detection_output_binary_accuracy: 0.9195 - val_classification_output_sparse_categorical_accuracy: 0.6883 - val_regression_output_mae: 0.1144 - lr: 0.0010
# Epoch 5/120
# 443/443 [==============================] - ETA: 0s - loss: 1.7740 - detection_output_loss: 0.1493 - classification_output_loss: 0.8224 - regression_output_loss: 0.0326 - detection_output_binary_accuracy: 0.9199 - classification_output_sparse_categorical_accuracy: 0.6690 - regression_output_mae: 0.1093
# Epoch 5: val_classification_output_sparse_categorical_accuracy improved from 0.68827 to 0.71160, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 17ms/step - loss: 1.7740 - detection_output_loss: 0.1493 - classification_output_loss: 0.8224 - regression_output_loss: 0.0326 - detection_output_binary_accuracy: 0.9199 - classification_output_sparse_categorical_accuracy: 0.6690 - regression_output_mae: 0.1093 - val_loss: 1.5512 - val_detection_output_loss: 0.1479 - val_classification_output_loss: 0.7112 - val_regression_output_loss: 0.0350 - val_detection_output_binary_accuracy: 0.9048 - val_classification_output_sparse_categorical_accuracy: 0.7116 - val_regression_output_mae: 0.1186 - lr: 0.0010
# Epoch 6/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.7235 - detection_output_loss: 0.1479 - classification_output_loss: 0.7987 - regression_output_loss: 0.0261 - detection_output_binary_accuracy: 0.9208 - classification_output_sparse_categorical_accuracy: 0.6797 - regression_output_mae: 0.0979
# Epoch 6: val_classification_output_sparse_categorical_accuracy improved from 0.71160 to 0.72309, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 1.7236 - detection_output_loss: 0.1481 - classification_output_loss: 0.7986 - regression_output_loss: 0.0261 - detection_output_binary_accuracy: 0.9207 - classification_output_sparse_categorical_accuracy: 0.6797 - regression_output_mae: 0.0979 - val_loss: 1.4362 - val_detection_output_loss: 0.1208 - val_classification_output_loss: 0.6657 - val_regression_output_loss: 0.0272 - val_detection_output_binary_accuracy: 0.9390 - val_classification_output_sparse_categorical_accuracy: 0.7231 - val_regression_output_mae: 0.0998 - lr: 0.0010
# Epoch 7/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.6788 - detection_output_loss: 0.1457 - classification_output_loss: 0.7778 - regression_output_loss: 0.0220 - detection_output_binary_accuracy: 0.9219 - classification_output_sparse_categorical_accuracy: 0.6891 - regression_output_mae: 0.0884
# Epoch 7: val_classification_output_sparse_categorical_accuracy improved from 0.72309 to 0.72778, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 9s 18ms/step - loss: 1.6783 - detection_output_loss: 0.1457 - classification_output_loss: 0.7776 - regression_output_loss: 0.0220 - detection_output_binary_accuracy: 0.9219 - classification_output_sparse_categorical_accuracy: 0.6893 - regression_output_mae: 0.0883 - val_loss: 1.4101 - val_detection_output_loss: 0.1263 - val_classification_output_loss: 0.6500 - val_regression_output_loss: 0.0304 - val_detection_output_binary_accuracy: 0.9390 - val_classification_output_sparse_categorical_accuracy: 0.7278 - val_regression_output_mae: 0.1034 - lr: 0.0010
# Epoch 8/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.6296 - detection_output_loss: 0.1429 - classification_output_loss: 0.7548 - regression_output_loss: 0.0191 - detection_output_binary_accuracy: 0.9239 - classification_output_sparse_categorical_accuracy: 0.6961 - regression_output_mae: 0.0814
# Epoch 8: val_classification_output_sparse_categorical_accuracy did not improve from 0.72778
# 443/443 [==============================] - 8s 17ms/step - loss: 1.6305 - detection_output_loss: 0.1430 - classification_output_loss: 0.7552 - regression_output_loss: 0.0191 - detection_output_binary_accuracy: 0.9239 - classification_output_sparse_categorical_accuracy: 0.6960 - regression_output_mae: 0.0814 - val_loss: 1.9516 - val_detection_output_loss: 0.2573 - val_classification_output_loss: 0.8704 - val_regression_output_loss: 0.0162 - val_detection_output_binary_accuracy: 0.9043 - val_classification_output_sparse_categorical_accuracy: 0.6794 - val_regression_output_mae: 0.0798 - lr: 0.0010
# Epoch 9/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.6055 - detection_output_loss: 0.1406 - classification_output_loss: 0.7439 - regression_output_loss: 0.0175 - detection_output_binary_accuracy: 0.9247 - classification_output_sparse_categorical_accuracy: 0.7018 - regression_output_mae: 0.0775
# Epoch 9: val_classification_output_sparse_categorical_accuracy did not improve from 0.72778
# 443/443 [==============================] - 8s 17ms/step - loss: 1.6050 - detection_output_loss: 0.1406 - classification_output_loss: 0.7436 - regression_output_loss: 0.0175 - detection_output_binary_accuracy: 0.9247 - classification_output_sparse_categorical_accuracy: 0.7018 - regression_output_mae: 0.0775 - val_loss: 1.7717 - val_detection_output_loss: 0.2551 - val_classification_output_loss: 0.7819 - val_regression_output_loss: 0.0125 - val_detection_output_binary_accuracy: 0.8996 - val_classification_output_sparse_categorical_accuracy: 0.6790 - val_regression_output_mae: 0.0692 - lr: 0.0010
# Epoch 10/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.5825 - detection_output_loss: 0.1391 - classification_output_loss: 0.7332 - regression_output_loss: 0.0163 - detection_output_binary_accuracy: 0.9266 - classification_output_sparse_categorical_accuracy: 0.7061 - regression_output_mae: 0.0739
# Epoch 10: val_classification_output_sparse_categorical_accuracy improved from 0.72778 to 0.74494, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 17ms/step - loss: 1.5823 - detection_output_loss: 0.1392 - classification_output_loss: 0.7330 - regression_output_loss: 0.0163 - detection_output_binary_accuracy: 0.9265 - classification_output_sparse_categorical_accuracy: 0.7062 - regression_output_mae: 0.0739 - val_loss: 1.3692 - val_detection_output_loss: 0.1254 - val_classification_output_loss: 0.6313 - val_regression_output_loss: 0.0208 - val_detection_output_binary_accuracy: 0.9323 - val_classification_output_sparse_categorical_accuracy: 0.7449 - val_regression_output_mae: 0.0797 - lr: 0.0010
# Epoch 11/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.5536 - detection_output_loss: 0.1362 - classification_output_loss: 0.7201 - regression_output_loss: 0.0152 - detection_output_binary_accuracy: 0.9281 - classification_output_sparse_categorical_accuracy: 0.7127 - regression_output_mae: 0.0710
# Epoch 11: val_classification_output_sparse_categorical_accuracy improved from 0.74494 to 0.74827, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 1.5531 - detection_output_loss: 0.1363 - classification_output_loss: 0.7198 - regression_output_loss: 0.0152 - detection_output_binary_accuracy: 0.9280 - classification_output_sparse_categorical_accuracy: 0.7126 - regression_output_mae: 0.0710 - val_loss: 1.3134 - val_detection_output_loss: 0.1237 - val_classification_output_loss: 0.6050 - val_regression_output_loss: 0.0151 - val_detection_output_binary_accuracy: 0.9327 - val_classification_output_sparse_categorical_accuracy: 0.7483 - val_regression_output_mae: 0.0686 - lr: 0.0010
# Epoch 12/120
# 443/443 [==============================] - ETA: 0s - loss: 1.5388 - detection_output_loss: 0.1367 - classification_output_loss: 0.7125 - regression_output_loss: 0.0150 - detection_output_binary_accuracy: 0.9275 - classification_output_sparse_categorical_accuracy: 0.7163 - regression_output_mae: 0.0696
# Epoch 12: val_classification_output_sparse_categorical_accuracy did not improve from 0.74827
# 443/443 [==============================] - 8s 17ms/step - loss: 1.5388 - detection_output_loss: 0.1367 - classification_output_loss: 0.7125 - regression_output_loss: 0.0150 - detection_output_binary_accuracy: 0.9275 - classification_output_sparse_categorical_accuracy: 0.7163 - regression_output_mae: 0.0696 - val_loss: 1.3819 - val_detection_output_loss: 0.1185 - val_classification_output_loss: 0.6422 - val_regression_output_loss: 0.0089 - val_detection_output_binary_accuracy: 0.9364 - val_classification_output_sparse_categorical_accuracy: 0.7358 - val_regression_output_mae: 0.0550 - lr: 0.0010
# Epoch 13/120
# 443/443 [==============================] - ETA: 0s - loss: 1.5098 - detection_output_loss: 0.1342 - classification_output_loss: 0.6992 - regression_output_loss: 0.0135 - detection_output_binary_accuracy: 0.9295 - classification_output_sparse_categorical_accuracy: 0.7194 - regression_output_mae: 0.0655
# Epoch 13: val_classification_output_sparse_categorical_accuracy did not improve from 0.74827
# 443/443 [==============================] - 8s 17ms/step - loss: 1.5098 - detection_output_loss: 0.1342 - classification_output_loss: 0.6992 - regression_output_loss: 0.0135 - detection_output_binary_accuracy: 0.9295 - classification_output_sparse_categorical_accuracy: 0.7194 - regression_output_mae: 0.0655 - val_loss: 1.4828 - val_detection_output_loss: 0.1666 - val_classification_output_loss: 0.6718 - val_regression_output_loss: 0.0196 - val_detection_output_binary_accuracy: 0.9130 - val_classification_output_sparse_categorical_accuracy: 0.7257 - val_regression_output_mae: 0.0800 - lr: 0.0010
# Epoch 14/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.4963 - detection_output_loss: 0.1329 - classification_output_loss: 0.6930 - regression_output_loss: 0.0132 - detection_output_binary_accuracy: 0.9314 - classification_output_sparse_categorical_accuracy: 0.7202 - regression_output_mae: 0.0641
# Epoch 14: val_classification_output_sparse_categorical_accuracy did not improve from 0.74827
# 443/443 [==============================] - 8s 17ms/step - loss: 1.4972 - detection_output_loss: 0.1331 - classification_output_loss: 0.6934 - regression_output_loss: 0.0132 - detection_output_binary_accuracy: 0.9312 - classification_output_sparse_categorical_accuracy: 0.7201 - regression_output_mae: 0.0641 - val_loss: 1.3876 - val_detection_output_loss: 0.1248 - val_classification_output_loss: 0.6426 - val_regression_output_loss: 0.0087 - val_detection_output_binary_accuracy: 0.9337 - val_classification_output_sparse_categorical_accuracy: 0.7459 - val_regression_output_mae: 0.0523 - lr: 0.0010
# Epoch 15/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.4800 - detection_output_loss: 0.1329 - classification_output_loss: 0.6849 - regression_output_loss: 0.0126 - detection_output_binary_accuracy: 0.9309 - classification_output_sparse_categorical_accuracy: 0.7256 - regression_output_mae: 0.0612
# Epoch 15: val_classification_output_sparse_categorical_accuracy improved from 0.74827 to 0.75753, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 1.4804 - detection_output_loss: 0.1330 - classification_output_loss: 0.6851 - regression_output_loss: 0.0126 - detection_output_binary_accuracy: 0.9309 - classification_output_sparse_categorical_accuracy: 0.7256 - regression_output_mae: 0.0612 - val_loss: 1.3095 - val_detection_output_loss: 0.1199 - val_classification_output_loss: 0.6036 - val_regression_output_loss: 0.0211 - val_detection_output_binary_accuracy: 0.9380 - val_classification_output_sparse_categorical_accuracy: 0.7575 - val_regression_output_mae: 0.0814 - lr: 0.0010
# Epoch 16/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.4619 - detection_output_loss: 0.1313 - classification_output_loss: 0.6768 - regression_output_loss: 0.0104 - detection_output_binary_accuracy: 0.9309 - classification_output_sparse_categorical_accuracy: 0.7296 - regression_output_mae: 0.0564
# Epoch 16: val_classification_output_sparse_categorical_accuracy improved from 0.75753 to 0.76926, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 1.4629 - detection_output_loss: 0.1314 - classification_output_loss: 0.6773 - regression_output_loss: 0.0104 - detection_output_binary_accuracy: 0.9309 - classification_output_sparse_categorical_accuracy: 0.7295 - regression_output_mae: 0.0564 - val_loss: 1.2137 - val_detection_output_loss: 0.1105 - val_classification_output_loss: 0.5602 - val_regression_output_loss: 0.0159 - val_detection_output_binary_accuracy: 0.9453 - val_classification_output_sparse_categorical_accuracy: 0.7693 - val_regression_output_mae: 0.0659 - lr: 0.0010
# Epoch 17/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.4335 - detection_output_loss: 0.1302 - classification_output_loss: 0.6631 - regression_output_loss: 0.0104 - detection_output_binary_accuracy: 0.9331 - classification_output_sparse_categorical_accuracy: 0.7338 - regression_output_mae: 0.0557
# Epoch 17: val_classification_output_sparse_categorical_accuracy improved from 0.76926 to 0.77469, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 17ms/step - loss: 1.4343 - detection_output_loss: 0.1304 - classification_output_loss: 0.6634 - regression_output_loss: 0.0104 - detection_output_binary_accuracy: 0.9329 - classification_output_sparse_categorical_accuracy: 0.7337 - regression_output_mae: 0.0556 - val_loss: 1.1865 - val_detection_output_loss: 0.1155 - val_classification_output_loss: 0.5457 - val_regression_output_loss: 0.0089 - val_detection_output_binary_accuracy: 0.9410 - val_classification_output_sparse_categorical_accuracy: 0.7747 - val_regression_output_mae: 0.0507 - lr: 0.0010
# Epoch 18/120
# 443/443 [==============================] - ETA: 0s - loss: 1.4238 - detection_output_loss: 0.1298 - classification_output_loss: 0.6584 - regression_output_loss: 0.0103 - detection_output_binary_accuracy: 0.9320 - classification_output_sparse_categorical_accuracy: 0.7345 - regression_output_mae: 0.0549
# Epoch 18: val_classification_output_sparse_categorical_accuracy did not improve from 0.77469
# 443/443 [==============================] - 8s 17ms/step - loss: 1.4238 - detection_output_loss: 0.1298 - classification_output_loss: 0.6584 - regression_output_loss: 0.0103 - detection_output_binary_accuracy: 0.9320 - classification_output_sparse_categorical_accuracy: 0.7345 - regression_output_mae: 0.0549 - val_loss: 1.2830 - val_detection_output_loss: 0.1192 - val_classification_output_loss: 0.5914 - val_regression_output_loss: 0.0161 - val_detection_output_binary_accuracy: 0.9344 - val_classification_output_sparse_categorical_accuracy: 0.7673 - val_regression_output_mae: 0.0664 - lr: 0.0010
# Epoch 19/120
# 443/443 [==============================] - ETA: 0s - loss: 1.4164 - detection_output_loss: 0.1285 - classification_output_loss: 0.6552 - regression_output_loss: 0.0103 - detection_output_binary_accuracy: 0.9322 - classification_output_sparse_categorical_accuracy: 0.7388 - regression_output_mae: 0.0545
# Epoch 19: val_classification_output_sparse_categorical_accuracy improved from 0.77469 to 0.77605, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 17ms/step - loss: 1.4164 - detection_output_loss: 0.1285 - classification_output_loss: 0.6552 - regression_output_loss: 0.0103 - detection_output_binary_accuracy: 0.9322 - classification_output_sparse_categorical_accuracy: 0.7388 - regression_output_mae: 0.0545 - val_loss: 1.2200 - val_detection_output_loss: 0.1155 - val_classification_output_loss: 0.5617 - val_regression_output_loss: 0.0142 - val_detection_output_binary_accuracy: 0.9430 - val_classification_output_sparse_categorical_accuracy: 0.7760 - val_regression_output_mae: 0.0670 - lr: 0.0010
# Epoch 20/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.4081 - detection_output_loss: 0.1268 - classification_output_loss: 0.6519 - regression_output_loss: 0.0095 - detection_output_binary_accuracy: 0.9330 - classification_output_sparse_categorical_accuracy: 0.7404 - regression_output_mae: 0.0515
# Epoch 20: val_classification_output_sparse_categorical_accuracy improved from 0.77605 to 0.78025, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 17ms/step - loss: 1.4080 - detection_output_loss: 0.1269 - classification_output_loss: 0.6518 - regression_output_loss: 0.0095 - detection_output_binary_accuracy: 0.9329 - classification_output_sparse_categorical_accuracy: 0.7404 - regression_output_mae: 0.0515 - val_loss: 1.1955 - val_detection_output_loss: 0.1259 - val_classification_output_loss: 0.5459 - val_regression_output_loss: 0.0101 - val_detection_output_binary_accuracy: 0.9363 - val_classification_output_sparse_categorical_accuracy: 0.7802 - val_regression_output_mae: 0.0525 - lr: 0.0010
# Epoch 21/120
# 443/443 [==============================] - ETA: 0s - loss: 1.3963 - detection_output_loss: 0.1264 - classification_output_loss: 0.6463 - regression_output_loss: 0.0086 - detection_output_binary_accuracy: 0.9345 - classification_output_sparse_categorical_accuracy: 0.7411 - regression_output_mae: 0.0491
# Epoch 21: val_classification_output_sparse_categorical_accuracy improved from 0.78025 to 0.78247, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3963 - detection_output_loss: 0.1264 - classification_output_loss: 0.6463 - regression_output_loss: 0.0086 - detection_output_binary_accuracy: 0.9345 - classification_output_sparse_categorical_accuracy: 0.7411 - regression_output_mae: 0.0491 - val_loss: 1.1638 - val_detection_output_loss: 0.1091 - val_classification_output_loss: 0.5370 - val_regression_output_loss: 0.0086 - val_detection_output_binary_accuracy: 0.9464 - val_classification_output_sparse_categorical_accuracy: 0.7825 - val_regression_output_mae: 0.0508 - lr: 0.0010
# Epoch 22/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.3813 - detection_output_loss: 0.1267 - classification_output_loss: 0.6388 - regression_output_loss: 0.0083 - detection_output_binary_accuracy: 0.9331 - classification_output_sparse_categorical_accuracy: 0.7442 - regression_output_mae: 0.0476
# Epoch 22: val_classification_output_sparse_categorical_accuracy did not improve from 0.78247
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3807 - detection_output_loss: 0.1266 - classification_output_loss: 0.6385 - regression_output_loss: 0.0083 - detection_output_binary_accuracy: 0.9331 - classification_output_sparse_categorical_accuracy: 0.7443 - regression_output_mae: 0.0476 - val_loss: 1.3414 - val_detection_output_loss: 0.1359 - val_classification_output_loss: 0.6154 - val_regression_output_loss: 0.0066 - val_detection_output_binary_accuracy: 0.9256 - val_classification_output_sparse_categorical_accuracy: 0.7660 - val_regression_output_mae: 0.0420 - lr: 0.0010
# Epoch 23/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.3734 - detection_output_loss: 0.1243 - classification_output_loss: 0.6357 - regression_output_loss: 0.0083 - detection_output_binary_accuracy: 0.9362 - classification_output_sparse_categorical_accuracy: 0.7454 - regression_output_mae: 0.0471
# Epoch 23: val_classification_output_sparse_categorical_accuracy did not improve from 0.78247
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3740 - detection_output_loss: 0.1245 - classification_output_loss: 0.6360 - regression_output_loss: 0.0083 - detection_output_binary_accuracy: 0.9361 - classification_output_sparse_categorical_accuracy: 0.7453 - regression_output_mae: 0.0471 - val_loss: 1.1650 - val_detection_output_loss: 0.1134 - val_classification_output_loss: 0.5361 - val_regression_output_loss: 0.0071 - val_detection_output_binary_accuracy: 0.9433 - val_classification_output_sparse_categorical_accuracy: 0.7772 - val_regression_output_mae: 0.0432 - lr: 0.0010
# Epoch 24/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.3618 - detection_output_loss: 0.1259 - classification_output_loss: 0.6294 - regression_output_loss: 0.0079 - detection_output_binary_accuracy: 0.9339 - classification_output_sparse_categorical_accuracy: 0.7469 - regression_output_mae: 0.0459
# Epoch 24: val_classification_output_sparse_categorical_accuracy did not improve from 0.78247
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3620 - detection_output_loss: 0.1259 - classification_output_loss: 0.6294 - regression_output_loss: 0.0079 - detection_output_binary_accuracy: 0.9338 - classification_output_sparse_categorical_accuracy: 0.7468 - regression_output_mae: 0.0459 - val_loss: 1.2360 - val_detection_output_loss: 0.1310 - val_classification_output_loss: 0.5645 - val_regression_output_loss: 0.0077 - val_detection_output_binary_accuracy: 0.9248 - val_classification_output_sparse_categorical_accuracy: 0.7789 - val_regression_output_mae: 0.0466 - lr: 0.0010
# Epoch 25/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.3432 - detection_output_loss: 0.1226 - classification_output_loss: 0.6214 - regression_output_loss: 0.0079 - detection_output_binary_accuracy: 0.9373 - classification_output_sparse_categorical_accuracy: 0.7486 - regression_output_mae: 0.0452
# Epoch 25: val_classification_output_sparse_categorical_accuracy did not improve from 0.78247
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3446 - detection_output_loss: 0.1226 - classification_output_loss: 0.6221 - regression_output_loss: 0.0079 - detection_output_binary_accuracy: 0.9372 - classification_output_sparse_categorical_accuracy: 0.7483 - regression_output_mae: 0.0452 - val_loss: 1.2236 - val_detection_output_loss: 0.1276 - val_classification_output_loss: 0.5597 - val_regression_output_loss: 0.0071 - val_detection_output_binary_accuracy: 0.9349 - val_classification_output_sparse_categorical_accuracy: 0.7784 - val_regression_output_mae: 0.0430 - lr: 0.0010
# Epoch 26/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.3461 - detection_output_loss: 0.1234 - classification_output_loss: 0.6225 - regression_output_loss: 0.0079 - detection_output_binary_accuracy: 0.9369 - classification_output_sparse_categorical_accuracy: 0.7512 - regression_output_mae: 0.0450
# Epoch 26: val_classification_output_sparse_categorical_accuracy did not improve from 0.78247
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3467 - detection_output_loss: 0.1235 - classification_output_loss: 0.6228 - regression_output_loss: 0.0079 - detection_output_binary_accuracy: 0.9369 - classification_output_sparse_categorical_accuracy: 0.7511 - regression_output_mae: 0.0450 - val_loss: 1.3461 - val_detection_output_loss: 0.1259 - val_classification_output_loss: 0.6215 - val_regression_output_loss: 0.0081 - val_detection_output_binary_accuracy: 0.9344 - val_classification_output_sparse_categorical_accuracy: 0.7623 - val_regression_output_mae: 0.0456 - lr: 0.0010
# Epoch 27/120
# 443/443 [==============================] - ETA: 0s - loss: 1.3508 - detection_output_loss: 0.1227 - classification_output_loss: 0.6253 - regression_output_loss: 0.0070 - detection_output_binary_accuracy: 0.9356 - classification_output_sparse_categorical_accuracy: 0.7484 - regression_output_mae: 0.0420
# Epoch 27: val_classification_output_sparse_categorical_accuracy improved from 0.78247 to 0.79519, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3508 - detection_output_loss: 0.1227 - classification_output_loss: 0.6253 - regression_output_loss: 0.0070 - detection_output_binary_accuracy: 0.9356 - classification_output_sparse_categorical_accuracy: 0.7484 - regression_output_mae: 0.0420 - val_loss: 1.1161 - val_detection_output_loss: 0.1045 - val_classification_output_loss: 0.5154 - val_regression_output_loss: 0.0056 - val_detection_output_binary_accuracy: 0.9477 - val_classification_output_sparse_categorical_accuracy: 0.7952 - val_regression_output_mae: 0.0390 - lr: 0.0010
# Epoch 28/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.3395 - detection_output_loss: 0.1236 - classification_output_loss: 0.6194 - regression_output_loss: 0.0063 - detection_output_binary_accuracy: 0.9367 - classification_output_sparse_categorical_accuracy: 0.7515 - regression_output_mae: 0.0405
# Epoch 28: val_classification_output_sparse_categorical_accuracy did not improve from 0.79519
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3391 - detection_output_loss: 0.1235 - classification_output_loss: 0.6192 - regression_output_loss: 0.0063 - detection_output_binary_accuracy: 0.9367 - classification_output_sparse_categorical_accuracy: 0.7517 - regression_output_mae: 0.0405 - val_loss: 1.1865 - val_detection_output_loss: 0.1129 - val_classification_output_loss: 0.5473 - val_regression_output_loss: 0.0057 - val_detection_output_binary_accuracy: 0.9425 - val_classification_output_sparse_categorical_accuracy: 0.7780 - val_regression_output_mae: 0.0406 - lr: 0.0010
# Epoch 29/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.3208 - detection_output_loss: 0.1210 - classification_output_loss: 0.6111 - regression_output_loss: 0.0064 - detection_output_binary_accuracy: 0.9391 - classification_output_sparse_categorical_accuracy: 0.7534 - regression_output_mae: 0.0402
# Epoch 29: val_classification_output_sparse_categorical_accuracy did not improve from 0.79519
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3209 - detection_output_loss: 0.1210 - classification_output_loss: 0.6111 - regression_output_loss: 0.0064 - detection_output_binary_accuracy: 0.9391 - classification_output_sparse_categorical_accuracy: 0.7535 - regression_output_mae: 0.0403 - val_loss: 1.2289 - val_detection_output_loss: 0.1253 - val_classification_output_loss: 0.5630 - val_regression_output_loss: 0.0087 - val_detection_output_binary_accuracy: 0.9323 - val_classification_output_sparse_categorical_accuracy: 0.7804 - val_regression_output_mae: 0.0450 - lr: 0.0010
# Epoch 30/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.3182 - detection_output_loss: 0.1210 - classification_output_loss: 0.6097 - regression_output_loss: 0.0064 - detection_output_binary_accuracy: 0.9395 - classification_output_sparse_categorical_accuracy: 0.7538 - regression_output_mae: 0.0402
# Epoch 30: val_classification_output_sparse_categorical_accuracy did not improve from 0.79519
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3179 - detection_output_loss: 0.1211 - classification_output_loss: 0.6095 - regression_output_loss: 0.0064 - detection_output_binary_accuracy: 0.9395 - classification_output_sparse_categorical_accuracy: 0.7538 - regression_output_mae: 0.0402 - val_loss: 1.2076 - val_detection_output_loss: 0.1346 - val_classification_output_loss: 0.5490 - val_regression_output_loss: 0.0067 - val_detection_output_binary_accuracy: 0.9293 - val_classification_output_sparse_categorical_accuracy: 0.7863 - val_regression_output_mae: 0.0392 - lr: 0.0010
# Epoch 31/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.2941 - detection_output_loss: 0.1184 - classification_output_loss: 0.5989 - regression_output_loss: 0.0056 - detection_output_binary_accuracy: 0.9396 - classification_output_sparse_categorical_accuracy: 0.7611 - regression_output_mae: 0.0379
# Epoch 31: val_classification_output_sparse_categorical_accuracy did not improve from 0.79519
# 443/443 [==============================] - 8s 17ms/step - loss: 1.2939 - detection_output_loss: 0.1184 - classification_output_loss: 0.5987 - regression_output_loss: 0.0056 - detection_output_binary_accuracy: 0.9397 - classification_output_sparse_categorical_accuracy: 0.7610 - regression_output_mae: 0.0379 - val_loss: 1.2845 - val_detection_output_loss: 0.1438 - val_classification_output_loss: 0.5833 - val_regression_output_loss: 0.0093 - val_detection_output_binary_accuracy: 0.9281 - val_classification_output_sparse_categorical_accuracy: 0.7762 - val_regression_output_mae: 0.0490 - lr: 0.0010
# Epoch 32/120
# 443/443 [==============================] - ETA: 0s - loss: 1.2949 - detection_output_loss: 0.1209 - classification_output_loss: 0.5982 - regression_output_loss: 0.0057 - detection_output_binary_accuracy: 0.9379 - classification_output_sparse_categorical_accuracy: 0.7597 - regression_output_mae: 0.0382
# Epoch 32: val_classification_output_sparse_categorical_accuracy did not improve from 0.79519
# 443/443 [==============================] - 8s 17ms/step - loss: 1.2949 - detection_output_loss: 0.1209 - classification_output_loss: 0.5982 - regression_output_loss: 0.0057 - detection_output_binary_accuracy: 0.9379 - classification_output_sparse_categorical_accuracy: 0.7597 - regression_output_mae: 0.0382 - val_loss: 1.3029 - val_detection_output_loss: 0.1373 - val_classification_output_loss: 0.5930 - val_regression_output_loss: 0.0234 - val_detection_output_binary_accuracy: 0.9280 - val_classification_output_sparse_categorical_accuracy: 0.7705 - val_regression_output_mae: 0.0844 - lr: 0.0010
# Epoch 33/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.2899 - detection_output_loss: 0.1214 - classification_output_loss: 0.5956 - regression_output_loss: 0.0055 - detection_output_binary_accuracy: 0.9370 - classification_output_sparse_categorical_accuracy: 0.7610 - regression_output_mae: 0.0373
# Epoch 33: val_classification_output_sparse_categorical_accuracy did not improve from 0.79519
# 443/443 [==============================] - 8s 17ms/step - loss: 1.2897 - detection_output_loss: 0.1214 - classification_output_loss: 0.5955 - regression_output_loss: 0.0055 - detection_output_binary_accuracy: 0.9371 - classification_output_sparse_categorical_accuracy: 0.7610 - regression_output_mae: 0.0373 - val_loss: 1.1629 - val_detection_output_loss: 0.1081 - val_classification_output_loss: 0.5373 - val_regression_output_loss: 0.0061 - val_detection_output_binary_accuracy: 0.9458 - val_classification_output_sparse_categorical_accuracy: 0.7906 - val_regression_output_mae: 0.0405 - lr: 0.0010
# Epoch 34/120
# 443/443 [==============================] - ETA: 0s - loss: 1.2846 - detection_output_loss: 0.1190 - classification_output_loss: 0.5939 - regression_output_loss: 0.0053 - detection_output_binary_accuracy: 0.9400 - classification_output_sparse_categorical_accuracy: 0.7604 - regression_output_mae: 0.0365
# Epoch 34: val_classification_output_sparse_categorical_accuracy did not improve from 0.79519
# 443/443 [==============================] - 8s 18ms/step - loss: 1.2846 - detection_output_loss: 0.1190 - classification_output_loss: 0.5939 - regression_output_loss: 0.0053 - detection_output_binary_accuracy: 0.9400 - classification_output_sparse_categorical_accuracy: 0.7604 - regression_output_mae: 0.0365 - val_loss: 1.1099 - val_detection_output_loss: 0.1094 - val_classification_output_loss: 0.5103 - val_regression_output_loss: 0.0058 - val_detection_output_binary_accuracy: 0.9463 - val_classification_output_sparse_categorical_accuracy: 0.7927 - val_regression_output_mae: 0.0380 - lr: 0.0010
# Epoch 35/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.2709 - detection_output_loss: 0.1187 - classification_output_loss: 0.5872 - regression_output_loss: 0.0053 - detection_output_binary_accuracy: 0.9391 - classification_output_sparse_categorical_accuracy: 0.7617 - regression_output_mae: 0.0371
# Epoch 35: val_classification_output_sparse_categorical_accuracy improved from 0.79519 to 0.80654, saving model to models/build_mmoe_model_0.keras
# 443/443 [==============================] - 8s 17ms/step - loss: 1.2710 - detection_output_loss: 0.1187 - classification_output_loss: 0.5872 - regression_output_loss: 0.0053 - detection_output_binary_accuracy: 0.9391 - classification_output_sparse_categorical_accuracy: 0.7616 - regression_output_mae: 0.0371 - val_loss: 1.0320 - val_detection_output_loss: 0.1002 - val_classification_output_loss: 0.4740 - val_regression_output_loss: 0.0127 - val_detection_output_binary_accuracy: 0.9520 - val_classification_output_sparse_categorical_accuracy: 0.8065 - val_regression_output_mae: 0.0545 - lr: 0.0010
# Epoch 36/120
# 443/443 [==============================] - ETA: 0s - loss: 1.2671 - detection_output_loss: 0.1183 - classification_output_loss: 0.5855 - regression_output_loss: 0.0049 - detection_output_binary_accuracy: 0.9401 - classification_output_sparse_categorical_accuracy: 0.7648 - regression_output_mae: 0.0352
# Epoch 36: val_classification_output_sparse_categorical_accuracy did not improve from 0.80654
# 443/443 [==============================] - 8s 17ms/step - loss: 1.2671 - detection_output_loss: 0.1183 - classification_output_loss: 0.5855 - regression_output_loss: 0.0049 - detection_output_binary_accuracy: 0.9401 - classification_output_sparse_categorical_accuracy: 0.7648 - regression_output_mae: 0.0352 - val_loss: 1.1014 - val_detection_output_loss: 0.1063 - val_classification_output_loss: 0.5073 - val_regression_output_loss: 0.0061 - val_detection_output_binary_accuracy: 0.9486 - val_classification_output_sparse_categorical_accuracy: 0.7917 - val_regression_output_mae: 0.0411 - lr: 0.0010
# Epoch 37/120
# 443/443 [==============================] - ETA: 0s - loss: 1.2650 - detection_output_loss: 0.1180 - classification_output_loss: 0.5846 - regression_output_loss: 0.0045 - detection_output_binary_accuracy: 0.9397 - classification_output_sparse_categorical_accuracy: 0.7640 - regression_output_mae: 0.0337
# Epoch 37: val_classification_output_sparse_categorical_accuracy did not improve from 0.80654
# 443/443 [==============================] - 8s 17ms/step - loss: 1.2650 - detection_output_loss: 0.1180 - classification_output_loss: 0.5846 - regression_output_loss: 0.0045 - detection_output_binary_accuracy: 0.9397 - classification_output_sparse_categorical_accuracy: 0.7640 - regression_output_mae: 0.0337 - val_loss: 1.1392 - val_detection_output_loss: 0.1209 - val_classification_output_loss: 0.5206 - val_regression_output_loss: 0.0044 - val_detection_output_binary_accuracy: 0.9373 - val_classification_output_sparse_categorical_accuracy: 0.7983 - val_regression_output_mae: 0.0333 - lr: 0.0010
# Epoch 38/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.2515 - detection_output_loss: 0.1170 - classification_output_loss: 0.5783 - regression_output_loss: 0.0044 - detection_output_binary_accuracy: 0.9398 - classification_output_sparse_categorical_accuracy: 0.7665 - regression_output_mae: 0.0332
# Epoch 38: val_classification_output_sparse_categorical_accuracy did not improve from 0.80654
# 443/443 [==============================] - 8s 17ms/step - loss: 1.2513 - detection_output_loss: 0.1170 - classification_output_loss: 0.5782 - regression_output_loss: 0.0044 - detection_output_binary_accuracy: 0.9398 - classification_output_sparse_categorical_accuracy: 0.7665 - regression_output_mae: 0.0332 - val_loss: 1.3716 - val_detection_output_loss: 0.1536 - val_classification_output_loss: 0.6234 - val_regression_output_loss: 0.0065 - val_detection_output_binary_accuracy: 0.9207 - val_classification_output_sparse_categorical_accuracy: 0.7663 - val_regression_output_mae: 0.0376 - lr: 0.0010
# Epoch 39/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.2545 - detection_output_loss: 0.1178 - classification_output_loss: 0.5795 - regression_output_loss: 0.0044 - detection_output_binary_accuracy: 0.9390 - classification_output_sparse_categorical_accuracy: 0.7681 - regression_output_mae: 0.0333
# Epoch 39: val_classification_output_sparse_categorical_accuracy did not improve from 0.80654
# 443/443 [==============================] - 8s 18ms/step - loss: 1.2544 - detection_output_loss: 0.1177 - classification_output_loss: 0.5795 - regression_output_loss: 0.0044 - detection_output_binary_accuracy: 0.9390 - classification_output_sparse_categorical_accuracy: 0.7681 - regression_output_mae: 0.0333 - val_loss: 1.1585 - val_detection_output_loss: 0.1203 - val_classification_output_loss: 0.5305 - val_regression_output_loss: 0.0045 - val_detection_output_binary_accuracy: 0.9410 - val_classification_output_sparse_categorical_accuracy: 0.7891 - val_regression_output_mae: 0.0318 - lr: 0.0010
# Epoch 40/120
# 443/443 [==============================] - ETA: 0s - loss: 1.2329 - detection_output_loss: 0.1146 - classification_output_loss: 0.5701 - regression_output_loss: 0.0037 - detection_output_binary_accuracy: 0.9430 - classification_output_sparse_categorical_accuracy: 0.7693 - regression_output_mae: 0.0310
# Epoch 40: val_classification_output_sparse_categorical_accuracy did not improve from 0.80654
# 443/443 [==============================] - 8s 18ms/step - loss: 1.2329 - detection_output_loss: 0.1146 - classification_output_loss: 0.5701 - regression_output_loss: 0.0037 - detection_output_binary_accuracy: 0.9430 - classification_output_sparse_categorical_accuracy: 0.7693 - regression_output_mae: 0.0310 - val_loss: 1.2222 - val_detection_output_loss: 0.1194 - val_classification_output_loss: 0.5627 - val_regression_output_loss: 0.0046 - val_detection_output_binary_accuracy: 0.9415 - val_classification_output_sparse_categorical_accuracy: 0.7879 - val_regression_output_mae: 0.0339 - lr: 0.0010
# Epoch 41/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.2382 - detection_output_loss: 0.1163 - classification_output_loss: 0.5720 - regression_output_loss: 0.0039 - detection_output_binary_accuracy: 0.9413 - classification_output_sparse_categorical_accuracy: 0.7687 - regression_output_mae: 0.0311
# Epoch 41: val_classification_output_sparse_categorical_accuracy did not improve from 0.80654
# 443/443 [==============================] - 8s 17ms/step - loss: 1.2381 - detection_output_loss: 0.1163 - classification_output_loss: 0.5720 - regression_output_loss: 0.0039 - detection_output_binary_accuracy: 0.9412 - classification_output_sparse_categorical_accuracy: 0.7686 - regression_output_mae: 0.0311 - val_loss: 1.1018 - val_detection_output_loss: 0.1092 - val_classification_output_loss: 0.5059 - val_regression_output_loss: 0.0090 - val_detection_output_binary_accuracy: 0.9432 - val_classification_output_sparse_categorical_accuracy: 0.7907 - val_regression_output_mae: 0.0470 - lr: 0.0010
# Epoch 42/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.2225 - detection_output_loss: 0.1147 - classification_output_loss: 0.5648 - regression_output_loss: 0.0037 - detection_output_binary_accuracy: 0.9418 - classification_output_sparse_categorical_accuracy: 0.7730 - regression_output_mae: 0.0306
# Epoch 42: val_classification_output_sparse_categorical_accuracy did not improve from 0.80654
# 443/443 [==============================] - 8s 18ms/step - loss: 1.2227 - detection_output_loss: 0.1148 - classification_output_loss: 0.5649 - regression_output_loss: 0.0037 - detection_output_binary_accuracy: 0.9418 - classification_output_sparse_categorical_accuracy: 0.7730 - regression_output_mae: 0.0306 - val_loss: 1.2058 - val_detection_output_loss: 0.1225 - val_classification_output_loss: 0.5526 - val_regression_output_loss: 0.0083 - val_detection_output_binary_accuracy: 0.9410 - val_classification_output_sparse_categorical_accuracy: 0.7864 - val_regression_output_mae: 0.0453 - lr: 0.0010
# Epoch 43/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.2180 - detection_output_loss: 0.1144 - classification_output_loss: 0.5628 - regression_output_loss: 0.0034 - detection_output_binary_accuracy: 0.9425 - classification_output_sparse_categorical_accuracy: 0.7733 - regression_output_mae: 0.0296
# Epoch 43: val_classification_output_sparse_categorical_accuracy did not improve from 0.80654
# 443/443 [==============================] - 8s 18ms/step - loss: 1.2188 - detection_output_loss: 0.1143 - classification_output_loss: 0.5632 - regression_output_loss: 0.0034 - detection_output_binary_accuracy: 0.9426 - classification_output_sparse_categorical_accuracy: 0.7731 - regression_output_mae: 0.0297 - val_loss: 1.2030 - val_detection_output_loss: 0.1286 - val_classification_output_loss: 0.5487 - val_regression_output_loss: 0.0093 - val_detection_output_binary_accuracy: 0.9304 - val_classification_output_sparse_categorical_accuracy: 0.7772 - val_regression_output_mae: 0.0499 - lr: 0.0010
# Epoch 44/120
# ...
# Epoch 108/120
# 438/443 [============================>.] - ETA: 0s - loss: 0.7937 - detection_output_loss: 0.1439 - classification_output_loss: 0.6492 - regression_output_loss: 6.4046e-04 - detection_output_binary_accuracy: 0.9272 - classification_output_sparse_categorical_accuracy: 0.7648 - regression_output_mae: 0.0147
# Epoch 108: val_classification_output_sparse_categorical_accuracy did not improve from 0.80222
# 443/443 [==============================] - 6s 12ms/step - loss: 0.7939 - detection_output_loss: 0.1439 - classification_output_loss: 0.6494 - regression_output_loss: 6.4034e-04 - detection_output_binary_accuracy: 0.9272 - classification_output_sparse_categorical_accuracy: 0.7648 - regression_output_mae: 0.0147 - val_loss: 0.7130 - val_detection_output_loss: 0.1434 - val_classification_output_loss: 0.5688 - val_regression_output_loss: 7.3553e-04 - val_detection_output_binary_accuracy: 0.9257 - val_classification_output_sparse_categorical_accuracy: 0.7967 - val_regression_output_mae: 0.0151 - lr: 1.2500e-04
# Epoch 109/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.7893 - detection_output_loss: 0.1420 - classification_output_loss: 0.6467 - regression_output_loss: 6.4364e-04 - detection_output_binary_accuracy: 0.9286 - classification_output_sparse_categorical_accuracy: 0.7648 - regression_output_mae: 0.0148
# Epoch 109: val_classification_output_sparse_categorical_accuracy did not improve from 0.80222
# 443/443 [==============================] - 6s 12ms/step - loss: 0.7892 - detection_output_loss: 0.1422 - classification_output_loss: 0.6464 - regression_output_loss: 6.4280e-04 - detection_output_binary_accuracy: 0.9286 - classification_output_sparse_categorical_accuracy: 0.7649 - regression_output_mae: 0.0148 - val_loss: 0.7128 - val_detection_output_loss: 0.1463 - val_classification_output_loss: 0.5659 - val_regression_output_loss: 6.2001e-04 - val_detection_output_binary_accuracy: 0.9252 - val_classification_output_sparse_categorical_accuracy: 0.7999 - val_regression_output_mae: 0.0143 - lr: 1.2500e-04
# Epoch 110/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7888 - detection_output_loss: 0.1420 - classification_output_loss: 0.6462 - regression_output_loss: 6.4621e-04 - detection_output_binary_accuracy: 0.9290 - classification_output_sparse_categorical_accuracy: 0.7656 - regression_output_mae: 0.0147
# Epoch 110: val_classification_output_sparse_categorical_accuracy improved from 0.80222 to 0.80259, saving model to models/build_single_task_model_2.keras
# 443/443 [==============================] - 6s 12ms/step - loss: 0.7888 - detection_output_loss: 0.1420 - classification_output_loss: 0.6462 - regression_output_loss: 6.4621e-04 - detection_output_binary_accuracy: 0.9290 - classification_output_sparse_categorical_accuracy: 0.7656 - regression_output_mae: 0.0147 - val_loss: 0.7045 - val_detection_output_loss: 0.1434 - val_classification_output_loss: 0.5606 - val_regression_output_loss: 5.1971e-04 - val_detection_output_binary_accuracy: 0.9256 - val_classification_output_sparse_categorical_accuracy: 0.8026 - val_regression_output_mae: 0.0132 - lr: 1.2500e-04
# Epoch 111/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.7925 - detection_output_loss: 0.1430 - classification_output_loss: 0.6489 - regression_output_loss: 6.3716e-04 - detection_output_binary_accuracy: 0.9284 - classification_output_sparse_categorical_accuracy: 0.7650 - regression_output_mae: 0.0147
# Epoch 111: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 6s 12ms/step - loss: 0.7928 - detection_output_loss: 0.1431 - classification_output_loss: 0.6490 - regression_output_loss: 6.3731e-04 - detection_output_binary_accuracy: 0.9284 - classification_output_sparse_categorical_accuracy: 0.7649 - regression_output_mae: 0.0147 - val_loss: 0.7093 - val_detection_output_loss: 0.1443 - val_classification_output_loss: 0.5645 - val_regression_output_loss: 4.7602e-04 - val_detection_output_binary_accuracy: 0.9227 - val_classification_output_sparse_categorical_accuracy: 0.7963 - val_regression_output_mae: 0.0129 - lr: 1.2500e-04
# Epoch 112/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.7907 - detection_output_loss: 0.1416 - classification_output_loss: 0.6485 - regression_output_loss: 6.2830e-04 - detection_output_binary_accuracy: 0.9296 - classification_output_sparse_categorical_accuracy: 0.7649 - regression_output_mae: 0.0146
# Epoch 112: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 6s 13ms/step - loss: 0.7907 - detection_output_loss: 0.1419 - classification_output_loss: 0.6481 - regression_output_loss: 6.2784e-04 - detection_output_binary_accuracy: 0.9293 - classification_output_sparse_categorical_accuracy: 0.7649 - regression_output_mae: 0.0145 - val_loss: 0.7097 - val_detection_output_loss: 0.1441 - val_classification_output_loss: 0.5650 - val_regression_output_loss: 5.5727e-04 - val_detection_output_binary_accuracy: 0.9258 - val_classification_output_sparse_categorical_accuracy: 0.7975 - val_regression_output_mae: 0.0135 - lr: 1.2500e-04
# Epoch 113/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7916 - detection_output_loss: 0.1417 - classification_output_loss: 0.6492 - regression_output_loss: 6.3235e-04 - detection_output_binary_accuracy: 0.9295 - classification_output_sparse_categorical_accuracy: 0.7657 - regression_output_mae: 0.0146
# Epoch 113: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 6s 12ms/step - loss: 0.7916 - detection_output_loss: 0.1417 - classification_output_loss: 0.6492 - regression_output_loss: 6.3235e-04 - detection_output_binary_accuracy: 0.9295 - classification_output_sparse_categorical_accuracy: 0.7657 - regression_output_mae: 0.0146 - val_loss: 0.7072 - val_detection_output_loss: 0.1443 - val_classification_output_loss: 0.5623 - val_regression_output_loss: 5.9922e-04 - val_detection_output_binary_accuracy: 0.9230 - val_classification_output_sparse_categorical_accuracy: 0.7960 - val_regression_output_mae: 0.0140 - lr: 1.2500e-04
# Epoch 114/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.7882 - detection_output_loss: 0.1432 - classification_output_loss: 0.6444 - regression_output_loss: 6.2145e-04 - detection_output_binary_accuracy: 0.9279 - classification_output_sparse_categorical_accuracy: 0.7661 - regression_output_mae: 0.0145
# Epoch 114: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 6s 12ms/step - loss: 0.7883 - detection_output_loss: 0.1430 - classification_output_loss: 0.6446 - regression_output_loss: 6.2124e-04 - detection_output_binary_accuracy: 0.9280 - classification_output_sparse_categorical_accuracy: 0.7660 - regression_output_mae: 0.0145 - val_loss: 0.7155 - val_detection_output_loss: 0.1448 - val_classification_output_loss: 0.5698 - val_regression_output_loss: 8.5519e-04 - val_detection_output_binary_accuracy: 0.9251 - val_classification_output_sparse_categorical_accuracy: 0.7968 - val_regression_output_mae: 0.0159 - lr: 1.2500e-04
# Epoch 115/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.7864 - detection_output_loss: 0.1416 - classification_output_loss: 0.6442 - regression_output_loss: 6.2967e-04 - detection_output_binary_accuracy: 0.9285 - classification_output_sparse_categorical_accuracy: 0.7655 - regression_output_mae: 0.0146
# Epoch 115: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 6s 12ms/step - loss: 0.7870 - detection_output_loss: 0.1418 - classification_output_loss: 0.6445 - regression_output_loss: 6.2941e-04 - detection_output_binary_accuracy: 0.9283 - classification_output_sparse_categorical_accuracy: 0.7653 - regression_output_mae: 0.0146 - val_loss: 0.7134 - val_detection_output_loss: 0.1436 - val_classification_output_loss: 0.5694 - val_regression_output_loss: 4.8595e-04 - val_detection_output_binary_accuracy: 0.9262 - val_classification_output_sparse_categorical_accuracy: 0.7957 - val_regression_output_mae: 0.0131 - lr: 1.2500e-04
# Epoch 116/120
# 439/443 [============================>.] - ETA: 0s - loss: 0.7928 - detection_output_loss: 0.1427 - classification_output_loss: 0.6495 - regression_output_loss: 6.2208e-04 - detection_output_binary_accuracy: 0.9281 - classification_output_sparse_categorical_accuracy: 0.7631 - regression_output_mae: 0.0145
# Epoch 116: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 5s 11ms/step - loss: 0.7926 - detection_output_loss: 0.1426 - classification_output_loss: 0.6493 - regression_output_loss: 6.2221e-04 - detection_output_binary_accuracy: 0.9281 - classification_output_sparse_categorical_accuracy: 0.7632 - regression_output_mae: 0.0145 - val_loss: 0.7048 - val_detection_output_loss: 0.1433 - val_classification_output_loss: 0.5609 - val_regression_output_loss: 5.5034e-04 - val_detection_output_binary_accuracy: 0.9242 - val_classification_output_sparse_categorical_accuracy: 0.7980 - val_regression_output_mae: 0.0136 - lr: 1.2500e-04
# Epoch 117/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.7839 - detection_output_loss: 0.1412 - classification_output_loss: 0.6421 - regression_output_loss: 6.1310e-04 - detection_output_binary_accuracy: 0.9297 - classification_output_sparse_categorical_accuracy: 0.7666 - regression_output_mae: 0.0144
# Epoch 117: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 5s 11ms/step - loss: 0.7842 - detection_output_loss: 0.1413 - classification_output_loss: 0.6423 - regression_output_loss: 6.1349e-04 - detection_output_binary_accuracy: 0.9296 - classification_output_sparse_categorical_accuracy: 0.7664 - regression_output_mae: 0.0144 - val_loss: 0.7040 - val_detection_output_loss: 0.1440 - val_classification_output_loss: 0.5595 - val_regression_output_loss: 4.6475e-04 - val_detection_output_binary_accuracy: 0.9258 - val_classification_output_sparse_categorical_accuracy: 0.8014 - val_regression_output_mae: 0.0125 - lr: 1.2500e-04
# Epoch 118/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7891 - detection_output_loss: 0.1429 - classification_output_loss: 0.6456 - regression_output_loss: 6.2020e-04 - detection_output_binary_accuracy: 0.9281 - classification_output_sparse_categorical_accuracy: 0.7664 - regression_output_mae: 0.0145
# Epoch 118: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 6s 13ms/step - loss: 0.7891 - detection_output_loss: 0.1429 - classification_output_loss: 0.6456 - regression_output_loss: 6.2020e-04 - detection_output_binary_accuracy: 0.9281 - classification_output_sparse_categorical_accuracy: 0.7664 - regression_output_mae: 0.0145 - val_loss: 0.7132 - val_detection_output_loss: 0.1447 - val_classification_output_loss: 0.5680 - val_regression_output_loss: 4.8468e-04 - val_detection_output_binary_accuracy: 0.9231 - val_classification_output_sparse_categorical_accuracy: 0.7962 - val_regression_output_mae: 0.0128 - lr: 1.2500e-04
# Epoch 119/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.7862 - detection_output_loss: 0.1410 - classification_output_loss: 0.6445 - regression_output_loss: 6.2644e-04 - detection_output_binary_accuracy: 0.9289 - classification_output_sparse_categorical_accuracy: 0.7660 - regression_output_mae: 0.0146
# Epoch 119: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 6s 12ms/step - loss: 0.7862 - detection_output_loss: 0.1410 - classification_output_loss: 0.6446 - regression_output_loss: 6.2626e-04 - detection_output_binary_accuracy: 0.9289 - classification_output_sparse_categorical_accuracy: 0.7659 - regression_output_mae: 0.0146 - val_loss: 0.7084 - val_detection_output_loss: 0.1438 - val_classification_output_loss: 0.5642 - val_regression_output_loss: 4.6768e-04 - val_detection_output_binary_accuracy: 0.9251 - val_classification_output_sparse_categorical_accuracy: 0.7970 - val_regression_output_mae: 0.0126 - lr: 1.2500e-04
# Epoch 120/120
# 439/443 [============================>.] - ETA: 0s - loss: 0.7859 - detection_output_loss: 0.1411 - classification_output_loss: 0.6442 - regression_output_loss: 6.1030e-04 - detection_output_binary_accuracy: 0.9290 - classification_output_sparse_categorical_accuracy: 0.7660 - regression_output_mae: 0.0144
# Epoch 120: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 120: val_classification_output_sparse_categorical_accuracy did not improve from 0.80259
# 443/443 [==============================] - 6s 11ms/step - loss: 0.7859 - detection_output_loss: 0.1410 - classification_output_loss: 0.6443 - regression_output_loss: 6.1031e-04 - detection_output_binary_accuracy: 0.9290 - classification_output_sparse_categorical_accuracy: 0.7660 - regression_output_mae: 0.0144 - val_loss: 0.7141 - val_detection_output_loss: 0.1462 - val_classification_output_loss: 0.5675 - val_regression_output_loss: 4.6348e-04 - val_detection_output_binary_accuracy: 0.9214 - val_classification_output_sparse_categorical_accuracy: 0.7912 - val_regression_output_mae: 0.0126 - lr: 1.2500e-04
# ✅ 模型 3 训练完成，耗时 725.75 秒
# 2025-10-20 11:57:51.026145: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype float and shape [16200,3]
# 	 [[{{node Placeholder/_3}}]]
# ================================================================================
# 📥 SingleTask 输入信号（前 5 条）
# ================================================================================
# 样本 0: [ 2.000e-04  1.022e-01 -1.000e+01] ...
# 样本 1: [  0.021    0.0987 -10.    ] ...
# 样本 2: [ 3.80e-03  9.86e-02 -1.00e+01] ...
# 样本 3: [ 1.00e-04  1.02e-01 -1.00e+01] ...
# 样本 4: [ 1.200e-03  1.017e-01 -1.000e+01] ...
#
# ================================================================================
# 📤 SingleTask 真实 vs 预测（前 5 条）
# ================================================================================
# 样本 0:
#   det_true: 1.0000  |  det_pred: 0.9114
#   cls_true: 2     |  cls_pred: 2
#   reg_true: [ 2.000e-04  1.022e-01 -1.000e+01]  |  reg_pred: [-1.70163810e-04  1.02522664e-01 -9.99896526e+00]
# 样本 1:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 7     |  cls_pred: 7
#   reg_true: [  0.021    0.0987 -10.    ]  |  reg_pred: [ 5.5305958e-03  9.1362849e-02 -1.0002022e+01]
# 样本 2:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 3     |  cls_pred: 3
#   reg_true: [ 3.80e-03  9.86e-02 -1.00e+01]  |  reg_pred: [-9.7736716e-05  9.1821812e-02 -9.9737129e+00]
# 样本 3:
#   det_true: 1.0000  |  det_pred: 0.9769
#   cls_true: 7     |  cls_pred: 7
#   reg_true: [ 1.00e-04  1.02e-01 -1.00e+01]  |  reg_pred: [-2.26944685e-04  1.00380726e-01 -9.99706078e+00]
# 样本 4:
#   det_true: 1.0000  |  det_pred: 0.9704
#   cls_true: 5     |  cls_pred: 7
#   reg_true: [ 1.200e-03  1.017e-01 -1.000e+01]  |  reg_pred: [-6.91585243e-04  1.02810375e-01 -1.00142632e+01]
#
# ================================================================================
# 📈 SingleTask NRMSE 报告
# ================================================================================
# 参数维度: [start_time, end_time, jnr_db]
# start_time: 0.1002
# end_time: 0.0948
# jnr_db: 3462827.5000
# 平均 NRMSE: 1154275.8750
# ✅ SingleTask NRMSE 报告已写入 reports/SingleTask_nrmse_report.txt
#
# ==================================================
# 📈 训练时间统计
# ==================================================
# MMoE 模型:
#   模型 1: 996.92 秒
#   模型 2: 997.45 秒
#   模型 3: 1003.42 秒
#
# 单任务 模型:
#   模型 1: 727.75 秒
#   模型 2: 629.04 秒
#   模型 3: 725.75 秒

# %%
# evaluate_mmoe_1015.py
import os
import json
import time
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (confusion_matrix, accuracy_score, precision_score,
                             recall_score, f1_score, mean_absolute_error)
from sklearn.preprocessing import StandardScaler
import matplotlib.font_manager as fm

# ---------------------- 中文字体 ----------------------
def set_chinese_font():
    try:
        font_paths = ['/usr/share/fonts/truetype/wqy/wqy-microhei.ttc',
                      'C:/Windows/Fonts/simhei.ttf',
                      '/System/Library/Fonts/PingFang.ttc']
        for font_path in font_paths:
            if os.path.exists(font_path):
                fm.fontManager.addfont(font_path)
                plt.rcParams['font.family'] = fm.FontProperties(fname=font_path).get_name()
                plt.rcParams['axes.unicode_minus'] = False
                print(f"✅ 成功设置中文字体: {plt.rcParams['font.family']}")
                return True
        plt.rcParams['font.family'] = ['SimHei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("⚠️ 未找到指定字体，使用默认兼容字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False
set_chinese_font()

# ---------------------- 加载数据集 ----------------------
def load_dataset(npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"):
    data = np.load(npz_path, allow_pickle=True)
    signals = data["signals"]
    labels = data["labels"].astype(np.int32)
    jnr_vals = data["jnr_values"].astype(np.float32)
    fs = float(data["fs"])
    L = int(data["L"])
    metadata = data["metadata"]
    type2label = data["type_to_label"].item()
    label2type = {v: k for k, v in type2label.items()}
    type2name = data["interference_type_names"].item()
    label2name = {i: type2name[k] for k, i in type2label.items()}
    return {
        "signals": signals,
        "labels": labels,
        "jnr_values": jnr_vals,
        "fs": fs,
        "L": L,
        "metadata": metadata,
        "type2label": type2label,
        "label2name": label2name,
        "type2name": type2name
    }

# ---------------------- 数据预处理 ----------------------
def preprocess_data(dataset):
    signals = dataset["signals"]
    labels = dataset["labels"]
    jnr_values = dataset["jnr_values"]
    L = dataset["L"]

    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() for s in signals])

    no_key = "satellite_signal"
    det_labels = (labels != dataset["type2label"][no_key]).astype(np.float32)

    param_labels = []
    for m in dataset["metadata"]:
        p = m.get("params", {})
        param_labels.append([
            float(p.get("start_time", 0)),
            float(p.get("end_time", 0)),
            float(p.get("jnr_db", 0))
        ])
    param_labels = np.array(param_labels, dtype=np.float32)

    X_test = signals
    y_det_test = det_labels
    y_type_test = labels
    y_param_test = param_labels
    jnr_test = jnr_values
    label2name = dataset["label2name"]

    return {
        "X_test": X_test,
        "y_det_test": y_det_test,
        "y_type_test": y_type_test,
        "y_param_test": y_param_test,
        "jnr_values_test": jnr_test,
        "label2name": label2name,
        "L": L
    }

# ---------------------- 加载模型并预测 ----------------------
def load_and_predict(model_paths, X_test):
    all_det, all_cls, all_reg = [], [], []
    for path in model_paths:
        print(f"🔁 加载模型: {path}")
        model = tf.keras.models.load_model(path)  # MMoE 无需 custom_objects
        start = time.time()
        det, cls, reg = model.predict(X_test, verbose=0)
        print(f"预测耗时: {time.time()-start:.2f} 秒")
        all_det.append(det)
        all_cls.append(cls)
        all_reg.append(reg)
    avg_det = np.mean(all_det, axis=0) > 0.5
    avg_cls = np.argmax(np.mean(all_cls, axis=0), axis=1)
    avg_reg = np.mean(all_reg, axis=0)
    return avg_det, avg_cls, avg_reg

# ---------------------- 绘制混淆矩阵 ----------------------
def plot_confusion_matrix(cm, labels, title, xlabel, ylabel, filename, dpi=150, rotate_x=False):
    cm_norm = cm.astype('float') / cm.sum(axis=1, keepdims=True)
    cm_norm = np.nan_to_num(cm_norm)
    plt.figure(figsize=(12, 10))
    ax = sns.heatmap(cm_norm, annot=True, fmt='.2f', cmap='Blues',
                     xticklabels=labels, yticklabels=labels, square=True,
                     annot_kws={"size": 14})
    cbar = ax.collections[0].colorbar
    cbar.ax.tick_params(labelsize=14)
    plt.title(title, pad=20, fontsize=18)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.xticks(rotation=45 if rotate_x else 0, ha='right' if rotate_x else 'center', fontsize=14)
    plt.yticks(rotation=0, fontsize=14)
    plt.tight_layout()
    plt.savefig(filename, dpi=dpi)
    plt.close()

# ---------------------- 按列归一化 NRMSE ----------------------
def nrmse_columnwise(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2, axis=0))
    y_range = np.max(y_true, axis=0) - np.min(y_true, axis=0)
    return rmse / (y_range + 1e-8)

# ---------------------- 主评估 ----------------------
def evaluate(models_dir="models",
             npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz",
             wanted_jnr=np.arange(-10, 31, 5),
             dpi=150):
    os.makedirs("visualizations", exist_ok=True)
    os.makedirs("reports", exist_ok=True)

    dataset = load_dataset(npz_path)
    data = preprocess_data(dataset)

    X_test = data["X_test"]
    y_det_test = data["y_det_test"]
    y_type_test = data["y_type_test"]
    y_param_test = data["y_param_test"]
    jnr_test = data["jnr_values_test"]
    label2name = data["label2name"]

    model_paths = [os.path.join(models_dir, f"build_mmoe_model_{i}.keras") for i in range(3)]
    avg_det, avg_cls, avg_reg = load_and_predict(model_paths, X_test)

    # 清理无效样本
    invalid_mask = (
        np.any(np.isnan(y_param_test), axis=1) |
        np.any(np.isinf(y_param_test), axis=1) |
        np.any(np.isnan(avg_reg), axis=1) |
        np.any(np.isinf(avg_reg), axis=1)
    )
    valid_y_param = y_param_test[~invalid_mask]
    valid_avg_reg = avg_reg[~invalid_mask]

    # 1. 检测混淆矩阵
    cm_det = confusion_matrix(y_det_test, avg_det)
    plot_confusion_matrix(cm_det, ['No Interference', 'Interference'],
                          'MMoE Detection Confusion Matrix',
                          'Predicted', 'True',
                          'visualizations/MMoE_detection_confusion_matrix_1015.png',
                          dpi=dpi)

    # 2. 分类混淆矩阵
    cm_type = confusion_matrix(y_type_test, avg_cls)
    plot_confusion_matrix(cm_type,
                          [label2name[i] for i in sorted(label2name.keys())],
                          'MMoE Classification Confusion Matrix',
                          'Predicted', 'True',
                          'visualizations/MMoE_classification_confusion_matrix_1015.png',
                          dpi=dpi, rotate_x=True)

    # 3. JNR vs Accuracy
    jnr_acc = []
    for jnr in wanted_jnr:
        mask = (jnr_test == jnr) & (~invalid_mask)
        acc = np.nan if mask.sum() == 0 else accuracy_score(y_type_test[mask], avg_cls[mask])
        jnr_acc.append(acc)

    plt.figure(figsize=(8, 5))
    valid_mask = ~np.isnan(jnr_acc)
    plt.plot(wanted_jnr[valid_mask], np.array(jnr_acc)[valid_mask], marker='o', linewidth=2)
    if np.any(~valid_mask):
        plt.scatter(wanted_jnr[~valid_mask], [1.0] * np.sum(~valid_mask),
                    facecolors='none', edgecolors='r', s=60)
    plt.xlabel('JNR (dB)', fontsize=14)
    plt.ylabel('Accuracy', fontsize=14)
    plt.title('Classification Accuracy vs JNR', fontsize=16)
    plt.xticks(wanted_jnr)
    plt.grid(True, ls='--', alpha=0.5)
    plt.ylim(0, 1.05)
    plt.tight_layout()
    plt.savefig('visualizations/MMoE_jnr_vs_accuracy_1015.png', dpi=dpi)
    plt.close()

    # 4. 指标计算
    det_acc = accuracy_score(y_det_test, avg_det)
    cls_acc = accuracy_score(y_type_test, avg_cls)
    cls_precision = precision_score(y_type_test, avg_cls, average='weighted', zero_division=0)
    cls_recall = recall_score(y_type_test, avg_cls, average='weighted', zero_division=0)
    cls_f1 = f1_score(y_type_test, avg_cls, average='weighted', zero_division=0)

    param_mae = mean_absolute_error(valid_y_param, valid_avg_reg, multioutput='raw_values')
    param_nrmse = nrmse_columnwise(valid_y_param, valid_avg_reg)
    param_names = ['Start Time (ms)', 'End Time (ms)', 'JNR (dB)']

    print("\n" + "="*50)
    print("📊 MMoE 模型集成评估结果")
    print("="*50)
    print(f"检测准确率: {det_acc:.4f}")
    print(f"分类准确率: {cls_acc:.4f}")
    print(f"分类精确率: {cls_precision:.4f}, 召回率: {cls_recall:.4f}, F1: {cls_f1:.4f}")
    print("\n参数估计误差（MAE & 按列 NRMSE）:")
    for i, (name, mae, nrmse) in enumerate(zip(param_names, param_mae, param_nrmse)):
        print(f"  {name}: MAE = {mae:.4f}, NRMSE = {nrmse:.4f}")
    print(f"  平均 NRMSE（三列分别归一化） = {np.mean(param_nrmse):.4f}")
    print("\nJNR 准确率:")
    for j, acc in zip(wanted_jnr, jnr_acc):
        print(f"  {int(j)}dB: {acc if not np.isnan(acc) else 'N/A'}")

    # 5. 保存报告
    report = {
        "detection_accuracy": float(det_acc),
        "classification_accuracy": float(cls_acc),
        "classification_precision": float(cls_precision),
        "classification_recall": float(cls_recall),
        "classification_f1": float(cls_f1),
        "parameter_mae": [float(m) for m in param_mae],
        "parameter_nrmse": [float(n) for n in param_nrmse],
        "average_columnwise_nrmse": float(np.mean(param_nrmse)),
        "parameter_details": {
            param_names[i]: {"mae": float(param_mae[i]), "nrmse": float(param_nrmse[i])}
            for i in range(len(param_names))
        },
        "jnr_accuracies": {f"{int(j)}dB": float(acc) if not np.isnan(acc) else None for j, acc in zip(wanted_jnr, jnr_acc)},
        "invalid_samples_count": int(np.sum(invalid_mask))
    }
    with open("reports/MMoE_evaluation_report_1015.json", "w", encoding='utf-8') as f:
        json.dump(report, f, indent=4, ensure_ascii=False)

    print("\n✅ 评估完成！混淆矩阵与报告已保存。")

# ---------------------- 主入口 ----------------------
if __name__ == "__main__":
    evaluate(models_dir="models",
             npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz",
             wanted_jnr=np.arange(-10, 31, 5),
             dpi=150)
# Out:
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# 🔁 加载模型: models/build_mmoe_model_0.keras
# 预测耗时: 10.20 秒
# 🔁 加载模型: models/build_mmoe_model_1.keras
# 预测耗时: 10.25 秒
# 🔁 加载模型: models/build_mmoe_model_2.keras
# 预测耗时: 8.70 秒
#
# ==================================================
# 📊 MMoE 模型集成评估结果
# ==================================================
# 检测准确率: 0.9754
# 分类准确率: 0.8876
# 分类精确率: 0.8918, 召回率: 0.8876, F1: 0.8872
#
# 参数估计误差（MAE & 按列 NRMSE）:
#   Start Time (ms): MAE = 0.1328, NRMSE = 0.2232
#   End Time (ms): MAE = 0.7672, NRMSE = 0.8073
#   JNR (dB): MAE = 20.0017, NRMSE = 0.5952
#   平均 NRMSE（三列分别归一化） = 0.5419
#
# JNR 准确率:
#   -10dB: 0.556
#   -5dB: 0.70775
#   0dB: 0.840625
#   5dB: 0.89225
#   10dB: 0.942
#   15dB: 0.971
#   20dB: 0.986875
#   25dB: 0.987375
#   30dB: 0.988875
#
# ✅ 评估完成！混淆矩阵与报告已保存。

# %% [markdown]
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# 🔁 加载模型: models/build_mmoe_model_0.keras
# 预测耗时: 10.20 秒
# 🔁 加载模型: models/build_mmoe_model_1.keras
# 预测耗时: 10.25 秒
# 🔁 加载模型: models/build_mmoe_model_2.keras
# 预测耗时: 8.70 秒
#
# ==================================================
# 📊 MMoE 模型集成评估结果
# ==================================================
# 检测准确率: 0.9754
# 分类准确率: 0.8876
# 分类精确率: 0.8918, 召回率: 0.8876, F1: 0.8872
#
# 参数估计误差（MAE & 按列 NRMSE）:
#   Start Time (ms): MAE = 0.1328, NRMSE = 0.2232
#   End Time (ms): MAE = 0.7672, NRMSE = 0.8073
#   JNR (dB): MAE = 20.0017, NRMSE = 0.5952
#   平均 NRMSE（三列分别归一化） = 0.5419
#
# JNR 准确率:
#   -10dB: 0.556
#   -5dB: 0.70775
#   0dB: 0.840625
#   5dB: 0.89225
#   10dB: 0.942
#   15dB: 0.971
#   20dB: 0.986875
#   25dB: 0.987375
#   30dB: 0.988875
