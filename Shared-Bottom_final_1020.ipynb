# %%
# train_shared_bottom_online_estimate_nrmse.py
import os
import time
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_absolute_error
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Dense, Concatenate, Conv1D, MaxPooling1D,
                                     Dropout, BatchNormalization, GlobalAveragePooling1D,
                                     Reshape)
from tensorflow.keras.layers import Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import BinaryCrossentropy, SparseCategoricalCrossentropy, MeanSquaredError
from tensorflow.keras.metrics import BinaryAccuracy, SparseCategoricalAccuracy
import matplotlib.font_manager as fm

# ---------------------- 中文字体 ----------------------
def set_chinese_font():
    try:
        font_paths = ['/usr/share/fonts/truetype/wqy/wqy-microhei.ttc',
                      'C:/Windows/Fonts/simhei.ttf',
                      '/System/Library/Fonts/PingFang.ttc']
        for font_path in font_paths:
            if os.path.exists(font_path):
                fm.fontManager.addfont(font_path)
                plt.rcParams['font.family'] = fm.FontProperties(fname=font_path).get_name()
                plt.rcParams['axes.unicode_minus'] = False
                print(f"✅ 成功设置中文字体: {plt.rcParams['font.family']}")
                return True
        plt.rcParams['font.family'] = ['SimHei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("⚠️ 未找到指定字体，使用默认兼容字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False
set_chinese_font()

# ---------------------- 加载数据集 ----------------------
def load_dataset(npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"):
    data = np.load(npz_path, allow_pickle=True)
    signals = data["signals"]
    labels = data["labels"].astype(np.int32)
    jnr_values = data["jnr_values"].astype(np.float32)
    fs = float(data["fs"])
    L = int(data["L"])
    noise_power_db = float(data["noise_power_db"])
    type2label = data["type_to_label"].item()

    interference_type_names = {
        "satellite_signal": "Satellite_Signal",
        "single_tone": "Single_Tone",
        "comb_spectra": "Comb_Spectra",
        "sweeping": "Sweeping-LFM",
        "pulse": "Pulse",
        "frequency_hopping": "Frequency_Hopping",
        "noise_fm": "Noise_FM",
        "noise_am": "Noise_AM",
        "random_combination": "Random_Combination"
    }
    label2name = {i: interference_type_names[k] for k, i in type2label.items()}
    return {
        "signals": signals,
        "labels": labels,
        "jnr_values": jnr_values,
        "fs": fs,
        "L": L,
        "noise_power_db": noise_power_db,
        "type2label": type2label,
        "label2name": label2name
    }

# ---------------------- 在线估算标签 ----------------------
def estimate_start_end(signal, fs, threshold_factor=2.0):
    power = signal ** 2
    avg_pow = np.mean(power)
    thresh = threshold_factor * avg_pow
    above = power > thresh
    diff = np.diff(above.astype(int))
    starts = np.where(diff == 1)[0]
    ends = np.where(diff == -1)[0]
    if len(starts) == 0 or len(ends) == 0:
        return 0.0, 0.0
    return float(starts[0] / fs * 1e3), float(ends[-1] / fs * 1e3)

def estimate_jnr(signal, noise_power_db):
    total_power = 10 * np.log10(np.mean(signal ** 2) + 1e-12)
    return float(total_power - noise_power_db)

# ---------------------- 数据预处理 ----------------------
def preprocess_data(dataset, aug_ratio=0.1):
    signals = dataset["signals"]
    labels = dataset["labels"]
    jnr_values = dataset["jnr_values"]
    L = dataset["L"]
    noise_power_db = dataset["noise_power_db"]

    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() for s in signals])

    no_key = "satellite_signal"
    det_labels = (labels != dataset["type2label"][no_key]).astype(np.float32)

    # 在线估算回归标签
    param_labels = []
    for sig in signals:
        st, et = estimate_start_end(sig, dataset["fs"])
        jnr = estimate_jnr(sig, noise_power_db)
        param_labels.append([st, et, jnr])
    param_labels = np.array(param_labels, dtype=np.float32)

    # 丢弃含 NaN/Inf 的样本
    mask = ~(
        np.any(np.isnan(signals), axis=1) |
        np.any(np.isinf(signals), axis=1) |
        np.isnan(det_labels) | np.isinf(det_labels) |
        np.isnan(labels) | np.isinf(labels) |
        np.any(np.isnan(param_labels), axis=1) | np.any(np.isinf(param_labels), axis=1)
    )
    print(f"🧹 丢弃 {np.sum(~mask)} / {len(mask)} 条含 NaN/Inf 的样本")
    signals, det_labels, labels, param_labels, jnr_values = \
        signals[mask], det_labels[mask], labels[mask], param_labels[mask], jnr_values[mask]

    X_train, X_tmp, y_det_train, y_det_tmp, y_type_train, y_type_tmp, y_param_train, y_param_tmp, jnr_train, jnr_tmp = train_test_split(
        signals, det_labels, labels, param_labels, jnr_values,
        test_size=0.3, random_state=42, stratify=labels
    )
    X_val, X_test, y_det_val, y_det_test, y_type_val, y_type_test, y_param_val, y_param_test, jnr_val, jnr_test = train_test_split(
        X_tmp, y_det_tmp, y_type_tmp, y_param_tmp, jnr_tmp,
        test_size=2/3, random_state=42, stratify=y_type_tmp
    )

    return {
        "X_train": X_train, "X_val": X_val, "X_test": X_test,
        "y_det_train": y_det_train, "y_det_val": y_det_val, "y_det_test": y_det_test,
        "y_type_train": y_type_train, "y_type_val": y_type_val, "y_type_test": y_type_test,
        "y_param_train": y_param_train, "y_param_val": y_param_val, "y_param_test": y_param_test,
        "jnr_values_train": jnr_train, "jnr_values_val": jnr_val, "jnr_values_test": jnr_test,
        "type2label": dataset["type2label"], "label2name": dataset["label2name"],
        "L": L, "fs": dataset["fs"], "noise_power_db": noise_power_db
    }

# ---------------------- 数据增强 ----------------------
@tf.function
def aug_fn(x):
    x = tf.cast(x, tf.float32)
    if tf.random.uniform([]) > 0.2:
        snr = tf.random.uniform([], 5., 25.)
        noise = tf.random.normal(tf.shape(x), dtype=tf.float32) * tf.math.reduce_std(x) * tf.cast(10.0 ** (-snr / 20.0), tf.float32)
        x = x + noise
    if tf.random.uniform([]) > 0.3:
        shift = tf.random.uniform([], -100, 100, dtype=tf.int32)
        x = tf.roll(x, shift=shift, axis=0)
    if tf.random.uniform([]) > 0.3:
        scale = tf.random.uniform([], 0.7, 1.3)
        x = x * scale
    if tf.random.uniform([]) > 0.7:
        freq_shift = tf.random.uniform([], -0.1, 0.1)
        n = tf.cast(tf.shape(x)[0], tf.float32)
        x = x * tf.cos(2 * np.pi * freq_shift * tf.range(n, dtype=tf.float32))
    return x

# ---------------------- Shared-Bottom 模型 ----------------------
def build_shared_bottom_model(input_shape, num_classes):
    inputs = Input(shape=input_shape, dtype=tf.float32)

    # 共享主干
    x = Reshape((input_shape[0], 1))(inputs)
    x = Conv1D(64, 7, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    x = Conv1D(128, 5, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    x = Conv1D(256, 3, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    shared_features = GlobalAveragePooling1D()(x)

    # 任务分支
    det_out = Dense(64, activation='relu')(shared_features)
    det_out = Dense(1, activation='sigmoid', name='detection_output')(det_out)

    cls_out = Dense(64, activation='relu')(shared_features)
    cls_out = Dense(num_classes, activation='softmax', name='classification_output')(cls_out)

    reg_feat = Dense(64, activation='relu')(shared_features)
    reg_feat = Dense(3, activation='linear')(reg_feat)
    reg_out = Lambda(lambda z: tf.clip_by_value(z, -1e3, 1e3), name='regression_output')(reg_feat)

    model = Model(inputs, [det_out, cls_out, reg_out])
    model.compile(
        optimizer=Adam(1e-3),
        loss={
            'detection_output': BinaryCrossentropy(),
            'classification_output': SparseCategoricalCrossentropy(),
            'regression_output': MeanSquaredError()
        },
        loss_weights={
            'detection_output': 0.8,
            'classification_output': 2.0,
            'regression_output': 0.3
        },
        metrics={
            'detection_output': BinaryAccuracy(),
            'classification_output': SparseCategoricalAccuracy(),
            'regression_output': 'mae'
        }
    )
    return model

# ---------------------- 按列分别归一化 NRMSE ----------------------
def nrmse_columnwise(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2, axis=0))  # shape (3,)
    y_range = np.max(y_true, axis=0) - np.min(y_true, axis=0)
    return rmse / (y_range + 1e-8)

# ---------------------- 评估 + 打印 + NRMSE ----------------------
def evaluate_and_print(models, data, batch=128, model_name="SharedBottom"):
    os.makedirs("reports", exist_ok=True)
    ds_test = tf.data.Dataset.from_tensor_slices((
        data['X_test'],
        {
            'detection_output': data['y_det_test'],
            'classification_output': data['y_type_test'],
            'regression_output': data['y_param_test']
        }
    )).batch(batch).prefetch(tf.data.AUTOTUNE)

    y_det_true, y_type_true, y_param_true = [], [], []
    y_det_pred, y_type_pred, y_param_pred = [], [], []

    for x, y in ds_test:
        y_det_true.append(y['detection_output'].numpy())
        y_type_true.append(y['classification_output'].numpy())
        y_param_true.append(y['regression_output'].numpy())

        preds = [m(x, training=False) for m in models]
        det_avg = np.mean([p[0].numpy() for p in preds], axis=0)
        cls_avg = np.mean([p[1].numpy() for p in preds], axis=0)
        reg_avg = np.mean([p[2].numpy() for p in preds], axis=0)

        y_det_pred.append(det_avg)
        y_type_pred.append(cls_avg)
        y_param_pred.append(reg_avg)

    y_det_true = np.concatenate(y_det_true, axis=0)
    y_type_true = np.concatenate(y_type_true, axis=0)
    y_param_true = np.concatenate(y_param_true, axis=0)
    y_det_pred = np.concatenate(y_det_pred, axis=0)
    y_type_pred = np.concatenate(y_type_pred, axis=0)
    y_param_pred = np.concatenate(y_param_pred, axis=0)

    # 前 5 条
    print("\n" + "="*80)
    print(f"📥 {model_name} 输入信号（前 5 条）")
    print("="*80)
    for i in range(5):
        print(f"样本 {i}: {y_param_true[i]} ...")

    print("\n" + "="*80)
    print(f"📤 {model_name} 真实 vs 预测（前 5 条）")
    print("="*80)
    for i in range(5):
        print(f"样本 {i}:")
        print(f"  det_true: {y_det_true[i]:.4f}  |  det_pred: {y_det_pred[i,0]:.4f}")
        print(f"  cls_true: {y_type_true[i]}     |  cls_pred: {np.argmax(y_type_pred[i])}")
        print(f"  reg_true: {y_param_true[i]}  |  reg_pred: {y_param_pred[i]}")

    # NRMSE（按列分别归一化）
    reg_nrmse = nrmse_columnwise(y_param_true, y_param_pred)
    param_names = ['Start Time (ms)', 'End Time (ms)', 'JNR (dB)']
    print("\n" + "="*80)
    print(f"📈 {model_name} NRMSE 报告（按列分别归一化）")
    print("="*80)
    for i, name in enumerate(param_names):
        print(f"{name}: {reg_nrmse[i]:.4f}")
    print(f"平均 NRMSE（三列分别归一化） = {np.mean(reg_nrmse):.4f}")

    # 保存
    with open(f"reports/{model_name}_nrmse_report.txt", "w", encoding="utf-8") as f:
        f.write("参数维度: [start_time, end_time, jnr_db]\n")
        for i, name in enumerate(param_names):
            f.write(f"{name}: {reg_nrmse[i]:.4f}\n")
        f.write(f"平均 NRMSE: {np.mean(reg_nrmse):.4f}\n")
    print(f"✅ {model_name} NRMSE 报告已写入 reports/{model_name}_nrmse_report.txt")
    return reg_nrmse

# ---------------------- 训练单个模型 ----------------------
def train_single_model(data, model_idx, epochs=120, batch=128):
    input_shape, num_classes = (data["L"],), len(data["type2label"])
    model = build_shared_bottom_model(input_shape, num_classes)

    unique_labels = np.unique(data['y_type_train'])
    cls_weights = compute_class_weight('balanced', classes=unique_labels, y=data['y_type_train'])
    cls_weight_dict = {lab: float(w) for lab, w in zip(unique_labels, cls_weights)}
    sample_weights = np.array([cls_weight_dict[lab] for lab in data['y_type_train']])

    def filter_nan(*args):
        x, y = args[0], args[1]
        ok = (tf.reduce_all(tf.math.is_finite(x)) &
              tf.math.is_finite(y['detection_output']) &
              tf.reduce_all(tf.math.is_finite(y['regression_output'])))
        if len(args) == 3:
            ok &= tf.math.is_finite(args[2])
        return ok

    ds_train = tf.data.Dataset.from_tensor_slices((
        data['X_train'],
        {
            'detection_output': data['y_det_train'],
            'classification_output': data['y_type_train'],
            'regression_output': data['y_param_train']
        },
        sample_weights
    ))
    ds_train = ds_train.filter(filter_nan)
    ds_train = ds_train.map(lambda x, y, w: (aug_fn(x), y, w), num_parallel_calls=tf.data.AUTOTUNE)
    ds_train = ds_train.shuffle(10000).batch(batch).prefetch(tf.data.AUTOTUNE)

    ds_val = tf.data.Dataset.from_tensor_slices((
        data['X_val'],
        {
            'detection_output': data['y_det_val'],
            'classification_output': data['y_type_val'],
            'regression_output': data['y_param_val']
        }
    ))
    ds_val = ds_val.filter(filter_nan)
    ds_val = ds_val.batch(batch).prefetch(tf.data.AUTOTUNE)

    os.makedirs("models", exist_ok=True)
    ckpt = f"models/shared_bottom_model_{model_idx}.keras"
    callbacks = [
        EarlyStopping(monitor='val_classification_output_sparse_categorical_accuracy', patience=20,
                      restore_best_weights=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_classification_output_sparse_categorical_accuracy', factor=0.5,
                          patience=10, min_lr=1e-5, mode='max', verbose=1),
        ModelCheckpoint(ckpt, save_best_only=True, save_weights_only=False,
                        monitor='val_classification_output_sparse_categorical_accuracy', mode='max', verbose=1)
    ]

    print(f"\n🔥 训练第 {model_idx + 1} 个 Shared-Bottom 模型（在线估算标签）...")
    start_time = time.time()
    history = model.fit(ds_train, validation_data=ds_val, epochs=epochs, callbacks=callbacks, verbose=1)
    end_time = time.time()
    training_time = end_time - start_time
    print(f"✅ 模型 {model_idx + 1} 训练完成，耗时 {training_time:.2f} 秒")
    return model, training_time

# ---------------------- 训练 Ensemble ----------------------
def train_ensemble(data, n_models=3, epochs=120, batch=128):
    models, training_times = [], []
    for i in range(n_models):
        model, t = train_single_model(data, i, epochs=epochs, batch=batch)
        models.append(model)
        training_times.append(t)
    return models, training_times

# ---------------------- 主函数 ----------------------
def main():
    for d in ["models", "visualizations", "reports"]:
        os.makedirs(d, exist_ok=True)

    print("=" * 80)
    print("🚀 开始训练 Shared-Bottom 多任务模型（在线估算标签 + 按列 NRMSE）")
    print("=" * 80)

    dataset = load_dataset()
    data = preprocess_data(dataset, aug_ratio=0.1)

    n_models = 3
    epochs = 120
    batch_size = 128

    models, training_times = train_ensemble(data, n_models=n_models, epochs=epochs, batch=batch_size)

    # 评估 & NRMSE
    evaluate_and_print(models, data, batch=batch_size, model_name="SharedBottom")

    print("\n" + "="*50)
    print("📈 训练时间统计")
    print("="*50)
    for i, t in enumerate(training_times):
        print(f"模型 {i + 1}: {t:.2f} 秒 ({t / 60:.2f} 分钟)")
    print(f"🔥 总训练时间: {sum(training_times):.2f} 秒 ({sum(training_times) / 60:.2f} 分钟)")
    print("="*50)
    print("\n✅ 所有 Shared-Bottom 模型训练完成！模型已保存至 models/shared_bottom_model_{i}.keras")
    print("📌 接下来可以使用 evaluate_models_nrmse_columnwise.py 进行加载、评估、画图、生成指标报告")

if __name__ == "__main__":
    main()
# Out:
# 2025-10-20 12:10:16.135023: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-20 12:10:16.175132: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-20 12:10:16.757922: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# ================================================================================
# 🚀 开始训练 Shared-Bottom 多任务模型（在线估算标签 + 按列 NRMSE）
# ================================================================================
# 🧹 丢弃 0 / 81000 条含 NaN/Inf 的样本
# 2025-10-20 12:10:39.088756: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46590 MB memory:  -> device: 0, name: NVIDIA vGPU-48GB, pci bus id: 0000:c8:00.0, compute capability: 8.9
# 🔥 训练第 1 个 Shared-Bottom 模型（在线估算标签）...
# Epoch 1/120
# 2025-10-20 12:10:40.690580: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [56700,1024]
# 	 [[{{node Placeholder/_0}}]]
# 2025-10-20 12:10:40.690847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype double and shape [56700]
# 	 [[{{node Placeholder/_4}}]]
# 2025-10-20 12:10:43.032213: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-10-20 12:10:43.221301: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-10-20 12:10:43.267697: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f776c029c50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-20 12:10:43.267744: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA vGPU-48GB, Compute Capability 8.9
# 2025-10-20 12:10:43.279973: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-20 12:10:43.427225: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#     443/Unknown - 9s 12ms/step - loss: 3.1522 - detection_output_loss: 0.2160 - classification_output_loss: 1.2674 - regression_output_loss: 1.4821 - detection_output_binary_accuracy: 0.8933 - classification_output_sparse_categorical_accuracy: 0.5210 - regression_output_mae: 0.4892
# 2025-10-20 12:10:50.309393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [8100]
# 	 [[{{node Placeholder/_2}}]]
# Epoch 1: val_classification_output_sparse_categorical_accuracy improved from -inf to 0.45704, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 11s 15ms/step - loss: 3.1522 - detection_output_loss: 0.2160 - classification_output_loss: 1.2674 - regression_output_loss: 1.4821 - detection_output_binary_accuracy: 0.8933 - classification_output_sparse_categorical_accuracy: 0.5210 - regression_output_mae: 0.4892 - val_loss: 3.3059 - val_detection_output_loss: 0.3672 - val_classification_output_loss: 1.4790 - val_regression_output_loss: 0.1803 - val_detection_output_binary_accuracy: 0.8889 - val_classification_output_sparse_categorical_accuracy: 0.4570 - val_regression_output_mae: 0.2667 - lr: 0.0010
# Epoch 2/120
# 442/443 [============================>.] - ETA: 0s - loss: 2.2142 - detection_output_loss: 0.1785 - classification_output_loss: 1.0180 - regression_output_loss: 0.1180 - detection_output_binary_accuracy: 0.9031 - classification_output_sparse_categorical_accuracy: 0.5998 - regression_output_mae: 0.1945
# Epoch 2: val_classification_output_sparse_categorical_accuracy improved from 0.45704 to 0.58272, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 2.2140 - detection_output_loss: 0.1784 - classification_output_loss: 1.0180 - regression_output_loss: 0.1179 - detection_output_binary_accuracy: 0.9031 - classification_output_sparse_categorical_accuracy: 0.5997 - regression_output_mae: 0.1945 - val_loss: 2.0507 - val_detection_output_loss: 0.1810 - val_classification_output_loss: 0.9417 - val_regression_output_loss: 0.0751 - val_detection_output_binary_accuracy: 0.8917 - val_classification_output_sparse_categorical_accuracy: 0.5827 - val_regression_output_mae: 0.1760 - lr: 0.0010
# Epoch 3/120
# 440/443 [============================>.] - ETA: 0s - loss: 2.0110 - detection_output_loss: 0.1650 - classification_output_loss: 0.9317 - regression_output_loss: 0.0522 - detection_output_binary_accuracy: 0.9101 - classification_output_sparse_categorical_accuracy: 0.6355 - regression_output_mae: 0.1352
# Epoch 3: val_classification_output_sparse_categorical_accuracy improved from 0.58272 to 0.68617, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 2.0116 - detection_output_loss: 0.1650 - classification_output_loss: 0.9320 - regression_output_loss: 0.0521 - detection_output_binary_accuracy: 0.9102 - classification_output_sparse_categorical_accuracy: 0.6352 - regression_output_mae: 0.1351 - val_loss: 1.6451 - val_detection_output_loss: 0.1311 - val_classification_output_loss: 0.7655 - val_regression_output_loss: 0.0311 - val_detection_output_binary_accuracy: 0.9426 - val_classification_output_sparse_categorical_accuracy: 0.6862 - val_regression_output_mae: 0.1107 - lr: 0.0010
# Epoch 4/120
# 439/443 [============================>.] - ETA: 0s - loss: 1.9100 - detection_output_loss: 0.1597 - classification_output_loss: 0.8865 - regression_output_loss: 0.0309 - detection_output_binary_accuracy: 0.9122 - classification_output_sparse_categorical_accuracy: 0.6531 - regression_output_mae: 0.1070
# Epoch 4: val_classification_output_sparse_categorical_accuracy improved from 0.68617 to 0.71679, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.9089 - detection_output_loss: 0.1596 - classification_output_loss: 0.8860 - regression_output_loss: 0.0308 - detection_output_binary_accuracy: 0.9122 - classification_output_sparse_categorical_accuracy: 0.6533 - regression_output_mae: 0.1069 - val_loss: 1.5710 - val_detection_output_loss: 0.1281 - val_classification_output_loss: 0.7310 - val_regression_output_loss: 0.0220 - val_detection_output_binary_accuracy: 0.9400 - val_classification_output_sparse_categorical_accuracy: 0.7168 - val_regression_output_mae: 0.1010 - lr: 0.0010
# Epoch 5/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.8331 - detection_output_loss: 0.1544 - classification_output_loss: 0.8514 - regression_output_loss: 0.0226 - detection_output_binary_accuracy: 0.9155 - classification_output_sparse_categorical_accuracy: 0.6647 - regression_output_mae: 0.0912
# Epoch 5: val_classification_output_sparse_categorical_accuracy did not improve from 0.71679
# 443/443 [==============================] - 6s 13ms/step - loss: 1.8326 - detection_output_loss: 0.1544 - classification_output_loss: 0.8512 - regression_output_loss: 0.0226 - detection_output_binary_accuracy: 0.9155 - classification_output_sparse_categorical_accuracy: 0.6648 - regression_output_mae: 0.0912 - val_loss: 1.6467 - val_detection_output_loss: 0.1283 - val_classification_output_loss: 0.7662 - val_regression_output_loss: 0.0384 - val_detection_output_binary_accuracy: 0.9323 - val_classification_output_sparse_categorical_accuracy: 0.7123 - val_regression_output_mae: 0.1243 - lr: 0.0010
# Epoch 6/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.7831 - detection_output_loss: 0.1527 - classification_output_loss: 0.8278 - regression_output_loss: 0.0176 - detection_output_binary_accuracy: 0.9171 - classification_output_sparse_categorical_accuracy: 0.6766 - regression_output_mae: 0.0796
# Epoch 6: val_classification_output_sparse_categorical_accuracy improved from 0.71679 to 0.72235, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.7829 - detection_output_loss: 0.1527 - classification_output_loss: 0.8277 - regression_output_loss: 0.0176 - detection_output_binary_accuracy: 0.9170 - classification_output_sparse_categorical_accuracy: 0.6766 - regression_output_mae: 0.0796 - val_loss: 1.5045 - val_detection_output_loss: 0.1386 - val_classification_output_loss: 0.6922 - val_regression_output_loss: 0.0308 - val_detection_output_binary_accuracy: 0.9196 - val_classification_output_sparse_categorical_accuracy: 0.7223 - val_regression_output_mae: 0.1005 - lr: 0.0010
# Epoch 7/120
# 443/443 [==============================] - ETA: 0s - loss: 1.7372 - detection_output_loss: 0.1492 - classification_output_loss: 0.8066 - regression_output_loss: 0.0156 - detection_output_binary_accuracy: 0.9199 - classification_output_sparse_categorical_accuracy: 0.6856 - regression_output_mae: 0.0735
# Epoch 7: val_classification_output_sparse_categorical_accuracy improved from 0.72235 to 0.73778, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.7372 - detection_output_loss: 0.1492 - classification_output_loss: 0.8066 - regression_output_loss: 0.0156 - detection_output_binary_accuracy: 0.9199 - classification_output_sparse_categorical_accuracy: 0.6856 - regression_output_mae: 0.0735 - val_loss: 1.5043 - val_detection_output_loss: 0.1196 - val_classification_output_loss: 0.7010 - val_regression_output_loss: 0.0218 - val_detection_output_binary_accuracy: 0.9428 - val_classification_output_sparse_categorical_accuracy: 0.7378 - val_regression_output_mae: 0.0854 - lr: 0.0010
# Epoch 8/120
# 443/443 [==============================] - ETA: 0s - loss: 1.7011 - detection_output_loss: 0.1466 - classification_output_loss: 0.7900 - regression_output_loss: 0.0126 - detection_output_binary_accuracy: 0.9212 - classification_output_sparse_categorical_accuracy: 0.6910 - regression_output_mae: 0.0657
# Epoch 8: val_classification_output_sparse_categorical_accuracy did not improve from 0.73778
# 443/443 [==============================] - 6s 13ms/step - loss: 1.7011 - detection_output_loss: 0.1466 - classification_output_loss: 0.7900 - regression_output_loss: 0.0126 - detection_output_binary_accuracy: 0.9212 - classification_output_sparse_categorical_accuracy: 0.6910 - regression_output_mae: 0.0657 - val_loss: 1.5478 - val_detection_output_loss: 0.1408 - val_classification_output_loss: 0.7153 - val_regression_output_loss: 0.0153 - val_detection_output_binary_accuracy: 0.9186 - val_classification_output_sparse_categorical_accuracy: 0.7177 - val_regression_output_mae: 0.0705 - lr: 0.0010
# Epoch 9/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.6635 - detection_output_loss: 0.1460 - classification_output_loss: 0.7715 - regression_output_loss: 0.0123 - detection_output_binary_accuracy: 0.9210 - classification_output_sparse_categorical_accuracy: 0.6983 - regression_output_mae: 0.0631
# Epoch 9: val_classification_output_sparse_categorical_accuracy improved from 0.73778 to 0.75642, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.6629 - detection_output_loss: 0.1458 - classification_output_loss: 0.7713 - regression_output_loss: 0.0123 - detection_output_binary_accuracy: 0.9211 - classification_output_sparse_categorical_accuracy: 0.6983 - regression_output_mae: 0.0631 - val_loss: 1.3531 - val_detection_output_loss: 0.1185 - val_classification_output_loss: 0.6264 - val_regression_output_loss: 0.0182 - val_detection_output_binary_accuracy: 0.9432 - val_classification_output_sparse_categorical_accuracy: 0.7564 - val_regression_output_mae: 0.0813 - lr: 0.0010
# Epoch 10/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.6409 - detection_output_loss: 0.1435 - classification_output_loss: 0.7613 - regression_output_loss: 0.0116 - detection_output_binary_accuracy: 0.9234 - classification_output_sparse_categorical_accuracy: 0.7017 - regression_output_mae: 0.0606
# Epoch 10: val_classification_output_sparse_categorical_accuracy did not improve from 0.75642
# 443/443 [==============================] - 6s 13ms/step - loss: 1.6408 - detection_output_loss: 0.1434 - classification_output_loss: 0.7613 - regression_output_loss: 0.0116 - detection_output_binary_accuracy: 0.9234 - classification_output_sparse_categorical_accuracy: 0.7018 - regression_output_mae: 0.0606 - val_loss: 1.4197 - val_detection_output_loss: 0.1404 - val_classification_output_loss: 0.6504 - val_regression_output_loss: 0.0221 - val_detection_output_binary_accuracy: 0.9163 - val_classification_output_sparse_categorical_accuracy: 0.7414 - val_regression_output_mae: 0.0892 - lr: 0.0010
# Epoch 11/120
# 443/443 [==============================] - ETA: 0s - loss: 1.6073 - detection_output_loss: 0.1408 - classification_output_loss: 0.7457 - regression_output_loss: 0.0107 - detection_output_binary_accuracy: 0.9250 - classification_output_sparse_categorical_accuracy: 0.7101 - regression_output_mae: 0.0569
# Epoch 11: val_classification_output_sparse_categorical_accuracy did not improve from 0.75642
# 443/443 [==============================] - 6s 12ms/step - loss: 1.6073 - detection_output_loss: 0.1408 - classification_output_loss: 0.7457 - regression_output_loss: 0.0107 - detection_output_binary_accuracy: 0.9250 - classification_output_sparse_categorical_accuracy: 0.7101 - regression_output_mae: 0.0569 - val_loss: 1.5263 - val_detection_output_loss: 0.1510 - val_classification_output_loss: 0.7009 - val_regression_output_loss: 0.0121 - val_detection_output_binary_accuracy: 0.9125 - val_classification_output_sparse_categorical_accuracy: 0.7258 - val_regression_output_mae: 0.0612 - lr: 0.0010
# Epoch 12/120
# 443/443 [==============================] - ETA: 0s - loss: 1.5914 - detection_output_loss: 0.1408 - classification_output_loss: 0.7379 - regression_output_loss: 0.0103 - detection_output_binary_accuracy: 0.9249 - classification_output_sparse_categorical_accuracy: 0.7126 - regression_output_mae: 0.0551
# Epoch 12: val_classification_output_sparse_categorical_accuracy did not improve from 0.75642
# 443/443 [==============================] - 6s 13ms/step - loss: 1.5914 - detection_output_loss: 0.1408 - classification_output_loss: 0.7379 - regression_output_loss: 0.0103 - detection_output_binary_accuracy: 0.9249 - classification_output_sparse_categorical_accuracy: 0.7126 - regression_output_mae: 0.0551 - val_loss: 1.3414 - val_detection_output_loss: 0.1206 - val_classification_output_loss: 0.6209 - val_regression_output_loss: 0.0104 - val_detection_output_binary_accuracy: 0.9388 - val_classification_output_sparse_categorical_accuracy: 0.7477 - val_regression_output_mae: 0.0559 - lr: 0.0010
# Epoch 13/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.5643 - detection_output_loss: 0.1399 - classification_output_loss: 0.7248 - regression_output_loss: 0.0093 - detection_output_binary_accuracy: 0.9256 - classification_output_sparse_categorical_accuracy: 0.7174 - regression_output_mae: 0.0521
# Epoch 13: val_classification_output_sparse_categorical_accuracy improved from 0.75642 to 0.76383, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.5645 - detection_output_loss: 0.1399 - classification_output_loss: 0.7249 - regression_output_loss: 0.0093 - detection_output_binary_accuracy: 0.9256 - classification_output_sparse_categorical_accuracy: 0.7173 - regression_output_mae: 0.0521 - val_loss: 1.2761 - val_detection_output_loss: 0.1172 - val_classification_output_loss: 0.5890 - val_regression_output_loss: 0.0145 - val_detection_output_binary_accuracy: 0.9446 - val_classification_output_sparse_categorical_accuracy: 0.7638 - val_regression_output_mae: 0.0626 - lr: 0.0010
# Epoch 14/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.5724 - detection_output_loss: 0.1407 - classification_output_loss: 0.7286 - regression_output_loss: 0.0090 - detection_output_binary_accuracy: 0.9246 - classification_output_sparse_categorical_accuracy: 0.7171 - regression_output_mae: 0.0506
# Epoch 14: val_classification_output_sparse_categorical_accuracy did not improve from 0.76383
# 443/443 [==============================] - 6s 13ms/step - loss: 1.5726 - detection_output_loss: 0.1408 - classification_output_loss: 0.7286 - regression_output_loss: 0.0090 - detection_output_binary_accuracy: 0.9246 - classification_output_sparse_categorical_accuracy: 0.7171 - regression_output_mae: 0.0506 - val_loss: 1.4244 - val_detection_output_loss: 0.1172 - val_classification_output_loss: 0.6628 - val_regression_output_loss: 0.0170 - val_detection_output_binary_accuracy: 0.9443 - val_classification_output_sparse_categorical_accuracy: 0.7381 - val_regression_output_mae: 0.0694 - lr: 0.0010
# Epoch 15/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.5367 - detection_output_loss: 0.1383 - classification_output_loss: 0.7118 - regression_output_loss: 0.0085 - detection_output_binary_accuracy: 0.9274 - classification_output_sparse_categorical_accuracy: 0.7210 - regression_output_mae: 0.0483
# Epoch 15: val_classification_output_sparse_categorical_accuracy did not improve from 0.76383
# 443/443 [==============================] - 6s 13ms/step - loss: 1.5373 - detection_output_loss: 0.1383 - classification_output_loss: 0.7120 - regression_output_loss: 0.0085 - detection_output_binary_accuracy: 0.9274 - classification_output_sparse_categorical_accuracy: 0.7209 - regression_output_mae: 0.0483 - val_loss: 1.3475 - val_detection_output_loss: 0.1190 - val_classification_output_loss: 0.6247 - val_regression_output_loss: 0.0099 - val_detection_output_binary_accuracy: 0.9402 - val_classification_output_sparse_categorical_accuracy: 0.7533 - val_regression_output_mae: 0.0557 - lr: 0.0010
# Epoch 16/120
# 443/443 [==============================] - ETA: 0s - loss: 1.5152 - detection_output_loss: 0.1371 - classification_output_loss: 0.7015 - regression_output_loss: 0.0083 - detection_output_binary_accuracy: 0.9270 - classification_output_sparse_categorical_accuracy: 0.7251 - regression_output_mae: 0.0473
# Epoch 16: val_classification_output_sparse_categorical_accuracy did not improve from 0.76383
# 443/443 [==============================] - 6s 12ms/step - loss: 1.5152 - detection_output_loss: 0.1371 - classification_output_loss: 0.7015 - regression_output_loss: 0.0083 - detection_output_binary_accuracy: 0.9270 - classification_output_sparse_categorical_accuracy: 0.7251 - regression_output_mae: 0.0473 - val_loss: 1.3917 - val_detection_output_loss: 0.1217 - val_classification_output_loss: 0.6458 - val_regression_output_loss: 0.0088 - val_detection_output_binary_accuracy: 0.9368 - val_classification_output_sparse_categorical_accuracy: 0.7515 - val_regression_output_mae: 0.0487 - lr: 0.0010
# Epoch 17/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.5053 - detection_output_loss: 0.1355 - classification_output_loss: 0.6972 - regression_output_loss: 0.0082 - detection_output_binary_accuracy: 0.9279 - classification_output_sparse_categorical_accuracy: 0.7268 - regression_output_mae: 0.0464
# Epoch 17: val_classification_output_sparse_categorical_accuracy improved from 0.76383 to 0.76642, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 12ms/step - loss: 1.5047 - detection_output_loss: 0.1354 - classification_output_loss: 0.6969 - regression_output_loss: 0.0082 - detection_output_binary_accuracy: 0.9280 - classification_output_sparse_categorical_accuracy: 0.7269 - regression_output_mae: 0.0464 - val_loss: 1.2716 - val_detection_output_loss: 0.1103 - val_classification_output_loss: 0.5905 - val_regression_output_loss: 0.0074 - val_detection_output_binary_accuracy: 0.9479 - val_classification_output_sparse_categorical_accuracy: 0.7664 - val_regression_output_mae: 0.0440 - lr: 0.0010
# Epoch 18/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.4870 - detection_output_loss: 0.1346 - classification_output_loss: 0.6885 - regression_output_loss: 0.0076 - detection_output_binary_accuracy: 0.9288 - classification_output_sparse_categorical_accuracy: 0.7303 - regression_output_mae: 0.0447
# Epoch 18: val_classification_output_sparse_categorical_accuracy improved from 0.76642 to 0.77901, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.4875 - detection_output_loss: 0.1347 - classification_output_loss: 0.6887 - regression_output_loss: 0.0076 - detection_output_binary_accuracy: 0.9287 - classification_output_sparse_categorical_accuracy: 0.7302 - regression_output_mae: 0.0447 - val_loss: 1.2024 - val_detection_output_loss: 0.1194 - val_classification_output_loss: 0.5520 - val_regression_output_loss: 0.0097 - val_detection_output_binary_accuracy: 0.9435 - val_classification_output_sparse_categorical_accuracy: 0.7790 - val_regression_output_mae: 0.0510 - lr: 0.0010
# Epoch 19/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.4758 - detection_output_loss: 0.1346 - classification_output_loss: 0.6831 - regression_output_loss: 0.0068 - detection_output_binary_accuracy: 0.9301 - classification_output_sparse_categorical_accuracy: 0.7316 - regression_output_mae: 0.0422
# Epoch 19: val_classification_output_sparse_categorical_accuracy did not improve from 0.77901
# 443/443 [==============================] - 6s 13ms/step - loss: 1.4756 - detection_output_loss: 0.1346 - classification_output_loss: 0.6829 - regression_output_loss: 0.0068 - detection_output_binary_accuracy: 0.9301 - classification_output_sparse_categorical_accuracy: 0.7316 - regression_output_mae: 0.0422 - val_loss: 1.3363 - val_detection_output_loss: 0.1289 - val_classification_output_loss: 0.6123 - val_regression_output_loss: 0.0283 - val_detection_output_binary_accuracy: 0.9311 - val_classification_output_sparse_categorical_accuracy: 0.7577 - val_regression_output_mae: 0.0932 - lr: 0.0010
# Epoch 20/120
# 443/443 [==============================] - ETA: 0s - loss: 1.4688 - detection_output_loss: 0.1329 - classification_output_loss: 0.6802 - regression_output_loss: 0.0069 - detection_output_binary_accuracy: 0.9306 - classification_output_sparse_categorical_accuracy: 0.7346 - regression_output_mae: 0.0423
# Epoch 20: val_classification_output_sparse_categorical_accuracy did not improve from 0.77901
# 443/443 [==============================] - 6s 12ms/step - loss: 1.4688 - detection_output_loss: 0.1329 - classification_output_loss: 0.6802 - regression_output_loss: 0.0069 - detection_output_binary_accuracy: 0.9306 - classification_output_sparse_categorical_accuracy: 0.7346 - regression_output_mae: 0.0423 - val_loss: 1.2737 - val_detection_output_loss: 0.1202 - val_classification_output_loss: 0.5870 - val_regression_output_loss: 0.0118 - val_detection_output_binary_accuracy: 0.9394 - val_classification_output_sparse_categorical_accuracy: 0.7748 - val_regression_output_mae: 0.0574 - lr: 0.0010
# Epoch 21/120
# 439/443 [============================>.] - ETA: 0s - loss: 1.4411 - detection_output_loss: 0.1317 - classification_output_loss: 0.6668 - regression_output_loss: 0.0068 - detection_output_binary_accuracy: 0.9311 - classification_output_sparse_categorical_accuracy: 0.7389 - regression_output_mae: 0.0418
# Epoch 21: val_classification_output_sparse_categorical_accuracy improved from 0.77901 to 0.78247, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.4410 - detection_output_loss: 0.1317 - classification_output_loss: 0.6668 - regression_output_loss: 0.0068 - detection_output_binary_accuracy: 0.9311 - classification_output_sparse_categorical_accuracy: 0.7389 - regression_output_mae: 0.0418 - val_loss: 1.2523 - val_detection_output_loss: 0.1248 - val_classification_output_loss: 0.5755 - val_regression_output_loss: 0.0045 - val_detection_output_binary_accuracy: 0.9383 - val_classification_output_sparse_categorical_accuracy: 0.7825 - val_regression_output_mae: 0.0354 - lr: 0.0010
# Epoch 22/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.4365 - detection_output_loss: 0.1330 - classification_output_loss: 0.6642 - regression_output_loss: 0.0060 - detection_output_binary_accuracy: 0.9305 - classification_output_sparse_categorical_accuracy: 0.7411 - regression_output_mae: 0.0393
# Epoch 22: val_classification_output_sparse_categorical_accuracy improved from 0.78247 to 0.78333, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.4360 - detection_output_loss: 0.1329 - classification_output_loss: 0.6639 - regression_output_loss: 0.0060 - detection_output_binary_accuracy: 0.9305 - classification_output_sparse_categorical_accuracy: 0.7411 - regression_output_mae: 0.0393 - val_loss: 1.2088 - val_detection_output_loss: 0.1107 - val_classification_output_loss: 0.5583 - val_regression_output_loss: 0.0122 - val_detection_output_binary_accuracy: 0.9458 - val_classification_output_sparse_categorical_accuracy: 0.7833 - val_regression_output_mae: 0.0584 - lr: 0.0010
# Epoch 23/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.4313 - detection_output_loss: 0.1304 - classification_output_loss: 0.6626 - regression_output_loss: 0.0060 - detection_output_binary_accuracy: 0.9318 - classification_output_sparse_categorical_accuracy: 0.7419 - regression_output_mae: 0.0392
# Epoch 23: val_classification_output_sparse_categorical_accuracy did not improve from 0.78333
# 443/443 [==============================] - 6s 13ms/step - loss: 1.4313 - detection_output_loss: 0.1303 - classification_output_loss: 0.6626 - regression_output_loss: 0.0060 - detection_output_binary_accuracy: 0.9318 - classification_output_sparse_categorical_accuracy: 0.7419 - regression_output_mae: 0.0391 - val_loss: 1.5089 - val_detection_output_loss: 0.2320 - val_classification_output_loss: 0.6607 - val_regression_output_loss: 0.0066 - val_detection_output_binary_accuracy: 0.8959 - val_classification_output_sparse_categorical_accuracy: 0.7388 - val_regression_output_mae: 0.0407 - lr: 0.0010
# Epoch 24/120
# 439/443 [============================>.] - ETA: 0s - loss: 1.4188 - detection_output_loss: 0.1283 - classification_output_loss: 0.6572 - regression_output_loss: 0.0058 - detection_output_binary_accuracy: 0.9335 - classification_output_sparse_categorical_accuracy: 0.7431 - regression_output_mae: 0.0386
# Epoch 24: val_classification_output_sparse_categorical_accuracy did not improve from 0.78333
# 443/443 [==============================] - 6s 13ms/step - loss: 1.4196 - detection_output_loss: 0.1288 - classification_output_loss: 0.6574 - regression_output_loss: 0.0058 - detection_output_binary_accuracy: 0.9333 - classification_output_sparse_categorical_accuracy: 0.7429 - regression_output_mae: 0.0386 - val_loss: 1.4325 - val_detection_output_loss: 0.1552 - val_classification_output_loss: 0.6530 - val_regression_output_loss: 0.0079 - val_detection_output_binary_accuracy: 0.9274 - val_classification_output_sparse_categorical_accuracy: 0.7414 - val_regression_output_mae: 0.0481 - lr: 0.0010
# Epoch 25/120
# 439/443 [============================>.] - ETA: 0s - loss: 1.4103 - detection_output_loss: 0.1296 - classification_output_loss: 0.6525 - regression_output_loss: 0.0053 - detection_output_binary_accuracy: 0.9322 - classification_output_sparse_categorical_accuracy: 0.7442 - regression_output_mae: 0.0370
# Epoch 25: val_classification_output_sparse_categorical_accuracy did not improve from 0.78333
# 443/443 [==============================] - 6s 12ms/step - loss: 1.4101 - detection_output_loss: 0.1296 - classification_output_loss: 0.6524 - regression_output_loss: 0.0053 - detection_output_binary_accuracy: 0.9322 - classification_output_sparse_categorical_accuracy: 0.7441 - regression_output_mae: 0.0370 - val_loss: 1.2873 - val_detection_output_loss: 0.1238 - val_classification_output_loss: 0.5932 - val_regression_output_loss: 0.0059 - val_detection_output_binary_accuracy: 0.9383 - val_classification_output_sparse_categorical_accuracy: 0.7688 - val_regression_output_mae: 0.0395 - lr: 0.0010
# Epoch 26/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.3941 - detection_output_loss: 0.1279 - classification_output_loss: 0.6452 - regression_output_loss: 0.0049 - detection_output_binary_accuracy: 0.9342 - classification_output_sparse_categorical_accuracy: 0.7491 - regression_output_mae: 0.0362
# Epoch 26: val_classification_output_sparse_categorical_accuracy improved from 0.78333 to 0.78988, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.3953 - detection_output_loss: 0.1281 - classification_output_loss: 0.6457 - regression_output_loss: 0.0049 - detection_output_binary_accuracy: 0.9339 - classification_output_sparse_categorical_accuracy: 0.7489 - regression_output_mae: 0.0362 - val_loss: 1.1902 - val_detection_output_loss: 0.1150 - val_classification_output_loss: 0.5485 - val_regression_output_loss: 0.0045 - val_detection_output_binary_accuracy: 0.9458 - val_classification_output_sparse_categorical_accuracy: 0.7899 - val_regression_output_mae: 0.0345 - lr: 0.0010
# Epoch 27/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.3922 - detection_output_loss: 0.1287 - classification_output_loss: 0.6439 - regression_output_loss: 0.0047 - detection_output_binary_accuracy: 0.9338 - classification_output_sparse_categorical_accuracy: 0.7484 - regression_output_mae: 0.0350
# Epoch 27: val_classification_output_sparse_categorical_accuracy improved from 0.78988 to 0.79185, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 12ms/step - loss: 1.3916 - detection_output_loss: 0.1287 - classification_output_loss: 0.6436 - regression_output_loss: 0.0047 - detection_output_binary_accuracy: 0.9338 - classification_output_sparse_categorical_accuracy: 0.7485 - regression_output_mae: 0.0350 - val_loss: 1.1343 - val_detection_output_loss: 0.1132 - val_classification_output_loss: 0.5211 - val_regression_output_loss: 0.0053 - val_detection_output_binary_accuracy: 0.9456 - val_classification_output_sparse_categorical_accuracy: 0.7919 - val_regression_output_mae: 0.0387 - lr: 0.0010
# Epoch 28/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.3814 - detection_output_loss: 0.1280 - classification_output_loss: 0.6388 - regression_output_loss: 0.0047 - detection_output_binary_accuracy: 0.9339 - classification_output_sparse_categorical_accuracy: 0.7490 - regression_output_mae: 0.0350
# Epoch 28: val_classification_output_sparse_categorical_accuracy did not improve from 0.79185
# 443/443 [==============================] - 6s 13ms/step - loss: 1.3811 - detection_output_loss: 0.1279 - classification_output_loss: 0.6387 - regression_output_loss: 0.0047 - detection_output_binary_accuracy: 0.9340 - classification_output_sparse_categorical_accuracy: 0.7490 - regression_output_mae: 0.0351 - val_loss: 1.3610 - val_detection_output_loss: 0.1642 - val_classification_output_loss: 0.6134 - val_regression_output_loss: 0.0097 - val_detection_output_binary_accuracy: 0.9162 - val_classification_output_sparse_categorical_accuracy: 0.7567 - val_regression_output_mae: 0.0507 - lr: 0.0010
# Epoch 29/120
# 443/443 [==============================] - ETA: 0s - loss: 1.3734 - detection_output_loss: 0.1281 - classification_output_loss: 0.6348 - regression_output_loss: 0.0044 - detection_output_binary_accuracy: 0.9337 - classification_output_sparse_categorical_accuracy: 0.7516 - regression_output_mae: 0.0339
# Epoch 29: val_classification_output_sparse_categorical_accuracy did not improve from 0.79185
# 443/443 [==============================] - 6s 13ms/step - loss: 1.3734 - detection_output_loss: 0.1281 - classification_output_loss: 0.6348 - regression_output_loss: 0.0044 - detection_output_binary_accuracy: 0.9337 - classification_output_sparse_categorical_accuracy: 0.7516 - regression_output_mae: 0.0339 - val_loss: 1.1883 - val_detection_output_loss: 0.1144 - val_classification_output_loss: 0.5478 - val_regression_output_loss: 0.0041 - val_detection_output_binary_accuracy: 0.9448 - val_classification_output_sparse_categorical_accuracy: 0.7893 - val_regression_output_mae: 0.0331 - lr: 0.0010
# Epoch 30/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.3759 - detection_output_loss: 0.1271 - classification_output_loss: 0.6365 - regression_output_loss: 0.0041 - detection_output_binary_accuracy: 0.9349 - classification_output_sparse_categorical_accuracy: 0.7509 - regression_output_mae: 0.0329
# Epoch 30: val_classification_output_sparse_categorical_accuracy did not improve from 0.79185
# 443/443 [==============================] - 6s 12ms/step - loss: 1.3754 - detection_output_loss: 0.1270 - classification_output_loss: 0.6363 - regression_output_loss: 0.0041 - detection_output_binary_accuracy: 0.9350 - classification_output_sparse_categorical_accuracy: 0.7510 - regression_output_mae: 0.0329 - val_loss: 1.2408 - val_detection_output_loss: 0.1295 - val_classification_output_loss: 0.5677 - val_regression_output_loss: 0.0058 - val_detection_output_binary_accuracy: 0.9338 - val_classification_output_sparse_categorical_accuracy: 0.7791 - val_regression_output_mae: 0.0391 - lr: 0.0010
# Epoch 31/120
# 443/443 [==============================] - ETA: 0s - loss: 1.3495 - detection_output_loss: 0.1251 - classification_output_loss: 0.6241 - regression_output_loss: 0.0040 - detection_output_binary_accuracy: 0.9362 - classification_output_sparse_categorical_accuracy: 0.7552 - regression_output_mae: 0.0327
# Epoch 31: val_classification_output_sparse_categorical_accuracy did not improve from 0.79185
# 443/443 [==============================] - 6s 13ms/step - loss: 1.3495 - detection_output_loss: 0.1251 - classification_output_loss: 0.6241 - regression_output_loss: 0.0040 - detection_output_binary_accuracy: 0.9362 - classification_output_sparse_categorical_accuracy: 0.7552 - regression_output_mae: 0.0327 - val_loss: 1.2439 - val_detection_output_loss: 0.1234 - val_classification_output_loss: 0.5719 - val_regression_output_loss: 0.0044 - val_detection_output_binary_accuracy: 0.9399 - val_classification_output_sparse_categorical_accuracy: 0.7794 - val_regression_output_mae: 0.0340 - lr: 0.0010
# Epoch 32/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.3551 - detection_output_loss: 0.1245 - classification_output_loss: 0.6271 - regression_output_loss: 0.0042 - detection_output_binary_accuracy: 0.9357 - classification_output_sparse_categorical_accuracy: 0.7531 - regression_output_mae: 0.0333
# Epoch 32: val_classification_output_sparse_categorical_accuracy improved from 0.79185 to 0.79235, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 13ms/step - loss: 1.3547 - detection_output_loss: 0.1245 - classification_output_loss: 0.6269 - regression_output_loss: 0.0042 - detection_output_binary_accuracy: 0.9357 - classification_output_sparse_categorical_accuracy: 0.7532 - regression_output_mae: 0.0333 - val_loss: 1.1935 - val_detection_output_loss: 0.1154 - val_classification_output_loss: 0.5501 - val_regression_output_loss: 0.0032 - val_detection_output_binary_accuracy: 0.9416 - val_classification_output_sparse_categorical_accuracy: 0.7923 - val_regression_output_mae: 0.0305 - lr: 0.0010
# Epoch 33/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.3557 - detection_output_loss: 0.1259 - classification_output_loss: 0.6269 - regression_output_loss: 0.0038 - detection_output_binary_accuracy: 0.9352 - classification_output_sparse_categorical_accuracy: 0.7549 - regression_output_mae: 0.0319
# Epoch 33: val_classification_output_sparse_categorical_accuracy did not improve from 0.79235
# 443/443 [==============================] - 6s 13ms/step - loss: 1.3557 - detection_output_loss: 0.1258 - classification_output_loss: 0.6269 - regression_output_loss: 0.0038 - detection_output_binary_accuracy: 0.9352 - classification_output_sparse_categorical_accuracy: 0.7548 - regression_output_mae: 0.0319 - val_loss: 1.2429 - val_detection_output_loss: 0.1260 - val_classification_output_loss: 0.5704 - val_regression_output_loss: 0.0045 - val_detection_output_binary_accuracy: 0.9330 - val_classification_output_sparse_categorical_accuracy: 0.7864 - val_regression_output_mae: 0.0356 - lr: 0.0010
# Epoch 34/120
# 439/443 [============================>.] - ETA: 0s - loss: 1.3455 - detection_output_loss: 0.1237 - classification_output_loss: 0.6227 - regression_output_loss: 0.0036 - detection_output_binary_accuracy: 0.9366 - classification_output_sparse_categorical_accuracy: 0.7551 - regression_output_mae: 0.0313
# Epoch 34: val_classification_output_sparse_categorical_accuracy improved from 0.79235 to 0.80543, saving model to models/shared_bottom_model_0.keras
# 443/443 [==============================] - 6s 12ms/step - loss: 1.3449 - detection_output_loss: 0.1239 - classification_output_loss: 0.6223 - regression_output_loss: 0.0036 - detection_output_binary_accuracy: 0.9366 - classification_output_sparse_categorical_accuracy: 0.7554 - regression_output_mae: 0.0313 - val_loss: 1.1087 - val_detection_output_loss: 0.1076 - val_classification_output_loss: 0.5107 - val_regression_output_loss: 0.0037 - val_detection_output_binary_accuracy: 0.9478 - val_classification_output_sparse_categorical_accuracy: 0.8054 - val_regression_output_mae: 0.0316 - lr: 0.0010
# Epoch 35/120
# 439/443 [============================>.] - ETA: 0s - loss: 1.3413 - detection_output_loss: 0.1239 - classification_output_loss: 0.6205 - regression_output_loss: 0.0035 - detection_output_binary_accuracy: 0.9368 - classification_output_sparse_categorical_accuracy: 0.7566 - regression_output_mae: 0.0310
# Epoch 35: val_classification_output_sparse_categorical_accuracy did not improve from 0.80543
# 443/443 [==============================] - 6s 12ms/step - loss: 1.3415 - detection_output_loss: 0.1239 - classification_output_loss: 0.6207 - regression_output_loss: 0.0035 - detection_output_binary_accuracy: 0.9368 - classification_output_sparse_categorical_accuracy: 0.7563 - regression_output_mae: 0.0309 - val_loss: 1.1027 - val_detection_output_loss: 0.1063 - val_classification_output_loss: 0.5081 - val_regression_output_loss: 0.0050 - val_detection_output_binary_accuracy: 0.9514 - val_classification_output_sparse_categorical_accuracy: 0.7978 - val_regression_output_mae: 0.0373 - lr: 0.0010
# Epoch 36/120
# 443/443 [==============================] - ETA: 0s - loss: 1.3272 - detection_output_loss: 0.1226 - classification_output_loss: 0.6140 - regression_output_loss: 0.0035 - detection_output_binary_accuracy: 0.9369 - classification_output_sparse_categorical_accuracy: 0.7606 - regression_output_mae: 0.0305
# Epoch 36: val_classification_output_sparse_categorical_accuracy did not improve from 0.80543
# 443/443 [==============================] - 6s 12ms/step - loss: 1.3272 - detection_output_loss: 0.1226 - classification_output_loss: 0.6140 - regression_output_loss: 0.0035 - detection_output_binary_accuracy: 0.9369 - classification_output_sparse_categorical_accuracy: 0.7606 - regression_output_mae: 0.0305 - val_loss: 1.1289 - val_detection_output_loss: 0.1063 - val_classification_output_loss: 0.5209 - val_regression_output_loss: 0.0067 - val_detection_output_binary_accuracy: 0.9480 - val_classification_output_sparse_categorical_accuracy: 0.7979 - val_regression_output_mae: 0.0447 - lr: 0.0010
# Epoch 37/120
# 443/443 [==============================] - ETA: 0s - loss: 1.3126 - detection_output_loss: 0.1229 - classification_output_loss: 0.6066 - regression_output_loss: 0.0033 - detection_output_binary_accuracy: 0.9372 - classification_output_sparse_categorical_accuracy: 0.7636 - regression_output_mae: 0.0299
# Epoch 37: val_classification_output_sparse_categorical_accuracy did not improve from 0.80543
# 443/443 [==============================] - 6s 13ms/step - loss: 1.3126 - detection_output_loss: 0.1229 - classification_output_loss: 0.6066 - regression_output_loss: 0.0033 - detection_output_binary_accuracy: 0.9372 - classification_output_sparse_categorical_accuracy: 0.7636 - regression_output_mae: 0.0299 - val_loss: 1.2055 - val_detection_output_loss: 0.1147 - val_classification_output_loss: 0.5564 - val_regression_output_loss: 0.0033 - val_detection_output_binary_accuracy: 0.9406 - val_classification_output_sparse_categorical_accuracy: 0.7795 - val_regression_output_mae: 0.0296 - lr: 0.0010
# Epoch 38/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.3144 - detection_output_loss: 0.1217 - classification_output_loss: 0.6080 - regression_output_loss: 0.0031 - detection_output_binary_accuracy: 0.9377 - classification_output_sparse_categorical_accuracy: 0.7595 - regression_output_mae: 0.0292
# Epoch 38: val_classification_output_sparse_categorical_accuracy did not improve from 0.80543
# 443/443 [==============================] - 6s 12ms/step - loss: 1.3144 - detection_output_loss: 0.1218 - classification_output_loss: 0.6080 - regression_output_loss: 0.0031 - detection_output_binary_accuracy: 0.9376 - classification_output_sparse_categorical_accuracy: 0.7595 - regression_output_mae: 0.0292 - val_loss: 1.1313 - val_detection_output_loss: 0.1158 - val_classification_output_loss: 0.5189 - val_regression_output_loss: 0.0031 - val_detection_output_binary_accuracy: 0.9400 - val_classification_output_sparse_categorical_accuracy: 0.7925 - val_regression_output_mae: 0.0300 - lr: 0.0010
# Epoch 39/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.3077 - detection_output_loss: 0.1224 - classification_output_loss: 0.6044 - regression_output_loss: 0.0029 - detection_output_binary_accuracy: 0.9375 - classification_output_sparse_categorical_accuracy: 0.7616 - regression_output_mae: 0.0284
# Epoch 39: val_classification_output_sparse_categorical_accuracy did not improve from 0.80543
# 443/443 [==============================] - 6s 13ms/step - loss: 1.3081 - detection_output_loss: 0.1227 - classification_output_loss: 0.6046 - regression_output_loss: 0.0029 - detection_output_binary_accuracy: 0.9373 - classification_output_sparse_categorical_accuracy: 0.7616 - regression_output_mae: 0.0284 - val_loss: 1.2565 - val_detection_output_loss: 0.1204 - val_classification_output_loss: 0.5794 - val_regression_output_loss: 0.0047 - val_detection_output_binary_accuracy: 0.9385 - val_classification_output_sparse_categorical_accuracy: 0.7744 - val_regression_output_mae: 0.0348 - lr: 0.0010
# Epoch 40/120
# 443/443 [==============================] - ETA: 0s - loss: 1.3057 - detection_output_loss: 0.1213 - classification_output_loss: 0.6039 - regression_output_loss: 0.0029 - detection_output_binary_accuracy: 0.9385 - classification_output_sparse_categorical_accuracy: 0.7628 - regression_output_mae: 0.0281
# Epoch 40: val_classification_output_sparse_categorical_accuracy did not improve from 0.80543
# 443/443 [==============================] - 6s 13ms/step - loss: 1.3057 - detection_output_loss: 0.1213 - classification_output_loss: 0.6039 - regression_output_loss: 0.0029 - detection_output_binary_accuracy: 0.9385 - classification_output_sparse_categorical_accuracy: 0.7628 - regression_output_mae: 0.0281 - val_loss: 1.1544 - val_detection_output_loss: 0.1319 - val_classification_output_loss: 0.5238 - val_regression_output_loss: 0.0044 - val_detection_output_binary_accuracy: 0.9302 - val_classification_output_sparse_categorical_accuracy: 0.7886 - val_regression_output_mae: 0.0351 - lr: 0.0010
# Epoch 41/120
# 443/443 [==============================] - ETA: 0s - loss: 1.2923 - detection_output_loss: 0.1208 - classification_output_loss: 0.5974 - regression_output_loss: 0.0026 - detection_output_binary_accuracy: 0.9388 - classification_output_sparse_categorical_accuracy: 0.7648 - regression_output_mae: 0.0272
# Epoch 41: val_classification_output_sparse_categorical_accuracy did not improve from 0.80543
# 443/443 [==============================] - 6s 12ms/step - loss: 1.2923 - detection_output_loss: 0.1208 - classification_output_loss: 0.5974 - regression_output_loss: 0.0026 - detection_output_binary_accuracy: 0.9388 - classification_output_sparse_categorical_accuracy: 0.7648 - regression_output_mae: 0.0272 - val_loss: 1.0932 - val_detection_output_loss: 0.1122 - val_classification_output_loss: 0.5011 - val_regression_output_loss: 0.0039 - val_detection_output_binary_accuracy: 0.9472 - val_classification_output_sparse_categorical_accuracy: 0.8000 - val_regression_output_mae: 0.0329 - lr: 0.0010
# Epoch 42/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.2920 - detection_output_loss: 0.1214 - classification_output_loss: 0.5970 - regression_output_loss: 0.0026 - detection_output_binary_accuracy: 0.9376 - classification_output_sparse_categorical_accuracy: 0.7655 - regression_output_mae: 0.0267
# Epoch 42: val_classification_output_sparse_categorical_accuracy did not improve from 0.80543
# 443/443 [==============================] - 6s 13ms/step - loss: 1.2922 - detection_output_loss: 0.1214 - classification_output_loss: 0.5971 - regression_output_loss: 0.0026 - detection_output_binary_accuracy: 0.9375 - classification_output_sparse_categorical_accuracy: 0.7654 - regression_output_mae: 0.0267 - val_loss: 1.2100 - val_detection_output_loss: 0.1171 - val_classification_output_loss: 0.5576 - val_regression_output_loss: 0.0037 - val_detection_output_binary_accuracy: 0.9420 - val_classification_output_sparse_categorical_accuracy: 0.7909 - val_regression_output_mae: 0.0317 - lr: 0.0010
# Epoch 43/120
# 439/443 [============================>.] - ETA: 0s - loss: 1.2951 - detection_output_loss: 0.1214 - classification_output_loss: 0.5986 - regression_output_loss: 0.0025 - detection_output_binary_accuracy: 0.9388 - classification_output_sparse_categorical_accuracy: 0.7644 - regression_output_mae: 0.0265
# Epoch 43: val_classification_output_sparse_categorical_accuracy did not improve from 0.80543
# 443/443 [==============================] - 6s 12ms/step - loss: 1.2957 - detection_output_loss: 0.1218 - classification_output_loss: 0.5988 - regression_output_loss: 0.0025 - detection_output_binary_accuracy: 0.9385 - classification_output_sparse_categorical_accuracy: 0.7644 - regression_output_mae: 0.0265 - val_loss: 1.1969 - val_detection_output_loss: 0.1132 - val_classification_output_loss: 0.5512 - val_regression_output_loss: 0.0133 - val_detection_output_binary_accuracy: 0.9447 - val_classification_output_sparse_categorical_accuracy: 0.7801 - val_regression_output_mae: 0.0644 - lr: 0.0010
# Epoch 44/120
# ...
# Epoch 107: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0625 - detection_output_loss: 0.1013 - classification_output_loss: 0.4907 - regression_output_loss: 1.6289e-04 - detection_output_binary_accuracy: 0.9512 - classification_output_sparse_categorical_accuracy: 0.8061 - regression_output_mae: 0.0078 - val_loss: 0.9141 - val_detection_output_loss: 0.1047 - val_classification_output_loss: 0.4152 - val_regression_output_loss: 1.3828e-04 - val_detection_output_binary_accuracy: 0.9499 - val_classification_output_sparse_categorical_accuracy: 0.8340 - val_regression_output_mae: 0.0071 - lr: 1.2500e-04
# Epoch 108/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.0601 - detection_output_loss: 0.1009 - classification_output_loss: 0.4897 - regression_output_loss: 1.6780e-04 - detection_output_binary_accuracy: 0.9516 - classification_output_sparse_categorical_accuracy: 0.8066 - regression_output_mae: 0.0079
# Epoch 108: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0604 - detection_output_loss: 0.1009 - classification_output_loss: 0.4898 - regression_output_loss: 1.6790e-04 - detection_output_binary_accuracy: 0.9516 - classification_output_sparse_categorical_accuracy: 0.8065 - regression_output_mae: 0.0079 - val_loss: 0.9313 - val_detection_output_loss: 0.1061 - val_classification_output_loss: 0.4232 - val_regression_output_loss: 1.6224e-04 - val_detection_output_binary_accuracy: 0.9489 - val_classification_output_sparse_categorical_accuracy: 0.8294 - val_regression_output_mae: 0.0079 - lr: 1.2500e-04
# Epoch 109/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.0680 - detection_output_loss: 0.1026 - classification_output_loss: 0.4929 - regression_output_loss: 1.6876e-04 - detection_output_binary_accuracy: 0.9502 - classification_output_sparse_categorical_accuracy: 0.8028 - regression_output_mae: 0.0079
# Epoch 109: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 109: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0678 - detection_output_loss: 0.1027 - classification_output_loss: 0.4928 - regression_output_loss: 1.6874e-04 - detection_output_binary_accuracy: 0.9502 - classification_output_sparse_categorical_accuracy: 0.8029 - regression_output_mae: 0.0079 - val_loss: 0.9348 - val_detection_output_loss: 0.1114 - val_classification_output_loss: 0.4228 - val_regression_output_loss: 1.4276e-04 - val_detection_output_binary_accuracy: 0.9510 - val_classification_output_sparse_categorical_accuracy: 0.8354 - val_regression_output_mae: 0.0071 - lr: 1.2500e-04
# Epoch 110/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.0542 - detection_output_loss: 0.0993 - classification_output_loss: 0.4873 - regression_output_loss: 1.4609e-04 - detection_output_binary_accuracy: 0.9515 - classification_output_sparse_categorical_accuracy: 0.8061 - regression_output_mae: 0.0073
# Epoch 110: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0541 - detection_output_loss: 0.0994 - classification_output_loss: 0.4873 - regression_output_loss: 1.4623e-04 - detection_output_binary_accuracy: 0.9515 - classification_output_sparse_categorical_accuracy: 0.8062 - regression_output_mae: 0.0073 - val_loss: 0.9150 - val_detection_output_loss: 0.1043 - val_classification_output_loss: 0.4158 - val_regression_output_loss: 1.2241e-04 - val_detection_output_binary_accuracy: 0.9509 - val_classification_output_sparse_categorical_accuracy: 0.8327 - val_regression_output_mae: 0.0065 - lr: 6.2500e-05
# Epoch 111/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.0589 - detection_output_loss: 0.1013 - classification_output_loss: 0.4889 - regression_output_loss: 1.4901e-04 - detection_output_binary_accuracy: 0.9516 - classification_output_sparse_categorical_accuracy: 0.8060 - regression_output_mae: 0.0072
# Epoch 111: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0579 - detection_output_loss: 0.1013 - classification_output_loss: 0.4884 - regression_output_loss: 1.4889e-04 - detection_output_binary_accuracy: 0.9516 - classification_output_sparse_categorical_accuracy: 0.8062 - regression_output_mae: 0.0072 - val_loss: 0.9179 - val_detection_output_loss: 0.1065 - val_classification_output_loss: 0.4163 - val_regression_output_loss: 1.2356e-04 - val_detection_output_binary_accuracy: 0.9530 - val_classification_output_sparse_categorical_accuracy: 0.8336 - val_regression_output_mae: 0.0068 - lr: 6.2500e-05
# Epoch 112/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.0479 - detection_output_loss: 0.0998 - classification_output_loss: 0.4840 - regression_output_loss: 1.4417e-04 - detection_output_binary_accuracy: 0.9517 - classification_output_sparse_categorical_accuracy: 0.8063 - regression_output_mae: 0.0072
# Epoch 112: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0481 - detection_output_loss: 0.0998 - classification_output_loss: 0.4841 - regression_output_loss: 1.4415e-04 - detection_output_binary_accuracy: 0.9517 - classification_output_sparse_categorical_accuracy: 0.8062 - regression_output_mae: 0.0072 - val_loss: 0.9174 - val_detection_output_loss: 0.1040 - val_classification_output_loss: 0.4171 - val_regression_output_loss: 1.2302e-04 - val_detection_output_binary_accuracy: 0.9526 - val_classification_output_sparse_categorical_accuracy: 0.8328 - val_regression_output_mae: 0.0065 - lr: 6.2500e-05
# Epoch 113/120
# 443/443 [==============================] - ETA: 0s - loss: 1.0645 - detection_output_loss: 0.1013 - classification_output_loss: 0.4917 - regression_output_loss: 1.4159e-04 - detection_output_binary_accuracy: 0.9501 - classification_output_sparse_categorical_accuracy: 0.8044 - regression_output_mae: 0.0072
# Epoch 113: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0645 - detection_output_loss: 0.1013 - classification_output_loss: 0.4917 - regression_output_loss: 1.4159e-04 - detection_output_binary_accuracy: 0.9501 - classification_output_sparse_categorical_accuracy: 0.8044 - regression_output_mae: 0.0072 - val_loss: 0.9100 - val_detection_output_loss: 0.1033 - val_classification_output_loss: 0.4137 - val_regression_output_loss: 1.2219e-04 - val_detection_output_binary_accuracy: 0.9519 - val_classification_output_sparse_categorical_accuracy: 0.8338 - val_regression_output_mae: 0.0067 - lr: 6.2500e-05
# Epoch 114/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.0544 - detection_output_loss: 0.1003 - classification_output_loss: 0.4871 - regression_output_loss: 1.4149e-04 - detection_output_binary_accuracy: 0.9509 - classification_output_sparse_categorical_accuracy: 0.8068 - regression_output_mae: 0.0072
# Epoch 114: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0548 - detection_output_loss: 0.1003 - classification_output_loss: 0.4872 - regression_output_loss: 1.4149e-04 - detection_output_binary_accuracy: 0.9509 - classification_output_sparse_categorical_accuracy: 0.8067 - regression_output_mae: 0.0072 - val_loss: 0.9176 - val_detection_output_loss: 0.1050 - val_classification_output_loss: 0.4167 - val_regression_output_loss: 1.2616e-04 - val_detection_output_binary_accuracy: 0.9491 - val_classification_output_sparse_categorical_accuracy: 0.8341 - val_regression_output_mae: 0.0068 - lr: 6.2500e-05
# Epoch 115/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.0501 - detection_output_loss: 0.0997 - classification_output_loss: 0.4851 - regression_output_loss: 1.4218e-04 - detection_output_binary_accuracy: 0.9527 - classification_output_sparse_categorical_accuracy: 0.8053 - regression_output_mae: 0.0072
# Epoch 115: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 12ms/step - loss: 1.0498 - detection_output_loss: 0.0996 - classification_output_loss: 0.4850 - regression_output_loss: 1.4284e-04 - detection_output_binary_accuracy: 0.9528 - classification_output_sparse_categorical_accuracy: 0.8054 - regression_output_mae: 0.0072 - val_loss: 0.9142 - val_detection_output_loss: 0.1042 - val_classification_output_loss: 0.4154 - val_regression_output_loss: 1.3314e-04 - val_detection_output_binary_accuracy: 0.9511 - val_classification_output_sparse_categorical_accuracy: 0.8357 - val_regression_output_mae: 0.0068 - lr: 6.2500e-05
# Epoch 116/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.0509 - detection_output_loss: 0.1003 - classification_output_loss: 0.4853 - regression_output_loss: 1.4319e-04 - detection_output_binary_accuracy: 0.9503 - classification_output_sparse_categorical_accuracy: 0.8066 - regression_output_mae: 0.0072
# Epoch 116: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 12ms/step - loss: 1.0520 - detection_output_loss: 0.1006 - classification_output_loss: 0.4857 - regression_output_loss: 1.4297e-04 - detection_output_binary_accuracy: 0.9503 - classification_output_sparse_categorical_accuracy: 0.8064 - regression_output_mae: 0.0072 - val_loss: 0.9155 - val_detection_output_loss: 0.1036 - val_classification_output_loss: 0.4163 - val_regression_output_loss: 1.2574e-04 - val_detection_output_binary_accuracy: 0.9517 - val_classification_output_sparse_categorical_accuracy: 0.8344 - val_regression_output_mae: 0.0068 - lr: 6.2500e-05
# Epoch 117/120
# 439/443 [============================>.] - ETA: 0s - loss: 1.0560 - detection_output_loss: 0.1017 - classification_output_loss: 0.4873 - regression_output_loss: 1.3960e-04 - detection_output_binary_accuracy: 0.9505 - classification_output_sparse_categorical_accuracy: 0.8057 - regression_output_mae: 0.0071
# Epoch 117: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0562 - detection_output_loss: 0.1016 - classification_output_loss: 0.4874 - regression_output_loss: 1.3947e-04 - detection_output_binary_accuracy: 0.9506 - classification_output_sparse_categorical_accuracy: 0.8056 - regression_output_mae: 0.0071 - val_loss: 0.9216 - val_detection_output_loss: 0.1051 - val_classification_output_loss: 0.4187 - val_regression_output_loss: 1.3442e-04 - val_detection_output_binary_accuracy: 0.9498 - val_classification_output_sparse_categorical_accuracy: 0.8349 - val_regression_output_mae: 0.0068 - lr: 6.2500e-05
# Epoch 118/120
# 443/443 [==============================] - ETA: 0s - loss: 1.0578 - detection_output_loss: 0.1013 - classification_output_loss: 0.4884 - regression_output_loss: 1.4282e-04 - detection_output_binary_accuracy: 0.9503 - classification_output_sparse_categorical_accuracy: 0.8056 - regression_output_mae: 0.0072
# Epoch 118: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0578 - detection_output_loss: 0.1013 - classification_output_loss: 0.4884 - regression_output_loss: 1.4282e-04 - detection_output_binary_accuracy: 0.9503 - classification_output_sparse_categorical_accuracy: 0.8056 - regression_output_mae: 0.0072 - val_loss: 0.9109 - val_detection_output_loss: 0.1034 - val_classification_output_loss: 0.4141 - val_regression_output_loss: 1.1809e-04 - val_detection_output_binary_accuracy: 0.9509 - val_classification_output_sparse_categorical_accuracy: 0.8352 - val_regression_output_mae: 0.0063 - lr: 6.2500e-05
# Epoch 119/120
# 443/443 [==============================] - ETA: 0s - loss: 1.0482 - detection_output_loss: 0.1003 - classification_output_loss: 0.4839 - regression_output_loss: 1.4368e-04 - detection_output_binary_accuracy: 0.9504 - classification_output_sparse_categorical_accuracy: 0.8081 - regression_output_mae: 0.0072Restoring model weights from the end of the best epoch: 99.
#
# Epoch 119: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 119: val_classification_output_sparse_categorical_accuracy did not improve from 0.83617
# 443/443 [==============================] - 6s 13ms/step - loss: 1.0482 - detection_output_loss: 0.1003 - classification_output_loss: 0.4839 - regression_output_loss: 1.4368e-04 - detection_output_binary_accuracy: 0.9504 - classification_output_sparse_categorical_accuracy: 0.8081 - regression_output_mae: 0.0072 - val_loss: 0.9150 - val_detection_output_loss: 0.1044 - val_classification_output_loss: 0.4157 - val_regression_output_loss: 1.3521e-04 - val_detection_output_binary_accuracy: 0.9504 - val_classification_output_sparse_categorical_accuracy: 0.8359 - val_regression_output_mae: 0.0070 - lr: 6.2500e-05
# Epoch 119: early stopping
# ✅ 模型 3 训练完成，耗时 735.36 秒
# 2025-10-20 12:47:47.835248: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [16200]
# 	 [[{{node Placeholder/_2}}]]
# ================================================================================
# 📥 SharedBottom 输入信号（前 5 条）
# ================================================================================
# 样本 0: [ 2.000e-04  1.022e-01 -1.000e+01] ...
# 样本 1: [  0.021    0.0987 -10.    ] ...
# 样本 2: [ 3.80e-03  9.86e-02 -1.00e+01] ...
# 样本 3: [ 1.00e-04  1.02e-01 -1.00e+01] ...
# 样本 4: [ 1.200e-03  1.017e-01 -1.000e+01] ...
#
# ================================================================================
# 📤 SharedBottom 真实 vs 预测（前 5 条）
# ================================================================================
# 样本 0:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 2     |  cls_pred: 2
#   reg_true: [ 2.000e-04  1.022e-01 -1.000e+01]  |  reg_pred: [ 2.2937388e-03  9.9639200e-02 -9.9855509e+00]
# 样本 1:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 7     |  cls_pred: 7
#   reg_true: [  0.021    0.0987 -10.    ]  |  reg_pred: [ 0.01206516  0.08963158 -9.99405   ]
# 样本 2:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 3     |  cls_pred: 3
#   reg_true: [ 3.80e-03  9.86e-02 -1.00e+01]  |  reg_pred: [ 8.211254e-03  9.429928e-02 -9.982654e+00]
# 样本 3:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 7     |  cls_pred: 7
#   reg_true: [ 1.00e-04  1.02e-01 -1.00e+01]  |  reg_pred: [ 2.0404719e-03  1.0057894e-01 -9.9929390e+00]
# 样本 4:
#   det_true: 1.0000  |  det_pred: 0.9994
#   cls_true: 5     |  cls_pred: 5
#   reg_true: [ 1.200e-03  1.017e-01 -1.000e+01]  |  reg_pred: [ 1.74589211e-03  1.00856818e-01 -1.00060005e+01]
#
# ================================================================================
# 📈 SharedBottom NRMSE 报告（按列分别归一化）
# ================================================================================
# Start Time (ms): 0.0921
# End Time (ms): 0.0928
# JNR (dB): 1257083.2500
# 平均 NRMSE（三列分别归一化） = 419027.7812
# ✅ SharedBottom NRMSE 报告已写入 reports/SharedBottom_nrmse_report.txt
#
# ==================================================
# 📈 训练时间统计
# ==================================================
# 模型 1: 739.98 秒 (12.33 分钟)
# 模型 2: 750.85 秒 (12.51 分钟)
# 模型 3: 735.36 秒 (12.26 分钟)
# 🔥 总训练时间: 2226.19 秒 (37.10 分钟)
# ==================================================
#
# ✅ 所有 Shared-Bottom 模型训练完成！模型已保存至 models/shared_bottom_model_{i}.keras
# 📌 接下来可以使用 evaluate_models_nrmse_columnwise.py 进行加载、评估、画图、生成指标报告

# %%
# evaluate_shared_bottom_nrmse_columnwise.py
import os
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (confusion_matrix, accuracy_score, precision_score,
                             recall_score, f1_score, mean_absolute_error)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from matplotlib import font_manager as fm
import time

# ---------------------- 中文字体 ----------------------
def set_chinese_font():
    try:
        font_paths = ['/usr/share/fonts/truetype/wqy/wqy-microhei.ttc',
                      'C:/Windows/Fonts/simhei.ttf',
                      '/System/Library/Fonts/PingFang.ttc']
        for font_path in font_paths:
            if os.path.exists(font_path):
                fm.fontManager.addfont(font_path)
                plt.rcParams['font.family'] = fm.FontProperties(fname=font_path).get_name()
                plt.rcParams['axes.unicode_minus'] = False
                print(f"✅ 成功设置中文字体: {plt.rcParams['font.family']}")
                return True
        plt.rcParams['font.family'] = ['SimHei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("⚠️ 未找到指定字体，使用默认兼容字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False
set_chinese_font()

# ---------------------- 加载数据集 ----------------------
def load_dataset(npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"):
    data = np.load(npz_path, allow_pickle=True)
    signals = data["signals"]
    labels = data["labels"].astype(np.int32)
    jnr_values = data["jnr_values"].astype(np.float32)
    fs = float(data["fs"])
    L = int(data["L"])
    noise_power_db = float(data["noise_power_db"])
    type2label = data["type_to_label"].item()

    interference_type_names = {
        "satellite_signal": "Satellite_Signal",
        "single_tone": "Single_Tone",
        "comb_spectra": "Comb_Spectra",
        "sweeping": "Sweeping-LFM",
        "pulse": "Pulse",
        "frequency_hopping": "Frequency_Hopping",
        "noise_fm": "Noise_FM",
        "noise_am": "Noise_AM",
        "random_combination": "Random_Combination"
    }
    label2name = {i: interference_type_names[k] for k, i in type2label.items()}
    return {
        "signals": signals,
        "labels": labels,
        "jnr_values": jnr_values,
        "fs": fs,
        "L": L,
        "noise_power_db": noise_power_db,
        "type2label": type2label,
        "label2name": label2name
    }

# ---------------------- 在线估算标签 ----------------------
def estimate_start_end(signal, fs, threshold_factor=2.0):
    power = signal ** 2
    avg_pow = np.mean(power)
    thresh = threshold_factor * avg_pow
    above = power > thresh
    diff = np.diff(above.astype(int))
    starts = np.where(diff == 1)[0]
    ends = np.where(diff == -1)[0]
    if len(starts) == 0 or len(ends) == 0:
        return 0.0, 0.0
    return float(starts[0] / fs * 1e3), float(ends[-1] / fs * 1e3)

def estimate_jnr(signal, noise_power_db):
    total_power = 10 * np.log10(np.mean(signal ** 2) + 1e-12)
    return float(total_power - noise_power_db)

# ---------------------- 数据预处理 ----------------------
def preprocess_data(dataset):
    signals = dataset["signals"]
    labels = dataset["labels"]
    jnr_values = dataset["jnr_values"]
    L = dataset["L"]
    fs = dataset["fs"]
    noise_power_db = dataset["noise_power_db"]

    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() for s in signals])

    no_key = "satellite_signal"
    det_labels = (labels != dataset["type2label"][no_key]).astype(np.float32)

    # 使用在线估算方法替代缺失的 metadata
    param_labels = []
    for i, signal in enumerate(signals):
        start_time, end_time = estimate_start_end(signal, fs)
        jnr_db = jnr_values[i]  # 直接使用已有的 jnr_values
        param_labels.append([start_time, end_time, jnr_db])
    param_labels = np.array(param_labels, dtype=np.float32)

    X_test = signals
    y_det_test = det_labels
    y_type_test = labels
    y_param_test = param_labels
    jnr_test = jnr_values
    label2name = dataset["label2name"]

    return {
        "X_test": X_test,
        "y_det_test": y_det_test,
        "y_type_test": y_type_test,
        "y_param_test": y_param_test,
        "jnr_values_test": jnr_test,
        "label2name": label2name,
        "L": L
    }

# ---------------------- 按列分别归一化 NRMSE ----------------------
def nrmse_columnwise(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2, axis=0))  # shape (3,)
    y_range = np.max(y_true, axis=0) - np.min(y_true, axis=0)
    return rmse / (y_range + 1e-8)

# ---------------------- 加载模型并预测 ----------------------
def load_and_predict(model_paths, X_test):
    all_det, all_cls, all_reg = [], [], []
    for path in model_paths:
        print(f"🔁 加载模型: {path}")
        model = tf.keras.models.load_model(path)
        start_time = time.time()
        det, cls, reg = model.predict(X_test, verbose=0)
        end_time = time.time()
        prediction_time = end_time - start_time
        print(f"预测时间: {prediction_time:.2f} 秒")
        all_det.append(det)
        all_cls.append(cls)
        all_reg.append(reg)
    avg_det = np.mean(all_det, axis=0) > 0.5
    avg_cls = np.argmax(np.mean(all_cls, axis=0), axis=1)
    avg_reg = np.mean(all_reg, axis=0)
    return avg_det, avg_cls, avg_reg

# ---------------------- 绘制混淆矩阵 ----------------------
def plot_confusion_matrix(cm, labels, title, xlabel, ylabel, filename, dpi=150, rotate_x=False):
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
    cm_normalized = np.nan_to_num(cm_normalized)

    plt.figure(figsize=(12, 10))
    ax = sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues',
                     xticklabels=labels, yticklabels=labels, square=True, annot_kws={"size": 14})
    cbar = ax.collections[0].colorbar
    cbar.ax.tick_params(labelsize=14)

    plt.title(title, pad=20, fontsize=18)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.xticks(rotation=45 if rotate_x else 0, ha='right' if rotate_x else 'center', fontsize=14)
    plt.yticks(rotation=0, fontsize=14)
    plt.tight_layout()
    plt.savefig(filename, dpi=dpi)
    plt.close()

# ---------------------- 主评估函数 ----------------------
def evaluate(models_dir="models",
             npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz",
             wanted_jnr=np.arange(-10, 31, 5),
             dpi=150):
    os.makedirs("visualizations", exist_ok=True)
    os.makedirs("reports", exist_ok=True)

    dataset = load_dataset(npz_path)
    data = preprocess_data(dataset)

    X_test = data["X_test"]
    y_det_test = data["y_det_test"]
    y_type_test = data["y_type_test"]
    y_param_test = data["y_param_test"]
    jnr_test = data["jnr_values_test"]
    label2name = data["label2name"]

    model_paths = [os.path.join(models_dir, f"shared_bottom_model_{i}.keras") for i in range(3)]
    avg_det, avg_cls, avg_reg = load_and_predict(model_paths, X_test)

    # 1. 检测混淆矩阵
    cm_det = confusion_matrix(y_det_test, avg_det)
    plot_confusion_matrix(
        cm=cm_det,
        labels=['No Interference', 'Interference'],
        title='Shared-Bottom Interference Detection Confusion Matrix',
        xlabel='Predicted',
        ylabel='True',
        filename='visualizations/Shared-Bottom_detection_confusion_matrix.png',
        dpi=dpi,
        rotate_x=False
    )

    # 2. 分类混淆矩阵
    cm_type = confusion_matrix(y_type_test, avg_cls)
    plot_confusion_matrix(
        cm=cm_type,
        labels=[label2name[i] for i in sorted(label2name.keys())],
        title='Shared-Bottom Classification Confusion Matrix',
        xlabel='Predicted',
        ylabel='True',
        filename='visualizations/Shared-Bottom_classification_confusion_matrix.png',
        dpi=dpi,
        rotate_x=True
    )

    # 3. JNR vs 准确率
    jnr_acc = []
    for jnr in wanted_jnr:
        mask = jnr_test == jnr
        acc = np.nan if np.sum(mask) == 0 else accuracy_score(y_type_test[mask], avg_cls[mask])
        jnr_acc.append(acc)

    plt.figure(figsize=(8, 5))
    valid_mask = ~np.isnan(jnr_acc)
    plt.plot(wanted_jnr[valid_mask], np.array(jnr_acc)[valid_mask], marker='o', linewidth=2)
    if np.any(~valid_mask):
        plt.scatter(wanted_jnr[~valid_mask], [1.0] * np.sum(~valid_mask),
                    facecolors='none', edgecolors='r', s=60)
    plt.xlabel('JNR (dB)', fontsize=14)
    plt.ylabel('Accuracy', fontsize=14)
    plt.title('Classification Accuracy vs JNR', fontsize=16)
    plt.xticks(wanted_jnr)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.ylim(0, 1.05)
    plt.tight_layout()
    plt.savefig('visualizations/Shared-Bottom_jnr_vs_accuracy.png', dpi=dpi)
    plt.close()

    # 4. 指标 & 按列分别归一化 NRMSE
    det_acc = accuracy_score(y_det_test, avg_det)
    cls_acc = accuracy_score(y_type_test, avg_cls)
    cls_precision = precision_score(y_type_test, avg_cls, average='weighted', zero_division=0)
    cls_recall = recall_score(y_type_test, avg_cls, average='weighted', zero_division=0)
    cls_f1 = f1_score(y_type_test, avg_cls, average='weighted', zero_division=0)
    param_mae = mean_absolute_error(y_param_test, avg_reg, multioutput='raw_values')

    # 按列分别归一化 NRMSE
    param_nrmse = nrmse_columnwise(y_param_test, avg_reg)
    param_names = ['Start Time (ms)', 'End Time (ms)', 'JNR (dB)']

    print("\n" + "="*50)
    print("📊 评估结果")
    print("="*50)
    print(f"检测准确率: {det_acc:.4f}")
    print(f"分类准确率: {cls_acc:.4f}")
    print(f"分类精确率: {cls_precision:.4f}, 召回率: {cls_recall:.4f}, F1: {cls_f1:.4f}")
    print("\n参数估计误差（MAE & 按列 NRMSE）:")
    for i, (name, mae, nrmse) in enumerate(zip(param_names, param_mae, param_nrmse)):
        print(f"  {name}: MAE = {mae:.4f}, NRMSE = {nrmse:.4f}")
    print(f"  平均 NRMSE（三列分别归一化） = {np.mean(param_nrmse):.4f}")

    print("\nJNR 准确率:")
    for j, acc in zip(wanted_jnr, jnr_acc):
        print(f"  {int(j)}dB: {acc if not np.isnan(acc) else 'N/A'}")

    # 5. 保存报告
    report = {
        "detection_accuracy": float(det_acc),
        "classification_accuracy": float(cls_acc),
        "classification_precision": float(cls_precision),
        "classification_recall": float(cls_recall),
        "classification_f1": float(cls_f1),
        "parameter_mae": [float(m) for m in param_mae],
        "parameter_nrmse": [float(n) for n in param_nrmse],
        "average_columnwise_nrmse": float(np.mean(param_nrmse)),
        "parameter_details": {
            param_names[i]: {"mae": float(param_mae[i]), "nrmse": float(param_nrmse[i])}
            for i in range(len(param_names))
        },
        "jnr_accuracies": {f"{int(j)}dB": float(acc) if not np.isnan(acc) else None for j, acc in zip(wanted_jnr, jnr_acc)}
    }
    with open("reports/Shared-Bottom_evaluation_report.json", "w", encoding='utf-8') as f:
        json.dump(report, f, indent=4, ensure_ascii=False)

    print("\n✅ 评估完成！混淆矩阵与报告已保存。")

# ---------------------- 主函数 ----------------------
if __name__ == "__main__":
    evaluate(models_dir="models",
             npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz",
             wanted_jnr=np.arange(-10, 31, 5),
             dpi=150)
# Out:
# 2025-10-22 23:46:31.223366: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-22 23:46:31.262276: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-22 23:46:31.805218: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# 🔁 加载模型: models/shared_bottom_model_0.keras
# 2025-10-22 23:46:53.223588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 918 MB memory:  -> device: 0, name: NVIDIA vGPU-48GB, pci bus id: 0000:16:00.0, compute capability: 8.9
# 2025-10-22 23:46:53.972155: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-10-22 23:46:54.154538: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 预测时间: 7.44 秒
# 🔁 加载模型: models/shared_bottom_model_1.keras
# 预测时间: 6.56 秒
# 🔁 加载模型: models/shared_bottom_model_2.keras
# 预测时间: 6.48 秒
#
# ==================================================
# 📊 评估结果
# ==================================================
# 检测准确率: 0.9705
# 分类准确率: 0.8695
# 分类精确率: 0.8763, 召回率: 0.8695, F1: 0.8691
#
# 参数估计误差（MAE & 按列 NRMSE）:
#   Start Time (ms): MAE = 0.0055, NRMSE = 0.0936
#   End Time (ms): MAE = 0.0054, NRMSE = 0.0941
#   JNR (dB): MAE = 19.9985, NRMSE = 0.5950
#   平均 NRMSE（三列分别归一化） = 0.2609
#
# JNR 准确率:
#   -10dB: 0.5318888888888889
#   -5dB: 0.6877777777777778
#   0dB: 0.8317777777777777
#   5dB: 0.8957777777777778
#   10dB: 0.942
#   15dB: 0.9757777777777777
#   20dB: 0.9875555555555555
#   25dB: 0.9864444444444445
#   30dB: 0.9861111111111112
#
# ✅ 评估完成！混淆矩阵与报告已保存。

# %% [markdown]
# 预测时间: 7.44 秒
# 🔁 加载模型: models/shared_bottom_model_1.keras
# 预测时间: 6.56 秒
# 🔁 加载模型: models/shared_bottom_model_2.keras
# 预测时间: 6.48 秒
#
# ==================================================
# 📊 评估结果
# ==================================================
# 检测准确率: 0.9705
# 分类准确率: 0.8695
# 分类精确率: 0.8763, 召回率: 0.8695, F1: 0.8691
#
# 参数估计误差（MAE & 按列 NRMSE）:
#   Start Time (ms): MAE = 0.0055, NRMSE = 0.0936
#   End Time (ms): MAE = 0.0054, NRMSE = 0.0941
#   JNR (dB): MAE = 19.9985, NRMSE = 0.5950
#   平均 NRMSE（三列分别归一化） = 0.2609
#
# JNR 准确率:
#   -10dB: 0.5318888888888889
#   -5dB: 0.6877777777777778
#   0dB: 0.8317777777777777
#   5dB: 0.8957777777777778
#   10dB: 0.942
#   15dB: 0.9757777777777777
#   20dB: 0.9875555555555555
#   25dB: 0.9864444444444445
#   30dB: 0.9861111111111112
