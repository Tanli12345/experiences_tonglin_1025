# %%
# train_cnn_gru_classifier_keras.py
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv1D, MaxPooling1D, 
                                   Dense, Dropout, BatchNormalization,
                                   Reshape, GRU)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (EarlyStopping, ReduceLROnPlateau, 
                                      ModelCheckpoint)
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# ---------- 中文字体设置 ----------
def set_chinese_font():
    """安全设置中文字体"""
    try:
        font_paths = ['/usr/share/fonts/truetype/wqy/wqy-microhei.ttc',
                     'C:/Windows/Fonts/simhei.ttf',
                     '/System/Library/Fonts/PingFang.ttc']
        for path in font_paths:
            if os.path.exists(path):
                fm.fontManager.addfont(path)
                plt.rcParams['font.family'] = fm.FontProperties(fname=path).get_name()
                plt.rcParams['axes.unicode_minus'] = False
                print(f"✅ 成功设置中文字体: {plt.rcParams['font.family']}")
                return True
        plt.rcParams['font.family'] = ['SimHei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("⚠️ 使用系统默认中文字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False
set_chinese_font()

# ---------- 模型保存配置 ----------
MODEL_FORMAT = "keras"  # 可选: "keras" 或 "h5"
MODEL_VERSION = "v1.0"

def save_model(model, model_dir="models", model_name="cnn_gru_classifier"):
    """统一保存模型为Keras格式"""
    os.makedirs(model_dir, exist_ok=True)
    
    # 生成带时间戳的文件名
    timestamp = time.strftime("%Y%m%d_%H%M%S")
    filename = f"{model_name}_{MODEL_VERSION}_{timestamp}.keras"
    save_path = os.path.join(model_dir, filename)
    
    # 保存模型
    model.save(save_path, save_format="tf")  # 使用TensorFlow SavedModel格式保存为.keras文件
    print(f"✅ 模型已保存为Keras格式: {save_path}")
    
    # 创建latest符号链接（仅限Unix系统）
    latest_path = os.path.join(model_dir, f"{model_name}_latest.keras")
    try:
        if os.path.exists(latest_path):
            os.remove(latest_path)
        os.symlink(filename, latest_path)
        print(f"✅ 创建最新模型符号链接: {latest_path} -> {filename}")
    except Exception as e:
        print(f"⚠️ 无法创建符号链接: {e}")
    
    return save_path

# ---------- 加载数据集 ----------
def load_dataset(npz_path):
    """加载并处理数据集"""
    data = np.load(npz_path, allow_pickle=True)
    
    # 基础数据
    dataset = {
        "signals": data["signals"],
        "labels": data["labels"].astype(np.int32),
        "fs": float(data["fs"]),
        "L": int(data["L"])
    }
    
    # 处理干扰类型名称
    if "interference_type_names" in data:
        type_names = data["interference_type_names"].item() if isinstance(data["interference_type_names"], np.ndarray) else data["interference_type_names"]
    else:
        type_names = {
            "satellite_signal": "Satellite_Signal",
            "single_tone": "Single_Tone",
            "comb_spectra": "Comb_Spectra",
            "sweeping": "Sweeping-LFM",
            "pulse": "Pulse",
            "frequency_hopping": "Frequency_Hopping",
            "noise_fm": "Noise_FM",
            "noise_am": "Noise_AM",
            "random_combination": "Random_Combination"
        }
    
    # 创建标签映射
    if "type_to_label" in data:
        type2label = data["type_to_label"].item() if isinstance(data["type_to_label"], np.ndarray) else data["type_to_label"]
    else:
        type2label = {
            "satellite_signal": 0,
            "single_tone": 1,
            "comb_spectra": 2,
            "sweeping": 3,
            "pulse": 4,
            "frequency_hopping": 5,
            "noise_fm": 6,
            "noise_am": 7,
            "random_combination": 8
        }
    
    label2name = {int(i): str(type_names[k]) for k, i in type2label.items()}
    
    dataset.update({
        "type2label": type2label,
        "label2name": label2name
    })
    return dataset

# ---------- 数据预处理 ----------
def preprocess_data(dataset):
    """预处理数据"""
    # 信号标准化
    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() 
                       for s in dataset["signals"]])
    
    # 数据集分割（保持分层抽样）
    X_train, X_test, y_train, y_test = train_test_split(
        signals, dataset["labels"],
        test_size=0.3, random_state=42, 
        stratify=dataset["labels"]
    )
    X_val, X_test, y_val, y_test = train_test_split(
        X_test, y_test,
        test_size=0.5, random_state=42,
        stratify=y_test
    )
    
    return {
        "X_train": X_train, "X_val": X_val, "X_test": X_test,
        "y_train": y_train, "y_val": y_val, "y_test": y_test,
        "label2name": dataset["label2name"],
        "L": dataset["L"]
    }

# ---------- CNN-GRU模型构建 ----------
def build_model(input_shape, num_classes):
    """构建CNN-GRU分类模型"""
    inputs = Input(shape=input_shape)
    x = Reshape((input_shape[0], 1))(inputs)  # [batch, length, 1]
    
    # CNN特征提取
    x = Conv1D(32, 7, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    
    x = Conv1D(64, 5, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    
    x = Conv1D(128, 3, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    
    # GRU时序建模
    x = GRU(64, return_sequences=True)(x)
    x = GRU(32)(x)
    
    # 分类头
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    model.compile(
        optimizer=Adam(1e-3),
        loss=SparseCategoricalCrossentropy(),
        metrics=[SparseCategoricalAccuracy()]
    )
    return model

# ---------- 数据增强 ----------
@tf.function
def aug_fn(x):
    """信号增强"""
    x = tf.cast(x, tf.float32)
    if tf.random.uniform([]) > 0.2:
        snr = tf.random.uniform([], 5., 25.)
        noise = tf.random.normal(tf.shape(x)) * tf.math.reduce_std(x) * 10.0**(-snr/20.0)
        x = x + noise
    if tf.random.uniform([]) > 0.3:
        shift = tf.random.uniform([], -100, 100, dtype=tf.int32)
        x = tf.roll(x, shift=shift, axis=0)
    if tf.random.uniform([]) > 0.3:
        scale = tf.random.uniform([], 0.7, 1.3)
        x = x * scale
    return x

# ---------- 训练函数 ----------
def train_single_model(data, model_idx=0, epochs=120, batch=128):
    """训练单个模型"""
    model = build_model((data["L"],), len(data["label2name"]))
    
    # 类别权重（处理不平衡）
    cls_weights = compute_class_weight('balanced', 
                                     classes=np.unique(data['y_train']), 
                                     y=data['y_train'])
    sample_weights = np.array([cls_weights[lab] for lab in data['y_train']])
    
    # 数据管道
    train_ds = tf.data.Dataset.from_tensor_slices(
        (data['X_train'], data['y_train'], sample_weights)
    )
    train_ds = train_ds.map(lambda x, y, w: (aug_fn(x), y, w))
    train_ds = train_ds.shuffle(10000).batch(batch).prefetch(tf.data.AUTOTUNE)
    
    val_ds = tf.data.Dataset.from_tensor_slices(
        (data['X_val'], data['y_val'])
    ).batch(batch).prefetch(tf.data.AUTOTUNE)
    
    # 回调函数
    os.makedirs("models", exist_ok=True)
    ckpt = f"models/cnn_gru_classifier_{model_idx}.keras"
    callbacks = [
        EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=20, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_sparse_categorical_accuracy', factor=0.5, patience=10),
        ModelCheckpoint(ckpt, save_best_only=True, monitor='val_sparse_categorical_accuracy', save_format="tf")
    ]
    
    print(f"\n🔥 训练模型 {model_idx + 1}...")
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=callbacks,
        verbose=1
    )
    return model

# ---------- 主函数 ----------
def main():
    os.makedirs("models", exist_ok=True)
    
    # 加载数据
    print("⏳ 加载数据集...")
    dataset = load_dataset("/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz")
    data = preprocess_data(dataset)
    
    # 训练模型
    model = train_single_model(data, model_idx=0, epochs=120, batch=128)
    
    # 评估测试集
    test_loss, test_acc = model.evaluate(data['X_test'], data['y_test'], verbose=0)
    print(f"\n📊 测试集准确率: {test_acc:.4f}")
    
    # 统一保存模型
    model_path = save_model(model, model_name="cnn_gru_classifier")
    
    print("\n✅ 训练完成！模型已保存至:", model_path)

if __name__ == "__main__":
    import time
    main()
# Out:
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# ⏳ 加载数据集...
# 2025-10-21 18:06:50.864132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:06:50.865746: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:06:50.866449: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-10-21 18:06:50.970876: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:06:50.971694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:06:50.972383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 🔥 训练模型 1...
# Epoch 1/120
# 2025-10-21 18:06:51.594627: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [56700]
# 	 [[{{node Placeholder/_2}}]]
# 2025-10-21 18:06:51.594870: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [56700,1024]
# 	 [[{{node Placeholder/_0}}]]
# 2025-10-21 18:06:51.768722: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:06:51.769674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:06:51.770472: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-10-21 18:06:51.869463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:06:51.870900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:06:51.871727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-10-21 18:06:52.758981: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:06:52.760399: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:06:52.761176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-10-21 18:06:52.857472: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:06:52.858354: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:06:52.859171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 443/443 [==============================] - ETA: 0s - loss: 1.3003 - sparse_categorical_accuracy: 0.5057
# 2025-10-21 18:07:07.269329: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype int32 and shape [12150]
# 	 [[{{node Placeholder/_1}}]]
# 2025-10-21 18:07:07.416623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:07:07.417490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:07:07.418215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-10-21 18:07:07.517407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:07:07.518608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:07:07.519322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 443/443 [==============================] - 17s 28ms/step - loss: 1.3003 - sparse_categorical_accuracy: 0.5057 - val_loss: 1.1198 - val_sparse_categorical_accuracy: 0.5401 - lr: 0.0010
# Epoch 2/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.8603 - sparse_categorical_accuracy: 0.6477 - val_loss: 0.7409 - val_sparse_categorical_accuracy: 0.6896 - lr: 0.0010
# Epoch 3/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.7845 - sparse_categorical_accuracy: 0.6738 - val_loss: 0.7074 - val_sparse_categorical_accuracy: 0.7013 - lr: 0.0010
# Epoch 4/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.7496 - sparse_categorical_accuracy: 0.6891 - val_loss: 0.7015 - val_sparse_categorical_accuracy: 0.7128 - lr: 0.0010
# Epoch 5/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.7318 - sparse_categorical_accuracy: 0.6971 - val_loss: 0.6934 - val_sparse_categorical_accuracy: 0.7048 - lr: 0.0010
# Epoch 6/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.7039 - sparse_categorical_accuracy: 0.7110 - val_loss: 0.6667 - val_sparse_categorical_accuracy: 0.7318 - lr: 0.0010
# Epoch 7/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.6869 - sparse_categorical_accuracy: 0.7206 - val_loss: 0.6222 - val_sparse_categorical_accuracy: 0.7442 - lr: 0.0010
# Epoch 8/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.6580 - sparse_categorical_accuracy: 0.7343 - val_loss: 0.5821 - val_sparse_categorical_accuracy: 0.7560 - lr: 0.0010
# Epoch 9/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.6401 - sparse_categorical_accuracy: 0.7414 - val_loss: 0.5871 - val_sparse_categorical_accuracy: 0.7562 - lr: 0.0010
# Epoch 10/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.6272 - sparse_categorical_accuracy: 0.7466 - val_loss: 0.5876 - val_sparse_categorical_accuracy: 0.7571 - lr: 0.0010
# Epoch 11/120
# 443/443 [==============================] - 12s 25ms/step - loss: 0.6206 - sparse_categorical_accuracy: 0.7502 - val_loss: 0.5622 - val_sparse_categorical_accuracy: 0.7685 - lr: 0.0010
# Epoch 12/120
# 443/443 [==============================] - 12s 25ms/step - loss: 0.6078 - sparse_categorical_accuracy: 0.7542 - val_loss: 0.5433 - val_sparse_categorical_accuracy: 0.7741 - lr: 0.0010
# Epoch 13/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.5965 - sparse_categorical_accuracy: 0.7574 - val_loss: 0.5569 - val_sparse_categorical_accuracy: 0.7687 - lr: 0.0010
# Epoch 14/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.5836 - sparse_categorical_accuracy: 0.7632 - val_loss: 0.5199 - val_sparse_categorical_accuracy: 0.7844 - lr: 0.0010
# Epoch 15/120
# 443/443 [==============================] - 13s 25ms/step - loss: 0.5756 - sparse_categorical_accuracy: 0.7704 - val_loss: 0.5218 - val_sparse_categorical_accuracy: 0.7926 - lr: 0.0010
# Epoch 16/120
# 443/443 [==============================] - 12s 25ms/step - loss: 0.5709 - sparse_categorical_accuracy: 0.7709 - val_loss: 0.5269 - val_sparse_categorical_accuracy: 0.7888 - lr: 0.0010
# Epoch 17/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.5562 - sparse_categorical_accuracy: 0.7765 - val_loss: 0.5242 - val_sparse_categorical_accuracy: 0.7902 - lr: 0.0010
# Epoch 18/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.5599 - sparse_categorical_accuracy: 0.7775 - val_loss: 0.5391 - val_sparse_categorical_accuracy: 0.7789 - lr: 0.0010
# Epoch 19/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.5510 - sparse_categorical_accuracy: 0.7780 - val_loss: 0.5505 - val_sparse_categorical_accuracy: 0.7901 - lr: 0.0010
# Epoch 20/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.5421 - sparse_categorical_accuracy: 0.7872 - val_loss: 0.4833 - val_sparse_categorical_accuracy: 0.8065 - lr: 0.0010
# Epoch 21/120
# 443/443 [==============================] - 12s 25ms/step - loss: 0.5359 - sparse_categorical_accuracy: 0.7868 - val_loss: 0.5244 - val_sparse_categorical_accuracy: 0.7962 - lr: 0.0010
# Epoch 22/120
# 443/443 [==============================] - 12s 25ms/step - loss: 0.5310 - sparse_categorical_accuracy: 0.7860 - val_loss: 0.4802 - val_sparse_categorical_accuracy: 0.8082 - lr: 0.0010
# Epoch 23/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.5280 - sparse_categorical_accuracy: 0.7910 - val_loss: 0.4823 - val_sparse_categorical_accuracy: 0.8046 - lr: 0.0010
# Epoch 24/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.5185 - sparse_categorical_accuracy: 0.7921 - val_loss: 0.4984 - val_sparse_categorical_accuracy: 0.8072 - lr: 0.0010
# Epoch 25/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.5154 - sparse_categorical_accuracy: 0.7950 - val_loss: 0.4862 - val_sparse_categorical_accuracy: 0.8108 - lr: 0.0010
# Epoch 26/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.5111 - sparse_categorical_accuracy: 0.7952 - val_loss: 0.4892 - val_sparse_categorical_accuracy: 0.8024 - lr: 0.0010
# Epoch 27/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.5125 - sparse_categorical_accuracy: 0.7953 - val_loss: 0.4938 - val_sparse_categorical_accuracy: 0.8082 - lr: 0.0010
# Epoch 28/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.5027 - sparse_categorical_accuracy: 0.7973 - val_loss: 0.4653 - val_sparse_categorical_accuracy: 0.8164 - lr: 0.0010
# Epoch 29/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.5010 - sparse_categorical_accuracy: 0.7985 - val_loss: 0.4633 - val_sparse_categorical_accuracy: 0.8154 - lr: 0.0010
# Epoch 30/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4974 - sparse_categorical_accuracy: 0.8009 - val_loss: 0.4835 - val_sparse_categorical_accuracy: 0.8083 - lr: 0.0010
# Epoch 31/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4967 - sparse_categorical_accuracy: 0.8017 - val_loss: 0.4602 - val_sparse_categorical_accuracy: 0.8184 - lr: 0.0010
# Epoch 32/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.4919 - sparse_categorical_accuracy: 0.8035 - val_loss: 0.4693 - val_sparse_categorical_accuracy: 0.8147 - lr: 0.0010
# Epoch 33/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.4913 - sparse_categorical_accuracy: 0.8020 - val_loss: 0.4589 - val_sparse_categorical_accuracy: 0.8160 - lr: 0.0010
# Epoch 34/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4858 - sparse_categorical_accuracy: 0.8052 - val_loss: 0.4659 - val_sparse_categorical_accuracy: 0.8188 - lr: 0.0010
# Epoch 35/120
# 443/443 [==============================] - 12s 25ms/step - loss: 0.4867 - sparse_categorical_accuracy: 0.8057 - val_loss: 0.4604 - val_sparse_categorical_accuracy: 0.8175 - lr: 0.0010
# Epoch 36/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4806 - sparse_categorical_accuracy: 0.8052 - val_loss: 0.4572 - val_sparse_categorical_accuracy: 0.8190 - lr: 0.0010
# Epoch 37/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4772 - sparse_categorical_accuracy: 0.8092 - val_loss: 0.4725 - val_sparse_categorical_accuracy: 0.8184 - lr: 0.0010
# Epoch 38/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4782 - sparse_categorical_accuracy: 0.8078 - val_loss: 0.4424 - val_sparse_categorical_accuracy: 0.8242 - lr: 0.0010
# Epoch 39/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4738 - sparse_categorical_accuracy: 0.8089 - val_loss: 0.4539 - val_sparse_categorical_accuracy: 0.8182 - lr: 0.0010
# Epoch 40/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4757 - sparse_categorical_accuracy: 0.8105 - val_loss: 0.5053 - val_sparse_categorical_accuracy: 0.8133 - lr: 0.0010
# Epoch 41/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4717 - sparse_categorical_accuracy: 0.8127 - val_loss: 0.4600 - val_sparse_categorical_accuracy: 0.8170 - lr: 0.0010
# Epoch 42/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4698 - sparse_categorical_accuracy: 0.8103 - val_loss: 0.4480 - val_sparse_categorical_accuracy: 0.8226 - lr: 0.0010
# Epoch 43/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.4678 - sparse_categorical_accuracy: 0.8117 - val_loss: 0.4384 - val_sparse_categorical_accuracy: 0.8269 - lr: 0.0010
# Epoch 44/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4635 - sparse_categorical_accuracy: 0.8120 - val_loss: 0.4503 - val_sparse_categorical_accuracy: 0.8244 - lr: 0.0010
# Epoch 45/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4653 - sparse_categorical_accuracy: 0.8139 - val_loss: 0.4372 - val_sparse_categorical_accuracy: 0.8244 - lr: 0.0010
# Epoch 46/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4588 - sparse_categorical_accuracy: 0.8160 - val_loss: 0.4426 - val_sparse_categorical_accuracy: 0.8230 - lr: 0.0010
# Epoch 47/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4600 - sparse_categorical_accuracy: 0.8167 - val_loss: 0.5031 - val_sparse_categorical_accuracy: 0.8139 - lr: 0.0010
# Epoch 48/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4561 - sparse_categorical_accuracy: 0.8171 - val_loss: 0.4363 - val_sparse_categorical_accuracy: 0.8286 - lr: 0.0010
# Epoch 49/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4546 - sparse_categorical_accuracy: 0.8161 - val_loss: 0.4233 - val_sparse_categorical_accuracy: 0.8333 - lr: 0.0010
# Epoch 50/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4569 - sparse_categorical_accuracy: 0.8160 - val_loss: 0.4327 - val_sparse_categorical_accuracy: 0.8276 - lr: 0.0010
# Epoch 51/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.4482 - sparse_categorical_accuracy: 0.8181 - val_loss: 0.4513 - val_sparse_categorical_accuracy: 0.8232 - lr: 0.0010
# Epoch 52/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4475 - sparse_categorical_accuracy: 0.8198 - val_loss: 0.4234 - val_sparse_categorical_accuracy: 0.8301 - lr: 0.0010
# Epoch 53/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4408 - sparse_categorical_accuracy: 0.8218 - val_loss: 0.4298 - val_sparse_categorical_accuracy: 0.8308 - lr: 0.0010
# Epoch 54/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4445 - sparse_categorical_accuracy: 0.8205 - val_loss: 0.4476 - val_sparse_categorical_accuracy: 0.8222 - lr: 0.0010
# Epoch 55/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4416 - sparse_categorical_accuracy: 0.8214 - val_loss: 0.4130 - val_sparse_categorical_accuracy: 0.8374 - lr: 0.0010
# Epoch 56/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4394 - sparse_categorical_accuracy: 0.8223 - val_loss: 0.4294 - val_sparse_categorical_accuracy: 0.8333 - lr: 0.0010
# Epoch 57/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4377 - sparse_categorical_accuracy: 0.8223 - val_loss: 0.4589 - val_sparse_categorical_accuracy: 0.8245 - lr: 0.0010
# Epoch 58/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4412 - sparse_categorical_accuracy: 0.8208 - val_loss: 0.4187 - val_sparse_categorical_accuracy: 0.8315 - lr: 0.0010
# Epoch 59/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.4420 - sparse_categorical_accuracy: 0.8220 - val_loss: 0.4165 - val_sparse_categorical_accuracy: 0.8329 - lr: 0.0010
# Epoch 60/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.4329 - sparse_categorical_accuracy: 0.8248 - val_loss: 0.4516 - val_sparse_categorical_accuracy: 0.8234 - lr: 0.0010
# Epoch 61/120
# 443/443 [==============================] - 12s 25ms/step - loss: 0.4340 - sparse_categorical_accuracy: 0.8241 - val_loss: 0.4478 - val_sparse_categorical_accuracy: 0.8230 - lr: 0.0010
# Epoch 62/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4312 - sparse_categorical_accuracy: 0.8248 - val_loss: 0.4505 - val_sparse_categorical_accuracy: 0.8255 - lr: 0.0010
# Epoch 63/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4320 - sparse_categorical_accuracy: 0.8242 - val_loss: 0.4357 - val_sparse_categorical_accuracy: 0.8312 - lr: 0.0010
# Epoch 64/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.4282 - sparse_categorical_accuracy: 0.8258 - val_loss: 0.4268 - val_sparse_categorical_accuracy: 0.8323 - lr: 0.0010
# Epoch 65/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4312 - sparse_categorical_accuracy: 0.8246 - val_loss: 0.5159 - val_sparse_categorical_accuracy: 0.8100 - lr: 0.0010
# Epoch 66/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4192 - sparse_categorical_accuracy: 0.8326 - val_loss: 0.4015 - val_sparse_categorical_accuracy: 0.8449 - lr: 5.0000e-04
# Epoch 67/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.4052 - sparse_categorical_accuracy: 0.8352 - val_loss: 0.4134 - val_sparse_categorical_accuracy: 0.8434 - lr: 5.0000e-04
# Epoch 68/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.4008 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.3945 - val_sparse_categorical_accuracy: 0.8449 - lr: 5.0000e-04
# Epoch 69/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3978 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.4006 - val_sparse_categorical_accuracy: 0.8438 - lr: 5.0000e-04
# Epoch 70/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3956 - sparse_categorical_accuracy: 0.8386 - val_loss: 0.3962 - val_sparse_categorical_accuracy: 0.8442 - lr: 5.0000e-04
# Epoch 71/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3942 - sparse_categorical_accuracy: 0.8391 - val_loss: 0.3993 - val_sparse_categorical_accuracy: 0.8443 - lr: 5.0000e-04
# Epoch 72/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3938 - sparse_categorical_accuracy: 0.8384 - val_loss: 0.3862 - val_sparse_categorical_accuracy: 0.8461 - lr: 5.0000e-04
# Epoch 73/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3908 - sparse_categorical_accuracy: 0.8385 - val_loss: 0.3993 - val_sparse_categorical_accuracy: 0.8419 - lr: 5.0000e-04
# Epoch 74/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3922 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.3974 - val_sparse_categorical_accuracy: 0.8453 - lr: 5.0000e-04
# Epoch 75/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3907 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.3993 - val_sparse_categorical_accuracy: 0.8424 - lr: 5.0000e-04
# Epoch 76/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3918 - sparse_categorical_accuracy: 0.8401 - val_loss: 0.4005 - val_sparse_categorical_accuracy: 0.8420 - lr: 5.0000e-04
# Epoch 77/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3880 - sparse_categorical_accuracy: 0.8419 - val_loss: 0.3950 - val_sparse_categorical_accuracy: 0.8449 - lr: 5.0000e-04
# Epoch 78/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3867 - sparse_categorical_accuracy: 0.8418 - val_loss: 0.3903 - val_sparse_categorical_accuracy: 0.8444 - lr: 5.0000e-04
# Epoch 79/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3843 - sparse_categorical_accuracy: 0.8435 - val_loss: 0.4151 - val_sparse_categorical_accuracy: 0.8356 - lr: 5.0000e-04
# Epoch 80/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3832 - sparse_categorical_accuracy: 0.8422 - val_loss: 0.4012 - val_sparse_categorical_accuracy: 0.8422 - lr: 5.0000e-04
# Epoch 81/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3867 - sparse_categorical_accuracy: 0.8402 - val_loss: 0.4077 - val_sparse_categorical_accuracy: 0.8405 - lr: 5.0000e-04
# Epoch 82/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3894 - sparse_categorical_accuracy: 0.8412 - val_loss: 0.3950 - val_sparse_categorical_accuracy: 0.8462 - lr: 5.0000e-04
# Epoch 83/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3699 - sparse_categorical_accuracy: 0.8487 - val_loss: 0.3914 - val_sparse_categorical_accuracy: 0.8436 - lr: 2.5000e-04
# Epoch 84/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3742 - sparse_categorical_accuracy: 0.8476 - val_loss: 0.3802 - val_sparse_categorical_accuracy: 0.8520 - lr: 2.5000e-04
# Epoch 85/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3703 - sparse_categorical_accuracy: 0.8479 - val_loss: 0.3785 - val_sparse_categorical_accuracy: 0.8510 - lr: 2.5000e-04
# Epoch 86/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3667 - sparse_categorical_accuracy: 0.8511 - val_loss: 0.3834 - val_sparse_categorical_accuracy: 0.8491 - lr: 2.5000e-04
# Epoch 87/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3665 - sparse_categorical_accuracy: 0.8495 - val_loss: 0.3852 - val_sparse_categorical_accuracy: 0.8501 - lr: 2.5000e-04
# Epoch 88/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3647 - sparse_categorical_accuracy: 0.8495 - val_loss: 0.3851 - val_sparse_categorical_accuracy: 0.8493 - lr: 2.5000e-04
# Epoch 89/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3654 - sparse_categorical_accuracy: 0.8497 - val_loss: 0.3859 - val_sparse_categorical_accuracy: 0.8477 - lr: 2.5000e-04
# Epoch 90/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3643 - sparse_categorical_accuracy: 0.8498 - val_loss: 0.3878 - val_sparse_categorical_accuracy: 0.8475 - lr: 2.5000e-04
# Epoch 91/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3648 - sparse_categorical_accuracy: 0.8506 - val_loss: 0.3841 - val_sparse_categorical_accuracy: 0.8536 - lr: 2.5000e-04
# Epoch 92/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3611 - sparse_categorical_accuracy: 0.8498 - val_loss: 0.3800 - val_sparse_categorical_accuracy: 0.8497 - lr: 2.5000e-04
# Epoch 93/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3651 - sparse_categorical_accuracy: 0.8506 - val_loss: 0.3793 - val_sparse_categorical_accuracy: 0.8514 - lr: 2.5000e-04
# Epoch 94/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3622 - sparse_categorical_accuracy: 0.8511 - val_loss: 0.3879 - val_sparse_categorical_accuracy: 0.8446 - lr: 2.5000e-04
# Epoch 95/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3666 - sparse_categorical_accuracy: 0.8489 - val_loss: 0.3844 - val_sparse_categorical_accuracy: 0.8476 - lr: 2.5000e-04
# Epoch 96/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3619 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.3811 - val_sparse_categorical_accuracy: 0.8489 - lr: 2.5000e-04
# Epoch 97/120
# 443/443 [==============================] - 12s 25ms/step - loss: 0.3639 - sparse_categorical_accuracy: 0.8491 - val_loss: 0.3863 - val_sparse_categorical_accuracy: 0.8495 - lr: 2.5000e-04
# Epoch 98/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3627 - sparse_categorical_accuracy: 0.8521 - val_loss: 0.3951 - val_sparse_categorical_accuracy: 0.8460 - lr: 2.5000e-04
# Epoch 99/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3553 - sparse_categorical_accuracy: 0.8517 - val_loss: 0.3889 - val_sparse_categorical_accuracy: 0.8472 - lr: 2.5000e-04
# Epoch 100/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3626 - sparse_categorical_accuracy: 0.8512 - val_loss: 0.3867 - val_sparse_categorical_accuracy: 0.8506 - lr: 2.5000e-04
# Epoch 101/120
# 443/443 [==============================] - 12s 26ms/step - loss: 0.3597 - sparse_categorical_accuracy: 0.8521 - val_loss: 0.3807 - val_sparse_categorical_accuracy: 0.8512 - lr: 2.5000e-04
# Epoch 102/120
# 443/443 [==============================] - 13s 27ms/step - loss: 0.3539 - sparse_categorical_accuracy: 0.8527 - val_loss: 0.3791 - val_sparse_categorical_accuracy: 0.8493 - lr: 1.2500e-04
# Epoch 103/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3515 - sparse_categorical_accuracy: 0.8573 - val_loss: 0.3765 - val_sparse_categorical_accuracy: 0.8515 - lr: 1.2500e-04
# Epoch 104/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3506 - sparse_categorical_accuracy: 0.8553 - val_loss: 0.3801 - val_sparse_categorical_accuracy: 0.8508 - lr: 1.2500e-04
# Epoch 105/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3527 - sparse_categorical_accuracy: 0.8566 - val_loss: 0.3806 - val_sparse_categorical_accuracy: 0.8518 - lr: 1.2500e-04
# Epoch 106/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3495 - sparse_categorical_accuracy: 0.8559 - val_loss: 0.3815 - val_sparse_categorical_accuracy: 0.8494 - lr: 1.2500e-04
# Epoch 107/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3489 - sparse_categorical_accuracy: 0.8555 - val_loss: 0.3858 - val_sparse_categorical_accuracy: 0.8488 - lr: 1.2500e-04
# Epoch 108/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3471 - sparse_categorical_accuracy: 0.8581 - val_loss: 0.3791 - val_sparse_categorical_accuracy: 0.8509 - lr: 1.2500e-04
# Epoch 109/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3512 - sparse_categorical_accuracy: 0.8556 - val_loss: 0.3799 - val_sparse_categorical_accuracy: 0.8501 - lr: 1.2500e-04
# Epoch 110/120
# 443/443 [==============================] - 13s 26ms/step - loss: 0.3514 - sparse_categorical_accuracy: 0.8546 - val_loss: 0.3862 - val_sparse_categorical_accuracy: 0.8500 - lr: 1.2500e-04
# Epoch 111/120
# 443/443 [==============================] - 12s 25ms/step - loss: 0.3488 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.3798 - val_sparse_categorical_accuracy: 0.8520 - lr: 1.2500e-04
# 2025-10-21 18:30:32.534312: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:30:32.535806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:30:32.536510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-10-21 18:30:32.631421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:30:32.632298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:30:32.633009: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 📊 测试集准确率: 0.8444
# ✅ 模型已保存为Keras格式: models/cnn_gru_classifier_v1.0_20251021_183035.keras
# ✅ 创建最新模型符号链接: models/cnn_gru_classifier_latest.keras -> cnn_gru_classifier_v1.0_20251021_183035.keras
#
# ✅ 训练完成！模型已保存至: models/cnn_gru_classifier_v1.0_20251021_183035.keras

# %%
### evaluate_cnn_gru_classifier.py
import os
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (accuracy_score, confusion_matrix, 
                            classification_report)
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.font_manager as fm

# ---------- 中文字体设置 ----------
def set_chinese_font():
    """安全设置中文字体"""
    try:
        font_paths = ['/usr/share/fonts/truetype/wqy/wqy-microhei.ttc',
                     'C:/Windows/Fonts/simhei.ttf',
                     '/System/Library/Fonts/PingFang.ttc']
        for path in font_paths:
            if os.path.exists(path):
                fm.fontManager.addfont(path)
                plt.rcParams['font.family'] = fm.FontProperties(fname=path).get_name()
                plt.rcParams['axes.unicode_minus'] = False
                print(f"✅ 成功设置中文字体: {plt.rcParams['font.family']}")
                return True
        plt.rcParams['font.family'] = ['SimHei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("⚠️ 使用系统默认中文字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False
set_chinese_font()

# ---------- 加载数据集 ----------
def load_dataset(npz_path):
    """加载并处理数据集"""
    data = np.load(npz_path, allow_pickle=True)
    
    # 基础数据
    dataset = {
        "signals": data["signals"],
        "labels": data["labels"].astype(np.int32),
        "jnr_values": data["jnr_values"].astype(np.float32),
        "fs": float(data["fs"]),
        "L": int(data["L"])
    }
    
    # 处理干扰类型名称
    if "interference_type_names" in data:
        type_names = data["interference_type_names"].item() if isinstance(data["interference_type_names"], np.ndarray) else data["interference_type_names"]
    else:
        type_names = {
            "satellite_signal": "Satellite_Signal",
            "single_tone": "Single_Tone",
            "comb_spectra": "Comb_Spectra",
            "sweeping": "Sweeping-LFM",
            "pulse": "Pulse",
            "frequency_hopping": "Frequency_Hopping",
            "noise_fm": "Noise_FM",
            "noise_am": "Noise_AM",
            "random_combination": "Random_Combination"
        }
        print("⚠️ 未找到干扰类型名称，使用默认值")
    
    # 创建标签映射
    if "type_to_label" in data:
        type2label = data["type_to_label"].item() if isinstance(data["type_to_label"], np.ndarray) else data["type_to_label"]
    else:
        type2label = {
            "satellite_signal": 0,
            "single_tone": 1,
            "comb_spectra": 2,
            "sweeping": 3,
            "pulse": 4,
            "frequency_hopping": 5,
            "noise_fm": 6,
            "noise_am": 7,
            "random_combination": 8
        }
    
    label2name = {int(i): str(type_names[k]) for k, i in type2label.items()}
    
    return {
        "signals": data["signals"],
        "labels": data["labels"].astype(np.int32),
        "jnr_values": data["jnr_values"].astype(np.float32),
        "label2name": label2name,
        "L": int(data["L"])
    }

# ---------- 数据预处理 ----------
def preprocess_data(dataset):
    """预处理数据"""
    # 信号标准化
    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() 
                       for s in dataset["signals"]])
    
    # 数据集分割（保持分层抽样）
    X_train, X_test, y_train, y_test, jnr_train, jnr_test = train_test_split(
        signals, dataset["labels"], dataset["jnr_values"],
        test_size=0.3, random_state=42, stratify=dataset["labels"]
    )
    
    return {
        "X_test": X_test,
        "y_test": y_test,
        "jnr_test": jnr_test,
        "label2name": dataset["label2name"]
    }

# ---------- 加载模型 ----------
def load_model(model_path):
    """加载训练好的CNN-GRU模型"""
    if os.path.exists(model_path):
        try:
            model = tf.keras.models.load_model(model_path)
            print(f"✅ 成功加载模型: {model_path}")
            return model
        except Exception as e:
            print(f"❌ 加载模型失败: {e}")
            return None
    print(f"⚠️ 未找到模型: {model_path}")
    return None

# ---------- 计算JNR准确率 ----------
def calculate_jnr_accuracy(y_true, y_pred, jnr_values, jnr_range):
    """计算每个JNR下的分类准确率"""
    jnr_acc = {}
    for jnr in jnr_range:
        mask = jnr_values == jnr
        if np.sum(mask) > 0:
            jnr_acc[jnr] = accuracy_score(y_true[mask], y_pred[mask])
        else:
            jnr_acc[jnr] = np.nan
    return jnr_acc

# ---------------------- 绘制混淆矩阵 ----------------------
def plot_confusion_matrix(cm, labels, title, xlabel, ylabel, filename, dpi=150, rotate_x=False):
    """专业混淆矩阵可视化"""
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
    cm_normalized = np.nan_to_num(cm_normalized)

    plt.figure(figsize=(12, 10))
    ax = sns.heatmap(cm_normalized,
                     annot=True,
                     fmt='.2f',
                     cmap='Blues',
                     xticklabels=labels,
                     yticklabels=labels,
                     square=True,
                     annot_kws={"size": 14})
    cbar = ax.collections[0].colorbar
    cbar.ax.tick_params(labelsize=14)

    plt.title(title, pad=20, fontsize=18)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.xticks(rotation=45 if rotate_x else 0, 
               ha='right' if rotate_x else 'center', 
               fontsize=14)
    plt.yticks(rotation=0, fontsize=14)
    plt.tight_layout()
    plt.savefig(filename, dpi=dpi)
    plt.close()

# ---------- 绘制JNR准确率曲线 ----------
def plot_jnr_accuracy(jnr_acc, filename):
    """绘制JNR-准确率曲线"""
    plt.figure(figsize=(10, 6))
    valid_jnr = [j for j in jnr_acc if not np.isnan(jnr_acc[j])]
    valid_acc = [jnr_acc[j] for j in valid_jnr]
    
    plt.plot(valid_jnr, valid_acc, 'o-', linewidth=2, markersize=8)
    plt.xlabel('JNR (dB)', fontsize=12)
    plt.ylabel('分类准确率', fontsize=12)
    plt.title('不同JNR下的干扰识别准确率', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.xticks(list(jnr_acc.keys()))
    plt.ylim(0, 1.05)
    plt.savefig(filename, dpi=300)
    plt.close()

# ---------- 主评估函数 ----------
def evaluate(model_path="models/cnn_gru_classifier_v1.0_20251021_183035.keras", 
             npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"):
    """主评估流程"""
    os.makedirs("visualizations", exist_ok=True)
    os.makedirs("reports", exist_ok=True)
    
    print("=" * 80)
    print("🚀 CNN-GRU干扰分类模型评估")
    print("=" * 80)

    # 1. 加载数据
    print("⏳ 加载数据集...")
    dataset = load_dataset(npz_path)
    data = preprocess_data(dataset)
    
    # 2. 加载模型
    print("⏳ 加载模型...")
    model = load_model(model_path)
    if not model:
        print("❌ 评估终止：无法加载模型")
        return
    
    # 3. 预测
    print("⏳ 进行预测...")
    y_pred = np.argmax(model.predict(data["X_test"], verbose=1), axis=1)
    
    # 4. 计算JNR准确率
    print("⏳ 计算各JNR下的准确率...")
    jnr_range = np.arange(-10, 31, 5)  # [-10, -5, 0, 5, ..., 30]
    jnr_acc = calculate_jnr_accuracy(data["y_test"], y_pred, data["jnr_test"], jnr_range)
    
    # 5. 生成混淆矩阵
    print("⏳ 生成混淆矩阵...")
    cm = confusion_matrix(data["y_test"], y_pred)
    class_names = [data["label2name"][i] for i in sorted(data["label2name"].keys())]
    plot_confusion_matrix(
        cm=cm,
        labels=class_names,
        title="CNN-GRU Classification Confusion Matrix",
        xlabel="Predicted",
        ylabel="True",
        filename="visualizations/cnn_gru_confusion_matrix.png",
        dpi=300,
        rotate_x=True
    )
    
    # 6. 绘制JNR准确率曲线
    print("⏳ 生成JNR准确率曲线...")
    plot_jnr_accuracy(jnr_acc, "visualizations/cnn_gru_jnr_accuracy.png")
    
    # 7. 保存评估报告
    print("⏳ 生成评估报告...")
    report = {
        "overall_accuracy": float(accuracy_score(data["y_test"], y_pred)),
        "jnr_accuracy": {int(j): float(acc) if not np.isnan(acc) else None 
                         for j, acc in jnr_acc.items()},
        "confusion_matrix": cm.tolist(),
        "class_names": class_names,
        "classification_report": classification_report(
            data["y_test"], y_pred, 
            target_names=class_names,
            output_dict=True
        )
    }
    
    with open("reports/cnn_gru_evaluation_report.json", "w", encoding="utf-8") as f:
        json.dump(report, f, indent=4, ensure_ascii=False)
    
    # 8. 打印结果
    print("\n" + "="*50)
    print("📊 评估结果摘要")
    print("="*50)
    print(f"整体分类准确率: {report['overall_accuracy']:.4f}")
    
    print("\n各JNR下的分类准确率:")
    for jnr in sorted(jnr_acc.keys()):
        acc = jnr_acc[jnr]
        acc_str = f"{acc:.4f}" if not np.isnan(acc) else "N/A"
        print(f"  JNR={jnr}dB: {acc_str}")
    
    print("\n✅ 评估完成！结果已保存至 reports/cnn_gru_evaluation_report.json")

# ---------- 主程序 ----------
if __name__ == "__main__":
    evaluate(
        model_path="models/cnn_gru_classifier_v1.0_20251021_183035.keras",
        npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"
    )
# Out:
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# ================================================================================
# 🚀 CNN-GRU干扰分类模型评估
# ================================================================================
# ⏳ 加载数据集...
# ⏳ 加载模型...
# 2025-10-21 18:49:41.301936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:49:41.303364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:49:41.304083: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-10-21 18:49:41.401548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:49:41.402401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:49:41.403088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# ✅ 成功加载模型: models/cnn_gru_classifier_v1.0_20251021_183035.keras
# ⏳ 进行预测...
# 2025-10-21 18:49:41.713176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:49:41.714115: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:49:41.715069: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-10-21 18:49:41.809633: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-10-21 18:49:41.810526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-10-21 18:49:41.811259: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 760/760 [==============================] - 7s 8ms/step
# ⏳ 计算各JNR下的准确率...
# ⏳ 生成混淆矩阵...
# ⏳ 生成JNR准确率曲线...
# ⏳ 生成评估报告...
#
# ==================================================
# 📊 评估结果摘要
# ==================================================
# 整体分类准确率: 0.8491
#
# 各JNR下的分类准确率:
#   JNR=-10dB: 0.4628
#   JNR=-5dB: 0.6603
#   JNR=0dB: 0.8118
#   JNR=5dB: 0.8840
#   JNR=10dB: 0.9275
#   JNR=15dB: 0.9602
#   JNR=20dB: 0.9732
#   JNR=25dB: 0.9803
#   JNR=30dB: 0.9770
#
# ✅ 评估完成！结果已保存至 reports/cnn_gru_evaluation_report.json

# %% [markdown]
# CNN-GRU整体分类准确率: 0.8491
#
# 各JNR下的分类准确率:
#   JNR=-10dB: 0.4628
#   JNR=-5dB: 0.6603
#   JNR=0dB: 0.8118
#   JNR=5dB: 0.8840
#   JNR=10dB: 0.9275
#   JNR=15dB: 0.9602
#   JNR=20dB: 0.9732
#   JNR=25dB: 0.9803
#   JNR=30dB: 0.9770
