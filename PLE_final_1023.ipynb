# %%
# PLE_final_1019.py
import os
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (confusion_matrix, accuracy_score, precision_score,
                             recall_score, f1_score, mean_absolute_error)
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv1D, BatchNormalization, MaxPooling1D,
                                     GlobalAveragePooling1D, Dense, Reshape, Layer)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import BinaryCrossentropy, SparseCategoricalCrossentropy, MeanSquaredError
from tensorflow.keras.metrics import BinaryAccuracy, SparseCategoricalAccuracy
import time

# ---------------------- 中文字体 ----------------------
def set_chinese_font():
    try:
        plt.rcParams['font.sans-serif'] = ['SimHei', 'WenQuanYi Micro Hei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("✅ 成功设置中文字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False

set_chinese_font()

# ---------------------- 自定义 PLE 层 ----------------------
class PLELayer(Layer):
    def __init__(self, num_tasks, num_shared_experts, num_task_experts, expert_dim, **kwargs):
        super(PLELayer, self).__init__(**kwargs)
        self.num_tasks = num_tasks
        self.num_shared_experts = num_shared_experts
        self.num_task_experts = num_task_experts
        self.expert_dim = expert_dim
        self.num_experts = num_shared_experts + num_task_experts
        
    def build(self, input_shape):
        input_dim = input_shape[-1]
        
        # 共享专家网络
        self.shared_experts = [
            Dense(self.expert_dim, activation='relu', name=f'shared_expert_{i}')
            for i in range(self.num_shared_experts)
        ]
        
        # 任务特定专家网络
        self.task_experts = [
            [
                Dense(self.expert_dim, activation='relu', name=f'task_{task}_expert_{i}')
                for i in range(self.num_task_experts)
            ]
            for task in range(self.num_tasks)
        ]
        
        # 门控网络
        self.gates = [
            Dense(self.num_experts, activation='softmax', name=f'gate_{task}')
            for task in range(self.num_tasks)
        ]
        
        super(PLELayer, self).build(input_shape)
        
    def call(self, inputs):
        # 生成共享专家输出
        shared_expert_outputs = [
            expert(inputs) for expert in self.shared_experts
        ]
        
        outputs = []
        for task in range(self.num_tasks):
            # 生成任务特定专家输出
            task_expert_outputs = [
                expert(inputs) for expert in self.task_experts[task]
            ]
            
            # 合并所有专家输出
            all_expert_outputs = shared_expert_outputs + task_expert_outputs  # (num_experts, batch, expert_dim)
            all_experts_concat = tf.stack(all_expert_outputs, axis=1)  # (batch, num_experts, expert_dim)
            
            # 计算门控权重
            gate_weights = self.gates[task](inputs)  # (batch, num_experts)
            gate_weights = tf.expand_dims(gate_weights, axis=-1)  # (batch, num_experts, 1)
            
            # 加权组合专家输出
            weighted_output = tf.reduce_sum(all_experts_concat * gate_weights, axis=1)  # (batch, expert_dim)
            outputs.append(weighted_output)
            
        return outputs

# ---------------------- 加载数据集 ----------------------
def load_dataset(npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"):
    data = np.load(npz_path, allow_pickle=True)
    signals = data["signals"]
    labels = data["labels"].astype(np.int32)
    jnr_vals = data["jnr_values"].astype(np.float32)
    fs = float(data["fs"])
    L = int(data["L"])
    metadata = data["metadata"]
    type2label = data["type_to_label"].item()
    label2type = {v: k for k, v in type2label.items()}
    type2name = data["interference_type_names"].item()
    label2name = {i: type2name[k] for k, i in type2label.items()}
    
    return {
        "signals": signals,
        "labels": labels,
        "jnr_values": jnr_vals,
        "fs": fs,
        "L": L,
        "metadata": metadata,
        "type2label": type2label,
        "label2type": label2type,
        "type2name": type2name,
        "label2name": label2name
    }

# ---------------------- 数据预处理 ----------------------
def preprocess_data(dataset):
    signals = dataset["signals"]
    labels = dataset["labels"]
    jnr_values = dataset["jnr_values"]
    metadata = dataset["metadata"]
    L = dataset["L"]

    # 1. 标准化信号
    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() for s in signals])

    # 2. 构建检测标签（卫星信号为无干扰，其他为有干扰）
    no_key = "satellite_signal"
    det_labels = (labels != dataset["type2label"][no_key]).astype(np.float32)

    # 3. 构建参数标签（与 completely_fixed_model.py 保持一致）
    param_labels = []
    for sig in signals:
        power = sig ** 2
        threshold = 2.0 * np.mean(power)
        above_threshold = power > threshold

        if np.any(above_threshold):
            start_idx = np.argmax(above_threshold)
            end_idx = len(above_threshold) - np.argmax(above_threshold[::-1]) - 1
        else:
            start_idx, end_idx = 0, len(sig) - 1

        start_time = start_idx / dataset["fs"] * 1e3      # ms
        end_time   = end_idx   / dataset["fs"] * 1e3
        jnr_db = 10 * np.log10(np.mean(power) + 1e-12) - dataset.get("noise_power_db", 0)

        param_labels.append([start_time, end_time, jnr_db])
    param_labels = np.array(param_labels, dtype=np.float32)

    # 4. 过滤无效样本 —— 与 completely_fixed_model.py 完全一致
    mask = ~(
        np.any(np.isnan(signals), axis=1) |
        np.any(np.isinf(signals), axis=1) |
        np.isnan(det_labels) | np.isinf(det_labels) |
        np.isnan(labels) | np.isinf(labels) |
        np.any(np.isnan(param_labels), axis=1) | np.any(np.isinf(param_labels), axis=1)
    )

    print(f"🧹 丢弃 {np.sum(~mask)} / {len(mask)} 条无效样本")
    signals, det_labels, labels, param_labels, jnr_values = \
        signals[mask], det_labels[mask], labels[mask], param_labels[mask], jnr_values[mask]

    # 5. 数据集分割（保持原逻辑）
    X_train, X_tmp, y_det_train, y_det_tmp, y_type_train, y_type_tmp, y_param_train, y_param_tmp, jnr_train, jnr_tmp = train_test_split(
        signals, det_labels, labels, param_labels, jnr_values,
        test_size=0.3, random_state=42, stratify=labels
    )

    X_val, X_test, y_det_val, y_det_test, y_type_val, y_type_test, y_param_val, y_param_test, jnr_val, jnr_test = train_test_split(
        X_tmp, y_det_tmp, y_type_tmp, y_param_tmp, jnr_tmp,
        test_size=2/3, random_state=42, stratify=y_type_tmp
    )

    return {
        "X_train": X_train, "X_val": X_val, "X_test": X_test,
        "y_det_train": y_det_train, "y_det_val": y_det_val, "y_det_test": y_det_test,
        "y_type_train": y_type_train, "y_type_val": y_type_val, "y_type_test": y_type_test,
        "y_param_train": y_param_train, "y_param_val": y_param_val, "y_param_test": y_param_test,
        "jnr_values_train": jnr_train, "jnr_values_val": jnr_val, "jnr_values_test": jnr_test,
        "type2label": dataset["type2label"], "label2name": dataset["label2name"],
        "L": L
    }

# ---------------------- PLE 模型结构 ----------------------
def build_ple_model(input_shape, num_classes, num_shared_experts=2, num_task_experts=1, expert_dim=64):
    inputs = Input(shape=input_shape, dtype=tf.float32)
    
    # 共享主干特征提取
    x = Reshape((input_shape[0], 1))(inputs)
    x = Conv1D(64, 7, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    x = Conv1D(128, 5, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2)(x)
    x = Conv1D(256, 3, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    shared_features = GlobalAveragePooling1D()(x)
    
    # PLE层 - 3个任务: 检测、分类、回归
    ple_outputs = PLELayer(
        num_tasks=3,
        num_shared_experts=num_shared_experts,
        num_task_experts=num_task_experts,
        expert_dim=expert_dim
    )(shared_features)
    
    # 任务特定特征处理
    det_feat = Dense(64, activation='relu')(ple_outputs[0])
    cls_feat = Dense(64, activation='relu')(ple_outputs[1])
    reg_feat = Dense(64, activation='relu')(ple_outputs[2])
    
    # 任务输出层
    det_out = Dense(1, activation='sigmoid', name='detection_output')(det_feat)
    cls_out = Dense(num_classes, activation='softmax', name='classification_output')(cls_feat)
    reg_out = Dense(3, activation='sigmoid', name='regression_output')(reg_feat)  # 使用sigmoid确保输出在[0,1]
    
    model = Model(inputs, [det_out, cls_out, reg_out])
    
    # 编译配置
    model.compile(
        optimizer=Adam(1e-3),
        loss={
            'detection_output': BinaryCrossentropy(),
            'classification_output': SparseCategoricalCrossentropy(),
            'regression_output': MeanSquaredError()
        },
        loss_weights={
            'detection_output': 0.8,
            'classification_output': 2.0,
            'regression_output': 0.5
        },
        metrics={
            'detection_output': BinaryAccuracy(),
            'classification_output': SparseCategoricalAccuracy(),
            'regression_output': 'mae'
        }
    )
    
    return model

# ---------------------- 训练单个 PLE 模型 ----------------------
def train_single_model(data, model_idx, epochs=120, batch=128):
    input_shape, num_classes = (data["L"],), len(data["type2label"])
    model = build_ple_model(input_shape, num_classes)
    
    # 计算分类任务的类别权重
    cls_weights = compute_class_weight(
        'balanced',
        classes=np.unique(data['y_type_train']),
        y=data['y_type_train']
    )
    cls_weights_dict = dict(enumerate(cls_weights))
    
    # 创建数据集
    ds_train = tf.data.Dataset.from_tensor_slices((
        data['X_train'],
        {
            'detection_output': data['y_det_train'],
            'classification_output': data['y_type_train'],
            'regression_output': data['y_param_train']
        }
    )).batch(batch).prefetch(tf.data.AUTOTUNE)
    
    ds_val = tf.data.Dataset.from_tensor_slices((
        data['X_val'],
        {
            'detection_output': data['y_det_val'],
            'classification_output': data['y_type_val'],
            'regression_output': data['y_param_val']
        }
    )).batch(batch).prefetch(tf.data.AUTOTUNE)
    
    # 设置回调函数
    ckpt = f"models/ple_model_1019_{model_idx}.keras"
    callbacks = [
        ReduceLROnPlateau(monitor='val_classification_output_sparse_categorical_accuracy',
                         factor=0.5, patience=10, min_lr=1e-5, mode='max', verbose=1),
        ModelCheckpoint(ckpt, save_best_only=True, save_weights_only=False,
                       monitor='val_classification_output_sparse_categorical_accuracy', 
                       mode='max', verbose=1)
    ]
    
    print(f"\n🔥 训练第 {model_idx + 1} 个PLE模型（适配v3归一化数据）...")
    start_time = time.time()
    history = model.fit(
        ds_train,
        validation_data=ds_val,
        epochs=epochs,
        callbacks=callbacks,
        verbose=1
    )
    end_time = time.time()
    training_time = end_time - start_time
    print(f"✅ 模型 {model_idx + 1} 训练完成，耗时 {training_time:.2f} 秒")
    
    return model, training_time

# ---------------------- 训练多个 PLE 模型（Ensemble） ----------------------
def train_ensemble(data, n_models=3, epochs=120, batch=128):
    models = []
    training_times = []
    for i in range(n_models):
        model, training_time = train_single_model(data, i, epochs=epochs, batch=batch)
        models.append(model)
        training_times.append(training_time)
    return models, training_times

# ---------------------- 主函数 ----------------------
def main():
    for d in ["models", "visualizations", "reports"]:
        os.makedirs(d, exist_ok=True)
    
    print("=" * 80)
    print("🚀 开始训练 PLE 多任务模型（检测/分类/回归，渐进分层提取，适配v3归一化数据）")
    print("=" * 80)
    
    # 加载并预处理数据
    dataset = load_dataset()
    data = preprocess_data(dataset)
    
    # 训练 Ensemble 模型
    n_models = 3
    epochs = 120
    batch_size = 128
    
    models, training_times = train_ensemble(data, n_models=n_models, epochs=epochs, batch=batch_size)
    
    # 打印训练时间
    print("\n" + "="*50)
    print("📈 训练时间统计")
    print("="*50)
    for i, t in enumerate(training_times):
        print(f"模型 {i + 1}: {t:.2f} 秒 ({t / 60:.2f} 分钟)")
    print(f"🔥 总训练时间: {sum(training_times):.2f} 秒 ({sum(training_times) / 60:.2f} 分钟)")
    print("="*50)
    
    print("\n✅ 所有PLE模型训练完成！模型已保存至 models/ple_model_1019_{i}.keras")
    print("📌 适配v3归一化数据的训练完成")

if __name__ == "__main__":
    main()
# Out:
# 2025-10-23 19:27:15.864215: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-23 19:27:15.903730: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-23 19:27:16.443494: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✅ 成功设置中文字体
# ================================================================================
# 🚀 开始训练 PLE 多任务模型（检测/分类/回归，渐进分层提取，适配v3归一化数据）
# ================================================================================
# 🧹 丢弃 0 / 81000 条无效样本
# 2025-10-23 19:27:38.449544: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46590 MB memory:  -> device: 0, name: NVIDIA vGPU-48GB, pci bus id: 0000:16:00.0, compute capability: 8.9
# 🔥 训练第 1 个PLE模型（适配v3归一化数据）...
# Epoch 1/120
# 2025-10-23 19:27:39.996066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [56700]
# 	 [[{{node Placeholder/_2}}]]
# 2025-10-23 19:27:41.967792: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-10-23 19:27:42.161794: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-10-23 19:27:42.201470: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x5557c05eec60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-23 19:27:42.201512: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA vGPU-48GB, Compute Capability 8.9
# 2025-10-23 19:27:42.213408: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-23 19:27:42.357660: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 443/443 [==============================] - ETA: 0s - loss: 2.0012 - detection_output_loss: 0.1658 - classification_output_loss: 0.9330 - regression_output_loss: 0.0052 - detection_output_binary_accuracy: 0.9125 - classification_output_sparse_categorical_accuracy: 0.6299 - regression_output_mae: 0.0272
# 2025-10-23 19:27:51.089646: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [8100]
# 	 [[{{node Placeholder/_2}}]]
# Epoch 1: val_classification_output_sparse_categorical_accuracy improved from -inf to 0.28309, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 12s 18ms/step - loss: 2.0012 - detection_output_loss: 0.1658 - classification_output_loss: 0.9330 - regression_output_loss: 0.0052 - detection_output_binary_accuracy: 0.9125 - classification_output_sparse_categorical_accuracy: 0.6299 - regression_output_mae: 0.0272 - val_loss: 14.4233 - val_detection_output_loss: 1.9397 - val_classification_output_loss: 6.4355 - val_regression_output_loss: 8.1749e-04 - val_detection_output_binary_accuracy: 0.8889 - val_classification_output_sparse_categorical_accuracy: 0.2831 - val_regression_output_mae: 0.0168 - lr: 0.0010
# Epoch 2/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.5783 - detection_output_loss: 0.1301 - classification_output_loss: 0.7371 - regression_output_loss: 2.1562e-04 - detection_output_binary_accuracy: 0.9312 - classification_output_sparse_categorical_accuracy: 0.6923 - regression_output_mae: 0.0087
# Epoch 2: val_classification_output_sparse_categorical_accuracy improved from 0.28309 to 0.69321, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 1.5772 - detection_output_loss: 0.1299 - classification_output_loss: 0.7366 - regression_output_loss: 2.1548e-04 - detection_output_binary_accuracy: 0.9313 - classification_output_sparse_categorical_accuracy: 0.6924 - regression_output_mae: 0.0087 - val_loss: 1.5444 - val_detection_output_loss: 0.1238 - val_classification_output_loss: 0.7226 - val_regression_output_loss: 2.7073e-04 - val_detection_output_binary_accuracy: 0.9331 - val_classification_output_sparse_categorical_accuracy: 0.6932 - val_regression_output_mae: 0.0097 - lr: 0.0010
# Epoch 3/120
# 443/443 [==============================] - ETA: 0s - loss: 1.4439 - detection_output_loss: 0.1208 - classification_output_loss: 0.6736 - regression_output_loss: 1.6565e-04 - detection_output_binary_accuracy: 0.9387 - classification_output_sparse_categorical_accuracy: 0.7165 - regression_output_mae: 0.0075
# Epoch 3: val_classification_output_sparse_categorical_accuracy improved from 0.69321 to 0.72864, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 1.4439 - detection_output_loss: 0.1208 - classification_output_loss: 0.6736 - regression_output_loss: 1.6565e-04 - detection_output_binary_accuracy: 0.9387 - classification_output_sparse_categorical_accuracy: 0.7165 - regression_output_mae: 0.0075 - val_loss: 1.3844 - val_detection_output_loss: 0.1226 - val_classification_output_loss: 0.6431 - val_regression_output_loss: 1.7992e-04 - val_detection_output_binary_accuracy: 0.9369 - val_classification_output_sparse_categorical_accuracy: 0.7286 - val_regression_output_mae: 0.0080 - lr: 0.0010
# Epoch 4/120
# 443/443 [==============================] - ETA: 0s - loss: 1.3540 - detection_output_loss: 0.1150 - classification_output_loss: 0.6310 - regression_output_loss: 1.3202e-04 - detection_output_binary_accuracy: 0.9426 - classification_output_sparse_categorical_accuracy: 0.7360 - regression_output_mae: 0.0066
# Epoch 4: val_classification_output_sparse_categorical_accuracy improved from 0.72864 to 0.73593, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 1.3540 - detection_output_loss: 0.1150 - classification_output_loss: 0.6310 - regression_output_loss: 1.3202e-04 - detection_output_binary_accuracy: 0.9426 - classification_output_sparse_categorical_accuracy: 0.7360 - regression_output_mae: 0.0066 - val_loss: 1.3799 - val_detection_output_loss: 0.1345 - val_classification_output_loss: 0.6361 - val_regression_output_loss: 1.5077e-04 - val_detection_output_binary_accuracy: 0.9296 - val_classification_output_sparse_categorical_accuracy: 0.7359 - val_regression_output_mae: 0.0072 - lr: 0.0010
# Epoch 5/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.2799 - detection_output_loss: 0.1099 - classification_output_loss: 0.5960 - regression_output_loss: 1.1418e-04 - detection_output_binary_accuracy: 0.9463 - classification_output_sparse_categorical_accuracy: 0.7518 - regression_output_mae: 0.0061
# Epoch 5: val_classification_output_sparse_categorical_accuracy improved from 0.73593 to 0.76568, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 1.2789 - detection_output_loss: 0.1097 - classification_output_loss: 0.5955 - regression_output_loss: 1.1405e-04 - detection_output_binary_accuracy: 0.9464 - classification_output_sparse_categorical_accuracy: 0.7519 - regression_output_mae: 0.0061 - val_loss: 1.2680 - val_detection_output_loss: 0.1150 - val_classification_output_loss: 0.5879 - val_regression_output_loss: 1.0526e-04 - val_detection_output_binary_accuracy: 0.9428 - val_classification_output_sparse_categorical_accuracy: 0.7657 - val_regression_output_mae: 0.0057 - lr: 0.0010
# Epoch 6/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.2162 - detection_output_loss: 0.1053 - classification_output_loss: 0.5659 - regression_output_loss: 1.0481e-04 - detection_output_binary_accuracy: 0.9493 - classification_output_sparse_categorical_accuracy: 0.7649 - regression_output_mae: 0.0057
# Epoch 6: val_classification_output_sparse_categorical_accuracy improved from 0.76568 to 0.77037, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 1.2154 - detection_output_loss: 0.1052 - classification_output_loss: 0.5656 - regression_output_loss: 1.0468e-04 - detection_output_binary_accuracy: 0.9494 - classification_output_sparse_categorical_accuracy: 0.7650 - regression_output_mae: 0.0057 - val_loss: 1.2500 - val_detection_output_loss: 0.1161 - val_classification_output_loss: 0.5786 - val_regression_output_loss: 1.0985e-04 - val_detection_output_binary_accuracy: 0.9438 - val_classification_output_sparse_categorical_accuracy: 0.7704 - val_regression_output_mae: 0.0060 - lr: 0.0010
# Epoch 7/120
# 443/443 [==============================] - ETA: 0s - loss: 1.1648 - detection_output_loss: 0.1010 - classification_output_loss: 0.5419 - regression_output_loss: 9.5067e-05 - detection_output_binary_accuracy: 0.9524 - classification_output_sparse_categorical_accuracy: 0.7759 - regression_output_mae: 0.0053
# Epoch 7: val_classification_output_sparse_categorical_accuracy improved from 0.77037 to 0.77272, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 1.1648 - detection_output_loss: 0.1010 - classification_output_loss: 0.5419 - regression_output_loss: 9.5067e-05 - detection_output_binary_accuracy: 0.9524 - classification_output_sparse_categorical_accuracy: 0.7759 - regression_output_mae: 0.0053 - val_loss: 1.2256 - val_detection_output_loss: 0.1182 - val_classification_output_loss: 0.5655 - val_regression_output_loss: 9.6705e-05 - val_detection_output_binary_accuracy: 0.9430 - val_classification_output_sparse_categorical_accuracy: 0.7727 - val_regression_output_mae: 0.0054 - lr: 0.0010
# Epoch 8/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.1175 - detection_output_loss: 0.0968 - classification_output_loss: 0.5200 - regression_output_loss: 8.7195e-05 - detection_output_binary_accuracy: 0.9551 - classification_output_sparse_categorical_accuracy: 0.7858 - regression_output_mae: 0.0051
# Epoch 8: val_classification_output_sparse_categorical_accuracy did not improve from 0.77272
# 443/443 [==============================] - 7s 15ms/step - loss: 1.1167 - detection_output_loss: 0.0967 - classification_output_loss: 0.5197 - regression_output_loss: 8.7078e-05 - detection_output_binary_accuracy: 0.9551 - classification_output_sparse_categorical_accuracy: 0.7860 - regression_output_mae: 0.0051 - val_loss: 1.2560 - val_detection_output_loss: 0.1272 - val_classification_output_loss: 0.5771 - val_regression_output_loss: 8.8068e-05 - val_detection_output_binary_accuracy: 0.9390 - val_classification_output_sparse_categorical_accuracy: 0.7720 - val_regression_output_mae: 0.0050 - lr: 0.0010
# Epoch 9/120
# 443/443 [==============================] - ETA: 0s - loss: 1.0752 - detection_output_loss: 0.0927 - classification_output_loss: 0.5005 - regression_output_loss: 8.1012e-05 - detection_output_binary_accuracy: 0.9577 - classification_output_sparse_categorical_accuracy: 0.7940 - regression_output_mae: 0.0048
# Epoch 9: val_classification_output_sparse_categorical_accuracy improved from 0.77272 to 0.77420, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 15ms/step - loss: 1.0752 - detection_output_loss: 0.0927 - classification_output_loss: 0.5005 - regression_output_loss: 8.1012e-05 - detection_output_binary_accuracy: 0.9577 - classification_output_sparse_categorical_accuracy: 0.7940 - regression_output_mae: 0.0048 - val_loss: 1.3056 - val_detection_output_loss: 0.1305 - val_classification_output_loss: 0.6006 - val_regression_output_loss: 9.0270e-05 - val_detection_output_binary_accuracy: 0.9375 - val_classification_output_sparse_categorical_accuracy: 0.7742 - val_regression_output_mae: 0.0053 - lr: 0.0010
# Epoch 10/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.0304 - detection_output_loss: 0.0876 - classification_output_loss: 0.4801 - regression_output_loss: 7.4973e-05 - detection_output_binary_accuracy: 0.9609 - classification_output_sparse_categorical_accuracy: 0.8017 - regression_output_mae: 0.0046
# Epoch 10: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 15ms/step - loss: 1.0297 - detection_output_loss: 0.0875 - classification_output_loss: 0.4798 - regression_output_loss: 7.4898e-05 - detection_output_binary_accuracy: 0.9609 - classification_output_sparse_categorical_accuracy: 0.8018 - regression_output_mae: 0.0046 - val_loss: 1.3683 - val_detection_output_loss: 0.1371 - val_classification_output_loss: 0.6293 - val_regression_output_loss: 7.4837e-05 - val_detection_output_binary_accuracy: 0.9342 - val_classification_output_sparse_categorical_accuracy: 0.7627 - val_regression_output_mae: 0.0046 - lr: 0.0010
# Epoch 11/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.9912 - detection_output_loss: 0.0824 - classification_output_loss: 0.4626 - regression_output_loss: 7.0680e-05 - detection_output_binary_accuracy: 0.9638 - classification_output_sparse_categorical_accuracy: 0.8091 - regression_output_mae: 0.0044
# Epoch 11: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 16ms/step - loss: 0.9903 - detection_output_loss: 0.0824 - classification_output_loss: 0.4622 - regression_output_loss: 7.0666e-05 - detection_output_binary_accuracy: 0.9639 - classification_output_sparse_categorical_accuracy: 0.8093 - regression_output_mae: 0.0044 - val_loss: 1.3030 - val_detection_output_loss: 0.1434 - val_classification_output_loss: 0.5941 - val_regression_output_loss: 6.6786e-05 - val_detection_output_binary_accuracy: 0.9357 - val_classification_output_sparse_categorical_accuracy: 0.7733 - val_regression_output_mae: 0.0041 - lr: 0.0010
# Epoch 12/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.9505 - detection_output_loss: 0.0762 - classification_output_loss: 0.4447 - regression_output_loss: 6.6821e-05 - detection_output_binary_accuracy: 0.9671 - classification_output_sparse_categorical_accuracy: 0.8149 - regression_output_mae: 0.0042
# Epoch 12: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 17ms/step - loss: 0.9497 - detection_output_loss: 0.0762 - classification_output_loss: 0.4443 - regression_output_loss: 6.6811e-05 - detection_output_binary_accuracy: 0.9671 - classification_output_sparse_categorical_accuracy: 0.8152 - regression_output_mae: 0.0042 - val_loss: 1.4343 - val_detection_output_loss: 0.1519 - val_classification_output_loss: 0.6564 - val_regression_output_loss: 6.8498e-05 - val_detection_output_binary_accuracy: 0.9406 - val_classification_output_sparse_categorical_accuracy: 0.7356 - val_regression_output_mae: 0.0042 - lr: 0.0010
# Epoch 13/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.9260 - detection_output_loss: 0.0708 - classification_output_loss: 0.4346 - regression_output_loss: 6.4353e-05 - detection_output_binary_accuracy: 0.9704 - classification_output_sparse_categorical_accuracy: 0.8194 - regression_output_mae: 0.0040
# Epoch 13: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 15ms/step - loss: 0.9252 - detection_output_loss: 0.0708 - classification_output_loss: 0.4342 - regression_output_loss: 6.4349e-05 - detection_output_binary_accuracy: 0.9705 - classification_output_sparse_categorical_accuracy: 0.8197 - regression_output_mae: 0.0040 - val_loss: 1.4812 - val_detection_output_loss: 0.1518 - val_classification_output_loss: 0.6799 - val_regression_output_loss: 6.4346e-05 - val_detection_output_binary_accuracy: 0.9402 - val_classification_output_sparse_categorical_accuracy: 0.7535 - val_regression_output_mae: 0.0040 - lr: 0.0010
# Epoch 14/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.8805 - detection_output_loss: 0.0654 - classification_output_loss: 0.4141 - regression_output_loss: 6.2170e-05 - detection_output_binary_accuracy: 0.9729 - classification_output_sparse_categorical_accuracy: 0.8264 - regression_output_mae: 0.0039
# Epoch 14: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 15ms/step - loss: 0.8802 - detection_output_loss: 0.0654 - classification_output_loss: 0.4139 - regression_output_loss: 6.2125e-05 - detection_output_binary_accuracy: 0.9729 - classification_output_sparse_categorical_accuracy: 0.8265 - regression_output_mae: 0.0039 - val_loss: 1.5558 - val_detection_output_loss: 0.1510 - val_classification_output_loss: 0.7175 - val_regression_output_loss: 6.2048e-05 - val_detection_output_binary_accuracy: 0.9385 - val_classification_output_sparse_categorical_accuracy: 0.7485 - val_regression_output_mae: 0.0039 - lr: 0.0010
# Epoch 15/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.8440 - detection_output_loss: 0.0586 - classification_output_loss: 0.3986 - regression_output_loss: 6.0487e-05 - detection_output_binary_accuracy: 0.9766 - classification_output_sparse_categorical_accuracy: 0.8330 - regression_output_mae: 0.0038
# Epoch 15: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 15ms/step - loss: 0.8437 - detection_output_loss: 0.0586 - classification_output_loss: 0.3984 - regression_output_loss: 6.0452e-05 - detection_output_binary_accuracy: 0.9766 - classification_output_sparse_categorical_accuracy: 0.8331 - regression_output_mae: 0.0038 - val_loss: 1.4805 - val_detection_output_loss: 0.1790 - val_classification_output_loss: 0.6686 - val_regression_output_loss: 6.3815e-05 - val_detection_output_binary_accuracy: 0.9384 - val_classification_output_sparse_categorical_accuracy: 0.7620 - val_regression_output_mae: 0.0039 - lr: 0.0010
# Epoch 16/120
# 443/443 [==============================] - ETA: 0s - loss: 0.8158 - detection_output_loss: 0.0541 - classification_output_loss: 0.3863 - regression_output_loss: 5.9646e-05 - detection_output_binary_accuracy: 0.9789 - classification_output_sparse_categorical_accuracy: 0.8360 - regression_output_mae: 0.0037
# Epoch 16: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 15ms/step - loss: 0.8158 - detection_output_loss: 0.0541 - classification_output_loss: 0.3863 - regression_output_loss: 5.9646e-05 - detection_output_binary_accuracy: 0.9789 - classification_output_sparse_categorical_accuracy: 0.8360 - regression_output_mae: 0.0037 - val_loss: 1.6980 - val_detection_output_loss: 0.2080 - val_classification_output_loss: 0.7658 - val_regression_output_loss: 6.0064e-05 - val_detection_output_binary_accuracy: 0.9343 - val_classification_output_sparse_categorical_accuracy: 0.7349 - val_regression_output_mae: 0.0037 - lr: 0.0010
# Epoch 17/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7844 - detection_output_loss: 0.0501 - classification_output_loss: 0.3721 - regression_output_loss: 5.8979e-05 - detection_output_binary_accuracy: 0.9802 - classification_output_sparse_categorical_accuracy: 0.8410 - regression_output_mae: 0.0036
# Epoch 17: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 15ms/step - loss: 0.7844 - detection_output_loss: 0.0501 - classification_output_loss: 0.3721 - regression_output_loss: 5.8979e-05 - detection_output_binary_accuracy: 0.9802 - classification_output_sparse_categorical_accuracy: 0.8410 - regression_output_mae: 0.0036 - val_loss: 1.8414 - val_detection_output_loss: 0.1963 - val_classification_output_loss: 0.8422 - val_regression_output_loss: 6.0740e-05 - val_detection_output_binary_accuracy: 0.9372 - val_classification_output_sparse_categorical_accuracy: 0.6774 - val_regression_output_mae: 0.0037 - lr: 0.0010
# Epoch 18/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.7482 - detection_output_loss: 0.0433 - classification_output_loss: 0.3568 - regression_output_loss: 5.8062e-05 - detection_output_binary_accuracy: 0.9833 - classification_output_sparse_categorical_accuracy: 0.8486 - regression_output_mae: 0.0036
# Epoch 18: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 15ms/step - loss: 0.7478 - detection_output_loss: 0.0432 - classification_output_loss: 0.3566 - regression_output_loss: 5.8133e-05 - detection_output_binary_accuracy: 0.9833 - classification_output_sparse_categorical_accuracy: 0.8487 - regression_output_mae: 0.0036 - val_loss: 2.1047 - val_detection_output_loss: 0.2461 - val_classification_output_loss: 0.9539 - val_regression_output_loss: 5.9002e-05 - val_detection_output_binary_accuracy: 0.9338 - val_classification_output_sparse_categorical_accuracy: 0.7000 - val_regression_output_mae: 0.0035 - lr: 0.0010
# Epoch 19/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7544 - detection_output_loss: 0.0472 - classification_output_loss: 0.3583 - regression_output_loss: 5.8020e-05 - detection_output_binary_accuracy: 0.9814 - classification_output_sparse_categorical_accuracy: 0.8486 - regression_output_mae: 0.0036
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 19: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 15ms/step - loss: 0.7544 - detection_output_loss: 0.0472 - classification_output_loss: 0.3583 - regression_output_loss: 5.8020e-05 - detection_output_binary_accuracy: 0.9814 - classification_output_sparse_categorical_accuracy: 0.8486 - regression_output_mae: 0.0036 - val_loss: 1.7561 - val_detection_output_loss: 0.2564 - val_classification_output_loss: 0.7755 - val_regression_output_loss: 5.7537e-05 - val_detection_output_binary_accuracy: 0.9273 - val_classification_output_sparse_categorical_accuracy: 0.7449 - val_regression_output_mae: 0.0035 - lr: 0.0010
# Epoch 20/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.6598 - detection_output_loss: 0.0385 - classification_output_loss: 0.3145 - regression_output_loss: 5.5534e-05 - detection_output_binary_accuracy: 0.9846 - classification_output_sparse_categorical_accuracy: 0.8646 - regression_output_mae: 0.0034
# Epoch 20: val_classification_output_sparse_categorical_accuracy did not improve from 0.77420
# 443/443 [==============================] - 7s 16ms/step - loss: 0.6595 - detection_output_loss: 0.0385 - classification_output_loss: 0.3144 - regression_output_loss: 5.5498e-05 - detection_output_binary_accuracy: 0.9847 - classification_output_sparse_categorical_accuracy: 0.8646 - regression_output_mae: 0.0034 - val_loss: 1.6158 - val_detection_output_loss: 0.2830 - val_classification_output_loss: 0.6947 - val_regression_output_loss: 5.5673e-05 - val_detection_output_binary_accuracy: 0.9304 - val_classification_output_sparse_categorical_accuracy: 0.7699 - val_regression_output_mae: 0.0034 - lr: 5.0000e-04
# Epoch 21/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.5894 - detection_output_loss: 0.0246 - classification_output_loss: 0.2848 - regression_output_loss: 5.5182e-05 - detection_output_binary_accuracy: 0.9915 - classification_output_sparse_categorical_accuracy: 0.8764 - regression_output_mae: 0.0034
# Epoch 21: val_classification_output_sparse_categorical_accuracy improved from 0.77420 to 0.77642, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 0.5891 - detection_output_loss: 0.0246 - classification_output_loss: 0.2847 - regression_output_loss: 5.5149e-05 - detection_output_binary_accuracy: 0.9916 - classification_output_sparse_categorical_accuracy: 0.8764 - regression_output_mae: 0.0034 - val_loss: 1.6508 - val_detection_output_loss: 0.3103 - val_classification_output_loss: 0.7013 - val_regression_output_loss: 5.5387e-05 - val_detection_output_binary_accuracy: 0.9327 - val_classification_output_sparse_categorical_accuracy: 0.7764 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 22/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.5421 - detection_output_loss: 0.0150 - classification_output_loss: 0.2650 - regression_output_loss: 5.4840e-05 - detection_output_binary_accuracy: 0.9953 - classification_output_sparse_categorical_accuracy: 0.8853 - regression_output_mae: 0.0034
# Epoch 22: val_classification_output_sparse_categorical_accuracy improved from 0.77642 to 0.78704, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 0.5418 - detection_output_loss: 0.0150 - classification_output_loss: 0.2649 - regression_output_loss: 5.4892e-05 - detection_output_binary_accuracy: 0.9954 - classification_output_sparse_categorical_accuracy: 0.8854 - regression_output_mae: 0.0034 - val_loss: 1.5871 - val_detection_output_loss: 0.2970 - val_classification_output_loss: 0.6747 - val_regression_output_loss: 5.5033e-05 - val_detection_output_binary_accuracy: 0.9357 - val_classification_output_sparse_categorical_accuracy: 0.7870 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 23/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.5060 - detection_output_loss: 0.0097 - classification_output_loss: 0.2491 - regression_output_loss: 5.4685e-05 - detection_output_binary_accuracy: 0.9974 - classification_output_sparse_categorical_accuracy: 0.8921 - regression_output_mae: 0.0034
# Epoch 23: val_classification_output_sparse_categorical_accuracy did not improve from 0.78704
# 443/443 [==============================] - 7s 15ms/step - loss: 0.5058 - detection_output_loss: 0.0097 - classification_output_loss: 0.2490 - regression_output_loss: 5.4677e-05 - detection_output_binary_accuracy: 0.9974 - classification_output_sparse_categorical_accuracy: 0.8921 - regression_output_mae: 0.0034 - val_loss: 1.6912 - val_detection_output_loss: 0.3390 - val_classification_output_loss: 0.7100 - val_regression_output_loss: 5.4987e-05 - val_detection_output_binary_accuracy: 0.9364 - val_classification_output_sparse_categorical_accuracy: 0.7846 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 24/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.4783 - detection_output_loss: 0.0061 - classification_output_loss: 0.2367 - regression_output_loss: 5.4524e-05 - detection_output_binary_accuracy: 0.9986 - classification_output_sparse_categorical_accuracy: 0.8964 - regression_output_mae: 0.0034
# Epoch 24: val_classification_output_sparse_categorical_accuracy did not improve from 0.78704
# 443/443 [==============================] - 7s 16ms/step - loss: 0.4781 - detection_output_loss: 0.0061 - classification_output_loss: 0.2366 - regression_output_loss: 5.4518e-05 - detection_output_binary_accuracy: 0.9986 - classification_output_sparse_categorical_accuracy: 0.8965 - regression_output_mae: 0.0034 - val_loss: 1.8433 - val_detection_output_loss: 0.3859 - val_classification_output_loss: 0.7673 - val_regression_output_loss: 5.5091e-05 - val_detection_output_binary_accuracy: 0.9351 - val_classification_output_sparse_categorical_accuracy: 0.7742 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 25/120
# 443/443 [==============================] - ETA: 0s - loss: 0.4613 - detection_output_loss: 0.0061 - classification_output_loss: 0.2282 - regression_output_loss: 5.4446e-05 - detection_output_binary_accuracy: 0.9981 - classification_output_sparse_categorical_accuracy: 0.9000 - regression_output_mae: 0.0034
# Epoch 25: val_classification_output_sparse_categorical_accuracy did not improve from 0.78704
# 443/443 [==============================] - 7s 16ms/step - loss: 0.4613 - detection_output_loss: 0.0061 - classification_output_loss: 0.2282 - regression_output_loss: 5.4446e-05 - detection_output_binary_accuracy: 0.9981 - classification_output_sparse_categorical_accuracy: 0.9000 - regression_output_mae: 0.0034 - val_loss: 1.9852 - val_detection_output_loss: 0.3976 - val_classification_output_loss: 0.8336 - val_regression_output_loss: 5.5161e-05 - val_detection_output_binary_accuracy: 0.9367 - val_classification_output_sparse_categorical_accuracy: 0.7530 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 26/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.4512 - detection_output_loss: 0.0070 - classification_output_loss: 0.2228 - regression_output_loss: 5.4374e-05 - detection_output_binary_accuracy: 0.9976 - classification_output_sparse_categorical_accuracy: 0.9028 - regression_output_mae: 0.0034
# Epoch 26: val_classification_output_sparse_categorical_accuracy did not improve from 0.78704
# 443/443 [==============================] - 7s 15ms/step - loss: 0.4509 - detection_output_loss: 0.0070 - classification_output_loss: 0.2227 - regression_output_loss: 5.4366e-05 - detection_output_binary_accuracy: 0.9976 - classification_output_sparse_categorical_accuracy: 0.9028 - regression_output_mae: 0.0034 - val_loss: 1.9065 - val_detection_output_loss: 0.3889 - val_classification_output_loss: 0.7977 - val_regression_output_loss: 5.5031e-05 - val_detection_output_binary_accuracy: 0.9375 - val_classification_output_sparse_categorical_accuracy: 0.7852 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 27/120
# 443/443 [==============================] - ETA: 0s - loss: 0.4339 - detection_output_loss: 0.0066 - classification_output_loss: 0.2143 - regression_output_loss: 5.4247e-05 - detection_output_binary_accuracy: 0.9976 - classification_output_sparse_categorical_accuracy: 0.9058 - regression_output_mae: 0.0034
# Epoch 27: val_classification_output_sparse_categorical_accuracy improved from 0.78704 to 0.79778, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 0.4339 - detection_output_loss: 0.0066 - classification_output_loss: 0.2143 - regression_output_loss: 5.4247e-05 - detection_output_binary_accuracy: 0.9976 - classification_output_sparse_categorical_accuracy: 0.9058 - regression_output_mae: 0.0034 - val_loss: 1.9649 - val_detection_output_loss: 0.3633 - val_classification_output_loss: 0.8371 - val_regression_output_loss: 5.4973e-05 - val_detection_output_binary_accuracy: 0.9411 - val_classification_output_sparse_categorical_accuracy: 0.7978 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 28/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.4263 - detection_output_loss: 0.0073 - classification_output_loss: 0.2102 - regression_output_loss: 5.4155e-05 - detection_output_binary_accuracy: 0.9973 - classification_output_sparse_categorical_accuracy: 0.9079 - regression_output_mae: 0.0034
# Epoch 28: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 15ms/step - loss: 0.4260 - detection_output_loss: 0.0073 - classification_output_loss: 0.2101 - regression_output_loss: 5.4207e-05 - detection_output_binary_accuracy: 0.9973 - classification_output_sparse_categorical_accuracy: 0.9080 - regression_output_mae: 0.0034 - val_loss: 2.3008 - val_detection_output_loss: 0.5093 - val_classification_output_loss: 0.9467 - val_regression_output_loss: 5.5507e-05 - val_detection_output_binary_accuracy: 0.9310 - val_classification_output_sparse_categorical_accuracy: 0.7694 - val_regression_output_mae: 0.0034 - lr: 5.0000e-04
# Epoch 29/120
# 443/443 [==============================] - ETA: 0s - loss: 0.4144 - detection_output_loss: 0.0090 - classification_output_loss: 0.2036 - regression_output_loss: 5.4105e-05 - detection_output_binary_accuracy: 0.9967 - classification_output_sparse_categorical_accuracy: 0.9107 - regression_output_mae: 0.0033
# Epoch 29: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 16ms/step - loss: 0.4144 - detection_output_loss: 0.0090 - classification_output_loss: 0.2036 - regression_output_loss: 5.4105e-05 - detection_output_binary_accuracy: 0.9967 - classification_output_sparse_categorical_accuracy: 0.9107 - regression_output_mae: 0.0033 - val_loss: 1.9930 - val_detection_output_loss: 0.3764 - val_classification_output_loss: 0.8459 - val_regression_output_loss: 5.5939e-05 - val_detection_output_binary_accuracy: 0.9401 - val_classification_output_sparse_categorical_accuracy: 0.7910 - val_regression_output_mae: 0.0034 - lr: 5.0000e-04
# Epoch 30/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.4071 - detection_output_loss: 0.0083 - classification_output_loss: 0.2002 - regression_output_loss: 5.4140e-05 - detection_output_binary_accuracy: 0.9968 - classification_output_sparse_categorical_accuracy: 0.9132 - regression_output_mae: 0.0033
# Epoch 30: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 16ms/step - loss: 0.4070 - detection_output_loss: 0.0083 - classification_output_loss: 0.2002 - regression_output_loss: 5.4114e-05 - detection_output_binary_accuracy: 0.9968 - classification_output_sparse_categorical_accuracy: 0.9132 - regression_output_mae: 0.0033 - val_loss: 2.1004 - val_detection_output_loss: 0.3712 - val_classification_output_loss: 0.9017 - val_regression_output_loss: 5.5164e-05 - val_detection_output_binary_accuracy: 0.9416 - val_classification_output_sparse_categorical_accuracy: 0.7937 - val_regression_output_mae: 0.0034 - lr: 5.0000e-04
# Epoch 31/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.3876 - detection_output_loss: 0.0058 - classification_output_loss: 0.1915 - regression_output_loss: 5.3944e-05 - detection_output_binary_accuracy: 0.9979 - classification_output_sparse_categorical_accuracy: 0.9170 - regression_output_mae: 0.0033
# Epoch 31: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 16ms/step - loss: 0.3875 - detection_output_loss: 0.0058 - classification_output_loss: 0.1914 - regression_output_loss: 5.3917e-05 - detection_output_binary_accuracy: 0.9980 - classification_output_sparse_categorical_accuracy: 0.9171 - regression_output_mae: 0.0033 - val_loss: 2.4241 - val_detection_output_loss: 0.4404 - val_classification_output_loss: 1.0359 - val_regression_output_loss: 5.4934e-05 - val_detection_output_binary_accuracy: 0.9358 - val_classification_output_sparse_categorical_accuracy: 0.7375 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 32/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.3710 - detection_output_loss: 0.0053 - classification_output_loss: 0.1834 - regression_output_loss: 5.3783e-05 - detection_output_binary_accuracy: 0.9980 - classification_output_sparse_categorical_accuracy: 0.9200 - regression_output_mae: 0.0033
# Epoch 32: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 16ms/step - loss: 0.3706 - detection_output_loss: 0.0052 - classification_output_loss: 0.1832 - regression_output_loss: 5.3839e-05 - detection_output_binary_accuracy: 0.9980 - classification_output_sparse_categorical_accuracy: 0.9201 - regression_output_mae: 0.0033 - val_loss: 2.8126 - val_detection_output_loss: 0.5839 - val_classification_output_loss: 1.1728 - val_regression_output_loss: 5.4833e-05 - val_detection_output_binary_accuracy: 0.9274 - val_classification_output_sparse_categorical_accuracy: 0.7126 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 33/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.3639 - detection_output_loss: 0.0056 - classification_output_loss: 0.1797 - regression_output_loss: 5.3640e-05 - detection_output_binary_accuracy: 0.9979 - classification_output_sparse_categorical_accuracy: 0.9231 - regression_output_mae: 0.0033
# Epoch 33: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 15ms/step - loss: 0.3636 - detection_output_loss: 0.0057 - classification_output_loss: 0.1795 - regression_output_loss: 5.3692e-05 - detection_output_binary_accuracy: 0.9979 - classification_output_sparse_categorical_accuracy: 0.9232 - regression_output_mae: 0.0033 - val_loss: 3.5114 - val_detection_output_loss: 0.5284 - val_classification_output_loss: 1.5443 - val_regression_output_loss: 5.5033e-05 - val_detection_output_binary_accuracy: 0.9301 - val_classification_output_sparse_categorical_accuracy: 0.7146 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 34/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.3601 - detection_output_loss: 0.0053 - classification_output_loss: 0.1779 - regression_output_loss: 5.3509e-05 - detection_output_binary_accuracy: 0.9981 - classification_output_sparse_categorical_accuracy: 0.9238 - regression_output_mae: 0.0033
# Epoch 34: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 15ms/step - loss: 0.3599 - detection_output_loss: 0.0052 - classification_output_loss: 0.1778 - regression_output_loss: 5.3566e-05 - detection_output_binary_accuracy: 0.9981 - classification_output_sparse_categorical_accuracy: 0.9239 - regression_output_mae: 0.0033 - val_loss: 2.3099 - val_detection_output_loss: 0.4306 - val_classification_output_loss: 0.9827 - val_regression_output_loss: 5.5177e-05 - val_detection_output_binary_accuracy: 0.9372 - val_classification_output_sparse_categorical_accuracy: 0.7910 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 35/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.3417 - detection_output_loss: 0.0035 - classification_output_loss: 0.1694 - regression_output_loss: 5.3389e-05 - detection_output_binary_accuracy: 0.9988 - classification_output_sparse_categorical_accuracy: 0.9279 - regression_output_mae: 0.0033
# Epoch 35: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 15ms/step - loss: 0.3412 - detection_output_loss: 0.0035 - classification_output_loss: 0.1692 - regression_output_loss: 5.3449e-05 - detection_output_binary_accuracy: 0.9988 - classification_output_sparse_categorical_accuracy: 0.9281 - regression_output_mae: 0.0033 - val_loss: 2.2722 - val_detection_output_loss: 0.4032 - val_classification_output_loss: 0.9748 - val_regression_output_loss: 5.5216e-05 - val_detection_output_binary_accuracy: 0.9412 - val_classification_output_sparse_categorical_accuracy: 0.7956 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 36/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.3275 - detection_output_loss: 0.0039 - classification_output_loss: 0.1622 - regression_output_loss: 5.3365e-05 - detection_output_binary_accuracy: 0.9985 - classification_output_sparse_categorical_accuracy: 0.9317 - regression_output_mae: 0.0033
# Epoch 36: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 15ms/step - loss: 0.3272 - detection_output_loss: 0.0039 - classification_output_loss: 0.1620 - regression_output_loss: 5.3366e-05 - detection_output_binary_accuracy: 0.9986 - classification_output_sparse_categorical_accuracy: 0.9318 - regression_output_mae: 0.0033 - val_loss: 2.3941 - val_detection_output_loss: 0.4194 - val_classification_output_loss: 1.0293 - val_regression_output_loss: 5.4892e-05 - val_detection_output_binary_accuracy: 0.9428 - val_classification_output_sparse_categorical_accuracy: 0.7973 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 37/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.3214 - detection_output_loss: 0.0044 - classification_output_loss: 0.1589 - regression_output_loss: 5.3412e-05 - detection_output_binary_accuracy: 0.9984 - classification_output_sparse_categorical_accuracy: 0.9326 - regression_output_mae: 0.0033
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 37: val_classification_output_sparse_categorical_accuracy did not improve from 0.79778
# 443/443 [==============================] - 7s 16ms/step - loss: 0.3214 - detection_output_loss: 0.0044 - classification_output_loss: 0.1589 - regression_output_loss: 5.3386e-05 - detection_output_binary_accuracy: 0.9984 - classification_output_sparse_categorical_accuracy: 0.9326 - regression_output_mae: 0.0033 - val_loss: 2.4847 - val_detection_output_loss: 0.4109 - val_classification_output_loss: 1.0780 - val_regression_output_loss: 5.5426e-05 - val_detection_output_binary_accuracy: 0.9411 - val_classification_output_sparse_categorical_accuracy: 0.7912 - val_regression_output_mae: 0.0033 - lr: 5.0000e-04
# Epoch 38/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.2776 - detection_output_loss: 0.0027 - classification_output_loss: 0.1377 - regression_output_loss: 5.2382e-05 - detection_output_binary_accuracy: 0.9991 - classification_output_sparse_categorical_accuracy: 0.9437 - regression_output_mae: 0.0032
# Epoch 38: val_classification_output_sparse_categorical_accuracy improved from 0.79778 to 0.80469, saving model to models/ple_model_1019_0.keras
# 443/443 [==============================] - 7s 16ms/step - loss: 0.2775 - detection_output_loss: 0.0027 - classification_output_loss: 0.1376 - regression_output_loss: 5.2387e-05 - detection_output_binary_accuracy: 0.9991 - classification_output_sparse_categorical_accuracy: 0.9438 - regression_output_mae: 0.0032 - val_loss: 2.3170 - val_detection_output_loss: 0.4155 - val_classification_output_loss: 0.9923 - val_regression_output_loss: 5.4674e-05 - val_detection_output_binary_accuracy: 0.9446 - val_classification_output_sparse_categorical_accuracy: 0.8047 - val_regression_output_mae: 0.0033 - lr: 2.5000e-04
# Epoch 39/120
# 443/443 [==============================] - ETA: 0s - loss: 0.2551 - detection_output_loss: 0.0010 - classification_output_loss: 0.1271 - regression_output_loss: 5.2277e-05 - detection_output_binary_accuracy: 0.9998 - classification_output_sparse_categorical_accuracy: 0.9492 - regression_output_mae: 0.0032
# Epoch 39: val_classification_output_sparse_categorical_accuracy did not improve from 0.80469
# 443/443 [==============================] - 7s 16ms/step - loss: 0.2551 - detection_output_loss: 0.0010 - classification_output_loss: 0.1271 - regression_output_loss: 5.2277e-05 - detection_output_binary_accuracy: 0.9998 - classification_output_sparse_categorical_accuracy: 0.9492 - regression_output_mae: 0.0032 - val_loss: 2.3848 - val_detection_output_loss: 0.4279 - val_classification_output_loss: 1.0213 - val_regression_output_loss: 5.4722e-05 - val_detection_output_binary_accuracy: 0.9417 - val_classification_output_sparse_categorical_accuracy: 0.8028 - val_regression_output_mae: 0.0033 - lr: 2.5000e-04
# Epoch 40/120
# 443/443 [==============================] - ETA: 0s - loss: 0.2408 - detection_output_loss: 4.7304e-04 - classification_output_loss: 0.1202 - regression_output_loss: 5.2207e-05 - detection_output_binary_accuracy: 0.9999 - classification_output_sparse_categorical_accuracy: 0.9525 - regression_output_mae: 0.0032
# Epoch 40: val_classification_output_sparse_categorical_accuracy did not improve from 0.80469
# 443/443 [==============================] - 7s 16ms/step - loss: 0.2408 - detection_output_loss: 4.7304e-04 - classification_output_loss: 0.1202 - regression_output_loss: 5.2207e-05 - detection_output_binary_accuracy: 0.9999 - classification_output_sparse_categorical_accuracy: 0.9525 - regression_output_mae: 0.0032 - val_loss: 2.4615 - val_detection_output_loss: 0.4566 - val_classification_output_loss: 1.0481 - val_regression_output_loss: 5.4795e-05 - val_detection_output_binary_accuracy: 0.9402 - val_classification_output_sparse_categorical_accuracy: 0.7998 - val_regression_output_mae: 0.0033 - lr: 2.5000e-04
# Epoch 41/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.2290 - detection_output_loss: 2.7316e-04 - classification_output_loss: 0.1144 - regression_output_loss: 5.2154e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9550 - regression_output_mae: 0.0032
# Epoch 41: val_classification_output_sparse_categorical_accuracy did not improve from 0.80469
# 443/443 [==============================] - 7s 16ms/step - loss: 0.2290 - detection_output_loss: 2.7416e-04 - classification_output_loss: 0.1144 - regression_output_loss: 5.2157e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9551 - regression_output_mae: 0.0032 - val_loss: 2.5574 - val_detection_output_loss: 0.4834 - val_classification_output_loss: 1.0853 - val_regression_output_loss: 5.4867e-05 - val_detection_output_binary_accuracy: 0.9383 - val_classification_output_sparse_categorical_accuracy: 0.7959 - val_regression_output_mae: 0.0033 - lr: 2.5000e-04
# Epoch 42/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.2176 - detection_output_loss: 2.3098e-04 - classification_output_loss: 0.1087 - regression_output_loss: 5.2130e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9580 - regression_output_mae: 0.0032
# Epoch 42: val_classification_output_sparse_categorical_accuracy did not improve from 0.80469
# 443/443 [==============================] - 7s 15ms/step - loss: 0.2176 - detection_output_loss: 2.3101e-04 - classification_output_loss: 0.1087 - regression_output_loss: 5.2134e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9581 - regression_output_mae: 0.0032 - val_loss: 2.7050 - val_detection_output_loss: 0.5325 - val_classification_output_loss: 1.1395 - val_regression_output_loss: 5.4919e-05 - val_detection_output_binary_accuracy: 0.9374 - val_classification_output_sparse_categorical_accuracy: 0.7922 - val_regression_output_mae: 0.0033 - lr: 2.5000e-04
# Epoch 43/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.2064 - detection_output_loss: 2.3044e-04 - classification_output_loss: 0.1031 - regression_output_loss: 5.2137e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9613 - regression_output_mae: 0.0032
# Epoch 43: val_classification_output_sparse_categorical_accuracy did not improve from 0.80469
# 443/443 [==============================] - 7s 15ms/step - loss: 0.2065 - detection_output_loss: 2.3028e-04 - classification_output_loss: 0.1032 - regression_output_loss: 5.2113e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9613 - regression_output_mae: 0.0032 - val_loss: 2.7708 - val_detection_output_loss: 0.5423 - val_classification_output_loss: 1.1685 - val_regression_output_loss: 5.5045e-05 - val_detection_output_binary_accuracy: 0.9375 - val_classification_output_sparse_categorical_accuracy: 0.7923 - val_regression_output_mae: 0.0033 - lr: 2.5000e-04
# Epoch 44/120
# ...
# Epoch 106/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.0115 - detection_output_loss: 3.8685e-06 - classification_output_loss: 0.0057 - regression_output_loss: 4.9538e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9993 - regression_output_mae: 0.0031
# Epoch 106: val_classification_output_sparse_categorical_accuracy did not improve from 0.79716
# 443/443 [==============================] - 7s 16ms/step - loss: 0.0115 - detection_output_loss: 3.8694e-06 - classification_output_loss: 0.0057 - regression_output_loss: 4.9592e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9993 - regression_output_mae: 0.0031 - val_loss: 5.1619 - val_detection_output_loss: 0.9183 - val_classification_output_loss: 2.2136 - val_regression_output_loss: 5.5093e-05 - val_detection_output_binary_accuracy: 0.9363 - val_classification_output_sparse_categorical_accuracy: 0.7969 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 107/120
# 443/443 [==============================] - ETA: 0s - loss: 0.0111 - detection_output_loss: 3.6249e-06 - classification_output_loss: 0.0055 - regression_output_loss: 4.9583e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9993 - regression_output_mae: 0.0031
# Epoch 107: val_classification_output_sparse_categorical_accuracy did not improve from 0.79716
# 443/443 [==============================] - 7s 15ms/step - loss: 0.0111 - detection_output_loss: 3.6249e-06 - classification_output_loss: 0.0055 - regression_output_loss: 4.9583e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9993 - regression_output_mae: 0.0031 - val_loss: 5.1834 - val_detection_output_loss: 0.9252 - val_classification_output_loss: 2.2216 - val_regression_output_loss: 5.5100e-05 - val_detection_output_binary_accuracy: 0.9367 - val_classification_output_sparse_categorical_accuracy: 0.7970 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 108/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.0107 - detection_output_loss: 3.3768e-06 - classification_output_loss: 0.0054 - regression_output_loss: 4.9602e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9993 - regression_output_mae: 0.0031
# Epoch 108: val_classification_output_sparse_categorical_accuracy did not improve from 0.79716
# 443/443 [==============================] - 7s 15ms/step - loss: 0.0107 - detection_output_loss: 3.3764e-06 - classification_output_loss: 0.0054 - regression_output_loss: 4.9575e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9993 - regression_output_mae: 0.0031 - val_loss: 5.2089 - val_detection_output_loss: 0.9335 - val_classification_output_loss: 2.2310 - val_regression_output_loss: 5.5106e-05 - val_detection_output_binary_accuracy: 0.9365 - val_classification_output_sparse_categorical_accuracy: 0.7963 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 109/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.0104 - detection_output_loss: 3.1677e-06 - classification_output_loss: 0.0052 - regression_output_loss: 4.9561e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9994 - regression_output_mae: 0.0031
# Epoch 109: val_classification_output_sparse_categorical_accuracy did not improve from 0.79716
# 443/443 [==============================] - 7s 16ms/step - loss: 0.0104 - detection_output_loss: 3.1626e-06 - classification_output_loss: 0.0052 - regression_output_loss: 4.9568e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9994 - regression_output_mae: 0.0031 - val_loss: 5.2270 - val_detection_output_loss: 0.9387 - val_classification_output_loss: 2.2380 - val_regression_output_loss: 5.5102e-05 - val_detection_output_binary_accuracy: 0.9365 - val_classification_output_sparse_categorical_accuracy: 0.7970 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 110/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.0101 - detection_output_loss: 2.9372e-06 - classification_output_loss: 0.0050 - regression_output_loss: 4.9505e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9994 - regression_output_mae: 0.0031
# Epoch 110: val_classification_output_sparse_categorical_accuracy did not improve from 0.79716
# 443/443 [==============================] - 7s 16ms/step - loss: 0.0100 - detection_output_loss: 2.9366e-06 - classification_output_loss: 0.0050 - regression_output_loss: 4.9559e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9994 - regression_output_mae: 0.0031 - val_loss: 5.2557 - val_detection_output_loss: 0.9472 - val_classification_output_loss: 2.2489 - val_regression_output_loss: 5.5108e-05 - val_detection_output_binary_accuracy: 0.9365 - val_classification_output_sparse_categorical_accuracy: 0.7972 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 111/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.0097 - detection_output_loss: 2.7551e-06 - classification_output_loss: 0.0049 - regression_output_loss: 4.9578e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9994 - regression_output_mae: 0.0031
# Epoch 111: val_classification_output_sparse_categorical_accuracy did not improve from 0.79716
# 443/443 [==============================] - 7s 15ms/step - loss: 0.0097 - detection_output_loss: 2.7541e-06 - classification_output_loss: 0.0049 - regression_output_loss: 4.9552e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9994 - regression_output_mae: 0.0031 - val_loss: 5.2726 - val_detection_output_loss: 0.9515 - val_classification_output_loss: 2.2557 - val_regression_output_loss: 5.5108e-05 - val_detection_output_binary_accuracy: 0.9368 - val_classification_output_sparse_categorical_accuracy: 0.7968 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 112/120
# 443/443 [==============================] - ETA: 0s - loss: 0.0094 - detection_output_loss: 2.5188e-06 - classification_output_loss: 0.0047 - regression_output_loss: 4.9543e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9994 - regression_output_mae: 0.0031
# Epoch 112: val_classification_output_sparse_categorical_accuracy did not improve from 0.79716
# 443/443 [==============================] - 7s 15ms/step - loss: 0.0094 - detection_output_loss: 2.5188e-06 - classification_output_loss: 0.0047 - regression_output_loss: 4.9543e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9994 - regression_output_mae: 0.0031 - val_loss: 5.3003 - val_detection_output_loss: 0.9582 - val_classification_output_loss: 2.2669 - val_regression_output_loss: 5.5113e-05 - val_detection_output_binary_accuracy: 0.9369 - val_classification_output_sparse_categorical_accuracy: 0.7970 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 113/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.0091 - detection_output_loss: 2.3773e-06 - classification_output_loss: 0.0045 - regression_output_loss: 4.9481e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9995 - regression_output_mae: 0.0031
# Epoch 113: val_classification_output_sparse_categorical_accuracy did not improve from 0.79716
# 443/443 [==============================] - 7s 15ms/step - loss: 0.0091 - detection_output_loss: 2.3756e-06 - classification_output_loss: 0.0045 - regression_output_loss: 4.9535e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9995 - regression_output_mae: 0.0031 - val_loss: 5.3181 - val_detection_output_loss: 0.9647 - val_classification_output_loss: 2.2732 - val_regression_output_loss: 5.5123e-05 - val_detection_output_binary_accuracy: 0.9369 - val_classification_output_sparse_categorical_accuracy: 0.7965 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 114/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.0088 - detection_output_loss: 2.2251e-06 - classification_output_loss: 0.0044 - regression_output_loss: 4.9474e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9995 - regression_output_mae: 0.0031
# Epoch 114: val_classification_output_sparse_categorical_accuracy improved from 0.79716 to 0.79753, saving model to models/ple_model_1019_2.keras
# 443/443 [==============================] - 7s 15ms/step - loss: 0.0088 - detection_output_loss: 2.2238e-06 - classification_output_loss: 0.0044 - regression_output_loss: 4.9528e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9995 - regression_output_mae: 0.0031 - val_loss: 5.3425 - val_detection_output_loss: 0.9696 - val_classification_output_loss: 2.2834 - val_regression_output_loss: 5.5128e-05 - val_detection_output_binary_accuracy: 0.9369 - val_classification_output_sparse_categorical_accuracy: 0.7975 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 115/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.0085 - detection_output_loss: 2.0663e-06 - classification_output_loss: 0.0042 - regression_output_loss: 4.9464e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9995 - regression_output_mae: 0.0031
# Epoch 115: val_classification_output_sparse_categorical_accuracy did not improve from 0.79753
# 443/443 [==============================] - 7s 15ms/step - loss: 0.0085 - detection_output_loss: 2.0647e-06 - classification_output_loss: 0.0042 - regression_output_loss: 4.9518e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9995 - regression_output_mae: 0.0031 - val_loss: 5.3702 - val_detection_output_loss: 0.9761 - val_classification_output_loss: 2.2946 - val_regression_output_loss: 5.5134e-05 - val_detection_output_binary_accuracy: 0.9372 - val_classification_output_sparse_categorical_accuracy: 0.7965 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 116/120
# 443/443 [==============================] - ETA: 0s - loss: 0.0082 - detection_output_loss: 1.9387e-06 - classification_output_loss: 0.0041 - regression_output_loss: 4.9512e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9995 - regression_output_mae: 0.0031
# Epoch 116: val_classification_output_sparse_categorical_accuracy did not improve from 0.79753
# 443/443 [==============================] - 7s 15ms/step - loss: 0.0082 - detection_output_loss: 1.9387e-06 - classification_output_loss: 0.0041 - regression_output_loss: 4.9512e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9995 - regression_output_mae: 0.0031 - val_loss: 5.3883 - val_detection_output_loss: 0.9794 - val_classification_output_loss: 2.3024 - val_regression_output_loss: 5.5136e-05 - val_detection_output_binary_accuracy: 0.9374 - val_classification_output_sparse_categorical_accuracy: 0.7972 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 117/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.0079 - detection_output_loss: 1.8029e-06 - classification_output_loss: 0.0039 - regression_output_loss: 4.9496e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9996 - regression_output_mae: 0.0031
# Epoch 117: val_classification_output_sparse_categorical_accuracy did not improve from 0.79753
# 443/443 [==============================] - 7s 16ms/step - loss: 0.0079 - detection_output_loss: 1.7997e-06 - classification_output_loss: 0.0039 - regression_output_loss: 4.9503e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9996 - regression_output_mae: 0.0031 - val_loss: 5.4151 - val_detection_output_loss: 0.9871 - val_classification_output_loss: 2.3127 - val_regression_output_loss: 5.5137e-05 - val_detection_output_binary_accuracy: 0.9375 - val_classification_output_sparse_categorical_accuracy: 0.7968 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 118/120
# 443/443 [==============================] - ETA: 0s - loss: 0.0076 - detection_output_loss: 1.6935e-06 - classification_output_loss: 0.0038 - regression_output_loss: 4.9495e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9996 - regression_output_mae: 0.0031
# Epoch 118: val_classification_output_sparse_categorical_accuracy did not improve from 0.79753
# 443/443 [==============================] - 7s 15ms/step - loss: 0.0076 - detection_output_loss: 1.6935e-06 - classification_output_loss: 0.0038 - regression_output_loss: 4.9495e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9996 - regression_output_mae: 0.0031 - val_loss: 5.4354 - val_detection_output_loss: 0.9961 - val_classification_output_loss: 2.3193 - val_regression_output_loss: 5.5146e-05 - val_detection_output_binary_accuracy: 0.9375 - val_classification_output_sparse_categorical_accuracy: 0.7963 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 119/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.0074 - detection_output_loss: 1.5876e-06 - classification_output_loss: 0.0037 - regression_output_loss: 4.9511e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9996 - regression_output_mae: 0.0031
# Epoch 119: val_classification_output_sparse_categorical_accuracy did not improve from 0.79753
# 443/443 [==============================] - 7s 16ms/step - loss: 0.0074 - detection_output_loss: 1.5877e-06 - classification_output_loss: 0.0037 - regression_output_loss: 4.9485e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9996 - regression_output_mae: 0.0031 - val_loss: 5.4631 - val_detection_output_loss: 1.0008 - val_classification_output_loss: 2.3312 - val_regression_output_loss: 5.5152e-05 - val_detection_output_binary_accuracy: 0.9378 - val_classification_output_sparse_categorical_accuracy: 0.7965 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# Epoch 120/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.0071 - detection_output_loss: 1.4828e-06 - classification_output_loss: 0.0035 - regression_output_loss: 4.9427e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9996 - regression_output_mae: 0.0031
# Epoch 120: val_classification_output_sparse_categorical_accuracy did not improve from 0.79753
# 443/443 [==============================] - 7s 16ms/step - loss: 0.0071 - detection_output_loss: 1.4803e-06 - classification_output_loss: 0.0035 - regression_output_loss: 4.9481e-05 - detection_output_binary_accuracy: 1.0000 - classification_output_sparse_categorical_accuracy: 0.9996 - regression_output_mae: 0.0031 - val_loss: 5.4812 - val_detection_output_loss: 1.0063 - val_classification_output_loss: 2.3380 - val_regression_output_loss: 5.5147e-05 - val_detection_output_binary_accuracy: 0.9380 - val_classification_output_sparse_categorical_accuracy: 0.7964 - val_regression_output_mae: 0.0032 - lr: 3.1250e-05
# ✅ 模型 3 训练完成，耗时 833.81 秒
#
# ==================================================
# 📈 训练时间统计
# ==================================================
# 模型 1: 832.74 秒 (13.88 分钟)
# 模型 2: 823.73 秒 (13.73 分钟)
# 模型 3: 833.81 秒 (13.90 分钟)
# 🔥 总训练时间: 2490.28 秒 (41.50 分钟)
# ==================================================
#
# ✅ 所有PLE模型训练完成！模型已保存至 models/ple_model_1019_{i}.keras
# 📌 适配v3归一化数据的训练完成

# %%
# evaluate_ple_fixed_nrmse_columnwise.py
import os
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (confusion_matrix, accuracy_score, precision_score,
                             recall_score, f1_score, mean_absolute_error)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from matplotlib import font_manager as fm
import time

# ---------------------- 中文字体 ----------------------
def set_chinese_font():
    try:
        font_paths = ['/usr/share/fonts/truetype/wqy/wqy-microhei.ttc',
                      'C:/Windows/Fonts/simhei.ttf',
                      '/System/Library/Fonts/PingFang.ttc']
        for font_path in font_paths:
            if os.path.exists(font_path):
                fm.fontManager.addfont(font_path)
                plt.rcParams['font.family'] = fm.FontProperties(fname=font_path).get_name()
                plt.rcParams['axes.unicode_minus'] = False
                print(f"✅ 成功设置中文字体: {plt.rcParams['font.family']}")
                return True
        plt.rcParams['font.family'] = ['SimHei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("⚠️ 未找到指定字体，使用默认兼容字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False
set_chinese_font()

# ---------------------- 修复的PLE层（关键修复） ----------------------
class PLELayer(tf.keras.layers.Layer):
    def __init__(self, num_tasks, num_shared_experts, num_task_experts, expert_dim, name="ple_layer", **kwargs):
        # 修复：正确传递name参数给父类[4](@ref)
        super(PLELayer, self).__init__(name=name, **kwargs)
        self.num_tasks = num_tasks
        self.num_shared_experts = num_shared_experts
        self.num_task_experts = num_task_experts
        self.expert_dim = expert_dim
        
    def build(self, input_shape):
        input_dim = input_shape[-1]
        
        # 共享专家网络
        self.shared_experts = []
        for i in range(self.num_shared_experts):
            self.shared_experts.append(
                tf.keras.layers.Dense(self.expert_dim, activation='relu', name=f'shared_expert_{i}')
            )
        
        # 任务特定专家网络
        self.task_experts = []
        for task in range(self.num_tasks):
            task_expert_list = []
            for i in range(self.num_task_experts):
                task_expert_list.append(
                    tf.keras.layers.Dense(self.expert_dim, activation='relu', name=f'task_{task}_expert_{i}')
                )
            self.task_experts.append(task_expert_list)
        
        # 门控网络
        self.gates = []
        for task in range(self.num_tasks):
            self.gates.append(
                tf.keras.layers.Dense(self.num_shared_experts + self.num_task_experts, 
                                     activation='softmax', name=f'gate_{task}')
            )
        
        super(PLELayer, self).build(input_shape)
        
    def call(self, inputs):
        # 生成共享专家输出
        shared_expert_outputs = [expert(inputs) for expert in self.shared_experts]
        
        outputs = []
        for task in range(self.num_tasks):
            # 生成任务特定专家输出
            task_expert_outputs = [expert(inputs) for expert in self.task_experts[task]]
            
            # 合并所有专家输出
            all_expert_outputs = shared_expert_outputs + task_expert_outputs
            all_experts_concat = tf.stack(all_expert_outputs, axis=1)
            
            # 计算门控权重
            gate_weights = self.gates[task](inputs)
            gate_weights = tf.expand_dims(gate_weights, axis=-1)
            
            # 加权组合专家输出
            weighted_output = tf.reduce_sum(all_experts_concat * gate_weights, axis=1)
            outputs.append(weighted_output)
            
        return outputs
    
    def get_config(self):
        # 修复：实现get_config方法用于序列化[7,8](@ref)
        config = super(PLELayer, self).get_config()
        config.update({
            'num_tasks': self.num_tasks,
            'num_shared_experts': self.num_shared_experts,
            'num_task_experts': self.num_task_experts,
            'expert_dim': self.expert_dim
        })
        return config

# ---------------------- 加载数据集 ----------------------
def load_dataset(npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"):
    data = np.load(npz_path, allow_pickle=True)
    signals = data["signals"]
    labels = data["labels"].astype(np.int32)
    jnr_values = data["jnr_values"].astype(np.float32)
    fs = float(data["fs"])
    L = int(data["L"])
    noise_power_db = float(data["noise_power_db"])
    type2label = data["type_to_label"].item()

    interference_type_names = {
        "satellite_signal": "Satellite_Signal",
        "single_tone": "Single_Tone",
        "comb_spectra": "Comb_Spectra",
        "sweeping": "Sweeping-LFM",
        "pulse": "Pulse",
        "frequency_hopping": "Frequency_Hopping",
        "noise_fm": "Noise_FM",
        "noise_am": "Noise_AM",
        "random_combination": "Random_Combination"
    }
    label2name = {i: interference_type_names[k] for k, i in type2label.items()}
    return {
        "signals": signals,
        "labels": labels,
        "jnr_values": jnr_values,
        "fs": fs,
        "L": L,
        "noise_power_db": noise_power_db,
        "type2label": type2label,
        "label2name": label2name
    }

# ---------------------- 在线估算标签 ----------------------
def estimate_start_end(signal, fs, threshold_factor=2.0):
    power = signal ** 2
    avg_pow = np.mean(power)
    thresh = threshold_factor * avg_pow
    above = power > thresh
    diff = np.diff(above.astype(int))
    starts = np.where(diff == 1)[0]
    ends = np.where(diff == -1)[0]
    if len(starts) == 0 or len(ends) == 0:
        return 0.0, 0.0
    return float(starts[0] / fs * 1e3), float(ends[-1] / fs * 1e3)

def estimate_jnr(signal, noise_power_db):
    total_power = 10 * np.log10(np.mean(signal ** 2) + 1e-12)
    return float(total_power - noise_power_db)

# ---------------------- 数据预处理 ----------------------
def preprocess_data(dataset):
    signals = dataset["signals"]
    labels = dataset["labels"]
    jnr_values = dataset["jnr_values"]
    L = dataset["L"]
    fs = dataset["fs"]
    noise_power_db = dataset["noise_power_db"]

    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() for s in signals])

    no_key = "satellite_signal"
    det_labels = (labels != dataset["type2label"][no_key]).astype(np.float32)

    # 使用在线估算方法
    param_labels = []
    for i, signal in enumerate(signals):
        start_time, end_time = estimate_start_end(signal, fs)
        jnr_db = jnr_values[i]
        param_labels.append([start_time, end_time, jnr_db])
    param_labels = np.array(param_labels, dtype=np.float32)

    X_test = signals
    y_det_test = det_labels
    y_type_test = labels
    y_param_test = param_labels
    jnr_test = jnr_values
    label2name = dataset["label2name"]

    return {
        "X_test": X_test,
        "y_det_test": y_det_test,
        "y_type_test": y_type_test,
        "y_param_test": y_param_test,
        "jnr_values_test": jnr_test,
        "label2name": label2name,
        "L": L
    }

# ---------------------- 按列分别归一化 NRMSE ----------------------
def nrmse_columnwise(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2, axis=0))
    y_range = np.max(y_true, axis=0) - np.min(y_true, axis=0)
    return rmse / (y_range + 1e-8)

# ---------------------- 修复的模型加载和预测 ----------------------
def load_and_predict(model_paths, X_test):
    all_det, all_cls, all_reg = [], [], []
    
    # 修复：正确注册自定义对象[6,8](@ref)
    custom_objects = {
        'PLELayer': PLELayer
    }
    
    for path in model_paths:
        print(f"🔁 加载模型: {path}")
        try:
            # 修复：使用custom_objects参数[7,10](@ref)
            model = tf.keras.models.load_model(path, custom_objects=custom_objects, compile=False)
            start_time = time.time()
            det, cls, reg = model.predict(X_test, verbose=0)
            end_time = time.time()
            prediction_time = end_time - start_time
            print(f"✅ 预测时间: {prediction_time:.2f} 秒")
            all_det.append(det)
            all_cls.append(cls)
            all_reg.append(reg)
        except Exception as e:
            print(f"❌ 加载模型失败: {e}")
            continue
    
    if len(all_det) == 0:
        raise ValueError("所有模型加载失败，请检查模型路径和自定义层定义")
    
    # 集成平均
    avg_det = (np.mean(all_det, axis=0) > 0.5).astype(int).ravel()
    avg_cls = np.argmax(np.mean(all_cls, axis=0), axis=1)
    avg_reg = np.mean(all_reg, axis=0)
    
    return avg_det, avg_cls, avg_reg

# ---------------------- 绘制混淆矩阵 ----------------------
def plot_confusion_matrix(cm, labels, title, xlabel, ylabel, filename, dpi=150, rotate_x=False):
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
    cm_normalized = np.nan_to_num(cm_normalized)

    plt.figure(figsize=(12, 10))
    ax = sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues',
                     xticklabels=labels, yticklabels=labels, square=True, annot_kws={"size": 14})
    cbar = ax.collections[0].colorbar
    cbar.ax.tick_params(labelsize=14)

    plt.title(title, pad=20, fontsize=18)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.xticks(rotation=45 if rotate_x else 0, ha='right' if rotate_x else 'center', fontsize=14)
    plt.yticks(rotation=0, fontsize=14)
    plt.tight_layout()
    plt.savefig(filename, dpi=dpi)
    plt.close()

# ---------------------- 主评估函数 ----------------------
def evaluate(models_dir="models",
             npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz",
             wanted_jnr=np.arange(-10, 31, 5),
             dpi=150):
    
    os.makedirs("visualizations", exist_ok=True)
    os.makedirs("reports", exist_ok=True)

    print("\n" + "="*60)
    print("📊 开始评估 PLE 多任务模型（修复版）")
    print("="*60)
    
    # 加载数据
    dataset = load_dataset(npz_path)
    data = preprocess_data(dataset)

    X_test = data["X_test"]
    y_det_test = data["y_det_test"]
    y_type_test = data["y_type_test"]
    y_param_test = data["y_param_test"]
    jnr_test = data["jnr_values_test"]
    label2name = data["label2name"]

    # 修复：使用正确的模型路径格式
    model_paths = [os.path.join(models_dir, f"ple_model_1019_{i}.keras") for i in range(3)]
    
    # 检查模型文件是否存在
    for path in model_paths:
        if not os.path.exists(path):
            print(f"⚠️ 警告: 模型文件 {path} 不存在")
    
    # 加载模型并预测
    avg_det, avg_cls, avg_reg = load_and_predict(model_paths, X_test)

    # 1. 检测混淆矩阵
    cm_det = confusion_matrix(y_det_test, avg_det)
    plot_confusion_matrix(
        cm=cm_det,
        labels=['No Interference', 'Interference'],
        title='PLE Interference Detection Confusion Matrix',
        xlabel='Predicted',
        ylabel='True',
        filename='visualizations/PLE_detection_confusion_matrix.png',
        dpi=dpi,
        rotate_x=False
    )

    # 2. 分类混淆矩阵
    cm_type = confusion_matrix(y_type_test, avg_cls)
    plot_confusion_matrix(
        cm=cm_type,
        labels=[label2name[i] for i in sorted(label2name.keys())],
        title='PLE Classification Confusion Matrix',
        xlabel='Predicted',
        ylabel='True',
        filename='visualizations/PLE_classification_confusion_matrix.png',
        dpi=dpi,
        rotate_x=True
    )

    # 3. JNR vs 准确率
    jnr_acc = []
    for jnr in wanted_jnr:
        mask = jnr_test == jnr
        if np.sum(mask) == 0:
            jnr_acc.append(np.nan)
        else:
            acc = accuracy_score(y_type_test[mask], avg_cls[mask])
            jnr_acc.append(acc)

    plt.figure(figsize=(8, 5))
    valid_mask = ~np.isnan(jnr_acc)
    plt.plot(wanted_jnr[valid_mask], np.array(jnr_acc)[valid_mask], marker='o', linewidth=2)
    if np.any(~valid_mask):
        plt.scatter(wanted_jnr[~valid_mask], [1.0] * np.sum(~valid_mask),
                    facecolors='none', edgecolors='r', s=60)
    plt.xlabel('JNR (dB)', fontsize=14)
    plt.ylabel('Accuracy', fontsize=14)
    plt.title('PLE Classification Accuracy vs JNR', fontsize=16)
    plt.xticks(wanted_jnr)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.ylim(0, 1.05)
    plt.tight_layout()
    plt.savefig('visualizations/PLE_jnr_vs_accuracy.png', dpi=dpi)
    plt.close()

    # 4. 指标计算
    det_acc = accuracy_score(y_det_test, avg_det)
    cls_acc = accuracy_score(y_type_test, avg_cls)
    cls_precision = precision_score(y_type_test, avg_cls, average='weighted', zero_division=0)
    cls_recall = recall_score(y_type_test, avg_cls, average='weighted', zero_division=0)
    cls_f1 = f1_score(y_type_test, avg_cls, average='weighted', zero_division=0)
    param_mae = mean_absolute_error(y_param_test, avg_reg, multioutput='raw_values')

    # 按列分别归一化 NRMSE
    param_nrmse = nrmse_columnwise(y_param_test, avg_reg)
    param_names = ['Start Time (ms)', 'End Time (ms)', 'JNR (dB)']

    print("\n" + "="*50)
    print("📊 PLE 评估结果（修复版）")
    print("="*50)
    print(f"检测准确率: {det_acc:.4f}")
    print(f"分类准确率: {cls_acc:.4f}")
    print(f"分类精确率: {cls_precision:.4f}, 召回率: {cls_recall:.4f}, F1: {cls_f1:.4f}")
    print("\n参数估计误差（MAE & 按列 NRMSE）:")
    for i, (name, mae, nrmse) in enumerate(zip(param_names, param_mae, param_nrmse)):
        print(f"  {name}: MAE = {mae:.4f}, NRMSE = {nrmse:.4f}")
    print(f"  平均 NRMSE（三列分别归一化） = {np.mean(param_nrmse):.4f}")

    print("\nJNR 准确率:")
    for j, acc in zip(wanted_jnr, jnr_acc):
        acc_str = f"{acc:.4f}" if not np.isnan(acc) else 'N/A'
        print(f"  {int(j)}dB: {acc_str}")

    # 5. 保存报告
    report = {
        "detection_accuracy": float(det_acc),
        "classification_accuracy": float(cls_acc),
        "classification_precision": float(cls_precision),
        "classification_recall": float(cls_recall),
        "classification_f1": float(cls_f1),
        "parameter_mae": [float(m) for m in param_mae],
        "parameter_nrmse": [float(n) for n in param_nrmse],
        "average_columnwise_nrmse": float(np.mean(param_nrmse)),
        "parameter_details": {
            param_names[i]: {"mae": float(param_mae[i]), "nrmse": float(param_nrmse[i])}
            for i in range(len(param_names))
        },
        "jnr_accuracies": {f"{int(j)}dB": float(acc) if not np.isnan(acc) else None 
                          for j, acc in zip(wanted_jnr, jnr_acc)}
    }
    
    with open("reports/PLE_evaluation_report_fixed.json", "w", encoding='utf-8') as f:
        json.dump(report, f, indent=4, ensure_ascii=False)

    print("\n✅ PLE 评估完成！混淆矩阵与报告已保存。")

# ---------------------- 主函数 ----------------------
if __name__ == "__main__":
    evaluate(models_dir="models",
             npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz",
             wanted_jnr=np.arange(-10, 31, 5),
             dpi=150)
# Out:
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
#
# ============================================================
# 📊 开始评估 PLE 多任务模型（修复版）
# ============================================================
# 🔁 加载模型: models/ple_model_1019_0.keras
# ✅ 预测时间: 9.52 秒
# 🔁 加载模型: models/ple_model_1019_1.keras
# ✅ 预测时间: 8.53 秒
# 🔁 加载模型: models/ple_model_1019_2.keras
# ✅ 预测时间: 8.80 秒
#
# ==================================================
# 📊 PLE 评估结果（修复版）
# ==================================================
# 检测准确率: 0.9813
# 分类准确率: 0.9402
# 分类精确率: 0.9414, 召回率: 0.9402, F1: 0.9403
#
# 参数估计误差（MAE & 按列 NRMSE）:
#   Start Time (ms): MAE = 0.0046, NRMSE = 0.0872
#   End Time (ms): MAE = 0.0047, NRMSE = 0.0880
#   JNR (dB): MAE = 13.3333, NRMSE = 0.4082
#   平均 NRMSE（三列分别归一化） = 0.1945
#
# JNR 准确率:
#   -10dB: 0.7970
#   -5dB: 0.8747
#   0dB: 0.9241
#   5dB: 0.9508
#   10dB: 0.9652
#   15dB: 0.9790
#   20dB: 0.9894
#   25dB: 0.9901
#   30dB: 0.9914
#
# ✅ PLE 评估完成！混淆矩阵与报告已保存。

# %% [markdown]
# ============================================================
# 📊 开始评估 PLE 多任务模型（修复版）
# ============================================================
# 🔁 加载模型: models/ple_model_1019_0.keras
# ✅ 预测时间: 9.52 秒
# 🔁 加载模型: models/ple_model_1019_1.keras
# ✅ 预测时间: 8.53 秒
# 🔁 加载模型: models/ple_model_1019_2.keras
# ✅ 预测时间: 8.80 秒
#
# ==================================================
# 📊 PLE 评估结果（修复版）
# ==================================================
# 检测准确率: 0.9813
# 分类准确率: 0.9402
# 分类精确率: 0.9414, 召回率: 0.9402, F1: 0.9403
#
# 参数估计误差（MAE & 按列 NRMSE）:
#   Start Time (ms): MAE = 0.0046, NRMSE = 0.0872
#   End Time (ms): MAE = 0.0047, NRMSE = 0.0880
#   JNR (dB): MAE = 13.3333, NRMSE = 0.4082
#   平均 NRMSE（三列分别归一化） = 0.1945
#
# JNR 准确率:
#   -10dB: 0.7970
#   -5dB: 0.8747
#   0dB: 0.9241
#   5dB: 0.9508
#   10dB: 0.9652
#   15dB: 0.9790
#   20dB: 0.9894
#   25dB: 0.9901
#   30dB: 0.9914
#
#
#   ============================================================
# 📊 开始评估 PLE 多任务模型（修复版）
# ============================================================
# 🔁 加载模型: models/ple_model_1019_0.keras
# ✅ 预测时间: 9.85 秒
# 🔁 加载模型: models/ple_model_1019_1.keras
# ✅ 预测时间: 8.91 秒
# 🔁 加载模型: models/ple_model_1019_2.keras
# ✅ 预测时间: 9.25 秒
#
# ==================================================
# 📊 PLE 评估结果（修复版）
# ==================================================
# 检测准确率: 0.9816
# 分类准确率: 0.9428
# 分类精确率: 0.9440, 召回率: 0.9428, F1: 0.9430
#
# 参数估计误差（MAE & 按列 NRMSE）:
#   Start Time (ms): MAE = 0.0046, NRMSE = 0.0871
#   End Time (ms): MAE = 0.0046, NRMSE = 0.0850
#   JNR (dB): MAE = 13.3333, NRMSE = 0.4082
#   平均 NRMSE（三列分别归一化） = 0.1934
#
# JNR 准确率:
#   -10dB: 0.7972
#   -5dB: 0.8732
#   0dB: 0.9349
#   5dB: 0.9548
