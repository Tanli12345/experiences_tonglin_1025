# %%
# train_model_online_estimate_v3_adapter.py
import os
import time
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, roc_auc_score, r2_score
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Concatenate, Conv1D, MaxPooling1D,
                                     Dense, Dropout, Lambda, BatchNormalization,
                                     GlobalAveragePooling1D, GlobalAveragePooling2D,
                                     Conv2D, MaxPooling2D, Reshape)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import BinaryCrossentropy, SparseCategoricalCrossentropy, MeanSquaredError
from tensorflow.keras.metrics import BinaryAccuracy, SparseCategoricalAccuracy
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

# ---------- 中文字体 ----------
def set_chinese_font():
    try:
        font_paths = ['/usr/share/fonts/truetype/wqy/wqy-microhei.ttc',
                      'C:/Windows/Fonts/simhei.ttf',
                      '/System/Library/Fonts/PingFang.ttc']
        for font_path in font_paths:
            if os.path.exists(font_path):
                fm.fontManager.addfont(font_path)
                plt.rcParams['font.family'] = fm.FontProperties(fname=font_path).get_name()
                plt.rcParams['axes.unicode_minus'] = False
                print(f"✅ 成功设置中文字体: {plt.rcParams['font.family']}")
                return True
        plt.rcParams['font.family'] = ['SimHei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("⚠️ 未找到指定字体，使用默认兼容字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False
set_chinese_font()

# ---------- 加载数据集 ----------
def load_dataset(npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"):
    """加载数据集并适配v3版归一化参数"""
    data = np.load(npz_path, allow_pickle=True)
    signals = data["signals"]
    labels = data["labels"].astype(np.int32)
    jnr_values = data["jnr_values"].astype(np.float32)
    fs = float(data["fs"])
    L = int(data["L"])
    noise_power_db = float(data["noise_power_db"])
    type2label = data["type_to_label"].item()
    
    # 从metadata中提取参数统计信息用于反归一化
    metadata = data["metadata"] if "metadata" in data else None
    param_stats = calculate_param_statistics(metadata, L, fs)
    
    interference_type_names = {
        "satellite_signal": "Satellite_Signal",
        "single_tone": "Single_Tone",
        "comb_spectra": "Comb_Spectra",
        "sweeping": "Sweeping-LFM",
        "pulse": "Pulse",
        "frequency_hopping": "Frequency_Hopping",
        "noise_fm": "Noise_FM",
        "noise_am": "Noise_AM",
        "random_combination": "Random_Combination"
    }
    label2name = {i: interference_type_names[k] for k, i in type2label.items()}

    return {
        "signals": signals,
        "labels": labels,
        "jnr_values": jnr_values,
        "fs": fs,
        "L": L,
        "noise_power_db": noise_power_db,
        "type2label": type2label,
        "label2name": label2name,
        "param_stats": param_stats  # 新增：参数统计信息
    }

def calculate_param_statistics(metadata, L, fs):
    """从metadata计算参数统计信息用于反归一化"""
    if metadata is None:
        return {"total_duration_ms": L/fs*1e3, "jnr_range": [-10, 30]}
    
    # 提取所有参数用于统计
    all_start_times = []
    all_end_times = []
    all_jnr_values = []
    
    for m in metadata:
        params = m.get("params", {})
        if "start_time" in params:
            all_start_times.append(params["start_time"])
        if "end_time" in params:
            all_end_times.append(params["end_time"])
        if "jnr_db" in params:
            all_jnr_values.append(params["jnr_db"])
    
    # 计算统计量
    total_duration_ms = L / fs * 1e3  # 信号总时长(ms)
    
    return {
        "total_duration_ms": total_duration_ms,
        "start_time_mean": np.mean(all_start_times) if all_start_times else 0.5,
        "end_time_mean": np.mean(all_end_times) if all_end_times else 0.5,
        "jnr_mean": np.mean(all_jnr_values) if all_jnr_values else 10.0,
        "start_time_std": np.std(all_start_times) if all_start_times else 0.2,
        "end_time_std": np.std(all_end_times) if all_end_times else 0.2,
        "jnr_std": np.std(all_jnr_values) if all_jnr_values else 10.0
    }

# ---------- 数据预处理（适配v3归一化） ----------
def preprocess_data(dataset, aug_ratio=0.1):
    signals = dataset["signals"]
    labels = dataset["labels"]
    jnr_values = dataset["jnr_values"]
    L = dataset["L"]
    param_stats = dataset["param_stats"]

    # 信号标准化
    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() for s in signals])

    # 检测标签
    no_key = "satellite_signal"
    det_labels = (labels != dataset["type2label"][no_key]).astype(np.float32)

    # 使用生成时记录的参数作为标签（v3版已归一化到[0,1]）
    param_labels = []
    if "metadata" in dataset and dataset["metadata"] is not None:
        for m in dataset["metadata"]:
            p = m.get("params", {})
            # v3版参数已经是归一化值，直接使用
            start_time = float(p.get("start_time", 0.0))   # ∈ [0,1]
            end_time = float(p.get("end_time", 0.0))     # ∈ [0,1]
            jnr_db = float(p.get("jnr_db", 0.0))          # 真实dB值
            
            param_labels.append([start_time, end_time, jnr_db])
    else:
        print("⚠️ 未找到 metadata，使用默认参数标签")
        param_labels = [[0.5, 0.5, 0.0] for _ in range(len(signals))]  # 使用中间值
    
    param_labels = np.array(param_labels, dtype=np.float32)

    # 对JNR进行归一化（与其他时间参数尺度一致）
    jnr_min, jnr_max = -10, 30  # JNR范围
    param_labels[:, 2] = (param_labels[:, 2] - jnr_min) / (jnr_max - jnr_min)  # 归一化到[0,1]

    # 丢弃含 NaN/Inf 的样本
    mask = ~(
        np.any(np.isnan(signals), axis=1) |
        np.any(np.isinf(signals), axis=1) |
        np.isnan(det_labels) | np.isinf(det_labels) |
        np.isnan(labels) | np.isinf(labels) |
        np.any(np.isnan(param_labels), axis=1) | np.any(np.isinf(param_labels), axis=1)
    )
    print(f"🧹 丢弃 {np.sum(~mask)} / {len(mask)} 条含 NaN/Inf 的样本")
    signals, det_labels, labels, param_labels, jnr_values = \
        signals[mask], det_labels[mask], labels[mask], param_labels[mask], jnr_values[mask]

    # 数据集分割
    X_train, X_tmp, y_det_train, y_det_tmp, y_type_train, y_type_tmp, y_param_train, y_param_tmp, jnr_train, jnr_tmp = train_test_split(
        signals, det_labels, labels, param_labels, jnr_values,
        test_size=0.3, random_state=42, stratify=labels
    )
    X_val, X_test, y_det_val, y_det_test, y_type_val, y_type_test, y_param_val, y_param_test, jnr_val, jnr_test = train_test_split(
        X_tmp, y_det_tmp, y_type_tmp, y_param_tmp, jnr_tmp,
        test_size=2/3, random_state=42, stratify=y_type_tmp
    )

    return {
        "X_train": X_train, "X_val": X_val, "X_test": X_test,
        "y_det_train": y_det_train, "y_det_val": y_det_val, "y_det_test": y_det_test,
        "y_type_train": y_type_train, "y_type_val": y_type_val, "y_type_test": y_type_test,
        "y_param_train": y_param_train, "y_param_val": y_param_val, "y_param_test": y_param_test,
        "jnr_values_train": jnr_train, "jnr_values_val": jnr_val, "jnr_values_test": jnr_test,
        "type2label": dataset["type2label"], "label2name": dataset["label2name"],
        "L": L, "fs": dataset["fs"], "noise_power_db": dataset["noise_power_db"],
        "param_stats": param_stats,  # 传递参数统计信息
        "jnr_range": [jnr_min, jnr_max]  # JNR范围用于反归一化
    }

# ---------- 反归一化函数 ----------
def denormalize_params(normalized_params, param_stats, jnr_range):
    """将归一化的参数反归一化为原始物理量"""
    total_duration_ms = param_stats["total_duration_ms"]
    jnr_min, jnr_max = jnr_range
    
    denormalized = np.zeros_like(normalized_params)
    # 反归一化开始时间：归一化值 → 毫秒
    denormalized[:, 0] = normalized_params[:, 0] * total_duration_ms
    # 反归一化结束时间：归一化值 → 毫秒  
    denormalized[:, 1] = normalized_params[:, 1] * total_duration_ms
    # 反归一化JNR：归一化值 → 原始dB值
    denormalized[:, 2] = normalized_params[:, 2] * (jnr_max - jnr_min) + jnr_min
    
    return denormalized

# ---------- 非均匀掩膜 ----------
@tf.function
def adaptive_diff_mask(x, n_levels=3):
    L = tf.shape(x)[0]
    seg_min = 2 ** n_levels
    L_pad = tf.cast(tf.math.ceil(L / seg_min) * seg_min, tf.int32)
    x_pad = tf.pad(x, [[0, L_pad - L]])
    x_avg = tf.squeeze(
        tf.nn.avg_pool1d(
            tf.expand_dims(tf.expand_dims(x_pad, 0), -1),
            ksize=seg_min, strides=seg_min, padding='VALID', data_format='NWC'
        ),
        [0, -1]
    )
    diff = x_avg[1:] - x_avg[:-1]
    flat_idx = tf.argmin(tf.abs(diff))
    n_seg = tf.shape(x_avg)[0]
    mask = tf.ones(n_seg, dtype=tf.float32)
    mask = tf.tensor_scatter_nd_update(mask, [[flat_idx]], [0.0])
    mask = tf.repeat(mask, seg_min)[:L_pad]
    return mask[:L]

# ---------- 数据增强 ----------
@tf.function
def aug_fn(x):
    x = tf.cast(x, tf.float32)
    if tf.random.uniform([]) > 0.2:
        snr = tf.random.uniform([], 5., 25.)
        noise = tf.random.normal(tf.shape(x), dtype=tf.float32) * tf.math.reduce_std(x) * tf.cast(10.0 ** (-snr / 20.0), tf.float32)
        x = x + noise
    if tf.random.uniform([]) > 0.3:
        shift = tf.random.uniform([], -100, 100, dtype=tf.int32)
        x = tf.roll(x, shift=shift, axis=0)
    if tf.random.uniform([]) > 0.3:
        scale = tf.random.uniform([], 0.7, 1.3)
        x = x * scale
    if tf.random.uniform([]) > 0.7:
        freq_shift = tf.random.uniform([], -0.1, 0.1)
        n = tf.cast(tf.shape(x)[0], tf.float32)
        x = x * tf.cos(2 * np.pi * freq_shift * tf.range(n, dtype=tf.float32))
    return x

@tf.function
def aug_fn_with_mask(x):
    x = aug_fn(x)
    mask = adaptive_diff_mask(x)
    x = x * mask
    return x

# ---------- 网络架构（适配v3归一化） ----------
def build_model(input_shape, num_classes):
    inputs = Input(shape=input_shape, dtype=tf.float32)
    x1 = Reshape((input_shape[0], 1))(inputs)
    x1 = Conv1D(64, 7, activation='relu', padding='same')(x1)
    x1 = BatchNormalization()(x1)
    x1 = MaxPooling1D(2)(x1)
    x1 = Conv1D(128, 5, activation='relu', padding='same')(x1)
    x1 = BatchNormalization()(x1)
    x1 = MaxPooling1D(2)(x1)
    x1 = Conv1D(256, 3, activation='relu', padding='same')(x1)
    x1 = BatchNormalization()(x1)
    branch1 = GlobalAveragePooling1D()(x1)

    def stft_layer(x):
        x = tf.squeeze(x, axis=-1) if x.shape[-1] == 1 else x
        stft = tf.signal.stft(x, frame_length=128, frame_step=64, fft_length=128)
        mag = tf.abs(stft)
        return mag
    x2 = Lambda(stft_layer)(inputs)
    x2 = Reshape((x2.shape[1], x2.shape[2], 1))(x2)
    x2 = Conv2D(64, (3, 3), activation='relu', padding='same')(x2)
    x2 = BatchNormalization()(x2)
    x2 = MaxPooling2D((2, 2))(x2)
    x2 = Conv2D(128, (3, 3), activation='relu', padding='same')(x2)
    x2 = BatchNormalization()(x2)
    x2 = MaxPooling2D((2, 2))(x2)
    branch2 = GlobalAveragePooling2D()(x2)

    def stats_layer(x):
        mean = tf.reduce_mean(x, axis=1, keepdims=True)
        std = tf.math.reduce_std(x, axis=1, keepdims=True)
        var = tf.math.reduce_variance(x, axis=1, keepdims=True)
        max_val = tf.reduce_max(x, axis=1, keepdims=True)
        min_val = tf.reduce_min(x, axis=1, keepdims=True)
        return tf.concat([mean, std, var, max_val, min_val], -1)
    x3 = Lambda(stats_layer)(inputs)
    x3 = Dense(64, activation='relu')(x3)
    x3 = BatchNormalization()(x3)
    branch3 = Dense(128, activation='relu')(x3)

    merged = Concatenate()([branch1, branch2, branch3])
    shared = Dense(256, activation='relu')(merged)
    shared = Dropout(0.5)(shared)
    shared = Dense(128, activation='relu')(shared)
    shared = Dropout(0.3)(shared)

    det_feat = Dense(64, activation='relu')(shared)
    cls_feat = Dense(64, activation='relu')(shared)
    reg_feat = Dense(64, activation='relu')(shared)

    det_out = Dense(1, activation='sigmoid', name='detection_output')(det_feat)
    cls_out = Dense(num_classes, activation='softmax', name='classification_output')(cls_feat)
    
    # 回归分支：输出归一化参数 ∈ [0,1]
    reg_out = Dense(3, activation='sigmoid', name='regression_output')(reg_feat)  # 使用sigmoid确保输出在[0,1]
    
    model = Model(inputs, [det_out, cls_out, reg_out])
    
    # 编译配置：调整损失权重适应归一化参数
    model.compile(
        optimizer=Adam(1e-3),
        loss={
            'detection_output': BinaryCrossentropy(),
            'classification_output': SparseCategoricalCrossentropy(),
            'regression_output': MeanSquaredError()
        },
        loss_weights={
            'detection_output': 0.8,
            'classification_output': 2.0,
            'regression_output': 0.5  # 提高回归权重，因参数范围已归一化
        },
        metrics={
            'detection_output': BinaryAccuracy(),
            'classification_output': SparseCategoricalAccuracy(),
            'regression_output': 'mae'
        }
    )
    return model

# ---------- 训练（适配v3归一化） ----------
def train_single_model(data, model_idx, epochs=120, batch=128):
    input_shape, num_classes = (data["L"],), len(data["type2label"])
    model = build_model(input_shape, num_classes)

    unique_labels = np.unique(data['y_type_train'])
    cls_weights = compute_class_weight('balanced', classes=unique_labels, y=data['y_type_train'])
    cls_weight_dict = {lab: float(w) for lab, w in zip(unique_labels, cls_weights)}
    sample_weights = np.array([cls_weight_dict[lab] for lab in data['y_type_train']])

    def filter_nan(*args):
        x, y = args[0], args[1]
        ok = (tf.reduce_all(tf.math.is_finite(x)) &
              tf.math.is_finite(y['detection_output']) &
              tf.reduce_all(tf.math.is_finite(y['regression_output'])))
        if len(args) == 3:
            ok &= tf.math.is_finite(args[2])
        return ok

    ds_train = tf.data.Dataset.from_tensor_slices((
        data['X_train'],
        {
            'detection_output': data['y_det_train'],
            'classification_output': data['y_type_train'],
            'regression_output': data['y_param_train']  # 已经是归一化值
        },
        sample_weights
    ))
    ds_train = ds_train.filter(filter_nan)
    ds_train = ds_train.map(lambda x, y, w: (aug_fn_with_mask(x), y, w), num_parallel_calls=tf.data.AUTOTUNE)
    ds_train = ds_train.shuffle(10000).batch(batch).prefetch(tf.data.AUTOTUNE)

    ds_val = tf.data.Dataset.from_tensor_slices((
        data['X_val'],
        {
            'detection_output': data['y_det_val'],
            'classification_output': data['y_type_val'],
            'regression_output': data['y_param_val']  # 已经是归一化值
        }
    ))
    ds_val = ds_val.filter(filter_nan)
    ds_val = ds_val.batch(batch).prefetch(tf.data.AUTOTUNE)

    os.makedirs("models", exist_ok=True)
    ckpt = f"models/combo_aug_model_v3_{model_idx}.keras"
    callbacks = [
        EarlyStopping(monitor='val_classification_output_sparse_categorical_accuracy', patience=20,
                      restore_best_weights=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_classification_output_sparse_categorical_accuracy', factor=0.5,
                          patience=10, min_lr=1e-5, mode='max', verbose=1),
        ModelCheckpoint(ckpt, save_best_only=True, save_weights_only=False,
                        monitor='val_classification_output_sparse_categorical_accuracy', mode='max', verbose=1)
    ]

    print(f"\n🔥 训练第 {model_idx + 1} 个模型（适配v3归一化数据）...")
    start_time = time.time()
    history = model.fit(ds_train, validation_data=ds_val, epochs=epochs, callbacks=callbacks, verbose=1)
    end_time = time.time()
    training_time = end_time - start_time
    print(f"✅ 模型 {model_idx + 1} 训练完成，耗时 {training_time:.2f} 秒")
    return model, training_time

def train_ensemble(data, n_models=3, epochs=120, batch=128):
    models, training_times = [], []
    for i in range(n_models):
        model, t = train_single_model(data, i, epochs=epochs, batch=batch)
        models.append(model)
        training_times.append(t)
    return models, training_times

# ---------- 评估 + 打印（适配v3归一化） ----------
def evaluate_and_print(models, data, batch=128):
    os.makedirs("reports", exist_ok=True)
    ds_test = tf.data.Dataset.from_tensor_slices((
        data['X_test'],
        {
            'detection_output': data['y_det_test'],
            'classification_output': data['y_type_test'],
            'regression_output': data['y_param_test']  # 归一化值
        }
    )).batch(batch).prefetch(tf.data.AUTOTUNE)

    y_det_true, y_type_true, y_param_true = [], [], []
    y_det_pred, y_type_pred, y_param_pred = [], [], []
    x_input = []

    for x, y in ds_test:
        x_input.append(x.numpy())
        y_det_true.append(y['detection_output'].numpy())
        y_type_true.append(y['classification_output'].numpy())
        y_param_true.append(y['regression_output'].numpy())

        preds = [m(x, training=False) for m in models]
        det_avg = np.mean([p[0].numpy() for p in preds], axis=0)
        cls_avg = np.mean([p[1].numpy() for p in preds], axis=0)
        reg_avg = np.mean([p[2].numpy() for p in preds], axis=0)

        y_det_pred.append(det_avg)
        y_type_pred.append(cls_avg)
        y_param_pred.append(reg_avg)

    x_input = np.concatenate(x_input, axis=0)
    y_det_true = np.concatenate(y_det_true, axis=0)
    y_type_true = np.concatenate(y_type_true, axis=0)
    y_param_true = np.concatenate(y_param_true, axis=0)
    y_det_pred = np.concatenate(y_det_pred, axis=0)
    y_type_pred = np.concatenate(y_type_pred, axis=0)
    y_param_pred = np.concatenate(y_param_pred, axis=0)

    # 反归一化参数用于显示和评估
    y_param_true_denorm = denormalize_params(y_param_true, data['param_stats'], data['jnr_range'])
    y_param_pred_denorm = denormalize_params(y_param_pred, data['param_stats'], data['jnr_range'])

    # 打印前 5 条（显示反归一化后的参数）
    print("\n" + "="*80)
    print("📥 输入信号（前 5 条）")
    print("="*80)
    for i in range(5):
        print(f"样本 {i}: {x_input[i][:10]} ... (len={len(x_input[i])})")

    print("\n" + "="*80)
    print("📤 真实 vs 预测（前 5 条）- 反归一化显示")
    print("="*80)
    for i in range(5):
        print(f"样本 {i}:")
        print(f"  det_true: {y_det_true[i]:.4f}  |  det_pred: {y_det_pred[i,0]:.4f}")
        print(f"  cls_true: {y_type_true[i]}     |  cls_pred: {np.argmax(y_type_pred[i])}")
        print(f"  reg_true: {y_param_true_denorm[i]}  |  reg_pred: {y_param_pred_denorm[i]}")

    # 使用反归一化后的参数计算NRMSE
    def nrmse(y_true, y_pred):
        rmse = np.sqrt(np.mean((y_true - y_pred) ** 2, axis=0))
        y_range = np.max(y_true, axis=0) - np.min(y_true, axis=0)
        return rmse / (y_range + 1e-8)

    reg_nrmse = nrmse(y_param_true_denorm, y_param_pred_denorm)
    print("\n" + "="*80)
    print("📈 NRMSE 报告（基于反归一化参数）")
    print("="*80)
    print("参数维度: [start_time(ms), end_time(ms), jnr_db]")
    for i, name in enumerate(["start_time", "end_time", "jnr_db"]):
        print(f"{name}: {reg_nrmse[i]:.4f}")
    print(f"平均 NRMSE: {np.mean(reg_nrmse):.4f}")

    # 保存评估报告
    with open("reports/nrmse_report_v3.txt", "w", encoding="utf-8") as f:
        f.write("参数维度: [start_time(ms), end_time(ms), jnr_db]\n")
        for i, name in enumerate(["start_time", "end_time", "jnr_db"]):
            f.write(f"{name}: {reg_nrmse[i]:.4f}\n")
        f.write(f"平均 NRMSE: {np.mean(reg_nrmse):.4f}\n")
    print("✅ NRMSE 报告已写入 reports/nrmse_report_v3.txt")

# ---------- 主函数 ----------
def main():
    for d in ["models", "visualizations", "reports"]:
        os.makedirs(d, exist_ok=True)

    print("=" * 80)
    print("🚀 开始训练组合干扰检测与分类模型（适配v3归一化数据）")
    print("=" * 80)

    dataset = load_dataset()
    data = preprocess_data(dataset, aug_ratio=0.1)

    n_models = 3
    epochs = 120
    batch_size = 128

    models, training_times = train_ensemble(data, n_models=n_models, epochs=epochs, batch=batch_size)

    print("\n" + "="*50)
    print("📈 训练时间统计")
    print("="*50)
    for i, t in enumerate(training_times):
        print(f"模型 {i + 1}: {t:.2f} 秒 ({t / 60:.2f} 分钟)")
    print(f"🔥 总训练时间: {sum(training_times):.2f} 秒 ({sum(training_times) / 60:.2f} 分钟)")
    print("="*50)

    print("\n" + "="*80)
    print("🔍 开始评估并打印输入/输出（前 5 条）与 NRMSE")
    print("="*80)
    evaluate_and_print(models, data, batch=batch_size)

    print("\n✅ 所有流程完成！模型已保存至 models/combo_aug_model_v3_{i}.keras")
    print("📌 适配v3归一化数据的训练完成")

if __name__ == "__main__":
    main()
# Out:
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# ================================================================================
# 🚀 开始训练组合干扰检测与分类模型（适配v3归一化数据）
# ================================================================================
# /root/miniconda3/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# ⚠️ 未找到 metadata，使用默认参数标签
# 🧹 丢弃 0 / 81000 条含 NaN/Inf 的样本
#
# 🔥 训练第 1 个模型（适配v3归一化数据）...
# Epoch 1/120
# 2025-10-19 23:03:02.264567: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype float and shape [56700,3]
# 	 [[{{node Placeholder/_3}}]]
# 2025-10-19 23:03:02.264822: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype float and shape [56700,3]
# 	 [[{{node Placeholder/_3}}]]
#     443/Unknown - 13s 17ms/step - loss: 2.3510 - detection_output_loss: 0.1879 - classification_output_loss: 1.0991 - regression_output_loss: 0.0049 - detection_output_binary_accuracy: 0.9014 - classification_output_sparse_categorical_accuracy: 0.5956 - regression_output_mae: 0.0470
# 2025-10-19 23:03:15.247602: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype float and shape [8100,3]
# 	 [[{{node Placeholder/_3}}]]
# Epoch 1: val_classification_output_sparse_categorical_accuracy improved from -inf to 0.63444, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 14s 19ms/step - loss: 2.3510 - detection_output_loss: 0.1879 - classification_output_loss: 1.0991 - regression_output_loss: 0.0049 - detection_output_binary_accuracy: 0.9014 - classification_output_sparse_categorical_accuracy: 0.5956 - regression_output_mae: 0.0470 - val_loss: 1.9143 - val_detection_output_loss: 0.1770 - val_classification_output_loss: 0.8862 - val_regression_output_loss: 7.2712e-04 - val_detection_output_binary_accuracy: 0.8889 - val_classification_output_sparse_categorical_accuracy: 0.6344 - val_regression_output_mae: 0.0177 - lr: 0.0010
# Epoch 2/120
# 443/443 [==============================] - ETA: 0s - loss: 1.6422 - detection_output_loss: 0.1367 - classification_output_loss: 0.7663 - regression_output_loss: 5.2446e-04 - detection_output_binary_accuracy: 0.9281 - classification_output_sparse_categorical_accuracy: 0.7071 - regression_output_mae: 0.0143
# Epoch 2: val_classification_output_sparse_categorical_accuracy improved from 0.63444 to 0.69580, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 9s 18ms/step - loss: 1.6422 - detection_output_loss: 0.1367 - classification_output_loss: 0.7663 - regression_output_loss: 5.2446e-04 - detection_output_binary_accuracy: 0.9281 - classification_output_sparse_categorical_accuracy: 0.7071 - regression_output_mae: 0.0143 - val_loss: 1.5318 - val_detection_output_loss: 0.1874 - val_classification_output_loss: 0.6909 - val_regression_output_loss: 8.7672e-05 - val_detection_output_binary_accuracy: 0.8947 - val_classification_output_sparse_categorical_accuracy: 0.6958 - val_regression_output_mae: 0.0056 - lr: 0.0010
# Epoch 3/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.4357 - detection_output_loss: 0.1227 - classification_output_loss: 0.6688 - regression_output_loss: 8.7687e-05 - detection_output_binary_accuracy: 0.9376 - classification_output_sparse_categorical_accuracy: 0.7424 - regression_output_mae: 0.0051
# Epoch 3: val_classification_output_sparse_categorical_accuracy improved from 0.69580 to 0.79580, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 1.4366 - detection_output_loss: 0.1227 - classification_output_loss: 0.6692 - regression_output_loss: 8.7452e-05 - detection_output_binary_accuracy: 0.9374 - classification_output_sparse_categorical_accuracy: 0.7421 - regression_output_mae: 0.0051 - val_loss: 1.1282 - val_detection_output_loss: 0.0891 - val_classification_output_loss: 0.5285 - val_regression_output_loss: 2.0816e-05 - val_detection_output_binary_accuracy: 0.9609 - val_classification_output_sparse_categorical_accuracy: 0.7958 - val_regression_output_mae: 0.0023 - lr: 0.0010
# Epoch 4/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.3223 - detection_output_loss: 0.1165 - classification_output_loss: 0.6145 - regression_output_loss: 3.1738e-05 - detection_output_binary_accuracy: 0.9421 - classification_output_sparse_categorical_accuracy: 0.7595 - regression_output_mae: 0.0028
# Epoch 4: val_classification_output_sparse_categorical_accuracy did not improve from 0.79580
# 443/443 [==============================] - 8s 17ms/step - loss: 1.3216 - detection_output_loss: 0.1164 - classification_output_loss: 0.6143 - regression_output_loss: 3.1624e-05 - detection_output_binary_accuracy: 0.9422 - classification_output_sparse_categorical_accuracy: 0.7597 - regression_output_mae: 0.0028 - val_loss: 1.9093 - val_detection_output_loss: 0.1084 - val_classification_output_loss: 0.9113 - val_regression_output_loss: 3.4932e-06 - val_detection_output_binary_accuracy: 0.9432 - val_classification_output_sparse_categorical_accuracy: 0.6957 - val_regression_output_mae: 9.3535e-04 - lr: 0.0010
# Epoch 5/120
# 443/443 [==============================] - ETA: 0s - loss: 1.2765 - detection_output_loss: 0.1152 - classification_output_loss: 0.5922 - regression_output_loss: 1.3336e-05 - detection_output_binary_accuracy: 0.9426 - classification_output_sparse_categorical_accuracy: 0.7679 - regression_output_mae: 0.0017
# Epoch 5: val_classification_output_sparse_categorical_accuracy did not improve from 0.79580
# 443/443 [==============================] - 8s 18ms/step - loss: 1.2765 - detection_output_loss: 0.1152 - classification_output_loss: 0.5922 - regression_output_loss: 1.3336e-05 - detection_output_binary_accuracy: 0.9426 - classification_output_sparse_categorical_accuracy: 0.7679 - regression_output_mae: 0.0017 - val_loss: 1.0552 - val_detection_output_loss: 0.1210 - val_classification_output_loss: 0.4792 - val_regression_output_loss: 1.2940e-06 - val_detection_output_binary_accuracy: 0.9281 - val_classification_output_sparse_categorical_accuracy: 0.7940 - val_regression_output_mae: 7.2846e-04 - lr: 0.0010
# Epoch 6/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.2222 - detection_output_loss: 0.1116 - classification_output_loss: 0.5664 - regression_output_loss: 7.0174e-06 - detection_output_binary_accuracy: 0.9450 - classification_output_sparse_categorical_accuracy: 0.7750 - regression_output_mae: 0.0012
# Epoch 6: val_classification_output_sparse_categorical_accuracy did not improve from 0.79580
# 443/443 [==============================] - 9s 18ms/step - loss: 1.2222 - detection_output_loss: 0.1117 - classification_output_loss: 0.5664 - regression_output_loss: 7.0092e-06 - detection_output_binary_accuracy: 0.9450 - classification_output_sparse_categorical_accuracy: 0.7751 - regression_output_mae: 0.0012 - val_loss: 1.3048 - val_detection_output_loss: 0.0929 - val_classification_output_loss: 0.6153 - val_regression_output_loss: 1.3567e-06 - val_detection_output_binary_accuracy: 0.9607 - val_classification_output_sparse_categorical_accuracy: 0.7778 - val_regression_output_mae: 6.4892e-04 - lr: 0.0010
# Epoch 7/120
# 443/443 [==============================] - ETA: 0s - loss: 1.1849 - detection_output_loss: 0.1101 - classification_output_loss: 0.5484 - regression_output_loss: 5.0710e-06 - detection_output_binary_accuracy: 0.9461 - classification_output_sparse_categorical_accuracy: 0.7837 - regression_output_mae: 0.0010
# Epoch 7: val_classification_output_sparse_categorical_accuracy improved from 0.79580 to 0.82667, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 9s 18ms/step - loss: 1.1849 - detection_output_loss: 0.1101 - classification_output_loss: 0.5484 - regression_output_loss: 5.0710e-06 - detection_output_binary_accuracy: 0.9461 - classification_output_sparse_categorical_accuracy: 0.7837 - regression_output_mae: 0.0010 - val_loss: 0.9061 - val_detection_output_loss: 0.0836 - val_classification_output_loss: 0.4196 - val_regression_output_loss: 1.2192e-06 - val_detection_output_binary_accuracy: 0.9636 - val_classification_output_sparse_categorical_accuracy: 0.8267 - val_regression_output_mae: 7.9802e-04 - lr: 0.0010
# Epoch 8/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.1573 - detection_output_loss: 0.1085 - classification_output_loss: 0.5353 - regression_output_loss: 3.9726e-06 - detection_output_binary_accuracy: 0.9465 - classification_output_sparse_categorical_accuracy: 0.7901 - regression_output_mae: 8.9904e-04
# Epoch 8: val_classification_output_sparse_categorical_accuracy did not improve from 0.82667
# 443/443 [==============================] - 9s 18ms/step - loss: 1.1566 - detection_output_loss: 0.1085 - classification_output_loss: 0.5349 - regression_output_loss: 4.0095e-06 - detection_output_binary_accuracy: 0.9465 - classification_output_sparse_categorical_accuracy: 0.7902 - regression_output_mae: 9.0218e-04 - val_loss: 0.9589 - val_detection_output_loss: 0.1053 - val_classification_output_loss: 0.4373 - val_regression_output_loss: 1.2255e-05 - val_detection_output_binary_accuracy: 0.9473 - val_classification_output_sparse_categorical_accuracy: 0.8148 - val_regression_output_mae: 0.0017 - lr: 0.0010
# Epoch 9/120
# 443/443 [==============================] - ETA: 0s - loss: 1.1344 - detection_output_loss: 0.1077 - classification_output_loss: 0.5241 - regression_output_loss: 3.0074e-06 - detection_output_binary_accuracy: 0.9468 - classification_output_sparse_categorical_accuracy: 0.7906 - regression_output_mae: 8.0438e-04
# Epoch 9: val_classification_output_sparse_categorical_accuracy improved from 0.82667 to 0.83741, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 9s 18ms/step - loss: 1.1344 - detection_output_loss: 0.1077 - classification_output_loss: 0.5241 - regression_output_loss: 3.0074e-06 - detection_output_binary_accuracy: 0.9468 - classification_output_sparse_categorical_accuracy: 0.7906 - regression_output_mae: 8.0438e-04 - val_loss: 0.8488 - val_detection_output_loss: 0.0912 - val_classification_output_loss: 0.3879 - val_regression_output_loss: 1.8386e-06 - val_detection_output_binary_accuracy: 0.9560 - val_classification_output_sparse_categorical_accuracy: 0.8374 - val_regression_output_mae: 8.5302e-04 - lr: 0.0010
# Epoch 10/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.1151 - detection_output_loss: 0.1038 - classification_output_loss: 0.5160 - regression_output_loss: 3.7694e-06 - detection_output_binary_accuracy: 0.9495 - classification_output_sparse_categorical_accuracy: 0.7956 - regression_output_mae: 9.6327e-04
# Epoch 10: val_classification_output_sparse_categorical_accuracy improved from 0.83741 to 0.83778, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 9s 18ms/step - loss: 1.1155 - detection_output_loss: 0.1038 - classification_output_loss: 0.5162 - regression_output_loss: 3.7626e-06 - detection_output_binary_accuracy: 0.9494 - classification_output_sparse_categorical_accuracy: 0.7954 - regression_output_mae: 9.6159e-04 - val_loss: 0.8348 - val_detection_output_loss: 0.0943 - val_classification_output_loss: 0.3797 - val_regression_output_loss: 3.5986e-07 - val_detection_output_binary_accuracy: 0.9547 - val_classification_output_sparse_categorical_accuracy: 0.8378 - val_regression_output_mae: 3.5176e-04 - lr: 0.0010
# Epoch 11/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.0961 - detection_output_loss: 0.1045 - classification_output_loss: 0.5062 - regression_output_loss: 4.1144e-06 - detection_output_binary_accuracy: 0.9480 - classification_output_sparse_categorical_accuracy: 0.7976 - regression_output_mae: 9.8306e-04
# Epoch 11: val_classification_output_sparse_categorical_accuracy did not improve from 0.83778
# 443/443 [==============================] - 8s 17ms/step - loss: 1.0959 - detection_output_loss: 0.1046 - classification_output_loss: 0.5061 - regression_output_loss: 4.1108e-06 - detection_output_binary_accuracy: 0.9480 - classification_output_sparse_categorical_accuracy: 0.7977 - regression_output_mae: 9.8283e-04 - val_loss: 0.9669 - val_detection_output_loss: 0.1064 - val_classification_output_loss: 0.4409 - val_regression_output_loss: 3.5359e-06 - val_detection_output_binary_accuracy: 0.9421 - val_classification_output_sparse_categorical_accuracy: 0.8065 - val_regression_output_mae: 0.0011 - lr: 0.0010
# Epoch 12/120
# 443/443 [==============================] - ETA: 0s - loss: 1.0851 - detection_output_loss: 0.1026 - classification_output_loss: 0.5015 - regression_output_loss: 5.3475e-06 - detection_output_binary_accuracy: 0.9506 - classification_output_sparse_categorical_accuracy: 0.7978 - regression_output_mae: 0.0011
# Epoch 12: val_classification_output_sparse_categorical_accuracy did not improve from 0.83778
# 443/443 [==============================] - 9s 18ms/step - loss: 1.0851 - detection_output_loss: 0.1026 - classification_output_loss: 0.5015 - regression_output_loss: 5.3475e-06 - detection_output_binary_accuracy: 0.9506 - classification_output_sparse_categorical_accuracy: 0.7978 - regression_output_mae: 0.0011 - val_loss: 0.8890 - val_detection_output_loss: 0.0909 - val_classification_output_loss: 0.4081 - val_regression_output_loss: 9.6016e-07 - val_detection_output_binary_accuracy: 0.9575 - val_classification_output_sparse_categorical_accuracy: 0.8288 - val_regression_output_mae: 6.4395e-04 - lr: 0.0010
# Epoch 13/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.0751 - detection_output_loss: 0.1041 - classification_output_loss: 0.4959 - regression_output_loss: 3.5128e-06 - detection_output_binary_accuracy: 0.9495 - classification_output_sparse_categorical_accuracy: 0.8009 - regression_output_mae: 9.4494e-04
# Epoch 13: val_classification_output_sparse_categorical_accuracy did not improve from 0.83778
# 443/443 [==============================] - 8s 18ms/step - loss: 1.0746 - detection_output_loss: 0.1041 - classification_output_loss: 0.4956 - regression_output_loss: 3.5028e-06 - detection_output_binary_accuracy: 0.9496 - classification_output_sparse_categorical_accuracy: 0.8008 - regression_output_mae: 9.4336e-04 - val_loss: 1.1872 - val_detection_output_loss: 0.0898 - val_classification_output_loss: 0.5577 - val_regression_output_loss: 8.6893e-07 - val_detection_output_binary_accuracy: 0.9573 - val_classification_output_sparse_categorical_accuracy: 0.7800 - val_regression_output_mae: 5.0568e-04 - lr: 0.0010
# Epoch 14/120
# 440/443 [============================>.] - ETA: 0s - loss: 1.0618 - detection_output_loss: 0.1036 - classification_output_loss: 0.4895 - regression_output_loss: 5.9325e-06 - detection_output_binary_accuracy: 0.9499 - classification_output_sparse_categorical_accuracy: 0.8020 - regression_output_mae: 0.0011
# Epoch 14: val_classification_output_sparse_categorical_accuracy did not improve from 0.83778
# 443/443 [==============================] - 9s 18ms/step - loss: 1.0636 - detection_output_loss: 0.1037 - classification_output_loss: 0.4903 - regression_output_loss: 5.8980e-06 - detection_output_binary_accuracy: 0.9499 - classification_output_sparse_categorical_accuracy: 0.8015 - regression_output_mae: 0.0011 - val_loss: 0.8522 - val_detection_output_loss: 0.0855 - val_classification_output_loss: 0.3919 - val_regression_output_loss: 2.7489e-07 - val_detection_output_binary_accuracy: 0.9653 - val_classification_output_sparse_categorical_accuracy: 0.8322 - val_regression_output_mae: 2.4944e-04 - lr: 0.0010
# Epoch 15/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.0524 - detection_output_loss: 0.1033 - classification_output_loss: 0.4849 - regression_output_loss: 1.4957e-06 - detection_output_binary_accuracy: 0.9505 - classification_output_sparse_categorical_accuracy: 0.8074 - regression_output_mae: 5.7039e-04
# Epoch 15: val_classification_output_sparse_categorical_accuracy did not improve from 0.83778
# 443/443 [==============================] - 9s 18ms/step - loss: 1.0525 - detection_output_loss: 0.1033 - classification_output_loss: 0.4849 - regression_output_loss: 1.4942e-06 - detection_output_binary_accuracy: 0.9504 - classification_output_sparse_categorical_accuracy: 0.8073 - regression_output_mae: 5.7038e-04 - val_loss: 1.1468 - val_detection_output_loss: 0.1265 - val_classification_output_loss: 0.5228 - val_regression_output_loss: 1.7075e-06 - val_detection_output_binary_accuracy: 0.9347 - val_classification_output_sparse_categorical_accuracy: 0.7788 - val_regression_output_mae: 5.6890e-04 - lr: 0.0010
# Epoch 16/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.0278 - detection_output_loss: 0.0995 - classification_output_loss: 0.4741 - regression_output_loss: 4.0115e-06 - detection_output_binary_accuracy: 0.9528 - classification_output_sparse_categorical_accuracy: 0.8084 - regression_output_mae: 0.0010
# Epoch 16: val_classification_output_sparse_categorical_accuracy did not improve from 0.83778
# 443/443 [==============================] - 8s 17ms/step - loss: 1.0277 - detection_output_loss: 0.0995 - classification_output_loss: 0.4741 - regression_output_loss: 4.0209e-06 - detection_output_binary_accuracy: 0.9528 - classification_output_sparse_categorical_accuracy: 0.8086 - regression_output_mae: 0.0010 - val_loss: 1.0362 - val_detection_output_loss: 0.0834 - val_classification_output_loss: 0.4847 - val_regression_output_loss: 3.3785e-06 - val_detection_output_binary_accuracy: 0.9636 - val_classification_output_sparse_categorical_accuracy: 0.8052 - val_regression_output_mae: 0.0014 - lr: 0.0010
# Epoch 17/120
# 443/443 [==============================] - ETA: 0s - loss: 1.0266 - detection_output_loss: 0.0994 - classification_output_loss: 0.4736 - regression_output_loss: 2.8699e-06 - detection_output_binary_accuracy: 0.9532 - classification_output_sparse_categorical_accuracy: 0.8086 - regression_output_mae: 8.7228e-04
# Epoch 17: val_classification_output_sparse_categorical_accuracy improved from 0.83778 to 0.85568, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 9s 18ms/step - loss: 1.0266 - detection_output_loss: 0.0994 - classification_output_loss: 0.4736 - regression_output_loss: 2.8699e-06 - detection_output_binary_accuracy: 0.9532 - classification_output_sparse_categorical_accuracy: 0.8086 - regression_output_mae: 8.7228e-04 - val_loss: 0.7587 - val_detection_output_loss: 0.0789 - val_classification_output_loss: 0.3478 - val_regression_output_loss: 8.9470e-06 - val_detection_output_binary_accuracy: 0.9668 - val_classification_output_sparse_categorical_accuracy: 0.8557 - val_regression_output_mae: 0.0014 - lr: 0.0010
# Epoch 18/120
# 441/443 [============================>.] - ETA: 0s - loss: 1.0159 - detection_output_loss: 0.0989 - classification_output_loss: 0.4684 - regression_output_loss: 6.7836e-06 - detection_output_binary_accuracy: 0.9534 - classification_output_sparse_categorical_accuracy: 0.8112 - regression_output_mae: 0.0013
# Epoch 18: val_classification_output_sparse_categorical_accuracy improved from 0.85568 to 0.85951, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 1.0162 - detection_output_loss: 0.0989 - classification_output_loss: 0.4685 - regression_output_loss: 6.7912e-06 - detection_output_binary_accuracy: 0.9534 - classification_output_sparse_categorical_accuracy: 0.8110 - regression_output_mae: 0.0013 - val_loss: 0.7401 - val_detection_output_loss: 0.0773 - val_classification_output_loss: 0.3391 - val_regression_output_loss: 6.6040e-06 - val_detection_output_binary_accuracy: 0.9679 - val_classification_output_sparse_categorical_accuracy: 0.8595 - val_regression_output_mae: 0.0019 - lr: 0.0010
# Epoch 19/120
# 442/443 [============================>.] - ETA: 0s - loss: 1.0090 - detection_output_loss: 0.0984 - classification_output_loss: 0.4651 - regression_output_loss: 1.0201e-05 - detection_output_binary_accuracy: 0.9530 - classification_output_sparse_categorical_accuracy: 0.8125 - regression_output_mae: 0.0015
# Epoch 19: val_classification_output_sparse_categorical_accuracy did not improve from 0.85951
# 443/443 [==============================] - 8s 17ms/step - loss: 1.0093 - detection_output_loss: 0.0984 - classification_output_loss: 0.4653 - regression_output_loss: 1.0182e-05 - detection_output_binary_accuracy: 0.9530 - classification_output_sparse_categorical_accuracy: 0.8124 - regression_output_mae: 0.0015 - val_loss: 0.7734 - val_detection_output_loss: 0.0825 - val_classification_output_loss: 0.3537 - val_regression_output_loss: 1.8562e-06 - val_detection_output_binary_accuracy: 0.9644 - val_classification_output_sparse_categorical_accuracy: 0.8515 - val_regression_output_mae: 7.3450e-04 - lr: 0.0010
# Epoch 20/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.9991 - detection_output_loss: 0.1001 - classification_output_loss: 0.4595 - regression_output_loss: 1.3214e-06 - detection_output_binary_accuracy: 0.9517 - classification_output_sparse_categorical_accuracy: 0.8139 - regression_output_mae: 5.2700e-04
# Epoch 20: val_classification_output_sparse_categorical_accuracy did not improve from 0.85951
# 443/443 [==============================] - 9s 18ms/step - loss: 1.0014 - detection_output_loss: 0.1002 - classification_output_loss: 0.4606 - regression_output_loss: 1.3476e-06 - detection_output_binary_accuracy: 0.9516 - classification_output_sparse_categorical_accuracy: 0.8136 - regression_output_mae: 5.3168e-04 - val_loss: 0.7679 - val_detection_output_loss: 0.0780 - val_classification_output_loss: 0.3528 - val_regression_output_loss: 3.6505e-06 - val_detection_output_binary_accuracy: 0.9656 - val_classification_output_sparse_categorical_accuracy: 0.8570 - val_regression_output_mae: 0.0010 - lr: 0.0010
# Epoch 21/120
# 443/443 [==============================] - ETA: 0s - loss: 1.0026 - detection_output_loss: 0.1001 - classification_output_loss: 0.4613 - regression_output_loss: 2.4074e-06 - detection_output_binary_accuracy: 0.9527 - classification_output_sparse_categorical_accuracy: 0.8140 - regression_output_mae: 6.8261e-04
# Epoch 21: val_classification_output_sparse_categorical_accuracy did not improve from 0.85951
# 443/443 [==============================] - 8s 18ms/step - loss: 1.0026 - detection_output_loss: 0.1001 - classification_output_loss: 0.4613 - regression_output_loss: 2.4074e-06 - detection_output_binary_accuracy: 0.9527 - classification_output_sparse_categorical_accuracy: 0.8140 - regression_output_mae: 6.8261e-04 - val_loss: 0.7412 - val_detection_output_loss: 0.0789 - val_classification_output_loss: 0.3390 - val_regression_output_loss: 1.4024e-07 - val_detection_output_binary_accuracy: 0.9653 - val_classification_output_sparse_categorical_accuracy: 0.8562 - val_regression_output_mae: 2.5863e-04 - lr: 0.0010
# Epoch 22/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.9863 - detection_output_loss: 0.0971 - classification_output_loss: 0.4543 - regression_output_loss: 4.4735e-06 - detection_output_binary_accuracy: 0.9536 - classification_output_sparse_categorical_accuracy: 0.8151 - regression_output_mae: 0.0010
# Epoch 22: val_classification_output_sparse_categorical_accuracy did not improve from 0.85951
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9869 - detection_output_loss: 0.0971 - classification_output_loss: 0.4546 - regression_output_loss: 4.4962e-06 - detection_output_binary_accuracy: 0.9536 - classification_output_sparse_categorical_accuracy: 0.8151 - regression_output_mae: 0.0010 - val_loss: 0.7676 - val_detection_output_loss: 0.0775 - val_classification_output_loss: 0.3528 - val_regression_output_loss: 3.9116e-06 - val_detection_output_binary_accuracy: 0.9663 - val_classification_output_sparse_categorical_accuracy: 0.8415 - val_regression_output_mae: 0.0011 - lr: 0.0010
# Epoch 23/120
# 443/443 [==============================] - ETA: 0s - loss: 0.9871 - detection_output_loss: 0.0965 - classification_output_loss: 0.4550 - regression_output_loss: 6.7506e-06 - detection_output_binary_accuracy: 0.9534 - classification_output_sparse_categorical_accuracy: 0.8162 - regression_output_mae: 0.0011
# Epoch 23: val_classification_output_sparse_categorical_accuracy did not improve from 0.85951
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9871 - detection_output_loss: 0.0965 - classification_output_loss: 0.4550 - regression_output_loss: 6.7506e-06 - detection_output_binary_accuracy: 0.9534 - classification_output_sparse_categorical_accuracy: 0.8162 - regression_output_mae: 0.0011 - val_loss: 3.0831 - val_detection_output_loss: 0.2198 - val_classification_output_loss: 1.4536 - val_regression_output_loss: 9.2930e-08 - val_detection_output_binary_accuracy: 0.9001 - val_classification_output_sparse_categorical_accuracy: 0.5868 - val_regression_output_mae: 1.6783e-04 - lr: 0.0010
# Epoch 24/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.9831 - detection_output_loss: 0.0976 - classification_output_loss: 0.4525 - regression_output_loss: 4.0742e-06 - detection_output_binary_accuracy: 0.9536 - classification_output_sparse_categorical_accuracy: 0.8146 - regression_output_mae: 9.0441e-04
# Epoch 24: val_classification_output_sparse_categorical_accuracy did not improve from 0.85951
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9830 - detection_output_loss: 0.0975 - classification_output_loss: 0.4525 - regression_output_loss: 4.0770e-06 - detection_output_binary_accuracy: 0.9537 - classification_output_sparse_categorical_accuracy: 0.8146 - regression_output_mae: 9.0544e-04 - val_loss: 0.7515 - val_detection_output_loss: 0.0736 - val_classification_output_loss: 0.3463 - val_regression_output_loss: 4.8992e-06 - val_detection_output_binary_accuracy: 0.9693 - val_classification_output_sparse_categorical_accuracy: 0.8486 - val_regression_output_mae: 0.0015 - lr: 0.0010
# Epoch 25/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.9672 - detection_output_loss: 0.0968 - classification_output_loss: 0.4449 - regression_output_loss: 4.5839e-06 - detection_output_binary_accuracy: 0.9542 - classification_output_sparse_categorical_accuracy: 0.8197 - regression_output_mae: 0.0011
# Epoch 25: val_classification_output_sparse_categorical_accuracy improved from 0.85951 to 0.86012, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9681 - detection_output_loss: 0.0968 - classification_output_loss: 0.4453 - regression_output_loss: 4.5801e-06 - detection_output_binary_accuracy: 0.9542 - classification_output_sparse_categorical_accuracy: 0.8196 - regression_output_mae: 0.0011 - val_loss: 0.7220 - val_detection_output_loss: 0.0787 - val_classification_output_loss: 0.3295 - val_regression_output_loss: 3.0571e-06 - val_detection_output_binary_accuracy: 0.9649 - val_classification_output_sparse_categorical_accuracy: 0.8601 - val_regression_output_mae: 0.0011 - lr: 0.0010
# Epoch 26/120
# 443/443 [==============================] - ETA: 0s - loss: 0.9816 - detection_output_loss: 0.0976 - classification_output_loss: 0.4518 - regression_output_loss: 3.9349e-06 - detection_output_binary_accuracy: 0.9535 - classification_output_sparse_categorical_accuracy: 0.8176 - regression_output_mae: 8.2236e-04
# Epoch 26: val_classification_output_sparse_categorical_accuracy did not improve from 0.86012
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9816 - detection_output_loss: 0.0976 - classification_output_loss: 0.4518 - regression_output_loss: 3.9349e-06 - detection_output_binary_accuracy: 0.9535 - classification_output_sparse_categorical_accuracy: 0.8176 - regression_output_mae: 8.2236e-04 - val_loss: 0.7631 - val_detection_output_loss: 0.0826 - val_classification_output_loss: 0.3485 - val_regression_output_loss: 7.2251e-06 - val_detection_output_binary_accuracy: 0.9648 - val_classification_output_sparse_categorical_accuracy: 0.8493 - val_regression_output_mae: 0.0011 - lr: 0.0010
# Epoch 27/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.9718 - detection_output_loss: 0.0974 - classification_output_loss: 0.4469 - regression_output_loss: 4.3148e-06 - detection_output_binary_accuracy: 0.9537 - classification_output_sparse_categorical_accuracy: 0.8190 - regression_output_mae: 9.5746e-04
# Epoch 27: val_classification_output_sparse_categorical_accuracy did not improve from 0.86012
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9717 - detection_output_loss: 0.0973 - classification_output_loss: 0.4469 - regression_output_loss: 4.3125e-06 - detection_output_binary_accuracy: 0.9538 - classification_output_sparse_categorical_accuracy: 0.8188 - regression_output_mae: 9.5734e-04 - val_loss: 0.8378 - val_detection_output_loss: 0.0935 - val_classification_output_loss: 0.3815 - val_regression_output_loss: 1.7734e-06 - val_detection_output_binary_accuracy: 0.9535 - val_classification_output_sparse_categorical_accuracy: 0.8395 - val_regression_output_mae: 8.6201e-04 - lr: 0.0010
# Epoch 28/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.9658 - detection_output_loss: 0.0966 - classification_output_loss: 0.4443 - regression_output_loss: 9.8878e-06 - detection_output_binary_accuracy: 0.9543 - classification_output_sparse_categorical_accuracy: 0.8205 - regression_output_mae: 0.0012
# Epoch 28: val_classification_output_sparse_categorical_accuracy did not improve from 0.86012
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9658 - detection_output_loss: 0.0966 - classification_output_loss: 0.4443 - regression_output_loss: 9.8507e-06 - detection_output_binary_accuracy: 0.9544 - classification_output_sparse_categorical_accuracy: 0.8204 - regression_output_mae: 0.0012 - val_loss: 0.7453 - val_detection_output_loss: 0.0742 - val_classification_output_loss: 0.3430 - val_regression_output_loss: 5.0083e-07 - val_detection_output_binary_accuracy: 0.9699 - val_classification_output_sparse_categorical_accuracy: 0.8548 - val_regression_output_mae: 3.8471e-04 - lr: 0.0010
# Epoch 29/120
# 443/443 [==============================] - ETA: 0s - loss: 0.9591 - detection_output_loss: 0.0952 - classification_output_loss: 0.4415 - regression_output_loss: 5.7705e-07 - detection_output_binary_accuracy: 0.9549 - classification_output_sparse_categorical_accuracy: 0.8187 - regression_output_mae: 3.7250e-04
# Epoch 29: val_classification_output_sparse_categorical_accuracy did not improve from 0.86012
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9591 - detection_output_loss: 0.0952 - classification_output_loss: 0.4415 - regression_output_loss: 5.7705e-07 - detection_output_binary_accuracy: 0.9549 - classification_output_sparse_categorical_accuracy: 0.8187 - regression_output_mae: 3.7250e-04 - val_loss: 0.7382 - val_detection_output_loss: 0.0755 - val_classification_output_loss: 0.3389 - val_regression_output_loss: 1.9601e-07 - val_detection_output_binary_accuracy: 0.9674 - val_classification_output_sparse_categorical_accuracy: 0.8504 - val_regression_output_mae: 2.7029e-04 - lr: 0.0010
# Epoch 30/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.9531 - detection_output_loss: 0.0963 - classification_output_loss: 0.4380 - regression_output_loss: 7.1674e-06 - detection_output_binary_accuracy: 0.9551 - classification_output_sparse_categorical_accuracy: 0.8210 - regression_output_mae: 9.1200e-04
# Epoch 30: val_classification_output_sparse_categorical_accuracy did not improve from 0.86012
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9526 - detection_output_loss: 0.0963 - classification_output_loss: 0.4378 - regression_output_loss: 7.1538e-06 - detection_output_binary_accuracy: 0.9551 - classification_output_sparse_categorical_accuracy: 0.8211 - regression_output_mae: 9.1102e-04 - val_loss: 0.7453 - val_detection_output_loss: 0.0790 - val_classification_output_loss: 0.3410 - val_regression_output_loss: 8.3033e-07 - val_detection_output_binary_accuracy: 0.9653 - val_classification_output_sparse_categorical_accuracy: 0.8515 - val_regression_output_mae: 5.7349e-04 - lr: 0.0010
# Epoch 31/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.9545 - detection_output_loss: 0.0968 - classification_output_loss: 0.4385 - regression_output_loss: 3.7100e-06 - detection_output_binary_accuracy: 0.9549 - classification_output_sparse_categorical_accuracy: 0.8211 - regression_output_mae: 8.1395e-04
# Epoch 31: val_classification_output_sparse_categorical_accuracy did not improve from 0.86012
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9543 - detection_output_loss: 0.0968 - classification_output_loss: 0.4385 - regression_output_loss: 3.7232e-06 - detection_output_binary_accuracy: 0.9549 - classification_output_sparse_categorical_accuracy: 0.8212 - regression_output_mae: 8.1604e-04 - val_loss: 0.7246 - val_detection_output_loss: 0.0743 - val_classification_output_loss: 0.3326 - val_regression_output_loss: 8.3319e-06 - val_detection_output_binary_accuracy: 0.9684 - val_classification_output_sparse_categorical_accuracy: 0.8574 - val_regression_output_mae: 0.0018 - lr: 0.0010
# Epoch 32/120
# 443/443 [==============================] - ETA: 0s - loss: 0.9454 - detection_output_loss: 0.0959 - classification_output_loss: 0.4343 - regression_output_loss: 5.5858e-06 - detection_output_binary_accuracy: 0.9551 - classification_output_sparse_categorical_accuracy: 0.8235 - regression_output_mae: 0.0012
# Epoch 32: val_classification_output_sparse_categorical_accuracy did not improve from 0.86012
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9454 - detection_output_loss: 0.0959 - classification_output_loss: 0.4343 - regression_output_loss: 5.5858e-06 - detection_output_binary_accuracy: 0.9551 - classification_output_sparse_categorical_accuracy: 0.8235 - regression_output_mae: 0.0012 - val_loss: 0.9265 - val_detection_output_loss: 0.1150 - val_classification_output_loss: 0.4172 - val_regression_output_loss: 1.1165e-06 - val_detection_output_binary_accuracy: 0.9378 - val_classification_output_sparse_categorical_accuracy: 0.8262 - val_regression_output_mae: 7.0976e-04 - lr: 0.0010
# Epoch 33/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.9445 - detection_output_loss: 0.0957 - classification_output_loss: 0.4340 - regression_output_loss: 4.2696e-06 - detection_output_binary_accuracy: 0.9549 - classification_output_sparse_categorical_accuracy: 0.8234 - regression_output_mae: 7.4030e-04
# Epoch 33: val_classification_output_sparse_categorical_accuracy did not improve from 0.86012
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9450 - detection_output_loss: 0.0956 - classification_output_loss: 0.4343 - regression_output_loss: 4.3097e-06 - detection_output_binary_accuracy: 0.9549 - classification_output_sparse_categorical_accuracy: 0.8233 - regression_output_mae: 7.4458e-04 - val_loss: 1.3386 - val_detection_output_loss: 0.0761 - val_classification_output_loss: 0.6389 - val_regression_output_loss: 2.0648e-05 - val_detection_output_binary_accuracy: 0.9667 - val_classification_output_sparse_categorical_accuracy: 0.7689 - val_regression_output_mae: 0.0022 - lr: 0.0010
# Epoch 34/120
# 443/443 [==============================] - ETA: 0s - loss: 0.9411 - detection_output_loss: 0.0944 - classification_output_loss: 0.4328 - regression_output_loss: 5.7481e-06 - detection_output_binary_accuracy: 0.9555 - classification_output_sparse_categorical_accuracy: 0.8243 - regression_output_mae: 0.0011
# Epoch 34: val_classification_output_sparse_categorical_accuracy improved from 0.86012 to 0.86210, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9411 - detection_output_loss: 0.0944 - classification_output_loss: 0.4328 - regression_output_loss: 5.7481e-06 - detection_output_binary_accuracy: 0.9555 - classification_output_sparse_categorical_accuracy: 0.8243 - regression_output_mae: 0.0011 - val_loss: 0.7264 - val_detection_output_loss: 0.0881 - val_classification_output_loss: 0.3280 - val_regression_output_loss: 7.9256e-07 - val_detection_output_binary_accuracy: 0.9595 - val_classification_output_sparse_categorical_accuracy: 0.8621 - val_regression_output_mae: 4.9799e-04 - lr: 0.0010
# Epoch 35/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.9331 - detection_output_loss: 0.0936 - classification_output_loss: 0.4291 - regression_output_loss: 3.5166e-06 - detection_output_binary_accuracy: 0.9563 - classification_output_sparse_categorical_accuracy: 0.8241 - regression_output_mae: 8.7954e-04
# Epoch 35: val_classification_output_sparse_categorical_accuracy improved from 0.86210 to 0.86444, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9334 - detection_output_loss: 0.0936 - classification_output_loss: 0.4293 - regression_output_loss: 3.5261e-06 - detection_output_binary_accuracy: 0.9563 - classification_output_sparse_categorical_accuracy: 0.8240 - regression_output_mae: 8.8012e-04 - val_loss: 0.7005 - val_detection_output_loss: 0.0746 - val_classification_output_loss: 0.3204 - val_regression_output_loss: 2.5411e-06 - val_detection_output_binary_accuracy: 0.9688 - val_classification_output_sparse_categorical_accuracy: 0.8644 - val_regression_output_mae: 8.1355e-04 - lr: 0.0010
# Epoch 36/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.9432 - detection_output_loss: 0.0964 - classification_output_loss: 0.4330 - regression_output_loss: 1.2153e-05 - detection_output_binary_accuracy: 0.9545 - classification_output_sparse_categorical_accuracy: 0.8234 - regression_output_mae: 0.0012
# Epoch 36: val_classification_output_sparse_categorical_accuracy did not improve from 0.86444
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9428 - detection_output_loss: 0.0964 - classification_output_loss: 0.4328 - regression_output_loss: 1.2182e-05 - detection_output_binary_accuracy: 0.9545 - classification_output_sparse_categorical_accuracy: 0.8234 - regression_output_mae: 0.0012 - val_loss: 0.7182 - val_detection_output_loss: 0.0776 - val_classification_output_loss: 0.3281 - val_regression_output_loss: 8.4984e-06 - val_detection_output_binary_accuracy: 0.9662 - val_classification_output_sparse_categorical_accuracy: 0.8604 - val_regression_output_mae: 0.0019 - lr: 0.0010
# Epoch 37/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.9298 - detection_output_loss: 0.0934 - classification_output_loss: 0.4275 - regression_output_loss: 3.3380e-06 - detection_output_binary_accuracy: 0.9563 - classification_output_sparse_categorical_accuracy: 0.8257 - regression_output_mae: 6.8781e-04
# Epoch 37: val_classification_output_sparse_categorical_accuracy did not improve from 0.86444
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9303 - detection_output_loss: 0.0935 - classification_output_loss: 0.4278 - regression_output_loss: 3.3339e-06 - detection_output_binary_accuracy: 0.9562 - classification_output_sparse_categorical_accuracy: 0.8255 - regression_output_mae: 6.8823e-04 - val_loss: 0.7306 - val_detection_output_loss: 0.0771 - val_classification_output_loss: 0.3344 - val_regression_output_loss: 8.8597e-07 - val_detection_output_binary_accuracy: 0.9675 - val_classification_output_sparse_categorical_accuracy: 0.8528 - val_regression_output_mae: 5.5418e-04 - lr: 0.0010
# Epoch 38/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.9305 - detection_output_loss: 0.0945 - classification_output_loss: 0.4275 - regression_output_loss: 1.6804e-06 - detection_output_binary_accuracy: 0.9558 - classification_output_sparse_categorical_accuracy: 0.8261 - regression_output_mae: 5.4881e-04
# Epoch 38: val_classification_output_sparse_categorical_accuracy did not improve from 0.86444
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9308 - detection_output_loss: 0.0946 - classification_output_loss: 0.4275 - regression_output_loss: 1.6770e-06 - detection_output_binary_accuracy: 0.9557 - classification_output_sparse_categorical_accuracy: 0.8260 - regression_output_mae: 5.4789e-04 - val_loss: 0.7367 - val_detection_output_loss: 0.0805 - val_classification_output_loss: 0.3361 - val_regression_output_loss: 5.8894e-08 - val_detection_output_binary_accuracy: 0.9636 - val_classification_output_sparse_categorical_accuracy: 0.8543 - val_regression_output_mae: 1.3808e-04 - lr: 0.0010
# Epoch 39/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.9267 - detection_output_loss: 0.0942 - classification_output_loss: 0.4256 - regression_output_loss: 8.8159e-06 - detection_output_binary_accuracy: 0.9554 - classification_output_sparse_categorical_accuracy: 0.8264 - regression_output_mae: 9.1308e-04
# Epoch 39: val_classification_output_sparse_categorical_accuracy did not improve from 0.86444
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9263 - detection_output_loss: 0.0943 - classification_output_loss: 0.4255 - regression_output_loss: 8.7787e-06 - detection_output_binary_accuracy: 0.9554 - classification_output_sparse_categorical_accuracy: 0.8265 - regression_output_mae: 9.1069e-04 - val_loss: 0.7044 - val_detection_output_loss: 0.0814 - val_classification_output_loss: 0.3197 - val_regression_output_loss: 4.4586e-07 - val_detection_output_binary_accuracy: 0.9615 - val_classification_output_sparse_categorical_accuracy: 0.8623 - val_regression_output_mae: 4.7470e-04 - lr: 0.0010
# Epoch 40/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.9137 - detection_output_loss: 0.0930 - classification_output_loss: 0.4196 - regression_output_loss: 8.4485e-07 - detection_output_binary_accuracy: 0.9570 - classification_output_sparse_categorical_accuracy: 0.8278 - regression_output_mae: 4.5623e-04
# Epoch 40: val_classification_output_sparse_categorical_accuracy did not improve from 0.86444
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9143 - detection_output_loss: 0.0930 - classification_output_loss: 0.4199 - regression_output_loss: 8.4323e-07 - detection_output_binary_accuracy: 0.9569 - classification_output_sparse_categorical_accuracy: 0.8276 - regression_output_mae: 4.5572e-04 - val_loss: 0.8419 - val_detection_output_loss: 0.1096 - val_classification_output_loss: 0.3771 - val_regression_output_loss: 2.9641e-07 - val_detection_output_binary_accuracy: 0.9422 - val_classification_output_sparse_categorical_accuracy: 0.8263 - val_regression_output_mae: 3.8990e-04 - lr: 0.0010
# Epoch 41/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.9192 - detection_output_loss: 0.0934 - classification_output_loss: 0.4222 - regression_output_loss: 9.9681e-06 - detection_output_binary_accuracy: 0.9571 - classification_output_sparse_categorical_accuracy: 0.8278 - regression_output_mae: 0.0011
# Epoch 41: val_classification_output_sparse_categorical_accuracy did not improve from 0.86444
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9192 - detection_output_loss: 0.0933 - classification_output_loss: 0.4222 - regression_output_loss: 9.9468e-06 - detection_output_binary_accuracy: 0.9572 - classification_output_sparse_categorical_accuracy: 0.8279 - regression_output_mae: 0.0011 - val_loss: 0.7542 - val_detection_output_loss: 0.0863 - val_classification_output_loss: 0.3426 - val_regression_output_loss: 1.9729e-08 - val_detection_output_binary_accuracy: 0.9620 - val_classification_output_sparse_categorical_accuracy: 0.8562 - val_regression_output_mae: 1.0364e-04 - lr: 0.0010
# Epoch 42/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.9118 - detection_output_loss: 0.0939 - classification_output_loss: 0.4184 - regression_output_loss: 7.9199e-07 - detection_output_binary_accuracy: 0.9565 - classification_output_sparse_categorical_accuracy: 0.8292 - regression_output_mae: 4.0086e-04
# Epoch 42: val_classification_output_sparse_categorical_accuracy improved from 0.86444 to 0.86963, saving model to models/combo_aug_model_v3_0.keras
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9117 - detection_output_loss: 0.0939 - classification_output_loss: 0.4183 - regression_output_loss: 7.9915e-07 - detection_output_binary_accuracy: 0.9564 - classification_output_sparse_categorical_accuracy: 0.8292 - regression_output_mae: 4.0273e-04 - val_loss: 0.6705 - val_detection_output_loss: 0.0730 - val_classification_output_loss: 0.3061 - val_regression_output_loss: 4.3923e-06 - val_detection_output_binary_accuracy: 0.9709 - val_classification_output_sparse_categorical_accuracy: 0.8696 - val_regression_output_mae: 0.0012 - lr: 0.0010
# Epoch 43/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.9114 - detection_output_loss: 0.0928 - classification_output_loss: 0.4186 - regression_output_loss: 1.1836e-05 - detection_output_binary_accuracy: 0.9569 - classification_output_sparse_categorical_accuracy: 0.8287 - regression_output_mae: 0.0016
# Epoch 43: val_classification_output_sparse_categorical_accuracy did not improve from 0.86963
# 443/443 [==============================] - 9s 18ms/step - loss: 0.9113 - detection_output_loss: 0.0927 - classification_output_loss: 0.4186 - regression_output_loss: 1.1762e-05 - detection_output_binary_accuracy: 0.9570 - classification_output_sparse_categorical_accuracy: 0.8287 - regression_output_mae: 0.0016 - val_loss: 0.7049 - val_detection_output_loss: 0.0772 - val_classification_output_loss: 0.3216 - val_regression_output_loss: 7.7728e-07 - val_detection_output_binary_accuracy: 0.9680 - val_classification_output_sparse_categorical_accuracy: 0.8635 - val_regression_output_mae: 3.8116e-04 - lr: 0.0010
# Epoch 44/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.9163 - detection_output_loss: 0.0928 - classification_output_loss: 0.4210 - regression_output_loss: 9.8503e-07 - detection_output_binary_accuracy: 0.9570 - classification_output_sparse_categorical_accuracy: 0.8281 - regression_output_mae: 4.4709e-04
# Epoch 44: val_classification_output_sparse_categorical_accuracy did not improve from 0.86963
# 443/443 [==============================] - 8s 18ms/step - loss: 0.9165 - detection_output_loss: 0.0930 - classification_output_loss: 0.4211 - regression_output_loss: 9.8604e-07 - detection_output_binary_accuracy: 0.9568 - classification_output_sparse_categorical_accuracy: 0.8281 - regression_output_mae: 4.4789e-04 - val_loss: 0.7539 - val_detection_output_loss: 0.0784 - val_classification_output_loss: 0.3456 - val_regression_output_loss: 1.1652e-06 - val_detection_output_binary_accuracy: 0.9642 - val_classification_output_sparse_categorical_accuracy: 0.8548 - val_regression_output_mae: 5.9273e-04 - lr: 0.0010
# Epoch 45/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.9200 - detection_output_loss: 0.0935 - classification_output_loss: 0.4226 - regression_output_loss: 3.7281e-06 - detection_output_binary_accuracy: 0.9563 - classification_output_sparse_categorical_accuracy: 0.8273 - regression_output_mae: 8.8875e-04
# Epoch 45: val_classification_output_sparse_categorical_accuracy did not improve from 0.86963
# ...
# Epoch 109/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.7510 - detection_output_loss: 0.0788 - classification_output_loss: 0.3440 - regression_output_loss: 1.0161e-08 - detection_output_binary_accuracy: 0.9651 - classification_output_sparse_categorical_accuracy: 0.8585 - regression_output_mae: 3.4248e-05
# Epoch 109: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 9s 18ms/step - loss: 0.7511 - detection_output_loss: 0.0788 - classification_output_loss: 0.3441 - regression_output_loss: 1.0148e-08 - detection_output_binary_accuracy: 0.9651 - classification_output_sparse_categorical_accuracy: 0.8584 - regression_output_mae: 3.4262e-05 - val_loss: 0.5981 - val_detection_output_loss: 0.0741 - val_classification_output_loss: 0.2694 - val_regression_output_loss: 1.4356e-08 - val_detection_output_binary_accuracy: 0.9679 - val_classification_output_sparse_categorical_accuracy: 0.8823 - val_regression_output_mae: 5.5426e-05 - lr: 6.2500e-05
# Epoch 110/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7564 - detection_output_loss: 0.0793 - classification_output_loss: 0.3465 - regression_output_loss: 7.1902e-09 - detection_output_binary_accuracy: 0.9638 - classification_output_sparse_categorical_accuracy: 0.8565 - regression_output_mae: 2.7856e-05
# Epoch 110: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 8s 18ms/step - loss: 0.7564 - detection_output_loss: 0.0793 - classification_output_loss: 0.3465 - regression_output_loss: 7.1902e-09 - detection_output_binary_accuracy: 0.9638 - classification_output_sparse_categorical_accuracy: 0.8565 - regression_output_mae: 2.7856e-05 - val_loss: 0.5936 - val_detection_output_loss: 0.0731 - val_classification_output_loss: 0.2676 - val_regression_output_loss: 9.9305e-10 - val_detection_output_binary_accuracy: 0.9689 - val_classification_output_sparse_categorical_accuracy: 0.8838 - val_regression_output_mae: 1.4007e-05 - lr: 6.2500e-05
# Epoch 111/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7490 - detection_output_loss: 0.0786 - classification_output_loss: 0.3431 - regression_output_loss: 1.9899e-08 - detection_output_binary_accuracy: 0.9651 - classification_output_sparse_categorical_accuracy: 0.8580 - regression_output_mae: 4.0564e-05
# Epoch 111: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 8s 18ms/step - loss: 0.7490 - detection_output_loss: 0.0786 - classification_output_loss: 0.3431 - regression_output_loss: 1.9899e-08 - detection_output_binary_accuracy: 0.9651 - classification_output_sparse_categorical_accuracy: 0.8580 - regression_output_mae: 4.0564e-05 - val_loss: 0.5896 - val_detection_output_loss: 0.0728 - val_classification_output_loss: 0.2657 - val_regression_output_loss: 2.2847e-09 - val_detection_output_binary_accuracy: 0.9694 - val_classification_output_sparse_categorical_accuracy: 0.8851 - val_regression_output_mae: 2.0988e-05 - lr: 6.2500e-05
# Epoch 112/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.7503 - detection_output_loss: 0.0777 - classification_output_loss: 0.3440 - regression_output_loss: 3.2809e-08 - detection_output_binary_accuracy: 0.9653 - classification_output_sparse_categorical_accuracy: 0.8574 - regression_output_mae: 4.4374e-05
# Epoch 112: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 9s 18ms/step - loss: 0.7506 - detection_output_loss: 0.0778 - classification_output_loss: 0.3441 - regression_output_loss: 3.2683e-08 - detection_output_binary_accuracy: 0.9653 - classification_output_sparse_categorical_accuracy: 0.8573 - regression_output_mae: 4.4304e-05 - val_loss: 0.5885 - val_detection_output_loss: 0.0727 - val_classification_output_loss: 0.2651 - val_regression_output_loss: 3.3917e-09 - val_detection_output_binary_accuracy: 0.9684 - val_classification_output_sparse_categorical_accuracy: 0.8832 - val_regression_output_mae: 2.4123e-05 - lr: 6.2500e-05
# Epoch 113/120
# 440/443 [============================>.] - ETA: 0s - loss: 0.7544 - detection_output_loss: 0.0794 - classification_output_loss: 0.3454 - regression_output_loss: 7.7343e-09 - detection_output_binary_accuracy: 0.9647 - classification_output_sparse_categorical_accuracy: 0.8561 - regression_output_mae: 1.3242e-05
# Epoch 113: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 9s 18ms/step - loss: 0.7549 - detection_output_loss: 0.0794 - classification_output_loss: 0.3457 - regression_output_loss: 8.3592e-09 - detection_output_binary_accuracy: 0.9647 - classification_output_sparse_categorical_accuracy: 0.8559 - regression_output_mae: 1.3822e-05 - val_loss: 0.5899 - val_detection_output_loss: 0.0727 - val_classification_output_loss: 0.2658 - val_regression_output_loss: 4.0153e-08 - val_detection_output_binary_accuracy: 0.9700 - val_classification_output_sparse_categorical_accuracy: 0.8836 - val_regression_output_mae: 8.3252e-05 - lr: 6.2500e-05
# Epoch 114/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7465 - detection_output_loss: 0.0794 - classification_output_loss: 0.3415 - regression_output_loss: 1.3175e-08 - detection_output_binary_accuracy: 0.9640 - classification_output_sparse_categorical_accuracy: 0.8581 - regression_output_mae: 2.4001e-05
# Epoch 114: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 9s 18ms/step - loss: 0.7465 - detection_output_loss: 0.0794 - classification_output_loss: 0.3415 - regression_output_loss: 1.3175e-08 - detection_output_binary_accuracy: 0.9640 - classification_output_sparse_categorical_accuracy: 0.8581 - regression_output_mae: 2.4001e-05 - val_loss: 0.5904 - val_detection_output_loss: 0.0730 - val_classification_output_loss: 0.2660 - val_regression_output_loss: 1.5995e-10 - val_detection_output_binary_accuracy: 0.9695 - val_classification_output_sparse_categorical_accuracy: 0.8857 - val_regression_output_mae: 5.9638e-06 - lr: 6.2500e-05
# Epoch 115/120
# 442/443 [============================>.] - ETA: 0s - loss: 0.7506 - detection_output_loss: 0.0782 - classification_output_loss: 0.3440 - regression_output_loss: 3.3314e-09 - detection_output_binary_accuracy: 0.9646 - classification_output_sparse_categorical_accuracy: 0.8552 - regression_output_mae: 1.2688e-05
# Epoch 115: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 9s 18ms/step - loss: 0.7509 - detection_output_loss: 0.0782 - classification_output_loss: 0.3442 - regression_output_loss: 3.3377e-09 - detection_output_binary_accuracy: 0.9646 - classification_output_sparse_categorical_accuracy: 0.8552 - regression_output_mae: 1.2742e-05 - val_loss: 0.5925 - val_detection_output_loss: 0.0736 - val_classification_output_loss: 0.2668 - val_regression_output_loss: 4.7436e-08 - val_detection_output_binary_accuracy: 0.9685 - val_classification_output_sparse_categorical_accuracy: 0.8831 - val_regression_output_mae: 1.3899e-04 - lr: 6.2500e-05
# Epoch 116/120
# 441/443 [============================>.] - ETA: 0s - loss: 0.7604 - detection_output_loss: 0.0795 - classification_output_loss: 0.3484 - regression_output_loss: 1.7933e-08 - detection_output_binary_accuracy: 0.9643 - classification_output_sparse_categorical_accuracy: 0.8558 - regression_output_mae: 4.2383e-05
# Epoch 116: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 9s 18ms/step - loss: 0.7608 - detection_output_loss: 0.0795 - classification_output_loss: 0.3486 - regression_output_loss: 1.7905e-08 - detection_output_binary_accuracy: 0.9643 - classification_output_sparse_categorical_accuracy: 0.8558 - regression_output_mae: 4.2374e-05 - val_loss: 0.5958 - val_detection_output_loss: 0.0749 - val_classification_output_loss: 0.2680 - val_regression_output_loss: 2.3822e-09 - val_detection_output_binary_accuracy: 0.9663 - val_classification_output_sparse_categorical_accuracy: 0.8815 - val_regression_output_mae: 2.8454e-05 - lr: 6.2500e-05
# Epoch 117/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7477 - detection_output_loss: 0.0785 - classification_output_loss: 0.3425 - regression_output_loss: 1.9485e-08 - detection_output_binary_accuracy: 0.9644 - classification_output_sparse_categorical_accuracy: 0.8574 - regression_output_mae: 3.5408e-05
# Epoch 117: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 8s 18ms/step - loss: 0.7477 - detection_output_loss: 0.0785 - classification_output_loss: 0.3425 - regression_output_loss: 1.9485e-08 - detection_output_binary_accuracy: 0.9644 - classification_output_sparse_categorical_accuracy: 0.8574 - regression_output_mae: 3.5408e-05 - val_loss: 0.5964 - val_detection_output_loss: 0.0736 - val_classification_output_loss: 0.2688 - val_regression_output_loss: 8.6580e-10 - val_detection_output_binary_accuracy: 0.9690 - val_classification_output_sparse_categorical_accuracy: 0.8853 - val_regression_output_mae: 1.2669e-05 - lr: 6.2500e-05
# Epoch 118/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7490 - detection_output_loss: 0.0780 - classification_output_loss: 0.3433 - regression_output_loss: 7.1972e-09 - detection_output_binary_accuracy: 0.9649 - classification_output_sparse_categorical_accuracy: 0.8571 - regression_output_mae: 2.4162e-05
# Epoch 118: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 118: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 8s 18ms/step - loss: 0.7490 - detection_output_loss: 0.0780 - classification_output_loss: 0.3433 - regression_output_loss: 7.1972e-09 - detection_output_binary_accuracy: 0.9649 - classification_output_sparse_categorical_accuracy: 0.8571 - regression_output_mae: 2.4162e-05 - val_loss: 0.5962 - val_detection_output_loss: 0.0737 - val_classification_output_loss: 0.2686 - val_regression_output_loss: 7.2973e-10 - val_detection_output_binary_accuracy: 0.9672 - val_classification_output_sparse_categorical_accuracy: 0.8817 - val_regression_output_mae: 9.5262e-06 - lr: 6.2500e-05
# Epoch 119/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7423 - detection_output_loss: 0.0782 - classification_output_loss: 0.3399 - regression_output_loss: 3.5467e-09 - detection_output_binary_accuracy: 0.9645 - classification_output_sparse_categorical_accuracy: 0.8566 - regression_output_mae: 5.8370e-06
# Epoch 119: val_classification_output_sparse_categorical_accuracy did not improve from 0.88568
# 443/443 [==============================] - 8s 18ms/step - loss: 0.7423 - detection_output_loss: 0.0782 - classification_output_loss: 0.3399 - regression_output_loss: 3.5467e-09 - detection_output_binary_accuracy: 0.9645 - classification_output_sparse_categorical_accuracy: 0.8566 - regression_output_mae: 5.8370e-06 - val_loss: 0.5904 - val_detection_output_loss: 0.0741 - val_classification_output_loss: 0.2656 - val_regression_output_loss: 2.3876e-10 - val_detection_output_binary_accuracy: 0.9663 - val_classification_output_sparse_categorical_accuracy: 0.8832 - val_regression_output_mae: 6.9686e-06 - lr: 3.1250e-05
# Epoch 120/120
# 443/443 [==============================] - ETA: 0s - loss: 0.7464 - detection_output_loss: 0.0779 - classification_output_loss: 0.3421 - regression_output_loss: 5.8843e-09 - detection_output_binary_accuracy: 0.9644 - classification_output_sparse_categorical_accuracy: 0.8547 - regression_output_mae: 1.0965e-05
# Epoch 120: val_classification_output_sparse_categorical_accuracy improved from 0.88568 to 0.88642, saving model to models/combo_aug_model_v3_2.keras
# 443/443 [==============================] - 8s 18ms/step - loss: 0.7464 - detection_output_loss: 0.0779 - classification_output_loss: 0.3421 - regression_output_loss: 5.8843e-09 - detection_output_binary_accuracy: 0.9644 - classification_output_sparse_categorical_accuracy: 0.8547 - regression_output_mae: 1.0965e-05 - val_loss: 0.5870 - val_detection_output_loss: 0.0728 - val_classification_output_loss: 0.2644 - val_regression_output_loss: 1.1823e-10 - val_detection_output_binary_accuracy: 0.9689 - val_classification_output_sparse_categorical_accuracy: 0.8864 - val_regression_output_mae: 4.0694e-06 - lr: 3.1250e-05
# ✅ 模型 3 训练完成，耗时 1025.62 秒
#
# ==================================================
# 📈 训练时间统计
# ==================================================
# 模型 1: 1027.34 秒 (17.12 分钟)
# 模型 2: 828.40 秒 (13.81 分钟)
# 模型 3: 1025.62 秒 (17.09 分钟)
# 🔥 总训练时间: 2881.36 秒 (48.02 分钟)
# ==================================================
#
# ================================================================================
# 🔍 开始评估并打印输入/输出（前 5 条）与 NRMSE
# ================================================================================
# 2025-10-19 23:51:04.654065: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype float and shape [16200,3]
# 	 [[{{node Placeholder/_3}}]]
# ================================================================================
# 📥 输入信号（前 5 条）
# ================================================================================
# 样本 0: [-1.05697181  0.00378731  0.42925926  1.55656698  1.4207378   0.19368606
#  -0.78710616 -0.63801489  0.52385147  0.51182554] ... (len=1024)
# 样本 1: [-0.62605659 -0.29576411 -0.14456531  0.57068346  0.50487261 -0.75098009
#   0.19402654  0.6368223   0.15793518 -0.01252269] ... (len=1024)
# 样本 2: [ 1.16228029 -0.28318971  0.57227453 -0.92191901  0.79554124 -0.62132521
#   0.8306696  -0.64934691  0.70676081 -0.51393337] ... (len=1024)
# 样本 3: [-0.42974032  1.24314353 -1.7718107   0.62841242  0.2246237   0.59423203
#  -0.6861552  -0.37785159 -1.3150014   0.85562484] ... (len=1024)
# 样本 4: [-0.28479713 -0.15391934  0.26693762 -0.05293526 -0.55105313 -1.39802339
#   0.43218271 -1.03412694  0.05577236 -0.39820111] ... (len=1024)
#
# ================================================================================
# 📤 真实 vs 预测（前 5 条）- 反归一化显示
# ================================================================================
# 样本 0:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 2     |  cls_pred: 2
#   reg_true: [0.0512 0.0512 0.    ]  |  reg_pred: [ 0.05119759  0.05119657 -0.00059986]
# 样本 1:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 7     |  cls_pred: 7
#   reg_true: [0.0512 0.0512 0.    ]  |  reg_pred: [ 0.05119778  0.05119739 -0.00024128]
# 样本 2:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 3     |  cls_pred: 3
#   reg_true: [0.0512 0.0512 0.    ]  |  reg_pred: [ 0.0511884   0.05119372 -0.00107861]
# 样本 3:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 7     |  cls_pred: 1
#   reg_true: [0.0512 0.0512 0.    ]  |  reg_pred: [5.1196091e-02 5.1198594e-02 5.1498413e-05]
# 样本 4:
#   det_true: 1.0000  |  det_pred: 1.0000
#   cls_true: 5     |  cls_pred: 5
#   reg_true: [0.0512 0.0512 0.    ]  |  reg_pred: [ 0.05119764  0.05119754 -0.00092697]
#
# ================================================================================
# 📈 NRMSE 报告（基于反归一化参数）
# ================================================================================
# 参数维度: [start_time(ms), end_time(ms), jnr_db]
# start_time: 716.0409
# end_time: 696.6753
# jnr_db: 126574.9219
# 平均 NRMSE: 42662.5469
# ✅ NRMSE 报告已写入 reports/nrmse_report_v3.txt
#
# ✅ 所有流程完成！模型已保存至 models/combo_aug_model_v3_{i}.keras
# 📌 适配v3归一化数据的训练完成

# %%
# evaluate_models_nrmse_columnwise.py
import os
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (confusion_matrix, accuracy_score, precision_score,
                             recall_score, f1_score, mean_absolute_error)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from matplotlib import font_manager as fm
from tensorflow.keras.layers import Dense
import time

# ---------------------- 中文字体 ----------------------
def set_chinese_font():
    try:
        font_paths = ['/usr/share/fonts/truetype/wqy/wqy-microhei.ttc',
                      'C:/Windows/Fonts/simhei.ttf',
                      '/System/Library/Fonts/PingFang.ttc']
        for font_path in font_paths:
            if os.path.exists(font_path):
                fm.fontManager.addfont(font_path)
                plt.rcParams['font.family'] = fm.FontProperties(fname=font_path).get_name()
                plt.rcParams['axes.unicode_minus'] = False
                print(f"✅ 成功设置中文字体: {plt.rcParams['font.family']}")
                return True
        plt.rcParams['font.family'] = ['SimHei', 'Arial Unicode MS']
        plt.rcParams['axes.unicode_minus'] = False
        print("⚠️ 未找到指定字体，使用默认兼容字体")
        return True
    except Exception as e:
        print(f"❌ 字体设置失败: {e}")
        return False
set_chinese_font()

# ---------------------- 自定义层 ----------------------
class AdaptiveCrossStitch(tf.keras.layers.Layer):
    def __init__(self, num_tasks=3, **kwargs):
        super().__init__(**kwargs)
        self.num_tasks = num_tasks

    def build(self, input_shape):
        feature_dims = [shape[-1] for shape in input_shape]
        if len(set(feature_dims)) != 1:
            raise ValueError("特征维度必须一致")
        self.alpha = self.add_weight(
            name='cross_stitch_alpha',
            shape=(self.num_tasks, self.num_tasks),
            initializer='identity',
            trainable=True
        )
        self.gate = Dense(self.num_tasks, activation='sigmoid')
        super().build(input_shape)

    def call(self, inputs):
        concat = tf.concat(inputs, axis=-1)
        gate = self.gate(concat)
        outputs = []
        for i in range(self.num_tasks):
            weighted = tf.zeros_like(inputs[0])
            for j in range(self.num_tasks):
                weighted += tf.expand_dims(gate[:, i], -1) * self.alpha[i, j] * inputs[j]
            outputs.append(weighted)
        return outputs

# ---------------------- 加载数据集 ----------------------
def load_dataset(npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz"):
    data = np.load(npz_path, allow_pickle=True)
    signals = data["signals"]
    labels = data["labels"].astype(np.int32)
    jnr_vals = data["jnr_values"].astype(np.float32)
    fs = float(data["fs"])
    L = int(data["L"])
    metadata = data["metadata"]
    type2label = data["type_to_label"].item()
    label2type = {v: k for k, v in type2label.items()}
    type2name = data["interference_type_names"].item()
    label2name = {i: type2name[k] for k, i in type2label.items()}
    return {
        "signals": signals,
        "labels": labels,
        "jnr_values": jnr_vals,
        "fs": fs,
        "L": L,
        "metadata": metadata,
        "type2label": type2label,
        "label2name": label2name,
        "type2name": type2name
    }

# ---------------------- 数据预处理 ----------------------
# ---------------------- 数据预处理 ----------------------
def preprocess_data(dataset):
    signals = dataset["signals"]
    labels = dataset["labels"]
    jnr_values = dataset["jnr_values"]
    L = dataset["L"]

    signals = np.array([StandardScaler().fit_transform(s.reshape(-1, 1)).ravel() for s in signals])

    no_key = "satellite_signal"
    det_labels = (labels != dataset["type2label"][no_key]).astype(np.float32)

    # 使用生成时记录的参数作为标签 - 修复None值处理
    param_labels = []
    for m in dataset["metadata"]:
        p = m.get("params", {})
        # 安全地处理可能为None的参数值
        start_time = p.get("start_time", 0)
        end_time = p.get("end_time", 0)
        jnr_db = p.get("jnr_db", 0)
        
        # 处理None值，将其转换为0或其他默认值
        start_time = float(start_time) if start_time is not None else 0.0
        end_time = float(end_time) if end_time is not None else 0.0
        jnr_db = float(jnr_db) if jnr_db is not None else 0.0
        
        param_labels.append([start_time, end_time, jnr_db])
    param_labels = np.array(param_labels, dtype=np.float32)

    X_test = signals
    y_det_test = det_labels
    y_type_test = labels
    y_param_test = param_labels
    jnr_test = jnr_values
    label2name = dataset["label2name"]

    return {
        "X_test": X_test,
        "y_det_test": y_det_test,
        "y_type_test": y_type_test,
        "y_param_test": y_param_test,
        "jnr_values_test": jnr_test,
        "label2name": label2name,
        "L": L
    }

# ---------------------- 加载模型并预测 ----------------------
def load_and_predict(model_paths, X_test):
    all_det, all_cls, all_reg = [], [], []
    for path in model_paths:
        print(f"🔁 加载模型: {path}")
        model = tf.keras.models.load_model(
            path,
            custom_objects={'AdaptiveCrossStitch': AdaptiveCrossStitch}
        )
        start_time = time.time()
        det, cls, reg = model.predict(X_test, verbose=0)
        end_time = time.time()
        prediction_time = end_time - start_time
        print(f"预测时间: {prediction_time:.2f} 秒")
        all_det.append(det)
        all_cls.append(cls)
        all_reg.append(reg)
    avg_det = np.mean(all_det, axis=0) > 0.5
    avg_cls = np.argmax(np.mean(all_cls, axis=0), axis=1)
    avg_reg = np.mean(all_reg, axis=0)
    return avg_det, avg_cls, avg_reg

# ---------------------- 绘制混淆矩阵 ----------------------
def plot_confusion_matrix(cm, labels, title, xlabel, ylabel, filename, dpi=150, rotate_x=False):
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
    cm_normalized = np.nan_to_num(cm_normalized)

    plt.figure(figsize=(12, 10))
    ax = sns.heatmap(cm_normalized,
                     annot=True,
                     fmt='.2f',
                     cmap='Blues',
                     xticklabels=labels,
                     yticklabels=labels,
                     square=True,
                     annot_kws={"size": 14})
    cbar = ax.collections[0].colorbar
    cbar.ax.tick_params(labelsize=14)

    plt.title(title, pad=20, fontsize=18)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.xticks(rotation=45 if rotate_x else 0, ha='right' if rotate_x else 'center', fontsize=14)
    plt.yticks(rotation=0, fontsize=14)
    plt.tight_layout()
    plt.savefig(filename, dpi=dpi)
    plt.close()

# ... existing code ...
# ---------------------- 按列分别归一化 NRMSE ----------------------
def nrmse_columnwise(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2, axis=0))  # shape (3,)
    y_range = np.max(y_true, axis=0) - np.min(y_true, axis=0)
    return rmse / (y_range + 1e-8)

# ---------------------- 优化后的评估函数 ----------------------
def evaluate(models_dir="models",
             npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz",
             wanted_jnr=np.arange(-10, 31, 5),
             dpi=150):
    """
    评估模型性能，包括检测、分类和参数估计
    
    Args:
        models_dir: 模型文件夹路径
        npz_path: 数据集路径
        wanted_jnr: 要评估的JNR值列表
        dpi: 图像分辨率
    """
    
    # 创建输出目录
    os.makedirs("visualizations", exist_ok=True)
    os.makedirs("reports", exist_ok=True)
    
    print("⏳ 加载数据集...")
    dataset = load_dataset(npz_path)
    data = preprocess_data(dataset)
    
    # 提取测试数据
    X_test = data["X_test"]
    y_det_test = data["y_det_test"]
    y_type_test = data["y_type_test"]
    y_param_test = data["y_param_test"]
    jnr_test = data["jnr_values_test"]
    label2name = data["label2name"]
    
    # 加载并预测
    model_paths = [os.path.join(models_dir, f"combo_aug_model_v3_{i}.keras") for i in range(3)]
    avg_det, avg_cls, avg_reg = load_and_predict(model_paths, X_test)
    
    # 数据清理：移除NaN和无穷大值
    invalid_mask = (
        np.any(np.isnan(y_param_test), axis=1) | 
        np.any(np.isinf(y_param_test), axis=1) |
        np.any(np.isnan(avg_reg), axis=1) | 
        np.any(np.isinf(avg_reg), axis=1)
    )
    
    valid_y_param_test = y_param_test[~invalid_mask]
    valid_avg_reg = avg_reg[~invalid_mask]
    
    # 1. 检测任务评估
    cm_det = confusion_matrix(y_det_test, avg_det)
    plot_confusion_matrix(
        cm=cm_det,
        labels=['No Interference', 'Interference'],
        title='Detection Confusion Matrix',
        xlabel='Predicted',
        ylabel='True',
        filename='visualizations/detection_confusion_matrix.png',
        dpi=dpi,
        rotate_x=False
    )
    
    det_acc = accuracy_score(y_det_test, avg_det)
    
    # 2. 分类任务评估（仅对干扰信号）
    # 获取干扰信号的索引
    interference_mask = y_det_test == 1
    if np.sum(interference_mask) > 0:
        # 只评估干扰信号的分类
        y_type_interf = y_type_test[interference_mask]
        avg_cls_interf = avg_cls[interference_mask]
        
        cm_type = confusion_matrix(y_type_interf, avg_cls_interf)
        plot_confusion_matrix(
            cm=cm_type,
            labels=[label2name[i] for i in sorted(label2name.keys())],
            title='Classification Confusion Matrix (Interference Only)',
            xlabel='Predicted',
            ylabel='True',
            filename='visualizations/classification_confusion_matrix.png',
            dpi=dpi,
            rotate_x=True
        )
        
        cls_acc = accuracy_score(y_type_interf, avg_cls_interf)
        cls_precision = precision_score(y_type_interf, avg_cls_interf, average='weighted', zero_division=0)
        cls_recall = recall_score(y_type_interf, avg_cls_interf, average='weighted', zero_division=0)
        cls_f1 = f1_score(y_type_interf, avg_cls_interf, average='weighted', zero_division=0)
    else:
        cls_acc = cls_precision = cls_recall = cls_f1 = 0.0
        print("⚠️  测试集中没有干扰信号，无法进行分类评估")
    
    # 3. JNR vs 准确率
    jnr_acc = []
    for jnr in wanted_jnr:
        mask = jnr_test == jnr
        mask = mask & ~invalid_mask
        if np.sum(mask) == 0:
            acc = np.nan
        else:
            acc = accuracy_score(y_type_test[mask], avg_cls[mask])
        jnr_acc.append(acc)
    
    plt.figure(figsize=(8, 5))
    valid_mask = ~np.isnan(jnr_acc)
    plt.plot(wanted_jnr[valid_mask], np.array(jnr_acc)[valid_mask], marker='o', linewidth=2)
    if np.any(~valid_mask):
        plt.scatter(wanted_jnr[~valid_mask], [1.0] * np.sum(~valid_mask),
                    facecolors='none', edgecolors='r', s=60)
    plt.xlabel('JNR (dB)', fontsize=14)
    plt.ylabel('Accuracy', fontsize=14)
    plt.title('Classification Accuracy vs JNR', fontsize=16)
    plt.xticks(wanted_jnr)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.ylim(0, 1.05)
    plt.tight_layout()
    plt.savefig('visualizations/jnr_vs_accuracy.png', dpi=dpi)
    plt.close()
    
    # 4. 参数估计评估
    param_mae = mean_absolute_error(valid_y_param_test, valid_avg_reg, multioutput='raw_values')
    param_names = ['Start Time (ms)', 'End Time (ms)', 'JNR (dB)']
    
    # 按列分别归一化 NRMSE
    def nrmse_columnwise(y_true, y_pred):
        rmse = np.sqrt(np.mean((y_true - y_pred) ** 2, axis=0))
        y_range = np.max(y_true, axis=0) - np.min(y_true, axis=0)
        return rmse / (y_range + 1e-8)
    
    param_nrmse = nrmse_columnwise(valid_y_param_test, valid_avg_reg)
    
    # 5. 输出评估结果
    print("\n" + "="*50)
    print("📊 评估结果")
    print("="*50)
    print(f"检测准确率: {det_acc:.4f}")
    print(f"分类准确率: {cls_acc:.4f}")
    print(f"分类精确率: {cls_precision:.4f}, 召回率: {cls_recall:.4f}, F1: {cls_f1:.4f}")
    print("\n参数估计误差（MAE & 按列 NRMSE）:")
    for i, (name, mae, nrmse) in enumerate(zip(param_names, param_mae, param_nrmse)):
        print(f"  {name}: MAE = {mae:.4f}, NRMSE = {nrmse:.4f}")
    print(f"  平均 NRMSE（三列分别归一化） = {np.mean(param_nrmse):.4f}")
    
    print("\nJNR 准确率:")
    for j, acc in zip(wanted_jnr, jnr_acc):
        print(f"  {int(j)}dB: {acc if not np.isnan(acc) else 'N/A'}")
    
    # 6. 保存报告
    report = {
        "detection_accuracy": float(det_acc),
        "classification_accuracy": float(cls_acc),
        "classification_precision": float(cls_precision),
        "classification_recall": float(cls_recall),
        "classification_f1": float(cls_f1),
        "parameter_mae": [float(m) for m in param_mae],
        "parameter_nrmse": [float(n) for n in param_nrmse],
        "average_columnwise_nrmse": float(np.mean(param_nrmse)),
        "parameter_details": {
            param_names[i]: {"mae": float(param_mae[i]), "nrmse": float(param_nrmse[i])}
            for i in range(len(param_names))
        },
        "jnr_accuracies": {f"{int(j)}dB": float(acc) if not np.isnan(acc) else None for j, acc in zip(wanted_jnr, jnr_acc)},
        "invalid_samples_count": int(np.sum(invalid_mask)),
        "total_samples": len(X_test),
        "interference_samples": int(np.sum(y_det_test))
    }
    
    with open("reports/evaluation_report.json", "w", encoding='utf-8') as f:
        json.dump(report, f, indent=4, ensure_ascii=False)
    
    print("\n✅ 评估完成！混淆矩阵与报告已保存。")
    
# ---------------------- 主函数 ----------------------
if __name__ == "__main__":
    evaluate(models_dir="models",
             npz_path="/root/yxun/20250826/dataset/interference_signals_natural_same_freq_1019.npz",
             wanted_jnr=np.arange(-10, 31, 5),
             dpi=150)
# Out:
# 2025-10-21 16:54:48.541760: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-21 16:54:48.581358: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-21 16:54:49.143543: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# ⏳ 加载数据集...
# 🔁 加载模型: models/combo_aug_model_v3_0.keras
# 2025-10-21 16:55:09.192052: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 890 MB memory:  -> device: 0, name: NVIDIA vGPU-48GB, pci bus id: 0000:d8:00.0, compute capability: 8.9
# 2025-10-21 16:55:10.433761: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-10-21 16:55:10.442767: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 预测时间: 10.85 秒
# 🔁 加载模型: models/combo_aug_model_v3_1.keras
# 预测时间: 10.30 秒
# 🔁 加载模型: models/combo_aug_model_v3_2.keras

# %% [markdown]
# ✅ 成功设置中文字体: ['WenQuanYi Micro Hei']
# 🔁 加载模型: models/combo_aug_model_v3_0.keras
# 预测时间: 9.99 秒
# 🔁 加载模型: models/combo_aug_model_v3_1.keras
# 预测时间: 10.55 秒
# 🔁 加载模型: models/combo_aug_model_v3_2.keras
# 预测时间: 10.35 秒
#
# ==================================================
# 📊 评估结果
# ==================================================
# 检测准确率: 0.9813
# 分类准确率: 0.9109
# 分类精确率: 0.9175, 召回率: 0.9109, F1: 0.9103
#
# 参数估计误差（MAE & 按列 NRMSE）:
#   Start Time (ms): MAE = 0.3839, NRMSE = 0.4120
#   End Time (ms): MAE = 0.3840, NRMSE = 0.4105
#   JNR (dB): MAE = 13.2500, NRMSE = 0.4045
#   平均 NRMSE（三列分别归一化） = 0.4090
#
# JNR 准确率:
#   -10dB: 0.653125
#   -5dB: 0.77925
#   0dB: 0.8715
#   5dB: 0.913375
#   10dB: 0.94525
#   15dB: 0.976
#   20dB: 0.9885
#   25dB: 0.99025
#   30dB: 0.9895
